# %%
import pickle
from collections import OrderedDict
import pandas as pd

# %%
translated_list = pickle.load( open( "_data/translated_list.pickle", "rb" ) )

# %%
list_uniques = []

# %%
for value in translated_list:
    texts = value.split('\n')
    for text in texts:
        list_uniques.append(text.strip())

# %%
list_uniques
# Out:
# ['leatherette',
#  'polar',
#  'linen',
#  'coated linen',
#  'coated cotton',
#  'suede',
#  'lapis lazuli',
#  'thimbles',
#  'buckwheat',
#  'flakes of polyester fibers',
#  'padding of polyester fiber flakes',
#  'polyester fiber flakes',
#  'giclée print',
#  'heavy cotton moulin du roy paper',
#  'roy heavy cotton paper mill',
#  'heavy cotton roy paper mill',
#  'mill of roy cotton paper',
#  'moulin du roy paper',
#  'spun glass',
#  'Murano glass',
#  'glass',
#  'copper',
#  'Pierre',
#  'fine stone',
#  'gem',
#  'gemstone',
#  'turquoise bead',
#  'button',
#  'torch-blown glass',
#  'pendant',
#  'Venetian pearls',
#  'rockery',
#  'rubber',
#  'metal',
#  'paper',
#  'organic cotton',
#  'leather',
#  'brass',
#  'golden brass',
#  'swarovski crystal',
#  'polymer clay',
#  'metal powder',
#  'aluminum wire',
#  'beads',
#  'coated fabric',
#  'cotton fabric',
#  'coating',
#  'zipper',
#  'fabric',
#  'bamboo',
#  'natural maple',
#  'maple',
#  'wood',
# ...

# %%
len(list_uniques)
# Out:
# 38760

# %%
df = pd.DataFrame.from_dict(list_uniques)

# %%
df.head()
# Out:
#                0
# 0    leatherette
# 1          polar
# 2          linen
# 3   coated linen
# 4  coated cotton

# %%
df.to_excel('_data/uniques_translated.xlsx')

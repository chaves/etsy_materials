# %%
import re
import enchant
import pickle
import pandas as pd

# %%
dictionary_FR = enchant.Dict("fr_FR")
dictionary_GB = enchant.Dict("en_GB")
dictionary_US = enchant.Dict("en_US")

# %%
def isFrenchWord(word):
    return dictionary_FR.check(word)

# %%
def isEnglighWord(word):
    return dictionary_GB.check(word) or dictionary_US.check(word)

# %%
# isFrenchWord('maison')
# True

# %%
def shouldWeTranslate(texte):
    words = texte.split()
    for word in words:
        if word.isalpha() and isFrenchWord(word) and not isEnglighWord(word):
            return True
    return False

# %%
# shouldWeTranslate("house 12px  ")
# False
# shouldWeTranslate("maison 12px  ")
# True

# %%
dic_uniques = pickle.load( open( "_data/dic_uniques.pickle", "rb" ) )
dic_to_translate = dict()

# %%
idx = 0
for (key, texte) in dic_uniques.items() :
    if shouldWeTranslate(texte):
        dic_to_translate[key] = texte

# %%
len(dic_to_translate)
# Out:
# 38807

# %%
dic_to_translate
# Out:
# {'simili_cuir': 'simili cuir',
#  'polaire': 'polaire',
#  'lin': 'lin',
#  'lin_enduit': 'lin enduit',
#  'coton_enduit': 'coton enduit',
#  'suedine': 'suédine',
#  'lapis_lazuli': 'lapis lazuli',
#  'cosses': 'cosses',
#  'sarrasin': 'sarrasin',
#  'flocons_de_fibres_de_polyester': 'flocons de fibres de polyester',
#  'rembourrage_de_flocons_de_fibres_de_polyester': 'rembourrage de flocons de fibres de polyester',
#  'flocons_fibres_de_polyester': 'flocons fibres de polyester',
#  'giclee_print': 'giclée print',
#  'heavy_cotton_moulin_du_roy_paper': 'heavy cotton moulin du roy paper',
#  'moulin_du_roy_heavy_cotton_paper': 'moulin du roy heavy cotton paper',
#  'heavy_cotton_moulin_de_roy_paper': 'heavy cotton moulin de roy paper',
#  'moulin_du_roy_cotton_paper': 'moulin du roy cotton paper',
#  'moulin_du_roy_paper': 'moulin du roy paper',
#  'verre_file': 'verre filé',
#  'verre_de_murano': 'verre de murano',
#  'verre': 'verre',
#  'cuivre': 'cuivré',
#  'pierre': 'pierre',
#  'pierre_fine': 'pierre fine',
#  'gemme': 'gemme',
#  'pierre_de_gemme': 'pierre de gemme',
#  'perle_turquoise': 'perle turquoise',
#  'bouton': 'bouton',
#  'verre_file_au_chalumeau': 'verre filé au chalumeau',
#  'pendentif': 'pendentif',
#  'perles_venitiennes': 'perles vénitiennes',
#  'rocaille': 'rocaille',
#  'caoutchouc': 'caoutchouc',
#  'metal': 'métal',
#  'papier': 'papier',
#  'coton_bio': 'coton bio',
#  'cuir': 'cuir',
#  'laiton': 'laiton',
#  'laiton_dore': 'laiton doré',
#  'cristal_swarovski': 'cristal swarovski',
#  'pate_polymere': 'pâte polymère',
#  'poudre_metallique': 'poudre métallique',
#  'fil_aluminium': 'fil aluminium',
#  'perles': 'perles',
#  'tissu_enduit': 'tissu enduit',
#  'tissu_coton': 'tissu coton',
#  'enduit': 'enduit',
#  'fermeture_eclair': 'fermeture éclair',
#  'tissu': 'tissu',
#  'bambou': 'bambou',
#  'erable_naturel': 'erable naturel',
#  'erable': 'érable',
#  'bois': 'bois',
#  'tissu_coton_oeko_tex': 'tissu coton oeko tex',
#  'non_traite': 'non traité',
#  'tissu_oeko_tex': 'tissu oeko tex',
#  'bois_naturel': 'bois naturel',
#  'biais': 'biais',
#  'elastique': 'élastique',
#  'eponge_de_bambou': 'éponge de bambou',
#  'epnge_de_bambou': 'épnge de bambou',
#  'coton_liberty': 'coton liberty',
#  'bouton_pression_kam': 'bouton pression kam',
#  'eponge': 'éponge',
#  'chaine': 'chaîne',
#  'perle': 'perlé',
#  'inoxydable': 'inoxydable',
#  'chaine_inoxydable': 'chaîne inoxydable',
#  'acier_inoxydable': 'acier inoxydable',
#  'resine': 'résine',
#  'ficelle_de_chanvre': 'ficelle de chanvre',
#  'papier_glassine': 'papier glassine',
#  'papier_de_riz': 'papier de riz',
#  'papier_washi': 'papier washi',
#  'ficelle': 'ficelle',
#  'papier_vintage': 'papier vintage',
#  'papier_ancien': 'papier ancien',
#  'livre_ancien': 'livre ancien',
#  'plastique': 'plastique',
#  'liege': 'liège',
#  'petales': 'pétales',
#  'lavande': 'lavande',
#  'paillettes': 'paillettes',
#  'fil': 'fil',
#  'chanvre': 'chanvre',
#  'papier_200g_sans_acides': 'papier 200g sans acides',
#  'fleurs_sechees': 'fleurs séchées',
#  'polystyrene': 'polystyrène',
#  'feuille_or': 'feuille or',
#  'cordon_en_coton': 'cordon en coton',
#  'feuille_argent': 'feuille argent',
#  'pigments_mineraux': 'pigments minéraux',
#  'toogle_plaque_argent': 'toogle plaqué argent',
#  'toggle_plaque_argent': 'toggle plaqué argent',
#  'cire_abeille': 'cire abeille',
#  'cire_d_abeille': 'cire d abeille',
#  'cire': 'ciré',
#  'abeille': 'abeille',
#  'abeilles': 'abeilles',
#  'cire_abeilles': 'cire abeilles',
#  'naturelle': 'naturelle',
#  'amethyste': 'améthyste',
#  'perles_de_rocaille': 'perles de rocaille',
#  'pierre_taillee': 'pierre taillée',
#  'pointe_de_fleche': 'pointe de flèche',
#  'silex': 'silex',
#  'perles_de_rocailles': 'perles de rocailles',
#  'chaine_de_strass': 'chaine de strass',
#  'strass': 'strass',
#  'chaine_email': 'chaîne émail',
#  'silk_charmeuse': 'silk charmeuse',
#  'dentelle': 'dentelle',
#  'mousseline': 'mousseline',
#  'silk_mousseline': 'silk mousseline',
#  'cuir_brut': 'cuir brut',
#  'acier_zingue': 'acier zingué',
#  'acier': 'acier',
#  'etain': 'étain',
#  'soudure': 'soudure',
#  'soudures': 'soudures',
#  'patine': 'patiné',
#  'miroir': 'miroir',
#  'contemporain': 'contemporain',
#  'mariage': 'mariage',
#  'cadeau': 'cadeau',
#  'lampe': 'lampe',
#  'mini_serre': 'mini serre',
#  'vitrail': 'vitrail',
#  'fait_main': 'fait main',
#  'dore': 'doré',
#  'attrape_soleil': 'attrape soleil',
#  'geometrique': 'géométrique',
#  'bougeoirs': 'bougeoirs',
#  'boite_a_bagues': 'boîte à bagues',
#  'plante': 'plante',
#  'verre_glass': 'verre glass',
#  'patines': 'patines',
#  'cristal': 'cristal',
#  'verre_colore': 'verre coloré',
#  'fanions': 'fanions',
#  'decoration': 'décoration',
#  'pic': 'pic',
#  'verre_vert': 'verre vert',
#  'boite': 'boîte',
#  'tissus': 'tissus',
#  'bougie': 'bougie',
#  'brillant': 'brillant',
#  'geometrie': 'géométrie',
#  'guirlande': 'guirlande',
#  'decoration_sapin': 'decoration sapin',
#  'decoration_mur': 'decoration mur',
#  'decor_mur': 'décor mur',
#  'soja': 'soja',
#  'aile_papillon': 'aile papillon',
#  'cuivre_copper': 'cuivre copper',
#  'acetate': 'acétate',
#  'suede': 'suède',
#  'papier_photo_210_gr': 'papier photo 210 gr',
#  'papier_170_gr': 'papier 170 gr',
#  'papier_photo_210gr': 'papier photo 210gr',
#  'papier_photo_epais_210_gr': 'papier photo épais 210 gr',
#  'papier_90gr': 'papier 90gr',
#  'papier_210_gr': 'papier 210 gr',
#  'papier_90_gr': 'papier 90 gr',
#  'papier_170gr': 'papier 170gr',
#  'papier_photo': 'papier photo',
#  'fil_de_fer': 'fil de fer',
#  'feuilles_de_papier': 'feuilles de papier',
#  'socle_en_bois_massif': 'socle en bois massif',
#  'poule': 'poule',
#  'fil_de_fer_de_vigne': 'fil de fer de vigne',
#  'laine': 'lainé',
#  'parfum': 'parfum',
#  'amarante': 'amarante',
#  'noix': 'noix',
#  'noix_de_banksia': 'noix de banksia',
#  'qualite': 'qualité',
#  'dore_a_l_or_fin_14k': 'dore a l or fin 14k',
#  'soleil_bleu': 'soleil bleu',
#  'grenat': 'grenat',
#  'pierre_semi_precieuse': 'pierre semi precieuse',
#  'howlite_blanche_et_grise': 'howlite blanche et grise',
#  'dore_a_l_or_fin': 'doré à l or fin',
#  'cordon_plat_de_liege': 'cordon plat de liège',
#  'perles_de_fossile': 'perles de fossile',
#  'fossile_poli': 'fossile poli',
#  'bois_de_coco': 'bois de coco',
#  'rocailles_de_couleur': 'rocailles de couleur',
#  'copeaux_de_liege': 'copeaux de liège',
#  'liege_veritable': 'liège véritable',
#  'matieres_naturelles': 'matières naturelles',
#  'rocailles': 'rocailles',
#  'morceaux_de_liege': 'morceaux de liège',
#  'materiau_hypoallergeniques': 'matériau hypoallergéniques',
#  'tissus_liberty': 'tissus liberty',
#  'jaspes': 'jaspes',
#  'cordon_de_cuir_fin': 'cordon de cuir fin',
#  'cuir_brun': 'cuir brun',
#  'perles_rondes': 'perles rondes',
#  'perles_de_turquoise': 'perles de turquoise',
#  'perles_en_bois': 'perles en bois',
#  'perles_naturelles': 'perles naturelles',
#  'non_teint': 'non teint',
#  'perles_nacrees': 'perles nacrées',
#  'perles_de_fossile_8mm': 'perles de fossile 8mm',
#  'matieres_hypoallergeniques': 'matières hypoallergéniques',
#  'acrylique': 'acrylique',
#  'passe_partout': 'passe partout',
#  'peinture': 'peinture',
#  'citrine': 'citrine',
#  'white_topaze': 'white topaze',
#  'carte_postale': 'carte postale',
#  'toile': 'toile',
#  'a_peindre': 'à peindre',
#  'ciseaux': 'ciseaux',
#  'pastel_gras': 'pastel gras',
#  'pastel_a_l_huile': 'pastel à l huile',
#  'feutre': 'feutré',
#  'impermeable': 'imperméable',
#  'imprime': 'imprimé',
#  'ruban_satin': 'ruban satin',
#  'metal_dore': 'métal doré',
#  'lucite_transparente': 'lucite transparente',
#  'alliage_cuivre': 'alliage cuivre',
#  'metal_argente': 'métal argenté',
#  'metal_bronze': 'métal bronze',
#  'metal_bronze_dore': 'métal bronze doré',
#  'email_rouge': 'émail rouge',
#  'nacre_naturelle': 'nacre naturelle',
#  'plaque_or': 'plaqué or',
#  'fils_de_couleur': 'fils de couleur',
#  'ceramique_peinte_vernie': 'céramique peinte vernie',
#  'metal_vert': 'métal vert',
#  'argent_tibetain': 'argent tibétain',
#  'ceramique_emaillee': 'céramique émaillée',
#  'email_bleu': 'émail bleu',
#  'verre_violet': 'verre violet',
#  'verre_taupe': 'verre taupe',
#  'metal_or_vieilli': 'métal or vieilli',
#  'metal_leger': 'métal léger',
#  'carton_leger': 'carton léger',
#  'fil_de_coton': 'fil de coton',
#  'metal_bronze_antique': 'métal bronze antique',
#  'plaque_argent': 'plaqué argent',
#  'strass_transparents': 'strass transparents',
#  'tissu_imprime': 'tissu imprimé',
#  'alliage_couleur_bronze': 'alliage couleur bronze',
#  'alliage_bronze': 'alliage bronze',
#  'metal_or': 'métal or',
#  'email': 'émail',
#  'metal_argente_clair': 'métal argenté clair',
#  'pate_de_verre': 'pâte de verre',
#  'tulle_dore': 'tulle doré',
#  'tulle_rose_fonce': 'tulle rose foncé',
#  'strass_jaunes': 'strass jaunes',
#  'metal_emaille': 'métal émaillé',
#  'deux_broches_papillon': 'deux broches papillon',
#  'papier_fort': 'papier fort',
#  'papier_cartonne': 'papier cartonné',
#  'perles_de_verre': 'perles de verre',
#  'metal_inox': 'métal inox',
#  'metal_cuivre': 'métal cuivre',
#  'resine_naturelle': 'résine naturelle',
#  'galalithe': 'galalithe',
#  'metal_nuance_bronze': 'métal nuance bronze',
#  'ceramique': 'céramique',
#  'fil_argent': 'fil argent',
#  'fil_or': 'fil or',
#  'terre_cuite_emaillee': 'terre cuite émaillée',
#  'opalines': 'opalines',
#  'metal_vieil_or': 'métal vieil or',
#  'verre_bleu': 'verre bleu',
#  'opaline': 'opaline',
#  'tissu_gaufre': 'tissu gaufré',
#  'agate_bicolore': 'agate bicolore',
#  'alliage_bronze_sans_nickel': 'alliage bronze sans nickel',
#  'verre_rouge': 'verre rouge',
#  'nacre': 'nacré',
#  'verre_orange': 'verre orange',
#  'coquillage_sculpte': 'coquillage sculpté',
#  'metal_couleur_bronze': 'métal couleur bronze',
#  'breloques_vertes_anciennes': 'breloques vertes anciennes',
#  'resine_blanche': 'résine blanche',
#  'coton_cire': 'coton ciré',
#  'metal_rouge': 'métal rouge',
#  'perles_sculptee': 'perles sculptée',
#  'resine_doree': 'résine dorée',
#  'fil_coton_et_satin': 'fil coton et satin',
#  'bronze_dore': 'bronze doré',
#  'fil_de_coton_satine': 'fil de coton satiné',
#  'toile_coton': 'toile coton',
#  'ruban': 'ruban',
#  'lettres_bois': 'lettres bois',
#  'joyeux_noel': 'joyeux noel',
#  'ours_polaire': 'ours polaire',
#  'carte_de_voeux': 'carte de voeux',
#  'hibou_noel': 'hibou noël',
#  'chouette_noel': 'chouette noël',
#  'sapin_noel': 'sapin noel',
#  'cadeau_noel': 'cadeau noël',
#  'bonhomme_de_neige': 'bonhomme de neige',
#  'vernis': 'vernis',
#  'peinture_huile': 'peinture huile',
#  'huile_sur_toile': 'huile sur toile',
#  'huile': 'huilé',
#  'toile_lin': 'toile lin',
#  'pastel_sur_papier': 'pastel sur papier',
#  'dorure': 'dorure',
#  'peinture_a_huile': 'peinture à huile',
#  'photographie_vintage': 'photographie vintage',
#  'transfert_textile': 'transfert textile',
#  'images_digitales': 'images digitales',
#  'images_retro': 'images rétro',
#  'fleurs_vintage': 'fleurs vintage',
#  'violette': 'violette',
#  'violette_fleur': 'violette fleur',
#  'violette_retro': 'violette rétro',
#  'violette_vintage': 'violette vintage',
#  'fleur_retro': 'fleur rétro',
#  'cabochon_oiseaux': 'cabochon oiseaux',
#  'oiseaux': 'oiseaux',
#  'colibri': 'colibri',
#  'fleurs_exotiques': 'fleurs exotiques',
#  'images_a_imprimer': 'images à imprimer',
#  'image_digitale': 'image digitale',
#  'cabochon_coeur': 'cabochon coeur',
#  'coeur': 'coeur',
#  'coeur_retro': 'coeur rétro',
#  'coeur_vintage': 'coeur vintage',
#  'metis': 'métis',
#  'limoges_china': 'limoges china',
#  'orange': 'orangé',
#  'raphia': 'raphia',
#  'fleurs_des_champs': 'fleurs des champs',
#  'coquillage': 'coquillage',
#  'fleur_de_coton': 'fleur de coton',
#  'pierre_de_corail': 'pierre de corail',
#  'chaine_couleur_bronze': 'chaîne couleur bronze',
#  'matiere_naturelle': 'matière naturelle',
#  'graines': 'graines',
#  'petales_de_fleur_de_coton': 'pétales de fleur de coton',
#  'chardons': 'chardons',
#  'metal_argente_sans_nickel': 'métal argenté sans nickel',
#  'petale_de_coton': 'pétale de coton',
#  'gland_de_chene': 'gland de chêne',
#  'limoges': 'limoges',
#  'paris': 'paris',
#  'fil_de_lin': 'fil de lin',
#  'cabochon_en_verre': 'cabochon en verre',
#  'metal_couleur_bronzev': 'métal couleur bronzev',
#  'metal_couleurs_bronze': 'métal couleurs bronze',
#  'metal_couleur_lbronze': 'métal couleur lbronze',
#  'rembourrage': 'rembourrage',
#  'magie': 'magie',
#  'hematite': 'hématite',
#  'fil_de_jade': 'fil de jade',
#  'fibres_melangees': 'fibres mélangées',
#  'lin_et_fibres_melangees': 'lin et fibres mélangées',
#  'fabric_coton': 'fabric coton',
#  'antirouille': 'antirouille',
#  'inox': 'inox',
#  'metallique': 'métallique',
#  'acier_inox': 'acier inox',
#  'acier_zinc': 'acier zinc',
#  'peridot': 'péridot',
#  'jaspe': 'jaspe',
#  'opale_rose': 'opale rose',
#  'rhodium_noir': 'rhodium noir',
#  'corail': 'corail',
#  'jaspe_rainforest': 'jaspe rainforest',
#  'topaze': 'topaze',
#  'opale_de_feu': 'opale de feu',
#  'rembourrage_anti_acarien': 'rembourrage anti acarien',
#  'yeux_de_securite': 'yeux de sécurité',
#  'laine_vierge': 'laine vierge',
#  'peluche_vache_crochet': 'peluche vache crochet',
#  'poupee_vache': 'poupée vache',
#  'mobile_ferme': 'mobile ferme',
#  'guirlande_ferme': 'guirlande ferme',
#  'mobile_animaux': 'mobile animaux',
#  'animaux_crochet': 'animaux crochet',
#  'margault_la_vache': 'margault la vache',
#  'vache_amande_etoilee': 'vache amande etoilee',
#  'peluche_lalylala': 'peluche lalylala',
#  'peluche_amande_etoilee': 'peluche amande etoilee',
#  'cadeau_naissance': 'cadeau naissance',
#  'doudou_bebe': 'doudou bébé',
#  'fabrique_en_france': 'fabriqué en france',
#  'perles_bois': 'perles bois',
#  'perles_acai': 'perles acai',
#  'rotin': 'rotin',
#  'vermeil': 'vermeil',
#  'argent_rhodie_et_vermeil': 'argent rhodié et vermeil',
#  'argent_rhodie_925': 'argent rhodié 925',
#  'argent_rhodie': 'argent rhodié',
#  'argent_925_rhodie': 'argent 925 rhodié',
#  'mohair_pompons': 'mohair pompons',
#  'placage': 'placage',
#  'noyer': 'noyer',
#  'vernis_au_tampon': 'vernis au tampon',
#  'chene': 'chêne',
#  'ebene': 'ébène',
#  'peuplier': 'peuplier',
#  'citronnier': 'citronnier',
#  'bois_de_rose': 'bois de rose',
#  'houx': 'houx',
#  'coton_createur': 'coton créateur',
#  'popeline': 'popeline',
#  'bouton_pression': 'bouton pression',
#  'coton_jersey': 'coton jersey',
#  'jersey_polaire': 'jersey polaire',
#  'pique_de_coton': 'piqué de coton',
#  'boutons': 'boutons',
#  'jersey_vert': 'jersey vert',
#  'coton_vert': 'coton vert',
#  'jersey_alpin': 'jersey alpin',
#  'polaire_alpin': 'polaire alpin',
#  'flanelle': 'flanelle',
#  'boutons_pressions': 'boutons pressions',
#  'boutons_pression': 'boutons pression',
#  'boutons_bois': 'boutons bois',
#  'coton_chambray': 'coton chambray',
#  'broderie_anglaise': 'broderie anglaise',
#  'coton_vichy': 'coton vichy',
#  'pression': 'pression',
#  'les_yeux_sur_la_fixation_securisee': 'les yeux sur la fixation sécurisée',
#  'remplisseur': 'remplisseur',
#  'tendresse_et_amour_de_mes_mains': 'tendresse et amour de mes mains',
#  'remplisseur_antiallergenique': 'remplisseur antiallergénique',
#  'acrylique_special_pour_les_enfants': 'acrylique spécial pour les enfants',
#  'les_yeux_sont_en_securite': 'les yeux sont en sécurité',
#  'acrylique_specialement_pour_les_bebes': 'acrylique spécialement pour les bébés',
#  'ligne': 'ligne',
#  'fil_de_muline': 'fil de muline',
#  'laine_acrylique': 'laine acrylique',
#  'ouate_synthetique': 'ouate synthétique',
#  'bourrage_synthetique': 'bourrage synthétique',
#  'laine_acrylique_crochet': 'laine acrylique crochet',
#  'synthetique': 'synthétique',
#  'cadeau_dauphin': 'cadeau dauphin',
#  'metal_ton_bronze': 'métal ton bronze',
#  'metal_ton_argente': 'métal ton argenté',
#  'image_haute_definition': 'image haute définition',
#  'apprets_sans_nickel': 'apprêts sans nickel',
#  'estampes_argentees': 'estampes argentées',
#  'cabochons_en_verre': 'cabochons en verre',
#  'strass_swarovski': 'strass swarovski',
#  'perles_en_verre': 'perles en verre',
#  'acrylique_sur_toile': 'acrylique sur toile',
#  'technique_mixte': 'technique mixte',
#  'crayon_sur_papier': 'crayon sur papier',
#  'encre': 'encre',
#  'lin_melange': 'lin mélangé',
#  'encre_de_chine': 'encre de chine',
#  'crayons_de_couleur': 'crayons de couleur',
#  'dessin': 'dessin',
#  'couleurs': 'couleurs',
#  'couleur': 'couleur',
#  'noir': 'noir',
#  'numerique': 'numérique',
#  'crayons_de_couleurs': 'crayons de couleurs',
#  'peinture_acrylique': 'peinture acrylique',
#  'texte': 'texte',
#  'aventure': 'aventure',
#  'neige': 'neige',
#  'soleil': 'soleil',
#  'papiers': 'papiers',
#  'etoiles': 'étoiles',
#  'terre': 'terre',
#  'univers': 'univers',
#  'lumiere': 'lumière',
#  'note_de_musique': 'note de musique',
#  'melodie': 'mélodie',
#  'poesie': 'poésie',
#  'colle': 'colle',
#  'enfance': 'enfance',
#  'beurres_vegetaux_vierges_et_bio': 'beurres végétaux vierges et bio',
#  'huiles_vegetales_extra_vierges_bio': 'huiles végétales extra vierges bio',
#  'peinture_verte': 'peinture verte',
#  'corne': 'corne',
#  'corne_de_zebu': 'corne de zébu',
#  'soie': 'soie',
#  'perles_de_tahiti': 'perles de tahiti',
#  'perle_de_tahiti': 'perle de tahiti',
#  'perle_de_culture': 'perle de culture',
#  'perles_de_culture': 'perles de culture',
#  'eponge_bambou': 'éponge bambou',
#  'tissus_bambou': 'tissus bambou',
#  'bambou_ecologique': 'bambou écologique',
#  'motifs_ananas': 'motifs ananas',
#  'tissu_en_coton': 'tissu en coton',
#  'tissus_motifs_ananas': 'tissus motifs ananas',
#  'bambou_reutilisables': 'bambou réutilisables',
#  'simili_dore': 'simili doré',
#  'coton_rose_poudre': 'coton rose poudré',
#  'toile_de_lin': 'toile de lin',
#  'molletonnee': 'molletonnée',
#  'lin_naturel': 'lin naturel',
#  'ouatine': 'ouatiné',
#  'serviettes_bambou': 'serviettes bambou',
#  'coton_japonais': 'coton japonais',
#  'simili_paillette': 'simili paillette',
#  'simili_bleu': 'simili bleu',
#  'tissu_en_lin': 'tissu en lin',
#  'bouton_en_bois': 'bouton en bois',
#  'coton_de_lin': 'coton de lin',
#  'tissus_japonais': 'tissus japonais',
#  'coton_noir': 'coton noir',
#  'tissus_liege': 'tissus liège',
#  'tissus_coton': 'tissus coton',
#  'cuir_de_liege': 'cuir de liège',
#  'cuir_vegane': 'cuir vegane',
#  'liege_vegane': 'liège vegane',
#  'liege_naturel': 'liège naturel',
#  'fermeture_tourniquet': 'fermeture tourniquet',
#  'mousquetons_laiton': 'mousquetons laiton',
#  'cuir_vegetal': 'cuir végétal',
#  'cuir_ananas': 'cuir ananas',
#  'cuir_pinatex': 'cuir piñatex',
#  'liege_portugais': 'liège portugais',
#  'molleton': 'molleton',
#  'tissus_petits_pois': 'tissus petits pois',
#  'coton_rouge': 'coton rouge',
#  'coton_fuchsia': 'coton fuchsia',
#  'coton_beige': 'coton beige',
#  'anneau_en_plastique': 'anneau en plastique',
#  'cotes_de_velours': 'côtés de velours',
#  'bord_cotes': 'bord cotes',
#  'tissus_velours': 'tissus velours',
#  'motifs_leopard': 'motifs léopard',
#  'coton_gris': 'coton gris',
#  'tissus_pingouins': 'tissus pingouins',
#  'cuir_ecologique': 'cuir ecologique',
#  'bord_cotes_extensibl': 'bord cotes extensibl',
#  'sweat_gris': 'sweat gris',
#  'sweat_bouclettes': 'sweat bouclettes',
#  'bord_cote': 'bord cote',
#  'cuir_liege': 'cuir liège',
#  'tissus_motifs_vagues': 'tissus motifs vagues',
#  'liege_marron': 'liège marron',
#  'motifs_japonais': 'motifs japonais',
#  'tissus_africain': 'tissus africain',
#  'eponge_microfibre': 'éponge microfibre',
#  'tissus_wax': 'tissus wax',
#  'tissu_japonais': 'tissu japonais',
#  'suedine_taupe': 'suédine taupe',
#  'suedine_beige': 'suédine beige',
#  'anasoha_argente': 'anasoha argenté',
#  'coton_asanoha': 'coton asanoha',
#  'liege_bordeaux': 'liège bordeaux',
#  'coton_emeraude': 'coton émeraude',
#  'toile_ethique': 'toile ethique',
#  'suedine_noir': 'suédine noir',
#  'tissus_fuchsia': 'tissus fuchsia',
#  'simili_paillettes': 'simili paillettes',
#  'simili_fuchsia': 'simili fuchsia',
#  'tissus_suedine': 'tissus suédine',
#  'bouton_magnetique': 'bouton magnétique',
#  'coton_a_colorier': 'coton à colorier',
#  'tissus_a_colorier': 'tissus a colorier',
#  'sac_en_coton': 'sac en coton',
#  'coton_blanc': 'coton blanc',
#  'coton_lin': 'coton lin',
#  'toile_de_coton': 'toile de coton',
#  'satin_cuivre': 'satin cuivre',
#  'coton_jaune': 'coton jaune',
#  'simili_cuir_noir': 'simili cuir noir',
#  'tissus_ethniques': 'tissus ethniques',
#  'coton_ethniques': 'coton ethniques',
#  'tissus_ameublement': 'tissus ameublement',
#  'ameublement_ethnique': 'ameublement ethnique',
#  'tissus_lin': 'tissus lin',
#  'faux_cuir': 'faux cuir',
#  'graphisme': 'graphisme',
#  'creation_textile': 'création textile',
#  'fermoir_metal': 'fermoir métal',
#  'boules_de_couleur': 'boules de couleur',
#  'cousu_main': 'cousu main',
#  'modele_original': 'modèle original',
#  'dessin_personnel': 'dessin personnel',
#  'graphisme_inedit': 'graphisme inédit',
#  'graphisme_exclusif': 'graphisme exclusif',
#  'impression_professionnelle': 'impression professionnelle',
#  'artisanat': 'artisanat',
#  'tissu_haut_de_gamme': 'tissu haut de gamme',
#  'qualite_professionnelle': 'qualité professionnelle',
#  'dessin_exclusif': 'dessin exclusif',
#  'papier_ilford': 'papier ilford',
#  'encres_pigmentees': 'encres pigmentées',
#  'tissu_unique': 'tissu unique',
#  'illustration_personnelle': 'illustration personnelle',
#  'encres_professionnelles': 'encres professionnelles',
#  'dessin_original': 'dessin original',
#  'graphisme_original': 'graphisme original',
#  'impression_artisanale': 'impression artisanale',
#  'encres': 'encres',
#  'toucher_veloute': 'toucher velouté',
#  'portrait_feminin': 'portrait féminin',
#  'creation_andi_lee': 'création andi lee',
#  'acier_galvanise': 'acier galvanisé',
#  'galvanise': 'galvanisé',
#  'lycopode': 'lycopode',
#  'polyamide': 'polyamide',
#  'agneau': 'agneau',
#  'oeil_de_tigre': 'oeil de tigre',
#  'argente': 'argenté',
#  'porcelaine_froide': 'porcelaine froide',
#  'pate_a_mais': 'pâte à maïs',
#  'pate_a_modeler': 'pâte à modeler',
#  'filigrane': 'filigrané',
#  'antique_sevres_france_rabbit': 'antique sevres france rabbit',
#  'handpainted_sevres': 'handpainted sevres',
#  'sevres_mnf_france_backstamp': 'sevres mnf france backstamp',
#  'antique_domed_limoges_ceramic_panel': 'antique domed limoges ceramic panel',
#  'hand_painted_limoges_ceramic': 'hand painted limoges ceramic',
#  'limoges_ceramic_pot': 'limoges ceramic pot',
#  'antique_limoges_enamel': 'antique limoges enamel',
#  'antique_brass_fleur_de_lys_decoration': 'antique brass fleur de lys decoration',
#  'limoges_roundel': 'limoges roundel',
#  'limoges_ceramic_panel': 'limoges ceramic panel',
#  'jesus_christ': 'jesus christ',
#  'painted_and_decorated_silk_jesus_christ': 'painted and decorated silk jesus christ',
#  'metal_label_marked_paris': 'metal label marked paris',
#  'signed_l_gilles': 'signed l gilles',
#  'cloisonne_enamels': 'cloisonne enamels',
#  'french_bronze_jesus_christ': 'french bronze jesus christ',
#  'paris_france_art_nouveau_dish': 'paris france art nouveau dish',
#  'antique_opaline_glass': 'antique opaline glass',
#  'hand_painted_portrait_on_limoges_panel': 'hand painted portrait on limoges panel',
#  'antique_french_fonte_d_art': 'antique french fonte d art',
#  'solid_paris_pewter': 'solid paris pewter',
#  'signed_h_huppe': 'signed h huppe',
#  'peau_de_mouton': 'peau de mouton',
#  'peaux_lainees': 'peaux lainées',
#  'fourrure': 'fourrure',
#  'peau_lainee': 'peau lainée',
#  'peaux_de_mouton': 'peaux de mouton',
#  'peaux_lainees_naturelles_haut_de_gamme': 'peaux lainées naturelles haut de gamme',
#  'cuir_de_veau': 'cuir de veau',
#  'cuir_de_chevre': 'cuir de chèvre',
#  'cuir_metallise': 'cuir métallisé',
#  'cuir_reconstitue': 'cuir reconstitué',
#  'cuir_veritable': 'cuir véritable',
#  'cuir_de_poisson': 'cuir de poisson',
#  'cuir_de_truite': 'cuir de truite',
#  'pierre_de_lune': 'pierre de lune',
#  'laiton_nickele': 'laiton nickelé',
#  'cuir_autruche': 'cuir autruche',
#  'cuir_exotique': 'cuir exotique',
#  'cuir_de_serpent': 'cuir de serpent',
#  'tannage_vegetal': 'tannage végétal',
#  'tanne_vegetal': 'tanné végétal',
#  'cuir_agneau': 'cuir agneau',
#  'metal_nickele': 'métal nickelé',
#  'cuir_tanne_vegetal': 'cuir tanné végétal',
#  'veau_facon_croco': 'veau façon croco',
#  'cuir_de_porc': 'cuir de porc',
#  'papier_lavable': 'papier lavable',
#  'cuir_de_saumon': 'cuir de saumon',
#  'cuir_de_veau_facon_croco': 'cuir de veau façon croco',
#  'cuir_autruche_violet': 'cuir autruche violet',
#  'cuir_autruche_veritable': 'cuir autruche véritable',
#  'coton_fabric': 'coton fabric',
#  'bille': 'bille',
#  'pompon': 'pompon',
#  'fiole': 'fiole',
#  'cercle_metal': 'cercle métal',
#  'cordelette': 'cordelette',
#  'cordon_coton': 'cordon coton',
#  'pierres': 'pierres',
#  'perles_ceramique': 'perles céramique',
#  'simili': 'simili',
#  'cordelette_coton': 'cordelette coton',
#  'feutrine': 'feutrine',
#  'fil_polyester': 'fil polyester',
#  'adhesif': 'adhésif',
#  'laine_bouillie': 'laine bouillie',
#  'perle_de_bois': 'perle de bois',
#  'velours_coton': 'velours coton',
#  'gants_laine_noire_brodee': 'gants laine noire brodée',
#  'gants_mitaines_en_laine_bouille': 'gants mitaines en laine bouille',
#  'polyester_et_coton': 'polyester et coton',
#  'fourrure_synthetique': 'fourrure synthétique',
#  'fleurs_coton': 'fleurs coton',
#  'coton_imprime': 'coton imprimé',
#  'doublure_coton': 'doublure coton',
#  'imprime_exclusif_anjesydesign': 'imprimé exclusif anjesydesign',
#  'coton_et_lin': 'coton et lin',
#  'zip_metal_ykk': 'zip métal ykk',
#  'noir_et_blanc': 'noir et blanc',
#  'doublure_coton_noir': 'doublure coton noir',
#  'doublure_nylon_impermeable': 'doublure nylon imperméable',
#  'zip_laiton_ykk': 'zip laiton ykk',
#  'imprime_anjesydesign': 'imprimé anjesydesign',
#  'imprime_en_serigraphie': 'imprimé en sérigraphie',
#  'mousqueton_metal': 'mousqueton métal',
#  '2_tailles_disponibles': '2 tailles disponibles',
#  'encre_ecofriendly': 'encre ecofriendly',
#  'doublure_impermeable': 'doublure imperméable',
#  'tissu_exclusif_anjesydesign': 'tissu exclusif anjesydesign',
#  'tissu_imprime_main': 'tissu imprimé main',
#  'serigraphie': 'sérigraphie',
#  'doublure_etanche': 'doublure étanche',
#  'doublure_waterproof': 'doublure waterproof',
#  'serigraphie_dore': 'sérigraphie doré',
#  'lin_coton': 'lin coton',
#  'cuir_de_luxe': 'cuir de luxe',
#  'cuir_dore': 'cuir doré',
#  'coton_serigraphie_noir_et_blanc': 'coton sérigraphié noir et blanc',
#  'tissu_tropical_anjesydesign': 'tissu tropical anjesydesign',
#  'imprime_ethnique': 'imprimé ethnique',
#  'dragonne_cuir_noir': 'dragonne cuir noir',
#  'motif_graphique_exclusif_anjesydesign': 'motif graphique exclusif anjesydesign',
#  'gilet_sans_manches': 'gilet sans manches',
#  'en_coton_et_acrylique': 'en coton et acrylique',
#  'couleur_bleu_marine': 'couleur bleu marine',
#  'dentelle_noire': 'dentelle noire',
#  'gilet_femme': 'gilet femme',
#  'cadeau_femme': 'cadeau femme',
#  'vetements_femme': 'vêtements femme',
#  'vetements_fille': 'vêtements fille',
#  'cadeau_fille': 'cadeau fille',
#  'laine_et_viscose': 'laine et viscose',
#  'couleur_beige_chine': 'couleur beige chiné',
#  'manteau_femme': 'manteau femme',
#  'manteau_fille': 'manteau fille',
#  'gris': 'gris',
#  'fausse_fourrure': 'fausse fourrure',
#  'marron': 'marron',
#  'manteau_trois_quart': 'manteau trois quart',
#  'leger_en_laine': 'léger en laine',
#  'viscose_et_dentelle': 'viscose et dentelle',
#  'couleur_noire': 'couleur noire',
#  'gilet_court': 'gilet court',
#  'coton_et_dentelle': 'coton et dentelle',
#  'couleur_noir': 'couleur noir',
#  'gilet_fille': 'gilet fille',
#  'cachemire': 'cachemire',
#  'vert_menthe': 'vert menthe',
#  'cachemire_et_acrylique': 'cachemire et acrylique',
#  'dentelle_blanche': 'dentelle blanche',
#  'pull_fille': 'pull fille',
#  'manches_longues': 'manches longues',
#  'maille_de_angora': 'maille de angora',
#  'laine_et_dentelle_noire': 'laine et dentelle noire',
#  'maille_de_coton': 'maille de coton',
#  'laine_et_dentelle': 'laine et dentelle',
#  'robe_fille': 'robe fille',
#  'soie_et_dentelle': 'soie et dentelle',
#  'blouson_sans_manches': 'blouson sans manches',
#  'fausse_fourrure_et_dentelle': 'fausse fourrure et dentelle',
#  'couleur_marron': 'couleur marron',
#  'blouson_femme': 'blouson femme',
#  'bleue': 'bleue',
#  'viscose_imprimee': 'viscose imprimée',
#  'soie_imprimee': 'soie imprimée',
#  'soie_gris': 'soie gris',
#  'satin_bleu': 'satin bleu',
#  'maille_en_coton': 'maille en coton',
#  'viscose_imprime': 'viscose imprimé',
#  'blouse_manches_courte': 'blouse manches courte',
#  'coton_marron': 'coton marron',
#  't_shirt_en_coton': 't shirt en coton',
#  'coton_bleu': 'coton bleu',
#  'velours_marron': 'velours marron',
#  'gilet_en_suedine': 'gilet en suédine',
#  'gilet_a_franges': 'gilet à franges',
#  'couleur_rose': 'couleur rose',
#  'livraison_gratuite': 'livraison gratuite',
#  'gilet_veste_en_cachemire': 'gilet veste en cachemire',
#  'pantalon_de_jogging': 'pantalon de jogging',
#  'coton_de_couleur_grise': 'coton de couleur grise',
#  'pantacourt_fille': 'pantacourt fille',
#  'pull_en_cachemire': 'pull en cachemire',
#  'veste_longue': 'veste longue',
#  'velours_imprime': 'velours imprimé',
#  'veste_habille': 'veste habillé',
#  'veste_femme': 'veste femme',
#  'veste_fille': 'veste fille',
#  'veste_a_rayures': 'veste à rayures',
#  'pantacourts_coton_et_lin': 'pantacourts coton et lin',
#  'couleur_beige_taupe': 'couleur beige taupe',
#  'pantalon_femme': 'pantalon femme',
#  'pantalon_fille': 'pantalon fille',
#  'jupe_longue': 'jupe longue',
#  'maille_de_viscose': 'maille de viscose',
#  'couleur_gris_chine': 'couleur gris chiné',
#  'jupe_femme': 'jupe femme',
#  'jupe_fille': 'jupe fille',
#  'tunique_forme_de_poncho': 'tunique forme de poncho',
#  'tunique_femme': 'tunique femme',
#  'tunique_fille': 'tunique fille',
#  'pull_tunique': 'pull tunique',
#  'manches_longue': 'manches longue',
#  'couleur_bleu_ciel': 'couleur bleu ciel',
#  'gilet_manches_longues': 'gilet manches longues',
#  'cachemire_et_dentelle': 'cachemire et dentelle',
#  'dentelle_de_coton_blanc': 'dentelle de coton blanc',
#  'trench_fille': 'trench fille',
#  'en_soie_et_dentelle': 'en soie et dentelle',
#  'couleur_gris_clair': 'couleur gris clair',
#  't_shirt_imprimee': 't shirt imprimée',
#  't_shirt_fille': 't shirt fille',
#  'en_viscose_imprimee': 'en viscose imprimée',
#  't_shirt_sans_manches': 't shirt sans manches',
#  'arrondi_sur_les_cotes': 'arrondi sur les cotés',
#  'couleur_beige': 'couleur beige',
#  'veste_legere': 'veste légère',
#  'lin_et_coton': 'lin et coton',
#  'dentelle_de_coton': 'dentelle de coton',
#  'veste_asymetrique': 'veste asymétrique',
#  'lin_et_dentelle': 'lin et dentelle',
#  'lin_beige': 'lin beige',
#  'dentelle_creme': 'dentelle crème',
#  'tunique_grande_taille': 'tunique grande taille',
#  'de_couleur_beige_taupe': 'de couleur beige taupe',
#  'couleur_bleu': 'couleur bleu',
#  'short_fille': 'short fille',
#  'chemisier_en_viscose_imprimee': 'chemisier en viscose imprimée',
#  'couleur_rouge_et_bleu': 'couleur rouge et bleu',
#  'chemisier_femme': 'chemisier femme',
#  'chemisier_fille': 'chemisier fille',
#  'cadeau_file': 'cadeau file',
#  'gilet_long': 'gilet long',
#  'suedine_de_couleur_marron': 'suédine de couleur marron',
#  'etole_de_mariage': 'étole de mariage',
#  'dentelle_de_couleur_noire': 'dentelle de couleur noire',
#  'etole_femme': 'étole femme',
#  'etole_fille': 'étole fille',
#  'accessoires_femme': 'accessoires femme',
#  'accessoires_fille': 'accessoires fille',
#  'chemisier_manches_longues': 'chemisier manches longues',
#  'coton_et_viscose': 'coton et viscose',
#  'veste_en_fausse_fourrure': 'veste en fausse fourrure',
#  'simili_cuir_et_dentelle': 'simili cuir et dentelle',
#  'couleur_vert_olive_et_gris': 'couleur vert olive et gris',
#  'ceste_femme': 'ceste femme',
#  'manteau_en_laine': 'manteau en laine',
#  'couleur_beige_claire': 'couleur beige claire',
#  'manteau_legere': 'manteau légère',
#  'viscose_te_dentelle': 'viscose te dentelle',
#  'couleur_noir_et_moutarde': 'couleur noir et moutarde',
#  'manteau_long': 'manteau long',
#  'style_militaire': 'style militaire',
#  'manteau_en_suedine': 'manteau en suédine',
#  'couleur_gris': 'couleur gris',
#  'acrylique_et_dentelle': 'acrylique et dentelle',
#  'imprime_vert_et_noir': 'imprimé vert et noir',
#  'imprime_rouge_et_noir': 'imprimé rouge et noir',
#  'manteau_court_en_laine': 'manteau court en laine',
#  'couleur_gris_et_noir': 'couleur gris et noir',
#  'manteau_en_velours_imprime': 'manteau en velours imprimé',
#  'couleur_bordeaux': 'couleur bordeaux',
#  'couleur_noir_et_ecru': 'couleur noir et écru',
#  'manteau_leger': 'manteau léger',
#  'longueur_trois_quart': 'longueur trois quart',
#  'gilet_en_mohair': 'gilet en mohair',
#  'dentelle_couleur_noire': 'dentelle couleur noire',
#  'manteaux_en_laine': 'manteaux en laine',
#  'gilet_manteau': 'gilet manteau',
#  'en_maille_de_coton': 'en maille de coton',
#  'motif_pied_de_poule': 'motif pied de poule',
#  'motif_geometrique': 'motif géométrique',
#  'chale': 'châle',
#  'chauffe_epaule': 'chauffe épaule',
#  'en_fausse_fourrure': 'en fausse fourrure',
#  'echarpe_femme': 'écharpe femme',
#  'col_en_fausse_fourrure': 'col en fausse fourrure',
#  'echarpe_en_coton': 'écharpe en coton',
#  'et_acrylique_beige': 'et acrylique beige',
#  'et_dentelle_noire': 'et dentelle noire',
#  'echarpe_fille': 'écharpe fille',
#  'vetement_femme': 'vêtement femme',
#  'vetement_fille': 'vêtement fille',
#  'accessoire_femme': 'accessoire femme',
#  'acrylique_et_crochet': 'acrylique et crochet',
#  'jupe_en_tissu_de_coton': 'jupe en tissu de coton',
#  'couleur_bleu_jean': 'couleur bleu jean',
#  'blouse_manches_longues': 'blouse manches longues',
#  'dentelle_rose': 'dentelle rose',
#  'blouse_fille': 'blouse fille',
#  'chemise_fille': 'chemise fille',
#  'couleur_bleu_clair': 'couleur bleu clair',
#  'couleur_bordeaux_et_noir': 'couleur bordeaux et noir',
#  'jupe_en_viscose': 'jupe en viscose',
#  'imprime_fleur': 'imprimé fleur',
#  'beige_et_bleu': 'beige et bleu',
#  'coton_imprime_et_dentelle': 'coton imprimé et dentelle',
#  'pantacourt_en_lin': 'pantacourt en lin',
#  'dentelle_de_couleur_noir': 'dentelle de couleur noir',
#  'soie_noire': 'soie noire',
#  'combinaison_en_soie': 'combinaison en soie',
#  'combinaison_femme': 'combinaison femme',
#  'combinaison_fille': 'combinaison fille',
#  'rayures': 'rayures',
#  'bermuda_en_coton': 'bermuda en coton',
#  'coton_a_rayures': 'coton à rayures',
#  'bleu_et_blanc': 'bleu et blanc',
#  'bermuda_femme': 'bermuda femme',
#  'fille': 'fille',
#  'bleu_et_rouge': 'bleu et rouge',
#  'chale_en_velours_noir': 'châle en velours noir',
#  'couleur_noir_et_rose': 'couleur noir et rose',
#  'vert_et_bleu': 'vert et bleu',
#  'chale_femme': 'châle femme',
#  'chale_fille': 'châle fille',
#  'motif_panthere': 'motif panthère',
#  'couleur_beige_et_marron': 'couleur beige et marron',
#  'cape_fille': 'cape fille',
#  'couleur_noir_et_rouge': 'couleur noir et rouge',
#  'taille_unique': 'taille unique',
#  'chemise_manches_longues': 'chemise manches longues',
#  'coton_a_motifs': 'coton à motifs',
#  'couleur_blanche': 'couleur blanche',
#  'jupe_evase': 'jupe évasé',
#  'satin_et_dentelle': 'satin et dentelle',
#  'chaine_dore': 'chaîne doré',
#  'gilet_en_maille_ajoure': 'gilet en maille ajouré',
#  'elasthanne_et_dentelle': 'élasthanne et dentelle',
#  'couleur_bleu_canard': 'couleur bleu canard',
#  'echarpe_en_plume_d_oiseau': 'écharpe en plume d oiseau',
#  'couleur_prune': 'couleur prune',
#  'maille': 'maille',
#  'robe_tunique': 'robe tunique',
#  'en_maille_de_viscose': 'en maille de viscose',
#  'de_couleur_noir_chine': 'de couleur noir chiné',
#  'coton_de_couleur_blanche': 'coton de couleur blanche',
#  'chemise_longue': 'chemise longue',
#  'coton_blanc_a_rayures': 'coton blanc à rayures',
#  'pull_en_coton': 'pull en coton',
#  'dentelle_couleur_beige': 'dentelle couleur beige',
#  'blouse_en_mousseline_imprime': 'blouse en mousseline imprime',
#  'couleur_corail': 'couleur corail',
#  'blouses_manches_longues': 'blouses manches longues',
#  'mousseline_de_soie': 'mousseline de soie',
#  'kaki': 'kaki',
#  'plusieurs_couleurs': 'plusieurs couleurs',
#  'grande_taille': 'grande taille',
#  'satin_imprime_et_dentelle': 'satin imprimé et dentelle',
#  'blanche': 'blanche',
#  'grise': 'grise',
#  'dentelle_de_couleur_bleu': 'dentelle de couleur bleu',
#  'salopette_en_toile_de_coton': 'salopette en toile de coton',
#  'motif_militaire': 'motif militaire',
#  'pantalon_militaire': 'pantalon militaire',
#  'pantacourt_en_coton': 'pantacourt en coton',
#  'couleur_gris_anthracite': 'couleur gris anthracite',
#  'ull_manches_longues': 'ull manches longues',
#  'blouse_en_mousseline': 'blouse en mousseline',
#  'brode_couleur_beige': 'brode couleur beige',
#  'attache_cheveux': 'attache cheveux',
#  'foulard_pour_les_cheveux': 'foulard pour les cheveux',
#  'leggings_pantalon': 'leggings pantalon',
#  'motifs_zebre': 'motifs zèbre',
#  'leggins_femme': 'leggins femme',
#  'tissu_de_crepe_et_dentelle': 'tissu de crêpe et dentelle',
#  'couleur_noir_et_blanc': 'couleur noir et blanc',
#  'acrylique_imprime_et_dentelle': 'acrylique imprimé et dentelle',
#  'doudoune_a_capuche': 'doudoune à capuche',
#  'dentelle_beige': 'dentelle beige',
#  'doudoune_fille': 'doudoune fille',
#  'tricot': 'tricot',
#  'gants_en_laine': 'gants en laine',
#  'acrylique_et_elasthanne': 'acrylique et élasthanne',
#  'decore_de_dentelle': 'décoré de dentelle',
#  'gants_femme': 'gants femme',
#  'guetres_en_coton': 'guêtres en coton',
#  'guetres_femme': 'guêtres femme',
#  'guetres_fille': 'guêtres fille',
#  'snood_en_acrylique': 'snood en acrylique',
#  'polyester_et_dentelle_couleur_bleu': 'polyester et dentelle couleur bleu',
#  'echarpe': 'écharpe',
#  'chauffe_epaules': 'chauffe épaules',
#  'a_rayures_larges': 'à rayures larges',
#  'dentelle_beige_et_noire': 'dentelle beige et noire',
#  'brode_main': 'brodé main',
#  'bleu': 'bleu',
#  'gilet_manche_longues': 'gilet manche longues',
#  'en_maille_jersey': 'en maille jersey',
#  'couleur_bleu_chine': 'couleur bleu chiné',
#  'gilet_en_mohair_et_dentelle': 'gilet en mohair et dentelle',
#  'gilet_cape': 'gilet cape',
#  'en_maille_imprime': 'en maille imprimé',
#  'crochet_et_acrylique': 'crochet et acrylique',
#  'manteau_en_laine_et_dentelle': 'manteau en laine et dentelle',
#  'couleur_grise': 'couleur grise',
#  'dentelle_de_coton_beige': 'dentelle de coton beige',
#  'jupon_en_resille': 'jupon en résille',
#  'jupon_en_resille_noire': 'jupon en résille noire',
#  'jupon_en_dentelle': 'jupon en dentelle',
#  'jupon_en_dentelle_noire': 'jupon en dentelle noire',
#  'couleur_imprime_noir': 'couleur imprimé noir',
#  'robe_manches_longues': 'robe manches longues',
#  'mohair_de_couleur_marron': 'mohair de couleur marron',
#  'robe_tricot': 'robe tricot',
#  'pull_manches_longues': 'pull manches longues',
#  'en_coton_et_modal': 'en coton et modal',
#  'pull_manches_courtes': 'pull manches courtes',
#  'mitaines_longues': 'mitaines longues',
#  'de_ceremonie': 'de cérémonie',
#  ...}

# %%
pickle.dump( dic_to_translate, open( "_data/dic_to_translate.pickle", "wb" ) )

# %%
df = pd.DataFrame.from_dict(dic_to_translate, orient='index')

# %%
df.to_excel('_data/uniques_to_translate.xlsx')

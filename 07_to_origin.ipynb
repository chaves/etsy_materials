# %%
import pickle
import pandas as pd
from collections import OrderedDict
import spacy
nlp = spacy.load('en')

# %%
ETSY_ROUND = '_2019'
OUTPUT_FOLDER = ETSY_ROUND + '/output/'

# %%
df = pd.read_excel(OUTPUT_FOLDER + 'uniques_translate_final.xlsx')

# %%
noisy_pos_tags = ["PROP","DET","PART","CCONJ","ADP","PRON","VERB","ADJ"]
min_token_length = 2 # minimum token length to remove

# %%
def is_noise(token):
    '''
    standard way to validate spacy tokens
    This method validate all the passed tokens and set true false on it
    '''
    is_noise = False
    if token.pos_ in noisy_pos_tags:
        is_noise = True
    elif token.is_stop == True:
        is_noise = True
    elif token.is_digit == True:
        is_noise = True
    elif token.is_space == True:
        is_noise = True
    elif len(token.string) <= min_token_length:
        is_noise = True
    return is_noise

# %%
def lemmanize(string):
    if isinstance(string, str):
        result_tempo = []
        nlp_words = nlp(string)
        for word in nlp_words:
            if not is_noise(word):
                result_tempo.append(word.lemma_)
        if len(result_tempo) > 0:
            return ' '.join(result_tempo)
        else:
            return ''
    else:
        print(string)

# %%
dic_translated = dict()

# %%
for index, row in df.iterrows():
    dic_translated[row.key] = row.en

# %%
dic_translated
# Out:
# {'laine': 'wool',
#  'soie': 'silk',
#  'pure_laine': 'pure wool',
#  'alpaga': 'alpaca',
#  'tricot': 'knitting',
#  'fait_main': 'handmade',
#  'merinos': 'merino',
#  'perles': 'beads',
#  'agate_blanche': 'white agate',
#  'agate_marbree': 'marbled agate',
#  'perle_de_bois_noir': 'black wooden bead',
#  'metal_argente': 'silver plated',
#  'verre_craquele': 'glass cracked',
#  'verre_blanc': 'white glass',
#  'cristal': 'crystal',
#  'cristal_noir': 'black crystal',
#  'murano_ovale_noir': 'Murano black oval',
#  'murano_rond_blanc': 'Murano round white',
#  'cubes_de_verre_noir': 'cubes of black glass',
#  'papillon_cristal_noir': 'butterfly black crystal',
#  'perles_de_bois': 'wooden beads',
#  'perle_metallique': 'metallic pearl',
#  'strass': 'strass',
#  'pierre_fine': 'gemstone',
#  'pierre_fine_noire_et_blanche': 'black and white fine stone',
#  'agate_noire_rayee': 'striped black agate',
#  'pierre_naturelle': 'natural stone',
#  'crochet_ou_clip': 'hook or clip',
#  'quartz_pasteque': 'quartz watermelon',
#  'pierres_fines': 'precious stones',
#  'verre_murano': 'Murano glass',
#  'strass_cristal': 'strass crystal',
#  'murano_noir': 'black Murano',
#  'murano_ovale': 'oval Murano',
#  'perle_murano': 'Murano bead',
#  'verre_murano_noir': 'Murano glass black',
#  'fluorine_vert': 'green fluorite',
#  'fluorine_arc_en_ciel': 'Fluorite rainbow',
#  'fluorine_cubique': 'cubic fluorite',
#  'albatre': 'alabaster',
#  'hematite': 'hematite',
#  'murano_fleur': 'Murano flower',
#  'strass_bead': 'rhinestone bead',
#  'pierre_gemme': 'gemstone',
#  'pierre_rouge': 'red stone',
#  'cristal_rouge': 'red crystal',
#  'cristal_metallise': 'crystal metallic',
#  'cristal_rouge_et_or': 'crystal red and gold',
#  'agate_depolie': 'agate frosted',
#  'clou': 'nail',
#  'clou_dore': 'gold nail',
#  'jade_vert': 'jade green',
#  'jade_vert_fonce': 'jade Dark green',
#  'jade_depoli': 'frosted jade',
#  'rocaille': 'rockery',
#  'perles_de_rocaille': 'seed beads',
#  'perles_or_sombre': 'dark gold beads',
#  'fermoir_dore': 'gold clasp',
#  'fermoir_note_de_musique': 'Clasp musical note',
#  'jade_partiellement_poli': 'jade partially polished',
#  'murano_vert': 'green Murano',
#  'murano_avec_roses': 'Murano with roses',
#  'clou_motif_roses': 'nail pink pattern',
#  'toupies_de_cristal': 'Router crystal',
#  'cristal_cuivre': 'crystal copper',
#  'cristal_taille': 'cut glass',
#  'rondelle_strass': 'Rhinestone Rondelle',
#  'verre_fait_mains': 'Glass made hands',
#  'verre_taille': 'cut glass',
#  'verre_spirale': 'spiral glass',
#  'fibule': 'fibula',
#  'anneau_de_strass': 'ring strass',
#  'corolle_doree': 'golden corolla',
#  'fibule_doree': 'golden fibula',
#  'fibule_argentee': 'silver fibula',
#  'murano_bleu': 'blue Murano',
#  'murano_multicolore': 'multicolor Murano',
#  'cristal_bicolore': 'bicolor crystal',
#  'cristal_irise': 'crystal iridescent',
#  'tubes_en_verre': 'glass tubes',
#  'lapis_lazuli': 'lapis lazuli',
#  'cristal_naturel': 'natural crystal',
#  'cristal_recouvert_de_titane': 'crystal coated with titanium',
#  'titane': 'titanium',
#  'fermoir_magnetique': 'magnetic clasp',
#  'nacre': 'pearly',
#  'crystal_irise': 'crystal iridescent',
#  'cristal_dore': 'crystal golden',
#  'cristal_emeraude': 'emerald crystal',
#  'perle_metal': 'metal bead',
#  'metal_noir': 'black metal',
#  'strass_transparent': 'strass transparent',
#  'details_argent': 'details money',
#  'perle_email_rouge': 'pearl red enamel',
#  'grosse_perle_email': 'large pearl enamel',
#  'navettes_rouges': 'red shuttles',
#  'perle_navettes': 'pearl shuttle',
#  'perles_de_verre': 'glass beads',
#  'verre_metallise': 'metallic glass',
#  'perle_navette': 'Shuttle pearl',
#  'cristal_de_boheme': 'crystal Bohemia',
#  'verre_de_boheme': 'glass Bohemia',
#  'arbre_de_vie': 'tree of Life',
#  'perle_arbre_de_vie': 'Pearl Tree of Life',
#  'cristal_turquoise': 'turquoise crystal',
#  'murano_bleu_et_argent': 'Murano blue and silver',
#  'perles_metal': 'metal beads',
#  'perles_metalliques': 'metal beads',
#  'perles_stardust': 'stardust beads',
#  'cristal_mauve': 'crystal purple',
#  'cristal_helix': 'crystal helix',
#  'pierre_fine_naturelle': 'fine natural stone',
#  'connecteur_cisele': 'chiselled connector',
#  'cristal_transparent': 'crystal clear',
#  'porcelaine_blanche': 'white porcelain',
#  'hematite_metallique': 'metal hematite',
#  'hematite_argentee': 'silvery hematite',
#  'crochets_d_oreille': 'ear hooks',
#  'hematite_losange': 'hematite diamond',
#  'perle_de_porcelaine': 'china pearl',
#  'corail_dore': 'coral gold',
#  'pate_de_verre': 'molten glass',
#  'pate_de_verre_orange': 'Dough orange glass',
#  'pate_de_verre_a_motifs': 'patterned glass paste',
#  'intercalaire_metal': 'intermediate metal',
#  'pierre_semi_precieuse': 'semi-precious stone',
#  'perle_de_verre': 'glass bead',
#  'papillon_cristal': 'butterfly crystal',
#  'aigue_marine_bleu_pale': 'acute pale blue',
#  'connecteur_triangulaire': 'triangular connector',
#  'aigue_marine_ovale': 'acute oval marine',
#  'aigue_marine_ronde': 'acute round marine',
#  'tube_cisele': 'chiselled tube',
#  'tube_argente': 'silver tube',
#  'toupie_de_cristal': 'crystal router',
#  'tablette_graphique': 'graphic tablet',
#  'peinture_sans_plomb': 'lead-free paint',
#  'tissu_recycle': 'recycled fabric',
#  'coton_imprime': 'printed cotton',
#  'recuperation': 'recovery',
#  'boucle_bronze': 'bronze buckle',
#  'tissu_vintage': 'vintage fabric',
#  'sangle_cuir': 'leather strap',
#  'faux_cuir': 'imitation leather',
#  'cuir_vegan': 'vegan leather',
#  'tissu_tapisserie': 'fabric upholstery',
#  'coton': 'cotton',
#  'tissu_imprime': 'printed cloth',
#  'cuir_et_toile': 'leather and canvas',
#  'boucle_en_bronze': 'bronze loop',
#  'fermoir_en_bronze': 'Clasp Bronze',
#  'toile_recuperation': 'canvas recovery',
#  'tissu_upcycle': 'fabric upcycle',
#  'bois': 'wood',
#  'caisse': 'checkout',
#  'lampe_led': 'lED lamp',
#  'peinture': 'painting',
#  'dessin_technique': 'technical drawing',
#  'design_graphique': 'graphic design',
#  'menuiserie': 'carpentry',
#  'boite_en_bois': 'wooden box',
#  'photophore': 'tealight',
#  'lampe_de_nuit': 'night lamp',
#  'caoutchouc': 'rubber',
#  'tissu_de_tapisserie': 'fabric upholstery',
#  'toile_et_cuir': 'Canvas and Leather',
#  'tissu_de_tappiserie': 'tissue tappiserie',
#  'cuir': 'leather',
#  'chambre_a_air': 'air chamber',
#  'chambre_a_air_velo': 'room air velo',
#  'boucle_metal': 'metal loop',
#  'sans_cruaute_animale': 'no animal cruelty',
#  'pneu': 'tire',
#  'roue_velo': 'bike wheel',
#  'daim': 'suede',
#  'suede': 'Sweden',
#  'perle_verre': 'glass bead',
#  'perle_forme_coeur': 'Pearl heart shape',
#  'pompon_jaune': 'yellow pompom',
#  'graine_acai': 'acai seed',
#  'perle_vegetale': 'vegetable pearl',
#  'fil_de_cuivre': 'copper wire',
#  'cuivre_naturel': 'natural copper',
#  'pampilles_de_verre': 'tassels glass',
#  'plumes_naturelles': 'natural feathers',
#  'fil_de_fer_recuit_noir': 'black annealed wire',
#  'vernis': 'varnish',
#  'fil_de_fer_recuit': 'wire annealing',
#  'ruban': 'ribbon',
#  'perle_verre_bleues': 'blue glass bead',
#  'perle_cristal': 'crystal pearl',
#  'perle_craquelees_azur': 'pearl blue cracked',
#  'plume_bleues': 'blue pen',
#  'perle_de_bois': 'wooden bead',
#  'breloque_chouette_hibou': 'charm owl owl',
#  'fil_de_fer': 'wire',
#  'fil_recuit': 'annealed wire',
#  'fil_noir': 'black wire',
#  'fil_de_fer_noir': 'black iron wire',
#  'argile_polymere': 'polymer clay',
#  'breloque_rose': 'pink charm',
#  'ruban_organza': 'ribbon organza',
#  'mousqueton_bronze': 'carabiner bronze',
#  'mousqueton_inox': 'stainless steel carabiner',
#  'plume_faisan': 'pheasant feather',
#  'pendentif_fimo': 'polymer clay pendant',
#  'breloque_trefle': 'clover charm',
#  'laiton_naturel': 'brass natural',
#  'tour_de_cou_noir': 'round neck black',
#  'fil_de_laiton': 'brass wire',
#  'plume_blanche': 'white feather',
#  'marque_page_metal': 'metal bookmark',
#  'connecteur_plaque_argent': 'plated connector',
#  'breloque_chouette': 'charm owl',
#  'breloque_hibou': 'owl charm',
#  'perle_amethyste': 'amethyst gem',
#  'perle_violette': 'purple pearl',
#  'perle_rocaille': 'rock gem',
#  'fil_de_cuivre_plaque_argent': 'silver plated copper wire',
#  'perles_vegetales': 'vegetable pearls',
#  'perles_rouge': 'red beads',
#  'fil_de_soie': 'silk',
#  'breloque': 'charm',
#  'breloques_argile': 'clay Charm',
#  'porte_cle': 'key ring',
#  'breloque_coeur': 'heart charm',
#  'imitation_cuir': 'imitation leather',
#  'perle_ronde': 'round pearl',
#  'perle_tube': 'pearl tube',
#  'fil_de_cuivre_naturel': 'Natural copper wire',
#  'perles_vertes': 'green beads',
#  'pampilles_verre': 'glass pendants',
#  'fil_inox': 'stainless steel wire',
#  'breloques': 'charms',
#  'verre_de_mer': 'sea \u200b\u200bglass',
#  'perles_verre_rouge': 'red glass beads',
#  'perles_sablees': 'sanded beads',
#  'perles_argent': 'silver beads',
#  'verre': 'glass',
#  'fil_enroule': 'wire wound',
#  'perles_pierre_rondes': 'Round stone beads',
#  'jaspe_rose': 'pink jasper',
#  'pierre_de_jaspe': 'jasper',
#  'plume_pintade': 'guinea fowl feather',
#  'plume_naturelle': 'natural feather',
#  'breloque_feuille': 'charm sheet',
#  'acier_noir': 'black steel',
#  'coquillage_naturel': 'natural shell',
#  'chaine': 'chain',
#  'breloque_papillon_argente': 'charm silver butterfly',
#  'perles_rouges': 'red beads',
#  'perles_transparentes': 'transparent beads',
#  'perles_bleues': 'blue beads',
#  'breloque_oiseau': 'bird charm',
#  'perles_cristal': 'crystal beads',
#  'perles_multicolores': 'multicolored beads',
#  'calligraphie': 'calligraphy',
#  'breloque_rose_bronze': 'Charm bronze pink',
#  'perles_magiques': 'magic beads',
#  'perles_craquelees_violet': 'cracked purple beads',
#  'perles_violettes': 'purple beads',
#  'metal': 'metal',
#  'limoges_porcelain': 'limoges porcelain',
#  'pochette': 'wallet',
#  'terre_d_acier': 'land of steel',
#  'percaline': 'percaline',
#  'fil': 'wire',
#  'papiers_sans_acide_et_ecologiques': 'acid-free papers and ecological',
#  'encres': 'inks',
#  'papier_en_coton_et_cellulose': 'paper and cotton cellulose',
#  'satin_de_coton_biologique': 'satin organic cotton',
#  'toile_lin_et_coton_melanges': 'canvas linen and cotton blend',
#  'encres_fines_pour_gravure': 'fine inks for gravure',
#  'papier_artisanal_coton_et_cellulose': 'artisanal cotton and cellulose paper',
#  'encre': 'ink',
#  'papier_coton_et_cellulose': 'cotton paper and cellulose',
#  'papier_en_coton': 'cotton paper',
#  'papier_japonais_washi': 'Japanese washi',
#  'encres_fines_pour_impression_manuelle': 'fine inks for manual printing',
#  'laine_alpaga_extrafine': 'superfine alpaca wool',
#  'boutons': 'buttons',
#  'fil_blanc': 'white thread',
#  'dentelle': 'lace',
#  'laine_blanche': 'white wool',
#  'fausse_fourrure_blanche': 'white faux fur',
#  'laine_poilue_blanche': 'white hairy wool',
#  'bouton': 'button',
#  'cachemire': 'cashmere',
#  'marron': 'Brown',
#  'chocolat_cup': 'chocolate cup',
#  'bakelite': 'bakelite',
#  'gouache': 'gouache',
#  'papier_mache': 'paper mache',
#  'erable': 'maple',
#  'plis': 'folds',
#  'huile_ecologique': 'ecological oil',
#  'skateboard_recycle': 'recycled skateboard',
#  'bois_recycle': 'recycled wood',
#  'bois_bleu': 'blue wood',
#  'bois_noir': 'black wood',
#  'organique': 'organic',
#  'huile': 'oil',
#  'tissus_recycle': 'recycled fabrics',
#  '7_plis': '7 folds',
#  'naturel': 'natural',
#  'liege': 'cork',
#  'diamants': 'diamonds',
#  'perle': 'pearl',
#  'ivoire': 'ivory',
#  'bois_dore': 'giltwood',
#  'francais': 'French',
#  'topaze': 'topaz',
#  'joaillerie_francaise': 'French jewelery',
#  'marbre': 'marble',
#  'bronze_dore': 'ormolu',
#  'antiquite_francaise': 'French antiquity',
#  'perle_fine': 'real pearl',
#  'papier_photo_fine_art': 'fine art photo paper',
#  'laine_naturelle': 'natural wool',
#  'ruban_a_sequins': 'Sequin strip',
#  'ruban_a_pompons': 'tape pompons',
#  'simili_cuir': 'leatherette',
#  'transfert': 'transfer',
#  'lin': 'linen',
#  'jersey_de_coton_recycle': 'jersey recycled cotton',
#  'suedine': 'suede',
#  'jacquard_de_coton': 'jacquard cotton',
#  'similicuir': 'leatherette',
#  'papier': 'paper',
#  'molleton': 'duffel',
#  'ruban_gros_grain': 'grosgrain ribbon',
#  'jersey_recycle': 'recycled jersey',
#  'bouton_en_plastique': 'plastic button',
#  'frit': 'fried',
#  'vitrail': 'stained glass',
#  'ruban_satin': 'satin ribbon',
#  'acrylique': 'acrylic',
#  'toile': 'canvas',
#  'acrylique_sur_toile': 'acrylic on canvas',
#  'huile_sur_toile': 'oil on canvas',
#  'technique_mixte': 'technique Mixte',
#  'crayon_sur_papier': 'pencil on paper',
#  'estampes_argentees': 'silver prints',
#  'cabochons_en_verre': 'studs glass',
#  'strass_swarovski': 'swarovski crystals',
#  'perles_en_verre': 'glass beads',
#  'imprime_exclusif_anjesydesign': 'exclusive print anjesydesign',
#  'serigraphie': 'serigraphy',
#  'doublure_coton': 'cotton lining',
#  'cuir_veritable': 'real leather',
#  'mousqueton_metal': 'carabiner metal',
#  'lin_naturel': 'natural linen',
#  'coton_et_lin': 'Cotton and linen',
#  'doublure_nylon_impermeable': 'lining impermeable nylon',
#  'imprime_anjesydesign': 'printed anjesydesign',
#  'coton_noir': 'black cotton',
#  'imprime_ethnique': 'ethnic print',
#  'doublure_coton_noir': 'Black cotton lining',
#  'zip_laiton_ykk': 'brass zip ykk',
#  'noir_et_blanc': 'black and white',
#  'imprime_en_serigraphie': 'screen printed',
#  'zip_metal_ykk': 'zip ykk metal',
#  'tissu_exclusif_anjesydesign': 'fabric exclusive anjesydesign',
#  'coton_lin': 'cotton linen',
#  'doublure_impermeable': 'waterproof lining',
#  'lin_coton': 'cotton linen',
#  'cuir_de_luxe': 'luxury leather',
#  'doublure_etanche': 'leakproof liner',
#  'doublure_waterproof': 'waterproof lining',
#  'serigraphie_dore': 'golden silkscreen',
#  'tissu_imprime_main': 'printed fabric hand',
#  'coton_natte': 'braided cotton',
#  'fermoir': 'clasp',
#  'bouton_aimante': 'magnetic button',
#  'peinture_textile': 'textile paint',
#  'etain': 'tin',
#  'ceramique': 'ceramic',
#  'terre_cuite': 'terracotta',
#  'emaille': 'enamel',
#  'laiton': 'brass',
#  'glace': 'ice',
#  'terre': 'Earth',
#  'terre_de_fer': 'ironstone',
#  'metal_blanc': 'white metal',
#  'chrome': 'chromium',
#  'fibres_melangees': 'mixed fibers',
#  'ruban_de_satin': 'satin ribbon',
#  'galon': 'braid',
#  'brocart': 'brocade',
#  'broderies': 'embroidery',
#  'broderie': 'embroidery',
#  'fausse_fourrure': 'fake fur',
#  'brandebourg': 'brandenburg',
#  'galon_dore': 'gold braid',
#  'lainage': 'woolen cloth',
#  'lacet': 'lace',
#  'synthetique': 'synthetic',
#  'acrylique_premium': 'premium acrylic',
#  'polyamide': 'polyamide',
#  'laine_vierge': 'new wool',
#  'perle_bois': 'wooden bead',
#  'verre_file': 'glass yarn',
#  'cuivre_brillant': 'copper polished',
#  'emaux_d_art': 'enamels of art',
#  'perles_papier': 'paper beads',
#  'cuivre_martele': 'hammered copper',
#  'ceramique_raku': 'raku',
#  'cuivre_patine': 'copper patina',
#  'plaque_argent': 'silver plated',
#  'laine_peignee': 'worsted',
#  'cuivre_emaille': 'enamelled copper',
#  'cuivre': 'copper',
#  'plaque_or_24_k': '24k gold plated',
#  'coquillage': 'shell',
#  'papier_recycle': 'recycled paper',
#  'poires_seaglass': 'seaglass pears',
#  'cones_filigranes_plaque_argent': 'cones plated filigree',
#  'coton_traite_aloe_vera': 'cotton treated aloe vera',
#  'hematites': 'haematite',
#  'rocaille_tcheque': 'Czech rock',
#  'connecteur_vintage': 'vintage connector',
#  'perles_de_jade': 'jade beads',
#  'coccinelle_en_verre_file': 'ladybird glass yarn',
#  'verre_file_a_la_flamme': 'glass queue has flame',
#  'jade_oceanique': 'jade ocean',
#  'perles_et_breloque_en_verre_file': 'beads and charms glass yarn',
#  'cuivre_martele_et_vieilli': 'hammered copper and aged',
#  'rocailles': 'rockeries',
#  'perles_de_papier': 'pearl paper',
#  'corail': 'coral',
#  'terra_cota': 'terra cotta',
#  'qualite_professionnelle': 'professional',
#  'papier_haut_de_gamme': 'paper upscale',
#  'papier_texture': 'textured paper',
#  'papeterie': 'stationery',
#  'amoureux_papier': 'love paper',
#  'giclee': 'splash',
#  'dessin': 'drawing',
#  'encre_pigmentee': 'pigment ink',
#  'impression_giclee': 'giclee print',
#  'haut_de_gamme': 'top of the line',
#  'epais': 'thick',
#  'aquarelle': 'watercolor',
#  'jet_d_encre': 'inkjet',
#  'tissu': 'fabric',
#  'poisson': 'fish',
#  'guipure': 'guipure',
#  'galuchat': 'sharkskin',
#  'peau_de_requin': 'sharkskin',
#  'boule': 'ball',
#  'doublure': 'lining',
#  'securite': 'security',
#  'coton_oekotex_100': 'cotton oekotex 100',
#  'eponge': 'sponge',
#  'dorure': 'gilding',
#  'acier': 'steel',
#  'languettes_de_canettes': 'cans tabs',
#  'capsule_de_canettes': 'capsule cans',
#  'cuir_synthetique_marron_fonce': 'synthetic dark brown leather',
#  'coton_a_motifs_marron_et_blanc': 'Cotton brown and white pattern',
#  'cuir_synthetique_peau_de_cobra': 'synthetic leather skin cobra',
#  'doree_ou_argentee': 'gold or silver',
#  'cuir_synthetique_noir_et_mini_strass': 'black synthetic leather and mini rhinestones',
#  'cuir_synthetique_blanc_et_mini_strass': 'white synthetic leather and mini rhinestones',
#  'pression_argentee': 'silver pressure',
#  'dragonne_amovible_bicolore': 'removable strap bicolor',
#  'cuir_synthetique_scintillant': 'glistening synthetic leather',
#  'noir_ou_rouge': 'black or red',
#  'bouton_pression_dore': 'gold snap',
#  'cuir_synthetique_rose_argente': 'synthetic silver pink leather',
#  'cuir_synthetique_gris': 'gray synthetic leather',
#  'coton_motif_wonder_woman': 'cotton pattern wonder woman',
#  'cuir_synthetique_noir': 'black synthetic leather',
#  'cuir_synthetique_marron': 'Synthetic brown leather',
#  'cuir_synthetique_cobra_rouge': 'synthetic red leather cobra',
#  'coton_a_potif': 'Cotton potif',
#  'cuir_syntetique_peau_de_poulain': 'syntetic leather colt skin',
#  'cuir_synthetique_brillant': 'shiny synthetic leather',
#  'cuir_synthetique_ivoire': 'ivory synthetic leather',
#  'cuir_synthetiaue_blanc_casse': 'synthétiaue leather off white',
#  'coton_terrasses_de_cafe_parisien': 'Cotton Parisian café terraces',
#  'pompon_en_suedine': 'tassel suede',
#  'cuir_synthetique_noir_a_pois_argente': 'black synthetic leather with silver dots',
#  'cuir_synthetique_rose_uni_mat': 'synthetic pink plain matte leather',
#  'cuir_synthetique_viel_or': 'synthetic leather viel gold',
#  'cuir_synthetique_bronze': 'synthetic leather bronze',
#  'cuir_synthetique_peau_d_autruche': 'Ostrich skin synthetic leather',
#  'cuir_synthetique_marbre_ivoire': 'ivory marbled synthetic leather',
#  'cuir_synthetique_vert': 'synthetic green leather',
#  'coton_graphique_japonais_jaune_et_blanc': 'cotton yellow and white Japanese graphic',
#  'cuir_synthetique_imprime': 'printed synthetic leather',
#  'tissus_waterproof_pour_la_doublure': 'Waterproof fabrics for lining',
#  'peau_d_autruche_noir_cuir_synthetique': 'Skin of black synthetic leather ostrich',
#  'cuir_synthetique_vert_fonce': 'dark green synthetic leather',
#  'cuir_synthetique_peau_autruche_fuchsia': 'synthetic leather skin fuchsia ostrich',
#  'breloques_couleur_bronze': 'bronze charms',
#  'cuir_synthetique_blanc': 'white synthetic leather',
#  'cuir_synthetique_blanc_graphique': 'Synthetic graphic white leather',
#  'coton_vichy_blanc_et_bleu': 'cotton white and blue gingham',
#  'bouton_pression_argente': 'button silver pressure',
#  'jean_noir': 'black jeans',
#  'coton_blanc_a_motif_rouge': 'White cotton with red pattern',
#  'pompon_rouge': 'red pompom',
#  'cuir_synthetique_peau_d_autruche_fuchsia': 'synthetic leather skin fuchsia ostrich',
#  'cuir_synthetique_lisse_marbre_ivoire': 'marbled smooth synthetic leather ivory',
#  'coton_blanc_avec_des_motifs_plumes_rose': 'White cotton with patterns pink feathers',
#  'bijou_de_sac_breloques_bronzes': 'jewelry bag charms bronzes',
#  'cuir_synthetique_de_la_couleur_choisie': 'synthetic leather of the chosen color',
#  'cuir_synthetique_gris_fonce': 'synthetic leather dark gray',
#  'cuir_synthetique_a_paillettes_argentees': 'synthetic leather in silver glitter',
#  'cuir_synthetique_mat_marron': 'Synthetic matte brown leather',
#  'cuir_synthetique_peau_de_dragon_rose': 'synthetic leather skin pink dragon',
#  'tissu_waterproof_imprime_en_serie_limitee': 'waterproof fabric printed in limited series',
#  'eponge_de_bambou': 'sponge bamboo',
#  'coton_bio': 'organic cotton',
#  'tissus_waterproof_pour_la_pochette': 'Waterproof fabrics for the cover',
#  'toile_plastique_transparente_avec_des_motifs': 'canvas transparent plastic with patterns',
#  'cuir_synthetique_peau_de_serpent_caramel': 'synthetic skin caramel leather snake',
#  'coton_marron_et_beige_imprime_shabby_chic': 'cotton brown and beige printed shabby chic',
#  'cuir_synthetique_violet': 'purple synthetic leather',
#  'coton_epais_pour_la_doublure': 'thick cotton for lining',
#  'cuir_synthetique_peau_de_cobra_rouge': 'synthetic skin red leather cobra',
#  'coton_a_motif_de_femmes_dessinees': 'cotton pattern comic women',
#  'cuir_synthetique_ebene': 'ebony synthetic leather',
#  'cuir_synthetique_bleu_canard': 'Synthetic leather blue duck',
#  'pression_aimantee_doree': 'golden magnetized pressure',
#  'dragonne_amovible_chaine_doree': 'gold chain removable strap',
#  'cuir_synthetique_taupe': 'synthetic leather taupe',
#  'pression_aimentee_doreee': 'pressure aimentée doréee',
#  'metal_dore': 'gold metal',
#  'cuir_synthetique_blanc_legerement_scintillant': 'Leather slightly sparkling white synthetic',
#  'cuir_synthetique_dore': 'golden synthetic leather',
#  'cuir_synthetique': 'synthetic leather',
#  'cuir_synthetique_marbre': 'marbled synthetic leather',
#  'pompon_en_suedine_marron_dore': 'tassel suede golden brown',
#  'mat_kaki': 'matt khaki',
#  'cuir_synthetique_peau_de_dragon_beige': 'synthetic skin dragon beige leather',
#  'cuir_synthetique_kaki': 'synthetic leather khaki',
#  'coton_motifs_leonard_de_vinci': 'cotton leonard reasons vinci',
#  'bachette_de_coton_bleu': 'blue cotton Bachette',
#  'coton_tisse_bleu_marine': 'cotton navy blue woven',
#  'coton_tisse_beige': 'woven beige cotton',
#  'coton_beige_avec_des_motifs_de_carte_postale': 'cotton beige with postcard motifs',
#  'cuir_synthetique_mat': 'synthetic leather mat',
#  'chocolat': 'chocolate',
#  'orange_et_vert_anis': 'orange and anise',
#  'cuir_synthetique_mlat': 'synthetic leather MLAT',
#  'gris_souris': 'mouse grey',
#  'scintillant': 'glittering',
#  'gris_rose_argentee': 'gray silver pink',
#  'cuir_synthetique_rose': 'synthetic leather pink',
#  'cuir_synthetique_argente': 'silver synthetic leather',
#  'cuir_synthetique_london_news': 'synthetic leather london news',
#  'cuir_synthetique_couleur_au_choix': 'synthetic leather color choice',
#  'coton_multicolore_visage_de_femmes_mode': "multicolored cotton face women's fashion",
#  'cuir_synthetique_vert_anis': 'synthetic leather green anise',
#  'coton_multicolor_a_dominante_kaki': 'multicolored cotton khaki dominant',
#  'cuir_synthetique_noir_avec_des_strass': 'black synthetic leather with rhinestones',
#  'cuir_synthetique_avec_des_motifs_bulles': 'synthetic leather with bubbles grounds',
#  'bleu_canard_et_vielle_or': 'peacock blue and old gold',
#  'pression_aimentee_doree': 'golden aimentée pressure',
#  'mousqueton_doree': 'carabiner gold',
#  'coton_organique': 'organic cotton',
#  'bleu_marine_et_orange': 'blue and orange',
#  'cuir_synthetique_de_couleur_mat': 'Synthetic leather matte color',
#  'cuir_synthetique_gris_acier': 'steel gray synthetic leather',
#  'legerement_brillant': 'slightly glossy',
#  'cuir_synthetique_ivoie': 'synthetic leather ivoie',
#  'cuir_synthetique_peau_de_dragon': 'synthetic leather dragon skin',
#  'cuir_syntetique_dragon_de_comodo_bleu': 'syntetic leather Dragon Comodo blue',
#  'pompon_en_suedine_blan': 'tassel suede blan',
#  'cuir_synthetique_souple': 'soft synthetic leather',
#  'coton_motif_plage_bretonne': 'cotton pattern beach in Brittany',
#  'toile_de_coton_tisse': 'woven cotton fabric',
#  'coton_fin_violet': 'cotton purple end',
#  'suedine_couleur_caramel': 'suede caramel color',
#  'suedine_blanche': 'white suede',
#  'suedine_grise': 'gray suede',
#  'coton_leopard_gris_blanc': 'cotton white gray leopard',
#  'coton_leopard_marron_blanc': 'cotton leopard white brown',
#  'coton_blanc_avec_des_violons': 'White cotton with violins',
#  'suedine_marron_fonce': 'dark brown suede',
#  'pompon_en_suedine_marron': 'tassel suede brown',
#  'cuir_synthetique_bleu': 'Synthetic blue leather',
#  'coton_raye_blanc_et_bleu': 'cotton white and blue striped',
#  'cuir_synthetique_peau_de_cobra_dore': 'synthetic skin cobra gold leather',
#  'cuir_synthetique_peau_de_cobra_argente': 'synthetic leather silver Cobrahide',
#  'cuir_synthetique_jaune_mate': 'synthetic leather matte yellow',
#  'pompon_en_suedine_dore': 'tassel suede gold',
#  'mousquetons_dores': 'gold hooks',
#  'cuir_synthetique_dragon_de_komodo': 'synthetic leather komodo dragon',
#  'beige_brillant': 'beige polished',
#  'cuir_synthetique_peau_de_dragon_rose_fuschia': 'Leather synthetic skin Dragon fuschia',
#  'mouqueton_dore': 'mouqueton gold',
#  'chaine_doree': 'golden chain',
#  'biais_en_cuir_dore': 'through golden leather',
#  'paillettes_dorees': 'gold glitter',
#  'coton_motifs_geometriques_bleus_fond_blanc': 'cotton blue geometric white background',
#  'mousquetons_argentee': 'carabiners silver',
#  'cuir_synthetique_belu_canard': 'synthetic leather belu duck',
#  'coton_vichy_noir_et_blanc': 'cotton gingham black and white',
#  'attache_metal': 'metal fastener',
#  'miroir': 'mirror',
#  'dore': 'golden',
#  'papier_yupo': 'paper yupo',
#  'cadre_bois': 'wood frame',
#  'plexiglas': 'plexiglass',
#  'decoupe_laser': 'laser cutting',
#  'plexi_miroir': 'plexi mirror',
#  'plastique': 'plastic',
#  'affaires_nomades_original_printed_linen': 'Business nomadic original printed linen',
#  'paille': 'Straw',
#  'clous_fer': 'iron nails',
#  'fibre_vegetale': 'vegetable fiber',
#  'tissus': 'tissues',
#  'bois_sculpte': 'carved wood',
#  'cordon_en_lin': 'flax cord',
#  'imprime': 'printed',
#  'fermeture_eclair': 'zipper',
#  'toile_enduite': 'coated canvas',
#  'chanvre': 'hemp',
#  'bois_peint': 'painted wood',
#  'linge_ancien': 'old linen',
#  'ecossais': 'Scottish',
#  'brun': 'brown',
#  'lin_lame': 'flax lamé',
#  'brode': 'embroidered',
#  'imprime_ancien': 'former print',
#  'corde': 'rope',
#  'bois_flotte': 'Driftwood',
#  'toile_aida': 'Aida fabric',
#  'heavy_cotton_moulin_du_roy_paper': 'roy heavy cotton paper mill',
#  'moulin_du_roy_heavy_cotton_paper': 'roy mill heavy cotton paper',
#  'heavy_cotton_moulin_de_roy_paper': 'heavy cotton mill roy paper',
#  'moulin_du_roy_cotton_paper': 'King cotton paper mill',
#  'moulin_du_roy_paper': 'King of paper mill',
#  'pate_polymere': 'polymer clay',
#  'poudre_metallique': 'metal powder',
#  'fil_aluminium': 'aluminum wire',
#  'tissu_enduit': 'coated fabric',
#  'tissu_coton': 'cotton cloth',
#  'enduit': 'coating',
#  'bambou': 'bamboo',
#  'erable_naturel': 'maple',
#  'tissu_coton_oeko_tex': 'Oeko Tex fabric cotton',
#  'non_traite': 'untreated',
#  'tissu_oeko_tex': 'oeko fabric tex',
#  'bois_naturel': 'natural wood',
#  'elastique': 'elastic',
#  'biais': 'angle',
#  'epnge_de_bambou': 'épnge bamboo',
#  'coton_liberty': 'liberty cotton',
#  'bouton_pression_kam': 'button kam pressure',
#  'resine': 'resin',
#  'chaine_inoxydable': 'stainless chain',
#  'acier_inoxydable': 'stainless steel',
#  'fine_bohemian_cristal': 'fine crystal bohemian',
#  'porcelaine_de_france': 'china France',
#  'perle_d_eau_douce': 'freshwater pearl',
#  'perle_de_culture': 'cultured pearl',
#  'paille_synthetique': 'synthetic straw',
#  'pompons_en_coton': 'pompoms Cotton',
#  'pompon_soyeux': 'silky tassel',
#  'pompon_en_fil_de_polyester_soyeux': 'tassel wire silky polyester',
#  'pompon_imitation_soie': 'imitation silk tassel',
#  'chaine_en_laiton': 'brass chain',
#  'pompon_gland': 'tassel tassel',
#  'etoile_en_laiton_dore': 'star golden brass',
#  'perle_en_coton_laque': 'lacquered cotton pearl',
#  'nacre_naturelle': 'natural pearl',
#  'piece_vintage_balmain': 'piece vintage Balmain',
#  'flamant_rose': 'Flamingo',
#  'paresseux': 'lazy',
#  'pieuvre': 'octopus',
#  'tigre_blanc': 'White Tiger',
#  'ours_polaire': 'polar bear',
#  'chouette': 'owl',
#  'passe_partout': 'master key',
#  'feutre': 'felt',
#  'ciseaux': 'scissors',
#  'polaire': 'polar',
#  'metal_nuance_cuivre_rose': 'metal copper pink shade',
#  'metal_argente_clair': 'bright silver metal',
#  'metal_bronze': 'bronze metal',
#  'ceramique_emaillee': 'glazed ceramic',
#  'alliage_bronze': 'bronze alloy',
#  'metal_or_vieilli': 'old gold metal',
#  'metal_cuivre': 'copper metal',
#  'resine_doree': 'golden resin',
#  'fil_de_coton_satine': 'satin cotton thread',
#  'verre_colore': 'stained glass',
#  'ceramique_peinte': 'painted ceramic',
#  'ceramique_peinte_vernie': 'painted glazed ceramics',
#  'fausses_perles': 'faux pearls',
#  'carton_leger': 'paperboard',
#  'fil_de_coton': 'cotton thread',
#  'metal_presse_dore': 'metal pressed golden',
#  'metal_emaille': 'enamelware',
#  'email': 'E-mail',
#  'fil_argent': 'over money',
#  'fil_or': 'gold thread',
#  'opalines': 'opaline',
#  'terre_cuite_emaillee': 'baked glazed pottery',
#  'plaque_or': 'gold plated',
#  'metal_presse_bronze': 'bronze pressed metal',
#  'email_bleu': 'blue enamel',
#  'metal_vieil_or': 'old gold metal',
#  'metal_nuance_bronze': 'metal bronze shade',
#  'verre_bleu': 'blue glass',
#  'metal_bronze_dore': 'metal ormolu',
#  'fils_de_couleur': 'son of color',
#  'fils_dores': 'golden son',
#  'opaline': 'opaline',
#  'metal_vert': 'green metal',
#  'tulle_dore': 'golden tulle',
#  'email_noir': 'black enamel',
#  'coton_cire': 'waxed cotton',
#  'alliage_bronze_sans_nickel': 'bronze alloy without nickel',
#  'metal_bronze_antique': 'antique bronze metal',
#  'metal_inox': 'stainless steel metal',
#  'perles_sculptees': 'carved beads',
#  'tulle_rose_fonce': 'tulle dark pink',
#  'papier_fort': 'strong paper',
#  'papier_cartonne': 'cardstock',
#  'fil_coton_et_satin': 'cotton and satin thread',
#  'metal_rouge': 'red metal',
#  'verre_orange': 'orange glass',
#  'vegetal': 'vegetal',
#  'orange': 'orange',
#  'matiere_naturelle': 'natural material',
#  'chardons': 'thistles',
#  'fleurs_sechees': 'dried flowers',
#  'raphia': 'raffia',
#  'metal_argente_sans_nickel': 'silver plated nickel',
#  'fleurs_des_champs': 'wildflowers',
#  'metal_couleur_bronze': 'metal bronze',
#  'noix_de_macadamia': 'macadamia nuts',
#  'petales_de_fleur_de_coton': 'cotton flower petals',
#  'limoges': 'limoges',
#  'paris': 'Paris',
#  'photographie_vintage': 'vintage photography',
#  'nana': 'girl',
#  'images_digitales': 'digital images',
#  'cabochon_coeur': 'cabochon heart',
#  'coeur': 'heart',
#  'image_digitale': 'digital image',
#  'coeur_retro': 'retro heart',
#  'coeur_vintage': 'vintage heart',
#  'cabochon_oiseaux': 'cabochon birds',
#  'oiseaux': 'birds',
#  'colibri': 'humming-bird',
#  'fleurs_exotiques': 'exotic flowers',
#  'images_a_imprimer': 'print images',
#  'images_retro': 'retro pictures',
#  'fleurs_vintage': 'vintage flowers',
#  'violette': 'violet',
#  'violette_fleur': 'violet flower',
#  'violette_retro': 'violet retro',
#  'violette_vintage': 'vintage violet',
#  'fleur_retro': 'retro flower',
#  'transfert_textile': 'textile transfer',
#  'magie': 'magic',
#  'rembourrage': 'padding',
#  'fabric_coton': 'cotton fabric',
#  'lin_et_fibres_melangees': 'linen and fibers mixed',
#  'elegance': 'elegance',
#  'acetate': 'acetate',
#  'peridot': 'peridot',
#  'citrine': 'citrine',
#  'jaspe': 'jasper',
#  'grenat': 'garnet',
#  'jaspe_rainforest': 'jasper rainforest',
#  'topaze_blanche': 'white topaz',
#  'feutrine': 'Felt',
#  'paillette': 'paillette',
#  'pompon': 'pompon',
#  'mohair_pompons': 'mohair pompoms',
#  'bouton_pression': 'snap',
#  'popeline': 'poplin',
#  'coton_jersey': 'cotton jersey',
#  'jersey_polaire': 'polar jersey',
#  'coton_createur': 'creator cotton',
#  'popeline_de_coton': 'cotton poplin',
#  'jersey_alpin': 'Alpine jersey',
#  'polaire_alpin': 'Alpine fleece',
#  'flanelle': 'flannel',
#  'pique_de_coton': 'cotton piqué',
#  'boutons_bois': 'wooden buttons',
#  'boutons_pressions': 'snaps',
#  'broderie_anglaise': 'eyelet',
#  'boutons_pression': 'snaps',
#  'coton_chambray': 'cotton chambray',
#  'raphia_naturel': 'natural raffia',
#  'rotin': 'rattan',
#  'laine_acrylique': 'acrylic wool',
#  'ouate_synthetique': 'fiberfill',
#  'bourrage_synthetique': 'synthetic stuffing',
#  'laine_crochet': 'wool hook',
#  'lin_melange': 'linen blends',
#  'toile_de_jouy': 'toile',
#  'tissu_en_coton_polyester': 'cotton fabric polyester',
#  'couleur': 'color',
#  'stylo': 'pen',
#  'encre_de_chine': 'Chinese ink',
#  'note_de_musique': 'music note',
#  'melodie': 'melody',
#  'texte': 'text',
#  'poesie': 'poetry',
#  'couleurs': 'colors',
#  'neige': 'snow',
#  'soleil': 'Sun',
#  'numerique': 'digital',
#  'etoiles': 'stars',
#  'univers': 'universe',
#  'lumiere': 'light',
#  'colle': 'glue',
#  'enfance': 'childhood',
#  'peinture_acrylique': 'acrylic paint',
#  'aventure': 'adventure',
#  'violoncelle': 'cello',
#  'guitare': 'guitar',
#  'papiers': 'papers',
#  'papier_brillant': 'glossy paper',
#  'papier_mat': 'matte paper',
#  'fil_polyester': 'polyester thread',
#  'oeil_de_tigre': 'Eye of tiger',
#  'perle_plaquee_argent': 'pearl silver plated',
#  'fil_polyester_cire': 'polyester yarn waxed',
#  'fossile': 'fossil',
#  'fil_cire': 'waxed thread',
#  'fil_macrame': 'macrame thread',
#  'tissus_coton': 'cotton fabrics',
#  'tissus_impermeable': 'waterproof fabrics',
#  'tissus_plu': 'tissue rained',
#  'tissus_jersey': 'jersey fabrics',
#  'eponge_bambou': 'bamboo terry',
#  'molleton_zorb': 'Fleece zorb',
#  'tissus_enduit': 'coated fabrics',
#  'coton_enduit': 'coated cotton',
#  'tissus_bambou': 'bamboo fabrics',
#  'bambou_ecologique': 'ecological bamboo',
#  'toile_de_lin': 'linen',
#  'tissu_en_coton': 'cotton fabric',
#  'ouatine': 'padded',
#  'eponge_bio': 'bio sponge',
#  'tissus_eponge': 'terry fabrics',
#  'serviettes_bambou': 'bamboo towels',
#  'cuir_vegetal': 'vegetable leather',
#  'cuir_vegane': 'vegan leather',
#  'cuir_ananas': 'pineapple leather',
#  'tissus_liege': 'cork fabric',
#  'cuir_de_liege': 'cork leather',
#  'liege_vegane': 'cork vegan',
#  'liege_naturel': 'natural cork',
#  'fermeture_tourniquet': 'tourniquet closure',
#  'coton_de_lin': 'linen cotton',
#  'liege_portugais': 'Portuguese cork',
#  'simili_dore': 'faux gold',
#  'bambou_reutilisables': 'reusable bamboo',
#  'nid_d_abeille': 'Honeycomb',
#  'eponge_nid_d_abeille': 'Bee nest sponge',
#  'nid_d_abeille_double': 'bee nest doubled',
#  'coton_rose_poudre': 'powder pink cotton',
#  'coton_japonais': 'Japanese cotton',
#  'simili_paillette': 'faux sequin',
#  'simili_bleu': 'faux blue',
#  'tissu_en_lin': 'linen fabric',
#  'coton_gris': 'gray cotton',
#  'bouton_en_bois': 'wood button',
#  'tissus_japonais': 'Japanese fabrics',
#  'coton_beige': 'cotton beige',
#  'cuir_liege': 'leather cork',
#  'tissus_motifs_vagues': 'Waves patterned fabrics',
#  'liege_marron': 'cork brown',
#  'motifs_japonais': 'Japanese motifs',
#  'tissus_lainage': 'woolen fabrics',
#  'lainage_chevrons': 'wool herringbone',
#  'tissus_chevrons': 'herringbone fabric',
#  'coton_marron': 'cotton brown',
#  'coton_motifs_licorne': 'cotton unicorn grounds',
#  'coton_arc_en_ciel': 'Cotton rainbow',
#  'liege_noir': 'black cork',
#  'chainette_argentee': 'silver chain',
#  'bouton_magnetique': 'magnetic button',
#  'bouton_amiante': 'asbestos button',
#  'lin_paillettes': 'flax glitters',
#  'coton_asanoha': 'cotton asanoha',
#  'liege_bordeaux': 'burgundy cork',
#  'cuir_ecologique': 'ecological leather',
#  'coton_anasoha': 'cotton anasoha',
#  'mousquetons_laiton': 'brass carabiners',
#  'tissus_pingouins': 'tissue penguins',
#  'coton_biologique': 'organic cotton',
#  'motifs_fleuries': 'floral patterns',
#  'coton_emeraude': 'cotton emerald',
#  'toile_ethique': 'ethics canvas',
#  'motifs_ananas': 'pineapple motifs',
#  'tissus_motifs_ananas': 'pineapple fabric patterns',
#  'cuir_pinatex': 'leather pinatex',
#  'microfibre_de_bambou': 'microfiber bamboo',
#  'anneaux_plastique': 'plastic rings',
#  'creation_textile': 'textile design',
#  'modele_original': 'original pattern',
#  'tissu_unique': 'unique fabric',
#  'illustration_personnelle': 'personal illustration',
#  'fermoir_metal': 'metal clasp',
#  'boules_de_couleur': 'colored balls',
#  'cousu_main': 'hand sewn',
#  'dessin_personnel': 'personal design',
#  'graphisme_exclusif': 'exclusive graphics',
#  'encres_professionnelles': 'professional inks',
#  'artisanat': 'craft',
#  'creation_andi_lee': 'creation andi lee',
#  'impression_professionnelle': 'professional print',
#  'graphisme_inedit': 'unique graphics',
#  'papier_ilford': 'paper ilford',
#  'encres_pigmentees': 'pigmented inks',
#  'dessin_exclusif': 'exclusive design',
#  'tissu_haut_de_gamme': 'luxury fabric',
#  'graphisme': 'graphics',
#  'toucher_veloute': 'velvety',
#  'portrait_feminin': 'female portrait',
#  'impression_artisanale': 'artisanal printing',
#  'dessin_original': 'original drawing',
#  'graphisme_original': 'original graphic',
#  'agneau': 'lamb',
#  'green_guilloche_enamel_brooch': 'green guilloche enamel brooch',
#  'antique_paris_jewel_box': 'paris antique jewel box',
#  'paris_france_jewel_box': 'paris France jewel box',
#  'cloisonne_enamels': 'cloisonne enamels',
#  'antique_paris_pin_box': 'paris antique pine box',
#  'papier_mache_box': 'paper mache box',
#  'chinoiserie_black_lacquer': 'black lacquer chinoiserie',
#  'signed_brousse': 'bush signed',
#  'paris_france_art_nouveau_dish': 'paris France new dish art',
#  'antique_french_fonte_d_art': 'antique french art cast',
#  'solid_paris_pewter': 'paris solid pewter',
#  'signed_h_huppe': 'signed h hoopoe',
#  'hand_painted_paris_porcelain': 'hand painted porcelain paris',
#  '1800s_paris_porcelain': '1800s paris porcelain',
#  'metal_label_marked_paris': 'metal label marked paris',
#  'antique_limoges_porcelain_panel': 'antique Limoges porcelain panel',
#  'antique_opaline_glass': 'antique opal glass',
#  'hand_painted_1800s_limoges_panel': 'hand painted Limoges 1800s panel',
#  'painted_and_decorated_silk_jesus_christ': 'painted and decorated silk jesus',
#  'french_bronze_jesus_christ': 'french bronze jesus',
#  'gold_gilt_paris': 'gold gilt paris',
#  'usa_standard_wiring_and_bulb_holders': 'usa standard wiring and bulb holders',
#  'signed_l_gilles': 'Gilles signed the',
#  'peau_lainee': 'fleecy skin',
#  'peaux_lainees': 'skins with wool',
#  'peaux_de_mouton': 'sheepskins',
#  'fourrure': 'fur',
#  'peau_de_mouton': "sheep's skin",
#  'peaux_lainees_naturelles_haut_de_gamme': 'skins with wool on natural premium',
#  'laiton_nickele': 'nickel-plated brass',
#  'pierre_de_lune': 'moon stone',
#  'amethyste': 'amethyst',
#  'cuir_de_veau': 'calfskin',
#  'cuir_de_poisson': 'Leather fish',
#  'cuir_de_truite': 'Leather Trout',
#  'cuir_reconstitue': 'Bonded leather',
#  'cuir_exotique': 'exotic leather',
#  'veau_facon_croco': 'croco calf',
#  'gemme': 'gem',
#  'tanne_vegetal': 'vegetable tanned',
#  'cuir_de_chevre': 'goatskin',
#  'cuir_de_veau_facon_croco': 'calfskin croco',
#  'cuir_agneau': 'lambskin',
#  'cuir_de_serpent': 'snake leather',
#  'cuir_autruche': 'ostrich leather',
#  'cuir_autruche_violet': 'purple ostrich leather',
#  'cuir_autruche_veritable': 'Ostrich genuine leather',
#  'cuir_de_porc': 'pig leather',
#  'cuir_metallise': 'metallic leather',
#  'fil_de_lin': 'linen thread',
#  'papier_lavable': 'washable paper',
#  'metal_nickele': 'nickel metal',
#  'cuir_tanne_vegetal': 'vegetable tanned leather',
#  'cuir_de_saumon': 'leather salmon',
#  'coton_fabric': 'cotton fabric',
#  'adhesif': 'adhesive',
#  'metal_couleur_argent': 'color silver metal',
#  'fourrure_synthetique': 'synthetic fur',
#  'laine_bouillie': 'boiled wool',
#  'doublure_polaire': 'fleece lining',
#  'gants_laine_noire_brodee': 'embroidered black wool gloves',
#  'gants_mitaines_en_laine_bouille': 'mittens woolen gloves boils',
#  'coton_a_broder': 'embroidery cotton',
#  'soie_naturelle': 'natural silk',
#  'perle_tibetaine_imitation_turquoise_et_corail': 'Tibetan turquoise and coral imitation pearl',
#  'perle_howlite': 'howlite pearl',
#  'metal_couleur_or': 'metal gold',
#  'bois_naturel_non_traite': 'natural untreated wood',
#  'perles_silicone_alimentaire': 'Food silicone beads',
#  'tissu_eponge': 'Spongey tissue',
#  'ouatine_traitee': 'fleece treated',
#  'tissu_africain': 'African fabric',
#  'fermeture': 'closing',
#  'fleurs_de_soie': 'silk flowers',
#  ...}

# %%
dic_uniques = pickle.load( open( OUTPUT_FOLDER + "dic_uniques.pickle", "rb" ) )

# %%
for (key, texte) in dic_uniques.items() :
    if key in dic_translated:
        dic_uniques[key] = dic_translated[key]

# %%
dic_uniques['corail_rouge']
# Out:
# 'red coral'

# %%
len(dic_uniques)
# Out:
# 61097

# %%
dic_uniques_lem = OrderedDict()

# %%
for (key, texte) in dic_uniques.items() :
        dic_uniques_lem[key] = [dic_uniques[key], lemmanize(dic_uniques[key])]
# Out:
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan

# %%
dic_uniques_lem['corail_rouge']
# Out:
# ['red coral', 'coral']

# %%
pickle.dump( dic_uniques_lem, open( OUTPUT_FOLDER + "dic_uniques_lem.pickle", "wb" ) )

# %%
data_dict = pickle.load( open( OUTPUT_FOLDER + "data_dict.pickle", "rb" ) )

# %%
len(data_dict)
# Out:
# 734124

# %%
data_dict
# Out:
# OrderedDict([('743909687_1', [743909687, 'laine', 'laine']),
#              ('743909687_2', [743909687, 'mohair', 'mohair']),
#              ('743909687_3', [743909687, 'soie', 'soie']),
#              ('743909687_4', [743909687, 'pure_laine', 'pure laine']),
#              ('742464511_1', [742464511, 'laine', 'laine']),
#              ('742464511_2', [742464511, 'mohair', 'mohair']),
#              ('742464511_3', [742464511, 'soie', 'soie']),
#              ('742464511_4', [742464511, 'pure_laine', 'pure laine']),
#              ('742463375_1', [742463375, 'laine', 'laine']),
#              ('742463375_2', [742463375, 'soie', 'soie']),
#              ('742463375_3', [742463375, 'mohair', 'mohair']),
#              ('732804293_1', [732804293, 'laine', 'laine']),
#              ('732804293_2', [732804293, 'mohair', 'mohair']),
#              ('732804293_3', [732804293, 'soie', 'soie']),
#              ('669600823_1', [669600823, 'laine', 'laine']),
#              ('669600823_2', [669600823, 'mohair', 'mohair']),
#              ('669600823_3', [669600823, 'soie', 'soie']),
#              ('691541095_1', [691541095, 'laine', 'laine']),
#              ('691541095_2', [691541095, 'alpaga', 'alpaga']),
#              ('691541095_3', [691541095, 'tricot', 'tricot']),
#              ('691541095_4', [691541095, 'fait_main', 'fait main']),
#              ('691539569_1', [691539569, 'laine', 'laine']),
#              ('691539569_2', [691539569, 'angora', 'angora']),
#              ('677687010_1', [677687010, 'laine', 'laine']),
#              ('677687010_2', [677687010, 'alpaga', 'alpaga']),
#              ('677687010_3', [677687010, 'tricot', 'tricot']),
#              ('677687010_4', [677687010, 'fait_main', 'fait main']),
#              ('672350909_1', [672350909, 'laine', 'laine']),
#              ('672350909_2', [672350909, 'angora', 'angora']),
#              ('672349865_1', [672349865, 'laine', 'laine']),
#              ('672349865_2', [672349865, 'angora', 'angora']),
#              ('671683649_1', [671683649, 'laine', 'laine']),
#              ('671683649_2', [671683649, 'mohair', 'mohair']),
#              ('671683649_3', [671683649, 'soie', 'soie']),
#              ('671682629_1', [671682629, 'laine', 'laine']),
#              ('671682629_2', [671682629, 'mohair', 'mohair']),
#              ('671682629_3', [671682629, 'soie', 'soie']),
#              ('671682629_4', [671682629, 'alpaga', 'alpaga']),
#              ('658505596_1', [658505596, 'laine', 'laine']),
#              ('658505596_2', [658505596, 'angora', 'angora']),
#              ('641630578_1', [641630578, 'laine', 'laine']),
#              ('641630578_2', [641630578, 'mohair', 'mohair']),
#              ('641630578_3', [641630578, 'soie', 'soie']),
#              ('641630578_4', [641630578, 'alpaga', 'alpaga']),
#              ('683748011_1', [683748011, 'laine', 'laine']),
#              ('683748011_2', [683748011, 'mohair', 'mohair']),
#              ('683748011_3', [683748011, 'soie', 'soie']),
#              ('683748011_4', [683748011, 'alpaga', 'alpaga']),
#              ('673292359_1', [673292359, 'laine', 'laine']),
#              ('673292359_2', [673292359, 'mohair', 'mohair']),
#              ('673292359_3', [673292359, 'soie', 'soie']),
#              ('672350245_1', [672350245, 'laine', 'laine']),
#              ('672350245_2', [672350245, 'angora', 'angora']),
#              ('667374192_1', [667374192, 'mohair', 'mohair']),
#              ('667374192_2', [667374192, 'soie', 'soie']),
#              ('667374192_3', [667374192, 'merinos', 'mérinos']),
#              ('667374192_4', [667374192, 'lurex', 'lurex']),
#              ('667374192_5', [667374192, 'perles', 'perles']),
#              ('643765030_1', [643765030, 'laine', 'laine']),
#              ('643765030_2', [643765030, 'mohair', 'mohair']),
#              ('643765030_3', [643765030, 'soie', 'soie']),
#              ('643765030_4', [643765030, 'alpaga', 'alpaga']),
#              ('543964019_1', [543964019, 'mohair', 'mohair']),
#              ('543964019_2', [543964019, 'soie', 'soie']),
#              ('543964019_3', [543964019, 'lurex', 'lurex']),
#              ('662882310_1', [662882310, 'laine', 'laine']),
#              ('662882310_2', [662882310, 'mohair', 'mohair']),
#              ('662882310_3', [662882310, 'soie', 'soie']),
#              ('662882310_4', [662882310, 'argent', 'argent']),
#              ('658506950_1', [658506950, 'laine', 'laine']),
#              ('658506950_2', [658506950, 'angora', 'angora']),
#              ('651464388_1', [651464388, 'steel', 'steel']),
#              ('651464388_2', [651464388, 'stone', 'stone']),
#              ('651464388_3', [651464388, 'jade', 'jade']),
#              ('231955174_1', [231955174, 'agate', 'agate']),
#              ('231955174_2', [231955174, 'agate_blanche', 'agate blanche']),
#              ('231955174_3', [231955174, 'agate_marbree', 'agate marbrée']),
#              ('231955174_4',
#               [231955174, 'perle_de_bois_noir', 'perle de bois noir']),
#              ('231955174_5', [231955174, 'metal_argente', 'métal argenté']),
#              ('231955174_6', [231955174, 'verre_craquele', 'verre craquelé']),
#              ('231955174_7', [231955174, 'verre_blanc', 'verre blanc']),
#              ('231948148_1', [231948148, 'cristal', 'cristal']),
#              ('231948148_2', [231948148, 'cristal_noir', 'cristal noir']),
#              ('231948148_3',
#               [231948148, 'murano_ovale_noir', 'murano ovale noir']),
#              ('231948148_4',
#               [231948148, 'murano_rond_blanc', 'murano rond blanc']),
#              ('231948148_5', [231948148, 'verre_craquele', 'verre craquelé']),
#              ('231948148_6',
#               [231948148, 'cubes_de_verre_noir', 'cubes de verre noir']),
#              ('231948148_7',
#               [231948148, 'papillon_cristal_noir', 'papillon cristal noir']),
#              ('231948148_8', [231948148, 'perles_de_bois', 'perles de bois']),
#              ('231948148_9', [231948148, 'murano', 'murano']),
#              ('231948148_10', [231948148, 'murano_oval', 'murano oval']),
#              ('231818097_1', [231818097, 'agate', 'agate']),
#              ('231818097_2', [231818097, 'agate_noire', 'agate noire']),
#              ('231818097_3', [231818097, 'agate_mate', 'agate mate']),
#              ('231818097_4', [231818097, 'metal_argente', 'métal argenté']),
#              ('231818097_5',
#               [231818097, 'perle_metallique', 'perle métallique']),
#              ('231818097_6', [231818097, 'strass', 'strass']),
#              ('231818097_7', [231818097, 'pierre_fine', 'pierre fine']),
#              ('231818097_8',
#               [231818097,
#                'pierre_fine_noire_et_blanche',
#                'pierre fine noire et blanche']),
#              ('231818097_9',
#               [231818097, 'agate_noire_rayee', 'agate noire rayée']),
#              ('231818097_10',
#               [231818097, 'pierre_naturelle', 'pierre naturelle']),
#              ('231818097_11',
#               [231818097, 'crochet_ou_clip', 'crochet ou clip']),
#              ('532016152_1', [532016152, 'glass', 'glass']),
#              ('532016152_2', [532016152, 'copper', 'copper']),
#              ('589794893_1', [589794893, 'glass', 'glass']),
#              ('589794893_2', [589794893, 'steel', 'steel']),
#              ('233560342_1', [233560342, 'quartz', 'quartz']),
#              ('233560342_2',
#               [233560342, 'quartz_pasteque', 'quartz pastèque']),
#              ('233560342_3', [233560342, 'quartz_rose', 'quartz rose']),
#              ('233560342_4', [233560342, 'pierres_fines', 'pierres fines']),
#              ('233560342_5', [233560342, 'metal_argente', 'métal argenté']),
#              ('232936302_1', [232936302, 'glass', 'glass']),
#              ('232936302_2', [232936302, 'steel', 'steel']),
#              ('232936302_3', [232936302, 'crystal', 'crystal']),
#              ('232936302_4',
#               [232936302, 'porcelain__ceramic', 'porcelain  ceramic']),
#              ('232936302_5', [232936302, 'aluminum', 'aluminum']),
#              ('231848808_1', [231848808, 'murano', 'murano']),
#              ('231848808_2', [231848808, 'murano_noire', 'murano noire']),
#              ('231848808_3',
#               [231848808, 'perle_metallique', 'perle métallique']),
#              ('231848808_4', [231848808, 'strass', 'strass']),
#              ('231848808_5', [231848808, 'verre_murano', 'verre murano']),
#              ('231848808_6',
#               [231848808, 'murano_noire_et_argent', 'murano noire et argent']),
#              ('231848808_7', [231848808, 'strass_cristal', 'strass cristal']),
#              ('231848808_8', [231848808, 'murano_noir', 'murano noir']),
#              ('231848808_9', [231848808, 'murano_ovale', 'murano ovale']),
#              ('231848808_10', [231848808, 'perle_murano', 'perle murano']),
#              ('231848808_11',
#               [231848808, 'verre_murano_noir', 'verre murano noir']),
#              ('532032600_1', [532032600, 'steel', 'steel']),
#              ('532032600_2', [532032600, 'glass', 'glass']),
#              ('532032600_3', [532032600, 'stone', 'stone']),
#              ('234536271_1', [234536271, 'fluorine', 'fluorine']),
#              ('234536271_2', [234536271, 'fluorine_vert', 'fluorine vert']),
#              ('234536271_3', [234536271, 'metal_argente', 'métal argenté']),
#              ('234536271_4', [234536271, 'clip', 'clip']),
#              ('234536271_5',
#               [234536271, 'fluorine_arc_en_ciel', 'fluorine arc en ciel']),
#              ('234536271_6', [234536271, 'flurite', 'flurite']),
#              ('234536271_7',
#               [234536271, 'fluorine_cubique', 'fluorine cubique']),
#              ('234536271_8', [234536271, 'cubic_fluorite', 'cubic fluorite']),
#              ('234536271_9',
#               [234536271, 'rainbow_fluorite', 'rainbow fluorite']),
#              ('671121851_1', [671121851, 'steel', 'steel']),
#              ('671121851_2', [671121851, 'stone', 'stone']),
#              ('671121851_3', [671121851, 'jade', 'jade']),
#              ('545834971_1',
#               [545834971, 'stainless_steel', 'stainless steel']),
#              ('545834971_2', [545834971, 'steel', 'steel']),
#              ('545834971_3', [545834971, 'stone', 'stone']),
#              ('532019466_1', [532019466, 'albatre', 'albatre']),
#              ('532019466_2', [532019466, 'hematite', 'hématite']),
#              ('532019466_3', [532019466, 'cristal', 'cristal']),
#              ('532019466_4', [532019466, 'crystal', 'crystal']),
#              ('532019466_5', [532019466, 'black_crystal', 'black crystal']),
#              ('532019466_6', [532019466, 'purple_crystal', 'purple crystal']),
#              ('532019466_7', [532019466, 'murano_noir', 'murano noir']),
#              ('532019466_8', [532019466, 'murano_fleur', 'murano fleur']),
#              ('532019466_9', [532019466, 'labradorite', 'labradorite']),
#              ('532019466_10', [532019466, 'strass', 'strass']),
#              ('532019466_11', [532019466, 'strass_bead', 'strass bead']),
#              ('532019466_12', [532019466, 'pierre_fine', 'pierre fine']),
#              ('532019466_13', [532019466, 'gemstone', 'gemstone']),
#              ('698729105_1',
#               [698729105, 'stainless_steel', 'stainless steel']),
#              ('698729105_2', [698729105, 'glass', 'glass']),
#              ('698729105_3', [698729105, 'ceramic', 'ceramic']),
#              ('545813273_1', [545813273, 'steel', 'steel']),
#              ('545813273_2', [545813273, 'glass', 'glass']),
#              ('545813273_3', [545813273, 'ceramic', 'ceramic']),
#              ('248261033_1', [248261033, 'jade', 'jade']),
#              ('248261033_2', [248261033, 'jade_rouge', 'jade rouge']),
#              ('248261033_3', [248261033, 'pierre_fine', 'pierre fine']),
#              ('248261033_4', [248261033, 'pierre_gemme', 'pierre gemme']),
#              ('248261033_5', [248261033, 'pierre_rouge', 'pierre rouge']),
#              ('248261033_6', [248261033, 'argent', 'argent']),
#              ('248261033_7', [248261033, 'chaine_argent', 'chaine argent']),
#              ('248261033_8',
#               [248261033, 'chaine_en_argent', 'chaine en argent']),
#              ('545814917_1', [545814917, 'steel', 'steel']),
#              ('545814917_2', [545814917, 'glass', 'glass']),
#              ('597844589_1', [597844589, 'steel', 'steel']),
#              ('597844589_2', [597844589, 'glass', 'glass']),
#              ('545836559_1', [545836559, 'stone', 'stone']),
#              ('545836559_2', [545836559, 'copper', 'copper']),
#              ('545836559_3', [545836559, 'jade', 'jade']),
#              ('243865167_1', [243865167, 'cristal', 'cristal']),
#              ('243865167_2', [243865167, 'cristal_rouge', 'cristal rouge']),
#              ('243865167_3',
#               [243865167, 'cristal_metallise', 'cristal métallisé']),
#              ('243865167_4',
#               [243865167, 'cristal_rouge_et_or', 'cristal rouge et or']),
#              ('243865167_5', [243865167, 'agate', 'agate']),
#              ('243865167_6', [243865167, 'agate_noire', 'agate noire']),
#              ('243865167_7', [243865167, 'agate_depolie', 'agate dépolie']),
#              ('243865167_8', [243865167, 'clou', 'clou']),
#              ('243865167_9', [243865167, 'clou_dore', 'clou doré']),
#              ('235094729_1', [235094729, 'jade', 'jade']),
#              ('235094729_2', [235094729, 'jade_vert', 'jade vert']),
#              ('235094729_3',
#               [235094729, 'jade_vert_fonce', 'jade vert foncé']),
#              ('235094729_4', [235094729, 'jade_depoli', 'jade dépoli']),
#              ('235094729_5', [235094729, 'rocaille', 'rocaille']),
#              ('235094729_6',
#               [235094729, 'perles_de_rocaille', 'perles de rocaille']),
#              ('235094729_7',
#               [235094729, 'perles_or_sombre', 'perles or sombre']),
#              ('235094729_8', [235094729, 'fermoir_dore', 'fermoir doré']),
#              ('235094729_9',
#               [235094729,
#                'fermoir_note_de_musique',
#                'fermoir note de musique']),
#              ('235094729_10',
#               [235094729,
#                'jade_partiellement_poli',
#                'jade partiellement poli']),
#              ('234583442_1', [234583442, 'pierre_fine', 'pierre fine']),
#              ('234583442_2', [234583442, 'jade', 'jade']),
#              ('234583442_3', [234583442, 'jade_vert', 'jade vert']),
#              ('234583442_4',
#               [234583442, 'jade_vert_fonce', 'jade vert foncé']),
#              ('234583442_5', [234583442, 'jade_mat', 'jade mat']),
#              ('234583442_6', [234583442, 'jade_depoli', 'jade dépoli']),
#              ('234583442_7', [234583442, 'muron', 'muron']),
#              ('234583442_8', [234583442, 'murano_vert', 'murano vert']),
#              ('234583442_9',
#               [234583442, 'murano_avec_roses', 'murano avec roses']),
#              ('234583442_10', [234583442, 'clou', 'clou']),
#              ('234583442_11',
#               [234583442, 'clou_motif_roses', 'clou motif roses']),
#              ('231285634_1', [231285634, 'murano', 'murano']),
#              ('231285634_2', [231285634, 'murano_blanc', 'murano blanc']),
#              ('231285634_3', [231285634, 'cristal', 'cristal']),
#              ('231285634_4',
#               [231285634, 'toupies_de_cristal', 'toupies de cristal']),
#              ('231285634_5',
#               [231285634, 'cristal_metallise', 'cristal métallisé']),
#              ('231285634_6', [231285634, 'cristal_cuivre', 'cristal cuivre']),
#              ('243859925_1', [243859925, 'cristal_taille', 'cristal taillé']),
#              ('243859925_2',
#               [243859925, 'cristal_metallise', 'cristal métallisé']),
#              ('243859925_3',
#               [243859925, 'cristal_rouge_et_or', 'cristal rouge et or']),
#              ('243859925_4', [243859925, 'agate', 'agate']),
#              ('243859925_5', [243859925, 'agate_noire', 'agate noire']),
#              ('243859925_6', [243859925, 'agate_depolie', 'agate dépolie']),
#              ('243859925_7', [243859925, 'murano', 'murano']),
#              ('243859925_8', [243859925, 'verre_murano', 'verre murano']),
#              ('243859925_9', [243859925, 'murano_rouge', 'murano rouge']),
#              ('243859925_10', [243859925, 'strass', 'strass']),
#              ('243859925_11',
#               [243859925, 'rondelle_strass', 'rondelle strass']),
#              ('233626379_1', [233626379, 'steel', 'steel']),
#              ('233626379_2', [233626379, 'glass', 'glass']),
#              ('233626379_3', [233626379, 'stone', 'stone']),
#              ('233626379_4', [233626379, 'wood', 'wood']),
#              ('233626379_5', [233626379, 'jade', 'jade']),
#              ('710489971_1', [710489971, 'steel', 'steel']),
#              ('710489971_2', [710489971, 'stone', 'stone']),
#              ('710489971_3', [710489971, 'jade', 'jade']),
#              ('710487513_1', [710487513, 'gemstone', 'gemstone']),
#              ('710487513_2', [710487513, 'steel', 'steel']),
#              ('710487513_3', [710487513, 'jade', 'jade']),
#              ('545835345_1', [545835345, 'lampwork_bead', 'lampwork bead']),
#              ('545835345_2',
#               [545835345, 'verre_fait_mains', 'verre fait mains']),
#              ('545835345_3', [545835345, 'verre_taille', 'verre taillé']),
#              ('545835345_4', [545835345, 'verre_spirale', 'verre spirale']),
#              ('545835345_5', [545835345, 'fibule', 'fibule']),
#              ('545835345_6', [545835345, 'strass', 'strass']),
#              ('545835345_7',
#               [545835345, 'anneau_de_strass', 'anneau de strass']),
#              ('545835345_8', [545835345, 'corolle_doree', 'corolle dorée']),
#              ('545835345_9', [545835345, 'fibule_doree', 'fibule dorée']),
#              ('545835345_10',
#               [545835345, 'fibule_argentee', 'fibule argentée']),
#              ('545833477_1', [545833477, 'glass', 'glass']),
#              ('658073939_1',
#               [658073939, 'stainless_steel', 'stainless steel']),
#              ('658073939_2', [658073939, 'steel', 'steel']),
#              ('658073939_3', [658073939, 'stone', 'stone']),
#              ('658073939_4', [658073939, 'turquoise', 'turquoise']),
#              ('584304476_1', [584304476, 'steel', 'steel']),
#              ('584304476_2', [584304476, 'glass', 'glass']),
#              ('584304476_3', [584304476, 'stone', 'stone']),
#              ('584304476_4', [584304476, 'turquoise', 'turquoise']),
#              ('232040536_1', [232040536, 'glass', 'glass']),
#              ('232040536_2', [232040536, 'steel', 'steel']),
#              ('231164839_1', [231164839, 'murano_bleu', 'murano bleu']),
#              ('231164839_2',
#               [231164839, 'murano_multicolore', 'murano multicolore']),
#              ('231164839_3',
#               [231164839, 'cristal_bicolore', 'cristal bicolore']),
#              ('231164839_4', [231164839, 'cristal_irise', 'cristal irisé']),
#              ('231164839_5',
#               [231164839, 'toupies_de_cristal', 'toupies de cristal']),
#              ('231164839_6', [231164839, 'metal_argente', 'métal argenté']),
#              ('231062440_1', [231062440, 'aigue_marine', 'aigue marine']),
#              ('231062440_2', [231062440, 'metal_argente', 'métal argenté']),
#              ('231062440_3', [231062440, 'tubes_en_verre', 'tubes en verre']),
#              ('230999973_1', [230999973, 'steel', 'steel']),
#              ('230999973_2', [230999973, 'stone', 'stone']),
#              ('230999973_3', [230999973, 'aquamarine', 'aquamarine']),
#              ('657280170_1',
#               [657280170, 'stainless_steel', 'stainless steel']),
#              ('657280170_2', [657280170, 'shell', 'shell']),
#              ('657280170_3', [657280170, 'steel', 'steel']),
#              ('657280170_4', [657280170, 'pearl', 'pearl']),
#              ('599427329_1', [599427329, 'steel', 'steel']),
#              ('599427329_2', [599427329, 'glass', 'glass']),
#              ('599427329_3', [599427329, 'stone', 'stone']),
#              ('545827991_1', [545827991, 'stone', 'stone']),
#              ('545827991_2', [545827991, 'copper', 'copper']),
#              ('545827991_3', [545827991, 'jade', 'jade']),
#              ('545827991_4', [545827991, 'glass', 'glass']),
#              ('545819983_1', [545819983, 'steel', 'steel']),
#              ('545819983_2', [545819983, 'stone', 'stone']),
#              ('545819983_3', [545819983, 'jade', 'jade']),
#              ('532029476_1', [532029476, 'shell', 'shell']),
#              ('532029476_2', [532029476, 'steel', 'steel']),
#              ('532029476_3', [532029476, 'stone', 'stone']),
#              ('532029476_4', [532029476, 'aquamarine', 'aquamarine']),
#              ('532010070_1', [532010070, 'steel', 'steel']),
#              ('532010070_2', [532010070, 'glass', 'glass']),
#              ('532010070_3', [532010070, 'stone', 'stone']),
#              ('532010070_4', [532010070, 'lapis_lazuli', 'lapis lazuli']),
#              ('234277276_1', [234277276, 'cristal', 'cristal']),
#              ('234277276_2',
#               [234277276, 'cristal_naturel', 'cristal naturel']),
#              ('234277276_3',
#               [234277276,
#                'cristal_recouvert_de_titane',
#                'cristal recouvert de titane']),
#              ('234277276_4', [234277276, 'titane', 'titane']),
#              ('234277276_5', [234277276, 'quartz', 'quartz']),
#              ('234277276_6', [234277276, 'quartz_rose', 'quartz rose']),
#              ('234277276_7',
#               [234277276, 'quartz_pasteque', 'quartz pastèque']),
#              ('233557232_1', [233557232, 'quartz', 'quartz']),
#              ('233557232_2',
#               [233557232, 'quartz_pasteque', 'quartz pastèque']),
#              ('233557232_3', [233557232, 'quartz_rose', 'quartz rose']),
#              ('233557232_4', [233557232, 'pierres_fines', 'pierres fines']),
#              ('233557232_5', [233557232, 'metal_argente', 'métal argenté']),
#              ('233557232_6',
#               [233557232, 'fermoir_magnetique', 'fermoir magnétique']),
#              ('233522467_1', [233522467, 'steel', 'steel']),
#              ('233522467_2', [233522467, 'stone', 'stone']),
#              ('233522467_3', [233522467, 'aluminum', 'aluminum']),
#              ('233522467_4', [233522467, 'rose_quartz', 'rose quartz']),
#              ('232489459_1', [232489459, 'nacre', 'nacre']),
#              ('232489459_2', [232489459, 'nacre_brute', 'nacre brute']),
#              ('232489459_3', [232489459, 'cristal', 'cristal']),
#              ('232489459_4', [232489459, 'cristal_irise', 'cristal irisé']),
#              ('232394841_1', [232394841, 'nacre', 'nacre']),
#              ('232394841_2', [232394841, 'nacre_brute', 'nacre brute']),
#              ('232394841_3', [232394841, 'cristal', 'cristal']),
#              ('232394841_4', [232394841, 'cristal_irise', 'cristal irisé']),
#              ('597846145_1', [597846145, 'steel', 'steel']),
#              ('597846145_2', [597846145, 'glass', 'glass']),
#              ('583759644_1', [583759644, 'steel', 'steel']),
#              ('583759644_2', [583759644, 'glass', 'glass']),
#              ('671121203_1', [671121203, 'steel', 'steel']),
#              ('671121203_2', [671121203, 'glass', 'glass']),
#              ('532026616_1', [532026616, 'silver', 'silver']),
#              ('532026616_2', [532026616, 'steel', 'steel']),
#              ('532026616_3', [532026616, 'glass', 'glass']),
#              ('532026616_4', [532026616, 'ceramic', 'ceramic']),
#              ('532023946_1', [532023946, 'gemstone', 'gemstone']),
#              ('532023946_2', [532023946, 'crystal', 'crystal']),
#              ('532023946_3', [532023946, 'jade', 'jade']),
#              ('532021188_1', [532021188, 'steel', 'steel']),
#              ('532021188_2', [532021188, 'stone', 'stone']),
#              ('532021188_3', [532021188, 'jade', 'jade']),
#              ('532009586_1', [532009586, 'glass', 'glass']),
#              ('532009586_2', [532009586, 'steel', 'steel']),
#              ('532009586_3', [532009586, 'crystal', 'crystal']),
#              ('584614682_1', [584614682, 'crystal', 'crystal']),
#              ('584614682_2',
#               [584614682, 'fermoir_magnetique', 'fermoir magnétique']),
#              ('584614682_3', [584614682, 'crystal_irise', 'crystal irisé']),
#              ('584614682_4', [584614682, 'cristal_dore', 'cristal doré']),
#              ('584614682_5', [584614682, 'cristal', 'cristal']),
#              ('584614682_6',
#               [584614682, 'cristal_emeraude', 'cristal émeraude']),
#              ('584614682_7', [584614682, 'perle_metal', 'perle métal']),
#              ('584614682_8', [584614682, 'metal_noir', 'métal noir']),
#              ('584614682_9', [584614682, 'strass', 'strass']),
#              ('584614682_10',
#               [584614682, 'strass_transparent', 'strass transparent']),
#              ('584614682_11',
#               [584614682, 'anneau_de_strass', 'anneau de strass']),
#              ('584614682_12', [584614682, 'details_argent', 'détails argent']),
#              ('233564130_1', [233564130, 'steel', 'steel']),
#              ('233564130_2', [233564130, 'stone', 'stone']),
#              ('230143944_1', [230143944, 'steel', 'steel']),
#              ('230143944_2', [230143944, 'glass', 'glass']),
#              ('234455675_1', [234455675, 'steel', 'steel']),
#              ('234455675_2', [234455675, 'glass', 'glass']),
#              ('532029606_1',
#               [532029606, 'perle_email_rouge', 'perle émail rouge']),
#              ('532029606_2',
#               [532029606, 'grosse_perle_email', 'grosse perle émail']),
#              ('532029606_3',
#               [532029606, 'navettes_rouges', 'navettes rouges']),
#              ('532029606_4', [532029606, 'perle_navettes', 'perle navettes']),
#              ('532029606_5',
#               [532029606, 'perles_de_verre', 'perles de verre']),
#              ('532029606_6', [532029606, 'verre_craquele', 'verre craquelé']),
#              ('532029606_7',
#               [532029606, 'verre_metallise', 'verre métallisé']),
#              ('532029606_8', [532029606, 'perle_navette', 'perle navette']),
#              ('600673201_1', [600673201, 'crystal', 'crystal']),
#              ('600673201_2',
#               [600673201, 'fermoir_magnetique', 'fermoir magnétique']),
#              ('600673201_3', [600673201, 'crystal_irise', 'crystal irisé']),
#              ('600673201_4', [600673201, 'cristal', 'cristal']),
#              ('600673201_5', [600673201, 'perle_metal', 'perle métal']),
#              ('600673201_6', [600673201, 'details_argent', 'détails argent']),
#              ('600673201_7',
#               [600673201, 'cristal_de_boheme', 'cristal de bohéme']),
#              ('600673201_8',
#               [600673201, 'verre_de_boheme', 'verre de bohème']),
#              ('600673201_9', [600673201, 'arbre_de_vie', 'arbre de vie']),
#              ('600673201_10',
#               [600673201, 'perle_arbre_de_vie', 'perle arbre de vie']),
#              ('600673201_11',
#               [600673201, 'cristal_turquoise', 'cristal turquoise']),
#              ('600673201_12',
#               [600673201, 'turquoise_crystal', 'turquoise crystal']),
#              ('231067536_1', [231067536, 'murano', 'murano']),
#              ('231067536_2', [231067536, 'murano_bleu', 'murano bleu']),
#              ('231067536_3',
#               [231067536, 'murano_bleu_et_argent', 'murano bleu et argent']),
#              ('231067536_4',
#               [231067536, 'murano_multicolore', 'murano multicolore']),
#              ('231067536_5', [231067536, 'perles_metal', 'perles métal']),
#              ('231067536_6',
#               [231067536, 'perles_metalliques', 'perles métalliques']),
#              ('231067536_7',
#               [231067536, 'perles_stardust', 'perles stardust']),
#              ('532014124_1', [532014124, 'steel', 'steel']),
#              ('532014124_2', [532014124, 'stone', 'stone']),
#              ('532014124_3', [532014124, 'jade', 'jade']),
#              ('545832075_1', [545832075, 'gemstone', 'gemstone']),
#              ('545832075_2', [545832075, 'crystal', 'crystal']),
#              ('545832075_3', [545832075, 'glass', 'glass']),
#              ('545832075_4', [545832075, 'jade', 'jade']),
#              ('545814251_1', [545814251, 'gemstone', 'gemstone']),
#              ('545814251_2', [545814251, 'steel', 'steel']),
#              ('545814251_3', [545814251, 'jade', 'jade']),
#              ('703675235_1', [703675235, 'gemstone', 'gemstone']),
#              ('703675235_2', [703675235, 'crystal', 'crystal']),
#              ('703675235_3', [703675235, 'steel', 'steel']),
#              ('703675235_4', [703675235, 'turquoise', 'turquoise']),
#              ('667614193_1',
#               [667614193, 'stainless_steel', 'stainless steel']),
#              ('667614193_2', [667614193, 'steel', 'steel']),
#              ('667614193_3', [667614193, 'stone', 'stone']),
#              ('532032696_1', [532032696, 'gemstone', 'gemstone']),
#              ('532032696_2', [532032696, 'lapis_lazuli', 'lapis lazuli']),
#              ('532032696_3', [532032696, 'steel', 'steel']),
#              ('532028628_1', [532028628, 'steel', 'steel']),
#              ('532028628_2', [532028628, 'stone', 'stone']),
#              ('532028628_3', [532028628, 'lapis_lazuli', 'lapis lazuli']),
#              ('702881789_1', [702881789, 'gemstone', 'gemstone']),
#              ('702881789_2', [702881789, 'crystal', 'crystal']),
#              ('702881789_3', [702881789, 'steel', 'steel']),
#              ('702881789_4', [702881789, 'amethyst', 'amethyst']),
#              ('689062364_1', [689062364, 'gemstone', 'gemstone']),
#              ('689062364_2', [689062364, 'crystal', 'crystal']),
#              ('689062364_3', [689062364, 'steel', 'steel']),
#              ('689062364_4', [689062364, 'amethyst', 'amethyst']),
#              ('559920628_1', [559920628, 'bronze', 'bronze']),
#              ('559920628_2', [559920628, 'steel', 'steel']),
#              ('559920628_3', [559920628, 'glass', 'glass']),
#              ('236507901_1', [236507901, 'fluorine', 'fluorine']),
#              ('236507901_2', [236507901, 'pierre_fine', 'pierre fine']),
#              ('236507901_3',
#               [236507901, 'fluorine_arc_en_ciel', 'fluorine arc en ciel']),
#              ('236507901_4', [236507901, 'fluorine_mauve', 'fluorine mauve']),
#              ('236507901_5', [236507901, 'cristal', 'cristal']),
#              ('236507901_6', [236507901, 'cristal_mauve', 'cristal mauve']),
#              ('236507901_7', [236507901, 'cristal_helix', 'cristal hélix']),
#              ('236507901_8', [236507901, 'metal_argente', 'métal argenté']),
#              ('236507901_9', [236507901, 'pierre_gemme', 'pierre gemme']),
#              ('236507901_10',
#               [236507901, 'pierre_fine_naturelle', 'pierre fine naturelle']),
#              ('235996069_1', [235996069, 'fluorite', 'fluorite']),
#              ('235996069_2', [235996069, 'fluorine', 'fluorine']),
#              ('235996069_3',
#               [235996069, 'fluorine_arc_en_ciel', 'fluorine arc en ciel']),
#              ('235996069_4', [235996069, 'fluorine_mauve', 'fluorine mauve']),
#              ('235996069_5', [235996069, 'pierre_fine', 'pierre fine']),
#              ('235996069_6', [235996069, 'metal_argente', 'métal argenté']),
#              ('235996069_7',
#               [235996069, 'connecteur_cisele', 'connecteur ciselé']),
#              ('235996069_8', [235996069, 'cristal', 'cristal']),
#              ('235996069_9', [235996069, 'cristal_taille', 'cristal taillé']),
#              ('235996069_10',
#               [235996069, 'cristal_transparent', 'cristal transparent']),
#              ('545824959_1', [545824959, 'silver', 'silver']),
#              ('545824959_2', [545824959, 'stone', 'stone']),
#              ('545824959_3', [545824959, 'jade', 'jade']),
#              ('532020766_1', [532020766, 'steel', 'steel']),
#              ('532020766_2', [532020766, 'stone', 'stone']),
#              ('532020766_3', [532020766, 'jade', 'jade']),
#              ('693178985_1', [693178985, 'gemstone', 'gemstone']),
#              ('693178985_2', [693178985, 'crystal', 'crystal']),
#              ('693178985_3', [693178985, 'steel', 'steel']),
#              ('545833717_1', [545833717, 'steel', 'steel']),
#              ('545833717_2', [545833717, 'stone', 'stone']),
#              ('545833717_3', [545833717, 'jade', 'jade']),
#              ('644052442_1', [644052442, 'silver', 'silver']),
#              ('644052442_2', [644052442, 'steel', 'steel']),
#              ('644052442_3', [644052442, 'glass', 'glass']),
#              ('568556083_1', [568556083, 'turquoise', 'turquoise']),
#              ('545829403_1', [545829403, 'porcelaine', 'porcelaine']),
#              ('545829403_2',
#               [545829403, 'porcelaine_blanche', 'porcelaine blanche']),
#              ('545829403_3', [545829403, 'hematite', 'hématite']),
#              ('545829403_4',
#               [545829403, 'hematite_metallique', 'hématite métallique']),
#              ('545829403_5',
#               [545829403, 'hematite_argentee', 'hématite argentée']),
#              ('545829403_6', [545829403, 'clips', 'clips']),
#              ('545829403_7',
#               [545829403, 'crochets_d_oreille', 'crochets d oreille']),
#              ('545829403_8',
#               [545829403, 'hematite_losange', 'hématite losange']),
#              ('545829403_9',
#               [545829403, 'perle_de_porcelaine', 'perle de porcelaine']),
#              ('545829403_10', [545829403, 'porcelain', 'porcelain']),
#              ('545829403_11',
#               [545829403, 'white_porcelain', 'white porcelain']),
#              ('545829403_12',
#               [545829403, 'diamond_hematite', 'diamond hematite']),
#              ('545829403_13', [545829403, 'hematite', 'hematite']),
#              ('532013540_1', [532013540, 'steel', 'steel']),
#              ('532013540_2', [532013540, 'glass', 'glass']),
#              ('532013540_3', [532013540, 'stone', 'stone']),
#              ('231203665_1', [231203665, 'murano_bleu', 'murano bleu']),
#              ('231203665_2',
#               [231203665, 'murano_multicolore', 'murano multicolore']),
#              ('231203665_3', [231203665, 'corail_dore', 'corail doré']),
#              ('231203665_4',
#               [231203665, 'perles_stardust', 'perles stardust']),
#              ('231203665_5', [231203665, 'metal_argente', 'métal argenté']),
#              ('545815731_1', [545815731, 'steel', 'steel']),
#              ('545815731_2', [545815731, 'glass', 'glass']),
#              ('231953249_1', [231953249, 'pate_de_verre', 'pâte de verre']),
#              ('231953249_2',
#               [231953249, 'pate_de_verre_orange', 'pate de verre orange']),
#              ('231953249_3',
#               [231953249, 'pate_de_verre_a_motifs', 'pate de verre à motifs']),
#              ('231953249_4', [231953249, 'murano', 'murano']),
#              ('231953249_5', [231953249, 'verre_murano', 'verre murano']),
#              ('231953249_6', [231953249, 'murano_blanc', 'murano blanc']),
#              ('231953249_7', [231953249, 'metal_argente', 'métal argenté']),
#              ('232012612_1', [232012612, 'pate_de_verre', 'pâte de verre']),
#              ('232012612_2',
#               [232012612, 'pate_de_verre_orange', 'pate de verre orange']),
#              ('232012612_3',
#               [232012612, 'pate_de_verre_a_motifs', 'pate de verre à motifs']),
#              ('232012612_4', [232012612, 'metal_argente', 'métal argenté']),
#              ('232010394_1', [232010394, 'pate_de_verre', 'pate de verre']),
#              ('232010394_2',
#               [232010394, 'pate_de_verre_orange', 'pate de verre orange']),
#              ('232010394_3',
#               [232010394, 'pate_de_verre_a_motifs', 'pate de verre à motifs']),
#              ('232010394_4', [232010394, 'murano', 'murano']),
#              ('232010394_5', [232010394, 'murano_blanc', 'murano blanc']),
#              ('232010394_6', [232010394, 'metal_argente', 'métal argenté']),
#              ('248358018_1', [248358018, 'metal_argente', 'métal argenté']),
#              ('248358018_2',
#               [248358018, 'intercalaire_metal', 'intercalaire métal']),
#              ('248358018_3', [248358018, 'jade', 'jade']),
#              ('248358018_4', [248358018, 'jade_rouge', 'jade rouge']),
#              ('248358018_5', [248358018, 'pierre_fine', 'pierre fine']),
#              ('248358018_6', [248358018, 'pierre_gemme', 'pierre gemme']),
#              ('248358018_7',
#               [248358018, 'pierre_semi_precieuse', 'pierre semi précieuse']),
#              ('248358018_8', [248358018, 'perle_de_verre', 'perle de verre']),
#              ('248358018_9',
#               [248358018, 'verre_metallise', 'verre métallisé']),
#              ('248358018_10', [248358018, 'verre_craquele', 'verre craquelé']),
#              ('248362420_1', [248362420, 'steel', 'steel']),
#              ('248362420_2', [248362420, 'glass', 'glass']),
#              ('248362420_3', [248362420, 'stone', 'stone']),
#              ('248362420_4', [248362420, 'jade', 'jade']),
#              ('545836461_1', [545836461, 'silver', 'silver']),
#              ('545836461_2', [545836461, 'stone', 'stone']),
#              ('545836461_3', [545836461, 'jade', 'jade']),
#              ('532025610_1', [532025610, 'steel', 'steel']),
#              ('532025610_2', [532025610, 'glass', 'glass']),
#              ('532025610_3', [532025610, 'stone', 'stone']),
#              ('532025610_4', [532025610, 'jade', 'jade']),
#              ('545818697_1', [545818697, 'copper', 'copper']),
#              ('245620098_1', [245620098, 'glass', 'glass']),
#              ('245620098_2', [245620098, 'steel', 'steel']),
#              ('245620098_3', [245620098, 'bronze', 'bronze']),
#              ('236105315_1', [236105315, 'fluorine', 'fluorine']),
#              ('236105315_2', [236105315, 'pierre_fine', 'pierre fine']),
#              ('236105315_3', [236105315, 'cristal', 'cristal']),
#              ('236105315_4',
#               [236105315, 'cristal_transparent', 'cristal transparent']),
#              ('236105315_5', [236105315, 'metal_argente', 'métal argenté']),
#              ('236105315_6',
#               [236105315, 'fluorine_arc_en_ciel', 'fluorine arc en ciel']),
#              ('236105315_7', [236105315, 'fluorine_mauve', 'fluorine mauve']),
#              ('236220322_1', [236220322, 'fluorine', 'fluorine']),
#              ('236220322_2', [236220322, 'metal_argente', 'métal argenté']),
#              ('236220322_3', [236220322, 'clip', 'clip']),
#              ('236220322_4',
#               [236220322, 'fluorine_arc_en_ciel', 'fluorine arc en ciel']),
#              ('236220322_5', [236220322, 'fluorine_mauve', 'fluorine mauve']),
#              ('236220322_6', [236220322, 'cristal', 'cristal']),
#              ('236220322_7', [236220322, 'cristal_irise', 'cristal irisé']),
#              ('236220322_8',
#               [236220322, 'papillon_cristal', 'papillon cristal']),
#              ('676498576_1', [676498576, 'gemstone', 'gemstone']),
#              ('676498576_2', [676498576, 'crystal', 'crystal']),
#              ('676498576_3', [676498576, 'steel', 'steel']),
#              ('693184955_1', [693184955, 'gemstone', 'gemstone']),
#              ('693184955_2', [693184955, 'steel', 'steel']),
#              ('693184955_3', [693184955, 'rose_quartz', 'rose quartz']),
#              ('650045354_1', [650045354, 'steel', 'steel']),
#              ('650045354_2', [650045354, 'stone', 'stone']),
#              ('650045354_3', [650045354, 'quartz', 'quartz']),
#              ('650031192_1', [650031192, 'steel', 'steel']),
#              ('650031192_2', [650031192, 'stone', 'stone']),
#              ('650031192_3', [650031192, 'jade', 'jade']),
#              ('532023792_1', [532023792, 'gemstone', 'gemstone']),
#              ('532023792_2', [532023792, 'steel', 'steel']),
#              ('532023792_3', [532023792, 'lapis_lazuli', 'lapis lazuli']),
#              ('532014024_1', [532014024, 'steel', 'steel']),
#              ('532014024_2', [532014024, 'glass', 'glass']),
#              ('532029062_1', [532029062, 'shell', 'shell']),
#              ('532029062_2', [532029062, 'steel', 'steel']),
#              ('532029062_3', [532029062, 'glass', 'glass']),
#              ('600833339_1', [600833339, 'steel', 'steel']),
#              ('600833339_2', [600833339, 'glass', 'glass']),
#              ('600833339_3', [600833339, 'stone', 'stone']),
#              ('600833339_4', [600833339, 'turquoise', 'turquoise']),
#              ('240736118_1', [240736118, 'pierre_fine', 'pierre fine']),
#              ('240736118_2', [240736118, 'metal_argente', 'métal argenté']),
#              ('240736118_3', [240736118, 'aigue_marine', 'aigue marine']),
#              ('240736118_4',
#               [240736118, 'aigue_marine_bleu_pale', 'aigue marine bleu pale']),
#              ('240736118_5',
#               [240736118,
#                'connecteur_triangulaire',
#                'connecteur triangulaire']),
#              ('240736118_6',
#               [240736118, 'aigue_marine_ovale', 'aigue marine ovale']),
#              ('240736118_7',
#               [240736118, 'aigue_marine_ronde', 'aigue marine ronde']),
#              ('240736118_8', [240736118, 'tube_cisele', 'tube ciselé']),
#              ('240736118_9', [240736118, 'tube_argente', 'tube argenté']),
#              ('240736118_10',
#               [240736118, 'toupie_de_cristal', 'toupie de cristal']),
#              ('532011276_1', [532011276, 'steel', 'steel']),
#              ('532011276_2', [532011276, 'glass', 'glass']),
#              ('532011276_3', [532011276, 'stone', 'stone']),
#              ('532011276_4', [532011276, 'jade', 'jade']),
#              ('579275600_1', [579275600, 'ceramic', 'ceramic']),
#              ('592484471_1', [592484471, 'ceramic', 'ceramic']),
#              ('592245527_1', [592245527, 'ceramic', 'ceramic']),
#              ('689310392_1', [689310392, 'ceramic', 'ceramic']),
#              ('583359394_1', [583359394, 'ceramic', 'ceramic']),
#              ('686780147_1', [686780147, 'wood', 'wood']),
#              ('679812793_1',
#               [679812793, 'tablette_graphique', 'tablette graphique']),
#              ('537717679_1', [537717679, 'porcelaine', 'porcelaine']),
#              ('537717679_2',
#               [537717679, 'lead_free_paint', 'lead free paint']),
#              ('537717679_3',
#               [537717679, 'peinture_sans_plomb', 'peinture sans plomb']),
#              ('537717679_4', [537717679, 'porcelain', 'porcelain']),
#              ('537717679_5', [537717679, 'porcelana', 'porcelana']),
#              ('537717679_6',
#               [537717679, 'pintura_sin_plomo', 'pintura sin plomo']),
#              ('562000657_1', [562000657, 'brass', 'brass']),
#              ('561997761_1', [561997761, 'brass', 'brass']),
#              ('548202020_1', [548202020, 'brass', 'brass']),
#              ('561993087_1', [561993087, 'brass', 'brass']),
#              ('548196240_1', [548196240, 'brass', 'brass']),
#              ('547358680_1', [547358680, 'tissu_recycle', 'tissu recyclé']),
#              ('547358680_2', [547358680, 'coton_imprime', 'coton imprimé']),
#              ('547358680_3', [547358680, 'recuperation', 'récupération']),
#              ('547358680_4', [547358680, 'upcycling', 'upcycling']),
#              ('547358680_5',
#               [547358680, 'crochet_vintage', 'crochet vintage']),
#              ('547358680_6', [547358680, 'motif_floral', 'motif floral']),
#              ('547358680_7', [547358680, 'boucle_bronze', 'boucle bronze']),
#              ('547358680_8', [547358680, 'tissu_vintage', 'tissu vintage']),
#              ('547358680_9', [547358680, 'sangle_cuir', 'sangle cuir']),
#              ('547358680_10', [547358680, 'faux_cuir', 'faux cuir']),
#              ('547358680_11', [547358680, 'cuir_vegan', 'cuir vegan']),
#              ('561148831_1',
#               [561148831, 'tissu_tapisserie', 'tissu tapisserie']),
#              ('561148831_2', [561148831, 'coton', 'coton']),
#              ('561148831_3', [561148831, 'tissu_imprime', 'tissu imprimé']),
#              ('561148831_4', [561148831, 'cuir_et_toile', 'cuir et toile']),
#              ('561148831_5',
#               [561148831, 'boucle_en_bronze', 'boucle en bronze']),
#              ('561148831_6',
#               [561148831, 'fermoir_en_bronze', 'fermoir en bronze']),
#              ('561148831_7', [561148831, 'tissu_recycle', 'tissu recyclé']),
#              ('561148831_8',
#               [561148831, 'toile_recuperation', 'toile récupération']),
#              ('561148831_9', [561148831, 'tissu_upcycle', 'tissu upcyclé']),
#              ('561148831_10', [561148831, 'motif_floral', 'motif floral']),
#              ('547342304_1', [547342304, 'bois', 'bois']),
#              ('547342304_2', [547342304, 'caisse', 'caisse']),
#              ('547342304_3', [547342304, 'lampe_led', 'lampe led']),
#              ('547342304_4', [547342304, 'peinture', 'peinture']),
#              ('547342304_5', [547342304, 'collage', 'collage']),
#              ('547342304_6',
#               [547342304, 'dessin_technique', 'dessin technique']),
#              ('547342304_7',
#               [547342304, 'design_graphique', 'design graphique']),
#              ('547342304_8', [547342304, 'fait_main', 'fait main']),
#              ('547342304_9', [547342304, 'menuiserie', 'menuiserie']),
#              ('547342304_10', [547342304, 'vintage_print', 'vintage print']),
#              ('547342304_11', [547342304, 'boite_en_bois', 'boite en bois']),
#              ('547342304_12', [547342304, 'photophore', 'photophore']),
#              ('547342304_13', [547342304, 'lampe_de_nuit', 'lampe de nuit']),
#              ('547341682_1', [547341682, 'bois', 'bois']),
#              ('547341682_2', [547341682, 'caisse', 'caisse']),
#              ('547341682_3', [547341682, 'lampe_led', 'lampe led']),
#              ('547341682_4', [547341682, 'peinture', 'peinture']),
#              ('547341682_5', [547341682, 'collage', 'collage']),
#              ('547341682_6',
#               [547341682, 'dessin_technique', 'dessin technique']),
#              ('547341682_7',
#               [547341682, 'design_graphique', 'design graphique']),
#              ('547341682_8', [547341682, 'fait_main', 'fait main']),
#              ('547341682_9', [547341682, 'menuiserie', 'menuiserie']),
#              ('547341682_10', [547341682, 'vintage_print', 'vintage print']),
#              ('547341682_11', [547341682, 'boite_en_bois', 'boite en bois']),
#              ('547341682_12', [547341682, 'photophore', 'photophore']),
#              ('547341682_13', [547341682, 'lampe_de_nuit', 'lampe de nuit']),
#              ('587613203_1', [587613203, 'bois', 'bois']),
#              ('587612211_1', [587612211, 'bois', 'bois']),
#              ('587611781_1', [587611781, 'bois', 'bois']),
#              ('587609195_1', [587609195, 'bois', 'bois']),
#              ('573806010_1', [573806010, 'bois', 'bois']),
#              ('573527120_1', [573527120, 'bois', 'bois']),
#              ('586793553_1', [586793553, 'bois', 'bois']),
#              ('586793553_2', [586793553, 'caisse', 'caisse']),
#              ('586793553_3', [586793553, 'lampe_led', 'lampe led']),
#              ('586793553_4', [586793553, 'peinture', 'peinture']),
#              ('586793553_5', [586793553, 'collage', 'collage']),
#              ('586793553_6',
#               [586793553, 'dessin_technique', 'dessin technique']),
#              ('586793553_7',
#               [586793553, 'design_graphique', 'design graphique']),
#              ('586793553_8', [586793553, 'fait_main', 'fait main']),
#              ('586793553_9', [586793553, 'menuiserie', 'menuiserie']),
#              ('586793553_10', [586793553, 'vintage_print', 'vintage print']),
#              ('586793553_11', [586793553, 'boite_en_bois', 'boite en bois']),
#              ('586793553_12', [586793553, 'photophore', 'photophore']),
#              ('586793553_13', [586793553, 'lampe_de_nuit', 'lampe de nuit']),
#              ('558839286_1', [558839286, 'caoutchouc', 'caoutchouc']),
#              ('558839286_2', [558839286, 'chambreaair', 'chambreàair']),
#              ('558839286_3',
#               [558839286, 'chambreaaircamion', 'chambreàaircamion']),
#              ('558839286_4',
#               [558839286, 'chambreaairvelo', 'chambreàairvélo']),
#              ('546731627_1',
#               [546731627, 'tissu_de_tapisserie', 'tissu de tapisserie']),
#              ('546731627_2', [546731627, 'coton', 'coton']),
# ...
#              ('529006938_7',
#               [529006938, 'pendant_serpent', 'pendant serpent']),
#              ('529006938_8', [529006938, 'fil_de_laiton', 'fil de laiton']),
#              ('671321361_1', [671321361, 'silver', 'silver']),
#              ('671321361_2', [671321361, 'glass', 'glass']),
#              ('671321361_3', [671321361, 'copper', 'copper']),
#              ('542810925_1', [542810925, 'silver', 'silver']),
#              ('542810925_2',
#               [542810925, 'stainless_steel', 'stainless steel']),
#              ('542810925_3', [542810925, 'glass', 'glass']),
#              ('542810925_4', [542810925, 'wool', 'wool']),
#              ('542810925_5', [542810925, 'copper', 'copper']),
#              ('542806441_1', [542806441, 'bronze', 'bronze']),
#              ('542806441_2', [542806441, 'brass', 'brass']),
#              ('542806441_3', [542806441, 'glass', 'glass']),
#              ('509682439_1', [509682439, 'copper', 'copper']),
#              ('509682439_2', [509682439, 'brass', 'brass']),
#              ('656223002_1', [656223002, 'plume_blanche', 'plume blanche']),
#              ('656223002_2',
#               [656223002, 'marque_page_metal', 'marque page métal']),
#              ('656223002_3',
#               [656223002,
#                'connecteur_plaque_argent',
#                'connecteur plaqué argent']),
#              ('656223002_4',
#               [656223002, 'breloque_chouette', 'breloque chouette']),
#              ('656223002_5', [656223002, 'breloque_hibou', 'breloque hibou']),
#              ('656223002_6', [656223002, 'plume_violet', 'plume violet']),
#              ('656223002_7',
#               [656223002, 'perle_amethyste', 'perle améthyste']),
#              ('656223002_8', [656223002, 'perle_violette', 'perle violette']),
#              ('656223002_9', [656223002, 'perle_rocaille', 'perle rocaille']),
#              ('542807057_1',
#               [542807057,
#                'fil_de_cuivre_plaque_argent',
#                'fil de cuivre plaqué argent']),
#              ('542807057_2', [542807057, 'argent', 'argent']),
#              ('542807057_3',
#               [542807057, 'perles_vegetales', 'perles végétales']),
#              ('542807057_4', [542807057, 'perles_rouge', 'perles rouge']),
#              ('542807057_5', [542807057, 'fil_de_soie', 'fil de soie']),
#              ('542807057_6', [542807057, 'breloque', 'breloque']),
#              ('542807057_7', [542807057, 'plumes', 'plumes']),
#              ('542807057_8', [542807057, 'marque_page', 'marque page']),
#              ('643389672_1', [643389672, 'bronze', 'bronze']),
#              ('643389672_2', [643389672, 'glass', 'glass']),
#              ('643389672_3', [643389672, 'copper', 'copper']),
#              ('542806157_1', [542806157, 'bronze', 'bronze']),
#              ('542806157_2', [542806157, 'brass', 'brass']),
#              ('542806157_3', [542806157, 'glass', 'glass']),
#              ('494809885_1',
#               [494809885, 'breloques_argile', 'breloques argile']),
#              ('494809885_2',
#               [494809885, 'argile_polymere', 'argile polymere']),
#              ('494809885_3', [494809885, 'fimo', 'fimo']),
#              ('494809885_4', [494809885, 'cernit', 'cernit']),
#              ('494809885_5',
#               [494809885, 'mousqueton_inox', 'mousqueton inox']),
#              ('494809885_6', [494809885, 'porte_cle', 'porte clé']),
#              ('494809885_7', [494809885, 'breloque_coeur', 'breloque coeur']),
#              ('494809885_8', [494809885, 'imitation_cuir', 'imitation cuir']),
#              ('494809885_9', [494809885, 'perle_ronde', 'perle ronde']),
#              ('494809885_10', [494809885, 'perle_tube', 'perle tube']),
#              ('513498058_1', [513498058, 'bronze', 'bronze']),
#              ('513498058_2', [513498058, 'stone', 'stone']),
#              ('513498058_3', [513498058, 'copper', 'copper']),
#              ('657477556_1', [657477556, 'stone', 'stone']),
#              ('657477556_2', [657477556, 'copper', 'copper']),
#              ('627844942_1', [627844942, 'fil_de_fer', 'fil de fer']),
#              ('627844942_2', [627844942, 'fil_recuit', 'fil recuit']),
#              ('627844942_3', [627844942, 'fil_noir', 'fil noir']),
#              ('627844942_4',
#               [627844942, 'fil_de_fer_noir', 'fil de fer noir']),
#              ('513139201_1',
#               [513139201, 'fil_de_cuivre_naturel', 'fil de cuivre naturel']),
#              ('513139201_2', [513139201, 'perle_de_verre', 'perle de verre']),
#              ('513139201_3', [513139201, 'perles_vertes', 'perles vertes']),
#              ('513139201_4',
#               [513139201, 'pampilles_verre', 'pampilles verre']),
#              ('513139201_5', [513139201, 'fil_inox', 'fil inox']),
#              ('513139201_6', [513139201, 'breloques', 'breloques']),
#              ('476073994_1', [476073994, 'silver', 'silver']),
#              ('476073994_2', [476073994, 'ceramic', 'ceramic']),
#              ('476073994_3', [476073994, 'copper', 'copper']),
#              ('475600550_1',
#               [475600550, 'stainless_steel', 'stainless steel']),
#              ('475600550_2', [475600550, 'silver', 'silver']),
#              ('475600550_3', [475600550, 'steel', 'steel']),
#              ('475600550_4', [475600550, 'ceramic', 'ceramic']),
#              ('475600550_5', [475600550, 'copper', 'copper']),
#              ('671321829_1', [671321829, 'verre_de_mer', 'verre de mer']),
#              ('671321829_2',
#               [671321829, 'perles_verre_rouge', 'perles verre rouge']),
#              ('671321829_3', [671321829, 'perles_sablees', 'perles sablées']),
#              ('671321829_4', [671321829, 'perles_argent', 'perles argent']),
#              ('671321829_5',
#               [671321829, 'mousqueton_inox', 'mousqueton inox']),
#              ('671321625_1', [671321625, 'verre', 'verre']),
#              ('671321625_2', [671321625, 'verre_de_mer', 'verre de mer']),
#              ('671321625_3', [671321625, 'breloque', 'breloque']),
#              ('671321625_4', [671321625, 'marque_page', 'marque page']),
#              ('671321625_5', [671321625, 'metal_argente', 'métal argenté']),
#              ('542812707_1', [542812707, 'stone', 'stone']),
#              ('542812707_2', [542812707, 'copper', 'copper']),
#              ('542812117_1', [542812117, 'bronze', 'bronze']),
#              ('542812117_2', [542812117, 'glass', 'glass']),
#              ('542812117_3', [542812117, 'copper', 'copper']),
#              ('542809495_1', [542809495, 'silver', 'silver']),
#              ('542809495_2', [542809495, 'glass', 'glass']),
#              ('542806659_1', [542806659, 'bronze', 'bronze']),
#              ('542806659_2', [542806659, 'glass', 'glass']),
#              ('542806659_3', [542806659, 'ceramic', 'ceramic']),
#              ('542806659_4', [542806659, 'copper', 'copper']),
#              ('529209179_1', [529209179, 'bronze', 'bronze']),
#              ('529209179_2', [529209179, 'brass', 'brass']),
#              ('529209179_3', [529209179, 'glass', 'glass']),
#              ('529006572_1', [529006572, 'copper', 'copper']),
#              ('529006572_2', [529006572, 'stone', 'stone']),
#              ('529006572_3', [529006572, 'bronze', 'bronze']),
#              ('480589834_1', [480589834, 'bronze', 'bronze']),
#              ('480589834_2', [480589834, 'glass', 'glass']),
#              ('480589834_3', [480589834, 'copper', 'copper']),
#              ('474365340_1', [474365340, 'bronze', 'bronze']),
#              ('474365340_2', [474365340, 'leather', 'leather']),
#              ('474365340_3', [474365340, 'stone', 'stone']),
#              ('474365340_4', [474365340, 'copper', 'copper']),
#              ('474365340_5', [474365340, 'turquoise', 'turquoise']),
#              ('648765880_1', [648765880, 'fil_de_cuivre', 'fil de cuivre']),
#              ('648765880_2', [648765880, 'fil_enroule', 'fil enroulé']),
#              ('648765880_3', [648765880, 'wire_wrap', 'wire wrap']),
#              ('648765880_4', [648765880, 'wire_wrapped', 'wire wrapped']),
#              ('648765880_5', [648765880, 'cuivre_naturel', 'cuivre naturel']),
#              ('648765880_6',
#               [648765880, 'perles_pierre_rondes', 'perles pierre rondes']),
#              ('648765880_7', [648765880, 'jaspe_rose', 'jaspe rose']),
#              ('648765880_8',
#               [648765880, 'pierre_de_jaspe', 'pierre de jaspe']),
#              ('542809153_1', [542809153, 'copper', 'copper']),
#              ('529002648_1', [529002648, 'copper', 'copper']),
#              ('452554380_1', [452554380, 'fimo', 'fimo']),
#              ('452554380_2',
#               [452554380, 'argile_polymere', 'argile polymère']),
#              ('452554380_3',
#               [452554380, 'mousqueton_bronze', 'mousqueton bronze']),
#              ('452554380_4', [452554380, 'fil_de_laiton', 'fil de laiton']),
#              ('452554380_5', [452554380, 'plume_pintade', 'plume pintade']),
#              ('452554380_6',
#               [452554380, 'plume_naturelle', 'plume naturelle']),
#              ('452554380_7',
#               [452554380, 'breloque_feuille', 'breloque feuille']),
#              ('657471618_1', [657471618, 'silver', 'silver']),
#              ('657471618_2',
#               [657471618, 'stainless_steel', 'stainless steel']),
#              ('657471618_3', [657471618, 'steel', 'steel']),
#              ('490171299_1', [490171299, 'silver', 'silver']),
#              ('490171299_2',
#               [490171299, 'stainless_steel', 'stainless steel']),
#              ('490171299_3', [490171299, 'faux_leather', 'faux leather']),
#              ('490171299_4', [490171299, 'leather', 'leather']),
#              ('490171299_5', [490171299, 'steel', 'steel']),
#              ('542807665_1', [542807665, 'brass', 'brass']),
#              ('542807665_2', [542807665, 'stone', 'stone']),
#              ('542807665_3', [542807665, 'moonstone', 'moonstone']),
#              ('501501800_1', [501501800, 'brass', 'brass']),
#              ('501501800_2', [501501800, 'stone', 'stone']),
#              ('501501800_3', [501501800, 'bronze', 'bronze']),
#              ('280709792_1', [280709792, 'copper', 'copper']),
#              ('280709792_2', [280709792, 'bronze', 'bronze']),
#              ('280709792_3', [280709792, 'ceramic', 'ceramic']),
#              ('280059352_1', [280059352, 'copper', 'copper']),
#              ('280059352_2', [280059352, 'ceramic', 'ceramic']),
#              ('642179681_1', [642179681, 'fil_de_fer', 'fil de fer']),
#              ('642179681_2', [642179681, 'fil_recuit', 'fil recuit']),
#              ('642179681_3', [642179681, 'fil_noir', 'fil noir']),
#              ('642179681_4',
#               [642179681, 'fil_de_fer_noir', 'fil de fer noir']),
#              ('529001472_1', [529001472, 'brass', 'brass']),
#              ('529001472_2', [529001472, 'stone', 'stone']),
#              ('529001472_3', [529001472, 'copper', 'copper']),
#              ('697325089_1', [697325089, 'fil_de_fer', 'fil de fer']),
#              ('697325089_2', [697325089, 'fil_recuit', 'fil recuit']),
#              ('697325089_3', [697325089, 'fil_noir', 'fil noir']),
#              ('697325089_4',
#               [697325089, 'fil_de_fer_noir', 'fil de fer noir']),
#              ('697325089_5', [697325089, 'acier_noir', 'acier noir']),
#              ('727085045_1', [727085045, 'breloque', 'breloque']),
#              ('727085045_2', [727085045, 'marque_page', 'marque page']),
#              ('727085045_3',
#               [727085045,
#                'marque_page_metal_plume',
#                'marque page metal plume']),
#              ('727085045_4',
#               [727085045, 'coquillage_naturel', 'coquillage naturel']),
#              ('727085045_5', [727085045, 'chaine', 'chaine']),
#              ('727085045_6',
#               [727085045,
#                'breloque_papillon_argente',
#                'breloque papillon argenté']),
#              ('590344172_1', [590344172, 'glass', 'glass']),
#              ('590344172_2', [590344172, 'amethyst', 'amethyst']),
#              ('590344172_3', [590344172, 'steel', 'steel']),
#              ('590344172_4', [590344172, 'silver', 'silver']),
#              ('590344172_5', [590344172, 'stone', 'stone']),
#              ('542809303_1', [542809303, 'silver', 'silver']),
#              ('542809303_2', [542809303, 'glass', 'glass']),
#              ('542809303_3', [542809303, 'copper', 'copper']),
#              ('631622851_1', [631622851, 'silver', 'silver']),
#              ('631622851_2', [631622851, 'glass', 'glass']),
#              ('631622851_3', [631622851, 'copper', 'copper']),
#              ('710605696_1', [710605696, 'cuivre_naturel', 'cuivre naturel']),
#              ('710605696_2',
#               [710605696, 'perles_de_verre', 'perles de verre']),
#              ('710605696_3', [710605696, 'perles_rouges', 'perles rouges']),
#              ('710605696_4',
#               [710605696, 'perles_transparentes', 'perles transparentes']),
#              ('710605696_5', [710605696, 'perles_bleues', 'perles bleues']),
#              ('710605696_6', [710605696, 'plumes', 'plumes']),
#              ('710605696_7', [710605696, 'perles_de_bois', 'perles de bois']),
#              ('710605696_8',
#               [710605696, 'breloque_oiseau', 'breloque oiseau']),
#              ('710605696_9', [710605696, 'perles_cristal', 'perles cristal']),
#              ('710605696_10',
#               [710605696, 'pampilles_verre', 'pampilles verre']),
#              ('710605696_11',
#               [710605696, 'perles_multicolores', 'perles multicolores']),
#              ('710132856_1', [710132856, 'bone__horn', 'bone  horn']),
#              ('710132856_2', [710132856, 'bronze', 'bronze']),
#              ('710132856_3', [710132856, 'copper', 'copper']),
#              ('710132856_4', [710132856, 'wood', 'wood']),
#              ('636668084_1', [636668084, 'fil_de_fer', 'fil de fer']),
#              ('636668084_2', [636668084, 'fil_recuit', 'fil recuit']),
#              ('636668084_3', [636668084, 'fil_noir', 'fil noir']),
#              ('636668084_4',
#               [636668084, 'fil_de_fer_noir', 'fil de fer noir']),
#              ('636668084_5', [636668084, 'acier_noir', 'acier noir']),
#              ('599878975_1', [599878975, 'stone', 'stone']),
#              ('599878975_2', [599878975, 'copper', 'copper']),
#              ('599878975_3', [599878975, 'quartz', 'quartz']),
#              ('721007367_1', [721007367, 'fil_de_fer', 'fil de fer']),
#              ('721007367_2', [721007367, 'fil_recuit', 'fil recuit']),
#              ('721007367_3', [721007367, 'fil_noir', 'fil noir']),
#              ('721007367_4',
#               [721007367, 'fil_de_fer_noir', 'fil de fer noir']),
#              ('721007367_5', [721007367, 'acier_noir', 'acier noir']),
#              ('721007367_6', [721007367, 'calligraphie', 'calligraphie']),
#              ('584719156_1', [584719156, 'silver', 'silver']),
#              ('584719156_2', [584719156, 'faux_leather', 'faux leather']),
#              ('584719156_3', [584719156, 'stone', 'stone']),
#              ('584719156_4', [584719156, 'copper', 'copper']),
#              ('706703594_1', [706703594, 'breloque', 'breloque']),
#              ('706703594_2', [706703594, 'marque_page', 'marque page']),
#              ('706703594_3',
#               [706703594,
#                'marque_page_metal_plume',
#                'marque page metal plume']),
#              ('706703594_4', [706703594, 'perles_bleues', 'perles bleues']),
#              ('706703594_5',
#               [706703594, 'breloque_rose_bronze', 'breloque rose bronze']),
#              ('706703594_6',
#               [706703594, 'coquillage_naturel', 'coquillage naturel']),
#              ('706703594_7', [706703594, 'chaine', 'chaine']),
#              ('671321673_1', [671321673, 'bronze', 'bronze']),
#              ('671321673_2', [671321673, 'stone', 'stone']),
#              ('671321673_3', [671321673, 'copper', 'copper']),
#              ('671321673_4', [671321673, 'silver', 'silver']),
#              ('671321673_5', [671321673, 'aluminum', 'aluminum']),
#              ('716808501_1',
#               [716808501, 'perles_de_verre', 'perles de verre']),
#              ...])

# %%
dict_final = OrderedDict()

# %%
for (key, row) in data_dict.items() :
    id_listing = row[0]
    key_texte = row[1]
    translated_texte = dic_uniques_lem[key_texte][0]
    lemmanized_texte = dic_uniques_lem[key_texte][1]
    dict_final[key] = [id_listing, key_texte, translated_texte, lemmanized_texte]

# %%
data_final = []

# %%
idx = 0
for (key, row) in dict_final.items():
    data_final.append(row)
    idx = idx + 1

# %%
df = pd.DataFrame(data_final, columns=['id_listing', 'key_texte', 'translated_texte', 'lemmanized_texte'])

# %%
df.head()
# Out:
#    id_listing   key_texte translated_texte lemmanized_texte
# 0   743909687       laine             wool             wool
# 1   743909687      mohair           mohair           mohair
# 2   743909687        soie             silk             silk
# 3   743909687  pure_laine        pure wool             wool
# 4   742464511       laine             wool             wool

# %%
df.to_csv(OUTPUT_FOLDER + 'df_final.csv')

# %%
import pickle
import pandas as pd
from collections import OrderedDict
import spacy
nlp = spacy.load('en')

# %%
df = pd.read_excel('_data/uniques_translate_final.xlsx')

# %%
noisy_pos_tags = ["PROP","DET","PART","CCONJ","ADP","PRON","VERB","ADJ"]
min_token_length = 2 # minimum token length to remove

# %%
def is_noise(token):
    '''
    standard way to validate spacy tokens
    This method validate all the passed tokens and set true false on it
    '''
    is_noise = False
    if token.pos_ in noisy_pos_tags:
        is_noise = True
    elif token.is_stop == True:
        is_noise = True
    elif token.is_digit == True:
        is_noise = True
    elif token.is_space == True:
        is_noise = True
    elif len(token.string) <= min_token_length:
        is_noise = True
    return is_noise

# %%
def lemmanize(string):
    result_tempo = []
    nlp_words = nlp(string)
    for word in nlp_words:
        if not is_noise(word):
            result_tempo.append(word.lemma_)
    if len(result_tempo) > 0:
        return ' '.join(result_tempo)
    else:
        return ''

# %%
dic_translated = dict()

# %%
for index, row in df.iterrows():
    dic_translated[row.key] = row.en

# %%
dic_translated
# Out:
# {'simili_cuir': 'leatherette',
#  'polaire': 'polar',
#  'lin': 'linen',
#  'lin_enduit': 'coated linen',
#  'coton_enduit': 'coated cotton',
#  'suedine': 'suede',
#  'lapis_lazuli': 'lapis lazuli',
#  'cosses': 'thimbles',
#  'sarrasin': 'buckwheat',
#  'flocons_de_fibres_de_polyester': 'flakes of polyester fibers',
#  'rembourrage_de_flocons_de_fibres_de_polyester': 'padding of polyester fiber flakes',
#  'flocons_fibres_de_polyester': 'polyester fiber flakes',
#  'giclee_print': 'giclée print',
#  'heavy_cotton_moulin_du_roy_paper': 'heavy cotton moulin du roy paper',
#  'moulin_du_roy_heavy_cotton_paper': 'roy heavy cotton paper mill',
#  'heavy_cotton_moulin_de_roy_paper': 'heavy cotton roy paper mill',
#  'moulin_du_roy_cotton_paper': 'mill of roy cotton paper',
#  'moulin_du_roy_paper': 'moulin du roy paper',
#  'verre_file': 'spun glass',
#  'verre_de_murano': 'Murano glass',
#  'verre': 'glass',
#  'cuivre': 'copper',
#  'pierre': 'Pierre',
#  'pierre_fine': 'fine stone',
#  'gemme': 'gem',
#  'pierre_de_gemme': 'gemstone',
#  'perle_turquoise': 'turquoise bead',
#  'bouton': 'button',
#  'verre_file_au_chalumeau': 'torch-blown glass',
#  'pendentif': 'pendant',
#  'perles_venitiennes': 'Venetian pearls',
#  'rocaille': 'rockery',
#  'caoutchouc': 'rubber',
#  'metal': 'metal',
#  'papier': 'paper',
#  'coton_bio': 'organic cotton',
#  'cuir': 'leather',
#  'laiton': 'brass',
#  'laiton_dore': 'golden brass',
#  'cristal_swarovski': 'swarovski crystal',
#  'pate_polymere': 'polymer clay',
#  'poudre_metallique': 'metal powder',
#  'fil_aluminium': 'aluminum wire',
#  'perles': 'beads',
#  'tissu_enduit': 'coated fabric',
#  'tissu_coton': 'cotton fabric',
#  'enduit': 'coating',
#  'fermeture_eclair': 'zipper',
#  'tissu': 'fabric',
#  'bambou': 'bamboo',
#  'erable_naturel': 'natural maple',
#  'erable': 'maple',
#  'bois': 'wood',
#  'tissu_coton_oeko_tex': 'cotton fabric oeko tex',
#  'non_traite': 'untreated',
#  'tissu_oeko_tex': 'oeko tex fabric',
#  'bois_naturel': 'natural wood',
#  'biais': 'angle',
#  'elastique': 'elastic',
#  'eponge_de_bambou': 'bamboo sponge',
#  'epnge_de_bambou': 'bamboo sponges',
#  'coton_liberty': 'Liberty cotton',
#  'bouton_pression_kam': 'kam snap button',
#  'eponge': 'sponge',
#  'chaine': 'chain',
#  'perle': 'pearl',
#  'inoxydable': 'stainless',
#  'chaine_inoxydable': 'stainless chain',
#  'acier_inoxydable': 'stainless steel',
#  'resine': 'resin',
#  'ficelle_de_chanvre': 'hemp twine',
#  'papier_glassine': 'glassine paper',
#  'papier_de_riz': 'rice paper',
#  'papier_washi': 'washi paper',
#  'ficelle': 'string',
#  'papier_vintage': 'vintage paper',
#  'papier_ancien': 'old paper',
#  'livre_ancien': 'old book',
#  'plastique': 'plastic',
#  'liege': 'cork',
#  'petales': 'petals',
#  'lavande': 'lavender',
#  'paillettes': 'flakes',
#  'fil': 'wire',
#  'chanvre': 'hemp',
#  'papier_200g_sans_acides': '200g paper without acids',
#  'fleurs_sechees': 'dried flowers',
#  'polystyrene': 'polystyrene',
#  'feuille_or': 'gold leaf',
#  'cordon_en_coton': 'cotton cord',
#  'feuille_argent': 'silver leaf',
#  'pigments_mineraux': 'mineral pigments',
#  'toogle_plaque_argent': 'silver plated togo',
#  'toggle_plaque_argent': 'silver plated toggle',
#  'cire_abeille': 'bee wax',
#  'cire_d_abeille': 'beeswax',
#  'cire': 'wax',
#  'abeille': 'bee',
#  'abeilles': 'bees',
#  'cire_abeilles': 'wax bees',
#  'naturelle': 'natural',
#  'amethyste': 'amethyst',
#  'perles_de_rocaille': 'seed beads',
#  'pierre_taillee': 'chipped stone',
#  'pointe_de_fleche': 'Arrowhead',
#  'silex': 'flint',
#  'perles_de_rocailles': 'seed beads',
#  'chaine_de_strass': 'chain of rhinestones',
#  'strass': 'strass',
#  'chaine_email': 'enamel chain',
#  'silk_charmeuse': 'charming silk',
#  'dentelle': 'lace',
#  'mousseline': 'muslin',
#  'silk_mousseline': 'silk chiffon',
#  'cuir_brut': 'rawhide',
#  'acier_zingue': 'galvanized steel',
#  'acier': 'steel',
#  'etain': 'tin',
#  'soudure': 'welding',
#  'soudures': 'welds',
#  'patine': 'patina',
#  'miroir': 'mirror',
#  'contemporain': 'contemporary',
#  'mariage': 'wedding',
#  'cadeau': 'gift',
#  'lampe': 'lamp',
#  'mini_serre': 'mini greenhouse',
#  'vitrail': 'stained glass',
#  'fait_main': 'handmade',
#  'dore': 'golden',
#  'attrape_soleil': 'catches sun',
#  'geometrique': 'geometric',
#  'bougeoirs': 'candlesticks',
#  'boite_a_bagues': 'ring box',
#  'plante': 'plant',
#  'verre_glass': 'glass glass',
#  'patines': 'patinas',
#  'cristal': 'crystal',
#  'verre_colore': 'colored glass',
#  'fanions': 'pennants',
#  'decoration': 'decoration',
#  'pic': 'peak',
#  'verre_vert': 'green glass',
#  'boite': 'box',
#  'tissus': 'tissues',
#  'bougie': 'candle',
#  'brillant': 'bright',
#  'geometrie': 'geometry',
#  'guirlande': 'garland',
#  'decoration_sapin': 'fir decoration',
#  'decoration_mur': 'wall decoration',
#  'decor_mur': 'wall decor',
#  'soja': 'soy',
#  'aile_papillon': 'butterfly wing',
#  'cuivre_copper': 'copper copper',
#  'acetate': 'acetate',
#  'suede': 'Sweden',
#  'papier_photo_210_gr': '210 gr photo paper',
#  'papier_170_gr': '170 gr paper',
#  'papier_photo_210gr': 'photo paper 210gr',
#  'papier_photo_epais_210_gr': '210 gr thick photo paper',
#  'papier_90gr': '90gr paper',
#  'papier_210_gr': '210 gr paper',
#  'papier_90_gr': '90 gr paper',
#  'papier_170gr': '170gr paper',
#  'papier_photo': 'photo paper',
#  'fil_de_fer': 'wire',
#  'feuilles_de_papier': 'sheets of paper',
#  'socle_en_bois_massif': 'solid wood pedestal',
#  'poule': 'hen',
#  'fil_de_fer_de_vigne': 'wire of vine',
#  'laine': 'wool',
#  'parfum': 'perfume',
#  'amarante': 'amaranth',
#  'noix': 'nuts',
#  'noix_de_banksia': 'banksia nuts',
#  'qualite': 'quality',
#  'dore_a_l_or_fin_14k': '14k gold gilded',
#  'soleil_bleu': 'blue sun',
#  'grenat': 'garnet',
#  'pierre_semi_precieuse': 'semi-precious stone',
#  'howlite_blanche_et_grise': 'white and gray howlite',
#  'dore_a_l_or_fin': 'gilded with fine gold',
#  'cordon_plat_de_liege': 'flat cord of cork',
#  'perles_de_fossile': 'fossil beads',
#  'fossile_poli': 'polished fossil',
#  'bois_de_coco': 'coconut wood',
#  'rocailles_de_couleur': 'colored rockeries',
#  'copeaux_de_liege': 'cork chips',
#  'liege_veritable': 'real cork',
#  'matieres_naturelles': 'natural materials',
#  'rocailles': 'rockeries',
#  'morceaux_de_liege': 'pieces of cork',
#  'materiau_hypoallergeniques': 'hypoallergenic material',
#  'tissus_liberty': 'liberty fabrics',
#  'jaspes': 'jasper',
#  'cordon_de_cuir_fin': 'fine leather cord',
#  'cuir_brun': 'brown leather',
#  'perles_rondes': 'round pearls',
#  'perles_de_turquoise': 'turquoise beads',
#  'perles_en_bois': 'wooden beads',
#  'perles_naturelles': 'natural pearls',
#  'non_teint': 'undyed',
#  'perles_nacrees': 'pearly pearls',
#  'perles_de_fossile_8mm': '8mm fossil beads',
#  'matieres_hypoallergeniques': 'hypoallergenic materials',
#  'acrylique': 'acrylic',
#  'passe_partout': 'master key',
#  'peinture': 'painting',
#  'citrine': 'citrine',
#  'white_topaze': 'white topaz',
#  'carte_postale': 'Post card',
#  'toile': 'canvas',
#  'a_peindre': 'to paint',
#  'ciseaux': 'scissors',
#  'pastel_gras': 'bold pastel',
#  'pastel_a_l_huile': 'oil pastel',
#  'feutre': 'felt',
#  'impermeable': 'raincoat',
#  'imprime': 'printed',
#  'ruban_satin': 'satin ribbon',
#  'metal_dore': 'golden metal',
#  'lucite_transparente': 'transparent lucite',
#  'alliage_cuivre': 'copper alloy',
#  'metal_argente': 'silver plated',
#  'metal_bronze': 'bronze metal',
#  'metal_bronze_dore': 'gilded bronze metal',
#  'email_rouge': 'red enamel',
#  'nacre_naturelle': 'natural mother-of-pearl',
#  'plaque_or': 'gold plated',
#  'fils_de_couleur': 'colored thread',
#  'ceramique_peinte_vernie': 'varnished painted ceramic',
#  'metal_vert': 'green metal',
#  'argent_tibetain': 'Tibetan silver',
#  'ceramique_emaillee': 'glazed ceramic',
#  'email_bleu': 'blue enamel',
#  'verre_violet': 'purple glass',
#  'verre_taupe': 'taupe glass',
#  'metal_or_vieilli': 'aged gold metal',
#  'metal_leger': 'light metal',
#  'carton_leger': 'light cardboard',
#  'fil_de_coton': 'cotton thread',
#  'metal_bronze_antique': 'antique bronze metal',
#  'plaque_argent': 'silver plated',
#  'strass_transparents': 'transparent rhinestones',
#  'tissu_imprime': 'printed fabric',
#  'alliage_couleur_bronze': 'alloy bronze color',
#  'alliage_bronze': 'bronze alloy',
#  'metal_or': 'gold metal',
#  'email': 'E-mail',
#  'metal_argente_clair': 'clear silver metal',
#  'pate_de_verre': 'molten glass',
#  'tulle_dore': 'golden tulle',
#  'tulle_rose_fonce': 'dark pink tulle',
#  'strass_jaunes': 'yellow rhinestones',
#  'metal_emaille': 'enamelled metal',
#  'deux_broches_papillon': 'two butterfly pins',
#  'papier_fort': 'strong paper',
#  'papier_cartonne': 'card stock',
#  'perles_de_verre': 'glass beads',
#  'metal_inox': 'stainless steel',
#  'metal_cuivre': 'copper metal',
#  'resine_naturelle': 'natural resin',
#  'galalithe': 'galalith',
#  'metal_nuance_bronze': 'bronze tone metal',
#  'ceramique': 'ceramic',
#  'fil_argent': 'silver wire',
#  'fil_or': 'gold wire',
#  'terre_cuite_emaillee': 'glazed terracotta',
#  'opalines': 'opaline',
#  'metal_vieil_or': 'old gold metal',
#  'verre_bleu': 'blue glass',
#  'opaline': 'opaline',
#  'tissu_gaufre': 'embossed fabric',
#  'agate_bicolore': 'two-tone agate',
#  'alliage_bronze_sans_nickel': 'nickel-free bronze alloy',
#  'verre_rouge': 'red glass',
#  'nacre': 'pearly',
#  'verre_orange': 'orange glass',
#  'coquillage_sculpte': 'carved shell',
#  'metal_couleur_bronze': 'bronze color metal',
#  'breloques_vertes_anciennes': 'old green charms',
#  'resine_blanche': 'white resin',
#  'coton_cire': 'waxed cotton',
#  'metal_rouge': 'red metal',
#  'perles_sculptee': 'carved beads',
#  'resine_doree': 'golden resin',
#  'fil_coton_et_satin': 'cotton and satin thread',
#  'bronze_dore': 'gilt bronze',
#  'fil_de_coton_satine': 'satin cotton thread',
#  'toile_coton': 'cotton canvas',
#  'ruban': 'ribbon',
#  'lettres_bois': 'wood letters',
#  'joyeux_noel': 'Merry Christmas',
#  'ours_polaire': 'polar bear',
#  'carte_de_voeux': 'wish card',
#  'hibou_noel': 'christmas owl',
#  'chouette_noel': 'christmas owl',
#  'sapin_noel': 'Christmas tree',
#  'cadeau_noel': 'christmas gift',
#  'bonhomme_de_neige': 'snowman',
#  'vernis': 'varnish',
#  'peinture_huile': 'oil painting',
#  'huile_sur_toile': 'oil on canvas',
#  'huile': 'oil',
#  'toile_lin': 'linen canvas',
#  'pastel_sur_papier': 'pastel on paper',
#  'dorure': 'gilding',
#  'peinture_a_huile': 'oil painting',
#  'photographie_vintage': 'vintage photography',
#  'transfert_textile': 'textile transfer',
#  'images_digitales': 'digital images',
#  'images_retro': 'retro images',
#  'fleurs_vintage': 'vintage flowers',
#  'violette': 'violet',
#  'violette_fleur': 'violet flower',
#  'violette_retro': 'retro violet',
#  'violette_vintage': 'vintage violet',
#  'fleur_retro': 'retro flower',
#  'cabochon_oiseaux': 'cabochon birds',
#  'oiseaux': 'birds',
#  'colibri': 'humming-bird',
#  'fleurs_exotiques': 'exotic flowers',
#  'images_a_imprimer': 'images to print',
#  'image_digitale': 'digital image',
#  'cabochon_coeur': 'heart cabochon',
#  'coeur': 'heart',
#  'coeur_retro': 'retro heart',
#  'coeur_vintage': 'vintage heart',
#  'metis': 'metis',
#  'limoges_china': 'limoges china',
#  'orange': 'orange',
#  'raphia': 'raffia',
#  'fleurs_des_champs': 'wildflowers',
#  'coquillage': 'shell',
#  'fleur_de_coton': 'cotton flower',
#  'pierre_de_corail': 'coral stone',
#  'chaine_couleur_bronze': 'bronze color chain',
#  'matiere_naturelle': 'natural material',
#  'graines': 'seeds',
#  'petales_de_fleur_de_coton': 'cotton flower petals',
#  'chardons': 'thistles',
#  'metal_argente_sans_nickel': 'silver metal nickel free',
#  'petale_de_coton': 'cotton petal',
#  'gland_de_chene': 'oak tassel',
#  'limoges': 'limoges',
#  'paris': 'Paris',
#  'fil_de_lin': 'linen thread',
#  'cabochon_en_verre': 'glass cabochon',
#  'metal_couleur_bronzev': 'metal color bronzev',
#  'metal_couleurs_bronze': 'metal bronze colors',
#  'metal_couleur_lbronze': 'metal color lbronze',
#  'rembourrage': 'padding',
#  'magie': 'magic',
#  'hematite': 'hematite',
#  'fil_de_jade': 'jade wire',
#  'fibres_melangees': 'mixed fibers',
#  'lin_et_fibres_melangees': 'linen and mixed fibers',
#  'fabric_coton': 'cotton fabric',
#  'antirouille': 'rustproof',
#  'inox': 'stainless steel',
#  'metallique': 'metallic',
#  'acier_inox': 'stainless steel',
#  'acier_zinc': 'zinc steel',
#  'peridot': 'peridot',
#  'jaspe': 'jasper',
#  'opale_rose': 'pink opal',
#  'rhodium_noir': 'black rhodium',
#  'corail': 'coral',
#  'jaspe_rainforest': 'rainforest jasper',
#  'topaze': 'topaz',
#  'opale_de_feu': 'fire opal',
#  'rembourrage_anti_acarien': 'anti mite padding',
#  'yeux_de_securite': 'safety eyes',
#  'laine_vierge': 'new wool',
#  'peluche_vache_crochet': 'plush cow crochet',
#  'poupee_vache': 'cow doll',
#  'mobile_ferme': 'mobile farm',
#  'guirlande_ferme': 'garland closes',
#  'mobile_animaux': 'mobile animals',
#  'animaux_crochet': 'animal hook',
#  'margault_la_vache': 'margault the cow',
#  'vache_amande_etoilee': 'almond cow etoilee',
#  'peluche_lalylala': 'plush lalylala',
#  'peluche_amande_etoilee': 'stuffed almond star',
#  'cadeau_naissance': 'birth gift',
#  'doudou_bebe': 'baby blanket',
#  'fabrique_en_france': 'Made in France',
#  'perles_bois': 'wood beads',
#  'perles_acai': 'acai beads',
#  'rotin': 'rattan',
#  'vermeil': 'red',
#  'argent_rhodie_et_vermeil': 'rhodium silver and vermeil',
#  'argent_rhodie_925': 'rhodium silver 925',
#  'argent_rhodie': 'rhodium silver',
#  'argent_925_rhodie': '925 silver rhodium',
#  'mohair_pompons': 'mohair pompons',
#  'placage': 'plating',
#  'noyer': 'walnut',
#  'vernis_au_tampon': 'buff varnish',
#  'chene': 'Oak',
#  'ebene': 'ebony',
#  'peuplier': 'poplar',
#  'citronnier': 'lemon',
#  'bois_de_rose': 'Rosewood',
#  'houx': 'holly',
#  'coton_createur': 'creative cotton',
#  'popeline': 'poplin',
#  'bouton_pression': 'snap',
#  'coton_jersey': 'cotton jersey',
#  'jersey_polaire': 'fleece jersey',
#  'pique_de_coton': 'cotton quilted',
#  'boutons': 'buttons',
#  'jersey_vert': 'green jersey',
#  'coton_vert': 'green cotton',
#  'jersey_alpin': 'alpine jersey',
#  'polaire_alpin': 'alpine polar',
#  'flanelle': 'flannel',
#  'boutons_pressions': 'snaps',
#  'boutons_pression': 'snaps',
#  'boutons_bois': 'wood buttons',
#  'coton_chambray': 'chambray cotton',
#  'broderie_anglaise': 'English embroidery',
#  'coton_vichy': 'gingham cotton',
#  'pression': 'pressure',
#  'les_yeux_sur_la_fixation_securisee': 'eyes on secured fixation',
#  'remplisseur': 'filler',
#  'tendresse_et_amour_de_mes_mains': 'tenderness and love of my hands',
#  'remplisseur_antiallergenique': 'antiallergenic filler',
#  'acrylique_special_pour_les_enfants': 'special acrylic for children',
#  'les_yeux_sont_en_securite': 'the eyes are safe',
#  'acrylique_specialement_pour_les_bebes': 'acrylic specially for babies',
#  'ligne': 'line',
#  'fil_de_muline': 'Muline thread',
#  'laine_acrylique': 'acrylic wool',
#  'ouate_synthetique': 'synthetic wadding',
#  'bourrage_synthetique': 'synthetic stuffing',
#  'laine_acrylique_crochet': 'acrylic wool hook',
#  'synthetique': 'synthetic',
#  'cadeau_dauphin': 'dolphin gift',
#  'metal_ton_bronze': 'metal tone bronze',
#  'metal_ton_argente': 'silver tone metal',
#  'image_haute_definition': 'high definition image',
#  'apprets_sans_nickel': 'nickel-free primers',
#  'estampes_argentees': 'silver prints',
#  'cabochons_en_verre': 'glass cabochons',
#  'strass_swarovski': 'swarovski rhinestones',
#  'perles_en_verre': 'glass beads',
#  'acrylique_sur_toile': 'acrylic on canvas',
#  'technique_mixte': 'technique Mixte',
#  'crayon_sur_papier': 'pencil on paper',
#  'encre': 'ink',
#  'lin_melange': 'mixed linen',
#  'encre_de_chine': 'Chinese ink',
#  'crayons_de_couleur': 'colouring pencils',
#  'dessin': 'drawing',
#  'couleurs': 'colors',
#  'couleur': 'color',
#  'noir': 'black',
#  'numerique': 'digital',
#  'crayons_de_couleurs': 'colored pencils',
#  'peinture_acrylique': 'acrylic paint',
#  'texte': 'text',
#  'aventure': 'adventure',
#  'neige': 'snow',
#  'soleil': 'Sun',
#  'papiers': 'papers',
#  'etoiles': 'stars',
#  'terre': 'Earth',
#  'univers': 'universe',
#  'lumiere': 'light',
#  'note_de_musique': 'music note',
#  'melodie': 'melody',
#  'poesie': 'poetry',
#  'colle': 'glue',
#  'enfance': 'childhood',
#  'beurres_vegetaux_vierges_et_bio': 'virgin and organic vegetable butters',
#  'huiles_vegetales_extra_vierges_bio': 'organic extra virgin vegetable oils',
#  'peinture_verte': 'green paint',
#  'corne': 'horn',
#  'corne_de_zebu': 'zebu horn',
#  'soie': 'silk',
#  'perles_de_tahiti': 'Tahitian pearls',
#  'perle_de_tahiti': 'pearl of tahiti',
#  'perle_de_culture': 'cultured pearl',
#  'perles_de_culture': 'cultured pearls',
#  'eponge_bambou': 'bamboo sponge',
#  'tissus_bambou': 'bamboo fabrics',
#  'bambou_ecologique': 'ecological bamboo',
#  'motifs_ananas': 'pineapple motifs',
#  'tissu_en_coton': 'cotton fabric',
#  'tissus_motifs_ananas': 'pineapple patterned fabrics',
#  'bambou_reutilisables': 'reusable bamboo',
#  'simili_dore': 'golden imitation',
#  'coton_rose_poudre': 'pink powdered cotton',
#  'toile_de_lin': 'linen',
#  'molletonnee': 'fleece',
#  'lin_naturel': 'natural linen',
#  'ouatine': 'padded',
#  'serviettes_bambou': 'bamboo towels',
#  'coton_japonais': 'Japanese cotton',
#  'simili_paillette': 'faux glitter',
#  'simili_bleu': 'blue imitation',
#  'tissu_en_lin': 'linen fabric',
#  'bouton_en_bois': 'wooden button',
#  'coton_de_lin': 'linen cotton',
#  'tissus_japonais': 'Japanese fabrics',
#  'coton_noir': 'black cotton',
#  'tissus_liege': 'cork fabrics',
#  'tissus_coton': 'cotton fabrics',
#  'cuir_de_liege': 'cork leather',
#  'cuir_vegane': 'vegan leather',
#  'liege_vegane': 'vegan cork',
#  'liege_naturel': 'natural cork',
#  'fermeture_tourniquet': 'turnstile closure',
#  'mousquetons_laiton': 'brass carabiners',
#  'cuir_vegetal': 'vegetable leather',
#  'cuir_ananas': 'pineapple leather',
#  'cuir_pinatex': 'piñatex leather',
#  'liege_portugais': 'Portuguese cork',
#  'molleton': 'duffel',
#  'tissus_petits_pois': 'pea tissue',
#  'coton_rouge': 'red cotton',
#  'coton_fuchsia': 'fuchsia cotton',
#  'coton_beige': 'beige cotton',
#  'anneau_en_plastique': 'plastic ring',
#  'cotes_de_velours': 'velvet sides',
#  'bord_cotes': 'edge ratings',
#  'tissus_velours': 'velvet fabrics',
#  'motifs_leopard': 'leopard patterns',
#  'coton_gris': 'gray cotton',
#  'tissus_pingouins': 'penguin fabrics',
#  'cuir_ecologique': 'ecological leather',
#  'bord_cotes_extensibl': 'extensibility rating',
#  'sweat_gris': 'gray sweatshirt',
#  'sweat_bouclettes': 'curly sweatshirt',
#  'bord_cote': 'score board',
#  'cuir_liege': 'Cork leather',
#  'tissus_motifs_vagues': 'wave patterned fabrics',
#  'liege_marron': 'brown cork',
#  'motifs_japonais': 'japanese motifs',
#  'tissus_africain': 'African fabrics',
#  'eponge_microfibre': 'microfiber sponge',
#  'tissus_wax': 'wax fabrics',
#  'tissu_japonais': 'japanese fabric',
#  'suedine_taupe': 'suede taupe',
#  'suedine_beige': 'suede beige',
#  'anasoha_argente': 'anasoha silver',
#  'coton_asanoha': 'asanoha cotton',
#  'liege_bordeaux': 'bordeaux cork',
#  'coton_emeraude': 'emerald cotton',
#  'toile_ethique': 'ethical web',
#  'suedine_noir': 'black suede',
#  'tissus_fuchsia': 'fuchsia fabrics',
#  'simili_paillettes': 'glitter',
#  'simili_fuchsia': 'imitation fuchsia',
#  'tissus_suedine': 'suede fabric',
#  'bouton_magnetique': 'magnetic button',
#  'coton_a_colorier': 'cotton coloring',
#  'tissus_a_colorier': 'coloring material',
#  'sac_en_coton': 'cotton bag',
#  'coton_blanc': 'white cotton',
#  'coton_lin': 'cotton linen',
#  'toile_de_coton': 'cotton canvas',
#  'satin_cuivre': 'copper satin',
#  'coton_jaune': 'yellow cotton',
#  'simili_cuir_noir': 'black leatherette',
#  'tissus_ethniques': 'ethnic fabrics',
#  'coton_ethniques': 'ethnic cotton',
#  'tissus_ameublement': 'upholstery fabrics',
#  'ameublement_ethnique': 'ethnic furnishings',
#  'tissus_lin': 'linen fabrics',
#  'faux_cuir': 'imitation leather',
#  'graphisme': 'graphics',
#  'creation_textile': 'textile creation',
#  'fermoir_metal': 'metal clasp',
#  'boules_de_couleur': 'colored balls',
#  'cousu_main': 'hand sewn',
#  'modele_original': 'original model',
#  'dessin_personnel': 'personal drawing',
#  'graphisme_inedit': 'unusual graphic design',
#  'graphisme_exclusif': 'exclusive graphics',
#  'impression_professionnelle': 'professional printing',
#  'artisanat': 'craft',
#  'tissu_haut_de_gamme': 'high-end fabric',
#  'qualite_professionnelle': 'professional quality',
#  'dessin_exclusif': 'exclusive design',
#  'papier_ilford': 'ilford paper',
#  'encres_pigmentees': 'pigmented inks',
#  'tissu_unique': 'unique fabric',
#  'illustration_personnelle': 'personal illustration',
#  'encres_professionnelles': 'professional inks',
#  'dessin_original': 'original drawing',
#  'graphisme_original': 'original graphics',
#  'impression_artisanale': 'craft printing',
#  'encres': 'inks',
#  'toucher_veloute': 'velvety touch',
#  'portrait_feminin': 'female portrait',
#  'creation_andi_lee': 'creation andi lee',
#  'acier_galvanise': 'galvanized steel',
#  'galvanise': 'galvanized',
#  'lycopode': 'lycopodium',
#  'polyamide': 'polyamide',
#  'agneau': 'lamb',
#  'oeil_de_tigre': 'Eye of tiger',
#  'argente': 'silver',
#  'porcelaine_froide': 'cold porcelain',
#  'pate_a_mais': 'corn dough',
#  'pate_a_modeler': 'modeling clay',
#  'filigrane': 'watermark',
#  'antique_sevres_france_rabbit': 'antique sevres france rabbit',
#  'handpainted_sevres': 'handpainted sevres',
#  'sevres_mnf_france_backstamp': 'sevres mnf france backstamp',
#  'antique_domed_limoges_ceramic_panel': 'antique domed limoges ceramic panel',
#  'hand_painted_limoges_ceramic': 'hand painted limoges ceramic',
#  'limoges_ceramic_pot': 'limoges ceramic pot',
#  'antique_limoges_enamel': 'antique limoges enamel',
#  'antique_brass_fleur_de_lys_decoration': 'antique brass fleur de lys decoration',
#  'limoges_roundel': 'limoges roundel',
#  'limoges_ceramic_panel': 'limoges ceramic panel',
#  'jesus_christ': 'Jesus Christ',
#  'painted_and_decorated_silk_jesus_christ': 'painted and decorated silk jesus christ',
#  'metal_label_marked_paris': 'metal label marked paris',
#  'signed_l_gilles': 'signed l gilles',
#  'cloisonne_enamels': 'cloisonne enamels',
#  'french_bronze_jesus_christ': 'french bronze jesus christ',
#  'paris_france_art_nouveau_dish': 'paris france art nouveau dish',
#  'antique_opaline_glass': 'antique opaline glass',
#  'hand_painted_portrait_on_limoges_panel': 'hand painted portrait on limoges panel',
#  'antique_french_fonte_d_art': 'antique french art',
#  'solid_paris_pewter': 'solid paris pewter',
#  'signed_h_huppe': 'signed h huppe',
#  'peau_de_mouton': "sheep's skin",
#  'peaux_lainees': 'woolly skins',
#  'fourrure': 'fur',
#  'peau_lainee': 'lined skin',
#  'peaux_de_mouton': 'sheepskins',
#  'peaux_lainees_naturelles_haut_de_gamme': 'high quality natural wool skin',
#  'cuir_de_veau': 'calfskin',
#  'cuir_de_chevre': 'goat leather',
#  'cuir_metallise': 'metallic leather',
#  'cuir_reconstitue': 'reconstituted leather',
#  'cuir_veritable': 'real leather',
#  'cuir_de_poisson': 'fish leather',
#  'cuir_de_truite': 'trout leather',
#  'pierre_de_lune': 'moon stone',
#  'laiton_nickele': 'nickel-plated brass',
#  'cuir_autruche': 'ostrich leather',
#  'cuir_exotique': 'exotic leather',
#  'cuir_de_serpent': 'snake leather',
#  'tannage_vegetal': 'vegetable tanning',
#  'tanne_vegetal': 'vegetable tanned',
#  'cuir_agneau': 'leather lambskin',
#  'metal_nickele': 'nickel-plated metal',
#  'cuir_tanne_vegetal': 'vegetable tanned leather',
#  'veau_facon_croco': 'crocodile-style calf',
#  'cuir_de_porc': 'pork leather',
#  'papier_lavable': 'washable paper',
#  'cuir_de_saumon': 'salmon leather',
#  'cuir_de_veau_facon_croco': 'croc-style calfskin',
#  'cuir_autruche_violet': 'purple ostrich leather',
#  'cuir_autruche_veritable': 'real ostrich leather',
#  'coton_fabric': 'cotton fabric',
#  'bille': 'ball',
#  'pompon': 'pompon',
#  'fiole': 'flask',
#  'cercle_metal': 'metal circle',
#  'cordelette': 'cord',
#  'cordon_coton': 'cotton cord',
#  'pierres': 'stone',
#  'perles_ceramique': 'ceramic beads',
#  'simili': 'faux',
#  'cordelette_coton': 'cotton cord',
#  'feutrine': 'Felt',
#  'fil_polyester': 'polyester thread',
#  'adhesif': 'adhesive',
#  'laine_bouillie': 'boiled wool',
#  'perle_de_bois': 'wood bead',
#  'velours_coton': 'cotton velvet',
#  'gants_laine_noire_brodee': 'embroidered black wool gloves',
#  'gants_mitaines_en_laine_bouille': 'mittens wool mitts gloves',
#  'polyester_et_coton': 'polyester and cotton',
#  'fourrure_synthetique': 'synthetic fur',
#  'fleurs_coton': 'cotton flowers',
#  'coton_imprime': 'printed cotton',
#  'doublure_coton': 'cotton lining',
#  'imprime_exclusif_anjesydesign': 'exclusive printed anjesydesign',
#  'coton_et_lin': 'cotton and linen',
#  'zip_metal_ykk': 'zip metal ykk',
#  'noir_et_blanc': 'black and white',
#  'doublure_coton_noir': 'black cotton lining',
#  'doublure_nylon_impermeable': 'waterproof nylon lining',
#  'zip_laiton_ykk': 'zip brass ykk',
#  'imprime_anjesydesign': 'printed anjesydesign',
#  'imprime_en_serigraphie': 'printed in silkscreen',
#  'mousqueton_metal': 'metal carabiner',
#  '2_tailles_disponibles': '2 sizes available',
#  'encre_ecofriendly': 'ecofriendly ink',
#  'doublure_impermeable': 'waterproof lining',
#  'tissu_exclusif_anjesydesign': 'exclusive anjesydesign fabric',
#  'tissu_imprime_main': 'hand printed fabric',
#  'serigraphie': 'serigraphy',
#  'doublure_etanche': 'waterproof lining',
#  'doublure_waterproof': 'waterproof lining',
#  'serigraphie_dore': 'gold screenprint',
#  'lin_coton': 'cotton linen',
#  'cuir_de_luxe': 'luxury leather',
#  'cuir_dore': 'golden leather',
#  'coton_serigraphie_noir_et_blanc': 'black and white silk-screen printed cotton',
#  'tissu_tropical_anjesydesign': 'tropical fabric anjesydesign',
#  'imprime_ethnique': 'ethnic print',
#  'dragonne_cuir_noir': 'black leather strap',
#  'motif_graphique_exclusif_anjesydesign': 'exclusive graphic pattern anjesydesign',
#  'gilet_sans_manches': 'sleeveless vest',
#  'en_coton_et_acrylique': 'cotton and acrylic',
#  'couleur_bleu_marine': 'navy blue color',
#  'dentelle_noire': 'black lace',
#  'gilet_femme': "women's vest",
#  'cadeau_femme': 'woman gift',
#  'vetements_femme': "women's clothing",
#  'vetements_fille': 'girl clothes',
#  'cadeau_fille': 'girl gift',
#  'laine_et_viscose': 'wool and viscose',
#  'couleur_beige_chine': 'heather beige color',
#  'manteau_femme': "woman's coat",
#  'manteau_fille': 'girl coat',
#  'gris': 'Grey',
#  'fausse_fourrure': 'fake fur',
#  'marron': 'Brown',
#  'manteau_trois_quart': 'three quarter coat',
#  'leger_en_laine': 'lightweight wool',
#  'viscose_et_dentelle': 'viscose and lace',
#  'couleur_noire': 'black color',
#  'gilet_court': 'short vest',
#  'coton_et_dentelle': 'cotton and lace',
#  'couleur_noir': 'black color',
#  'gilet_fille': "girl's vest",
#  'cachemire': 'cashmere',
#  'vert_menthe': 'mint green',
#  'cachemire_et_acrylique': 'cashmere and acrylic',
#  'dentelle_blanche': 'white lace',
#  'pull_fille': 'sweater girl',
#  'manches_longues': 'long sleeves',
#  'maille_de_angora': 'mesh of angora',
#  'laine_et_dentelle_noire': 'wool and black lace',
#  'maille_de_coton': 'cotton mesh',
#  'laine_et_dentelle': 'wool and lace',
#  'robe_fille': 'girl dress',
#  'soie_et_dentelle': 'silk and lace',
#  'blouson_sans_manches': 'sleeveless jacket',
#  'fausse_fourrure_et_dentelle': 'fake fur and lace',
#  'couleur_marron': 'Brown color',
#  'blouson_femme': 'jacket woman',
#  'bleue': 'blue',
#  'viscose_imprimee': 'printed viscose',
#  'soie_imprimee': 'printed silk',
#  'soie_gris': 'gray silk',
#  'satin_bleu': 'blue satin',
#  'maille_en_coton': 'cotton mesh',
#  'viscose_imprime': 'printed viscose',
#  'blouse_manches_courte': 'short sleeve blouse',
#  'coton_marron': 'brown cotton',
#  't_shirt_en_coton': 'cotton t shirt',
#  'coton_bleu': 'blue cotton',
#  'velours_marron': 'brown velvet',
#  'gilet_en_suedine': 'sweater in suede',
#  'gilet_a_franges': 'fringed vest',
#  'couleur_rose': 'pink color',
#  'livraison_gratuite': 'free delivery',
#  'gilet_veste_en_cachemire': 'vest cashmere jacket',
#  'pantalon_de_jogging': 'jogging pants',
#  'coton_de_couleur_grise': 'gray cotton',
#  'pantacourt_fille': "girl's cropped trousers",
#  'pull_en_cachemire': 'cashmere sweater',
#  'veste_longue': 'long jacket',
#  'velours_imprime': 'printed velvet',
#  'veste_habille': 'dressed jacket',
#  'veste_femme': 'woman jacket',
#  'veste_fille': 'jacket girl',
#  'veste_a_rayures': 'striped jacket',
#  'pantacourts_coton_et_lin': 'cotton and linen cropped trousers',
#  'couleur_beige_taupe': 'taupe beige color',
#  'pantalon_femme': "women's trousers",
#  'pantalon_fille': 'girl pants',
#  'jupe_longue': 'long skirt',
#  'maille_de_viscose': 'viscose mesh',
#  'couleur_gris_chine': 'heather gray color',
#  'jupe_femme': "women's skirt",
#  'jupe_fille': 'girl skirt',
#  'tunique_forme_de_poncho': 'tunic poncho shape',
#  'tunique_femme': "women's tunic",
#  'tunique_fille': 'girl tunic',
#  'pull_tunique': 'tunic sweater',
#  'manches_longue': 'long sleeves',
#  'couleur_bleu_ciel': 'sky blue color',
#  'gilet_manches_longues': 'long sleeve vest',
#  'cachemire_et_dentelle': 'cashmere and lace',
#  'dentelle_de_coton_blanc': 'white cotton lace',
#  'trench_fille': 'trench girl',
#  'en_soie_et_dentelle': 'silk and lace',
#  'couleur_gris_clair': 'light gray color',
#  't_shirt_imprimee': 'printed t shirt',
#  't_shirt_fille': 't shirt girl',
#  'en_viscose_imprimee': 'printed viscose',
#  't_shirt_sans_manches': 'sleeveless t shirt',
#  'arrondi_sur_les_cotes': 'rounded on the sides',
#  'couleur_beige': 'beige',
#  'veste_legere': 'light jacket',
#  'lin_et_coton': 'linen and cotton',
#  'dentelle_de_coton': 'cotton lace',
#  'veste_asymetrique': 'asymmetrical jacket',
#  'lin_et_dentelle': 'linen and lace',
#  'lin_beige': 'beige linen',
#  'dentelle_creme': 'cream lace',
#  'tunique_grande_taille': 'large tunic',
#  'de_couleur_beige_taupe': 'beige taupe',
#  'couleur_bleu': 'blue color',
#  'short_fille': 'girl shorts',
#  'chemisier_en_viscose_imprimee': 'printed viscose blouse',
#  'couleur_rouge_et_bleu': 'red and blue color',
#  'chemisier_femme': 'blouse woman',
#  'chemisier_fille': 'girl blouse',
#  'cadeau_file': 'gift file',
#  'gilet_long': 'long vest',
#  'suedine_de_couleur_marron': 'suede brown',
#  'etole_de_mariage': 'wedding stole',
#  'dentelle_de_couleur_noire': 'black lace',
#  'etole_femme': 'woman stole',
#  'etole_fille': 'stole girl',
#  'accessoires_femme': "women's accessories",
#  'accessoires_fille': 'girl accessories',
#  'chemisier_manches_longues': 'long sleeve blouse',
#  'coton_et_viscose': 'cotton and viscose',
#  'veste_en_fausse_fourrure': 'faux fur jacket',
#  'simili_cuir_et_dentelle': 'faux leather and lace',
#  'couleur_vert_olive_et_gris': 'olive green and gray color',
#  'ceste_femme': 'this woman',
#  'manteau_en_laine': 'woolen coat',
#  'couleur_beige_claire': 'light beige color',
#  'manteau_legere': 'light coat',
#  'viscose_te_dentelle': 'viscose and lace',
#  'couleur_noir_et_moutarde': 'black and mustard color',
#  'manteau_long': 'long coat',
#  'style_militaire': 'military style',
#  'manteau_en_suedine': 'suede coat',
#  'couleur_gris': 'grey color',
#  'acrylique_et_dentelle': 'acrylic and lace',
#  'imprime_vert_et_noir': 'green and black print',
#  'imprime_rouge_et_noir': 'red and black print',
#  'manteau_court_en_laine': 'woolen short coat',
#  'couleur_gris_et_noir': 'gray and black color',
#  'manteau_en_velours_imprime': 'printed velvet coat',
#  'couleur_bordeaux': 'Burgundy',
#  'couleur_noir_et_ecru': 'black and ecru',
#  'manteau_leger': 'light coat',
#  'longueur_trois_quart': 'three quarter length',
#  'gilet_en_mohair': 'mohair vest',
#  'dentelle_couleur_noire': 'lace black color',
#  'manteaux_en_laine': 'woolen coats',
#  'gilet_manteau': 'coat vest',
#  'en_maille_de_coton': 'cotton mesh',
#  'motif_pied_de_poule': 'houndstooth pattern',
#  'motif_geometrique': 'geometric pattern',
#  'chale': 'shawl',
#  'chauffe_epaule': 'shoulder warmer',
#  'en_fausse_fourrure': 'faux fur',
#  'echarpe_femme': 'woman scarf',
#  'col_en_fausse_fourrure': 'faux fur collar',
#  'echarpe_en_coton': 'cotton scarf',
#  'et_acrylique_beige': 'and beige acrylic',
#  'et_dentelle_noire': 'and black lace',
#  'echarpe_fille': 'girl scarf',
#  'vetement_femme': "women's clothing",
#  'vetement_fille': 'girl clothes',
#  'accessoire_femme': 'woman accessory',
#  'acrylique_et_crochet': 'acrylic and hook',
#  'jupe_en_tissu_de_coton': 'cotton fabric skirt',
#  'couleur_bleu_jean': 'color blue jeans',
#  'blouse_manches_longues': 'long sleeve blouse',
#  'dentelle_rose': 'pink lace',
#  'blouse_fille': "girl's blouse",
#  'chemise_fille': 'shirt girl',
#  'couleur_bleu_clair': 'light blue color',
#  'couleur_bordeaux_et_noir': 'burgundy and black',
#  'jupe_en_viscose': 'viscose skirt',
#  'imprime_fleur': 'flower print',
#  'beige_et_bleu': 'beige and blue',
#  'coton_imprime_et_dentelle': 'printed cotton and lace',
#  'pantacourt_en_lin': 'linen cropped trousers',
#  'dentelle_de_couleur_noir': 'black lace',
#  'soie_noire': 'black silk',
#  'combinaison_en_soie': 'silk suit',
#  'combinaison_femme': "women's suit",
#  'combinaison_fille': 'girl combination',
#  'rayures': 'scratch',
#  'bermuda_en_coton': 'cotton Bermuda shorts',
#  'coton_a_rayures': 'striped cotton',
#  'bleu_et_blanc': 'blue and white',
#  'bermuda_femme': "women's bermuda",
#  'fille': 'girl',
#  'bleu_et_rouge': 'blue and red',
#  'chale_en_velours_noir': 'black velvet shawl',
#  'couleur_noir_et_rose': 'black and pink color',
#  'vert_et_bleu': 'green and blue',
#  'chale_femme': 'shawl woman',
#  'chale_fille': 'shawl girl',
#  'motif_panthere': 'panther pattern',
#  'couleur_beige_et_marron': 'beige and brown color',
#  'cape_fille': 'girl cloak',
#  'couleur_noir_et_rouge': 'black and red color',
#  'taille_unique': 'unique size',
#  'chemise_manches_longues': 'long sleeves shirt',
#  'coton_a_motifs': 'patterned cotton',
#  'couleur_blanche': 'White color',
#  'jupe_evase': 'flared skirt',
#  'satin_et_dentelle': 'satin and lace',
#  'chaine_dore': 'golden chain',
#  'gilet_en_maille_ajoure': 'openwork knit vest',
#  'elasthanne_et_dentelle': 'elastane and lace',
#  'couleur_bleu_canard': 'color blue duck',
#  'echarpe_en_plume_d_oiseau': 'bird feather scarf',
#  'couleur_prune': 'plum colour',
#  'maille': 'stitch',
#  'robe_tunique': 'tunic dress',
#  'en_maille_de_viscose': 'viscose knit',
#  'de_couleur_noir_chine': 'black heather',
#  'coton_de_couleur_blanche': 'white cotton',
#  'chemise_longue': 'long shirt',
#  'coton_blanc_a_rayures': 'striped white cotton',
#  'pull_en_coton': 'cotton sweater',
#  'dentelle_couleur_beige': 'lace beige color',
#  'blouse_en_mousseline_imprime': 'printed chiffon blouse',
#  'couleur_corail': 'Coral color',
#  'blouses_manches_longues': 'long sleeve blouses',
#  'mousseline_de_soie': 'chiffon',
#  'kaki': 'khaki',
#  'plusieurs_couleurs': 'several colors',
#  'grande_taille': 'big size',
#  'satin_imprime_et_dentelle': 'printed satin and lace',
#  'blanche': 'white',
#  'grise': 'gray',
#  'dentelle_de_couleur_bleu': 'blue colored lace',
#  'salopette_en_toile_de_coton': 'overalls in cotton canvas',
#  'motif_militaire': 'military motive',
#  'pantalon_militaire': 'military pants',
#  'pantacourt_en_coton': 'cotton cropped trousers',
#  'couleur_gris_anthracite': 'anthracite gray color',
#  'ull_manches_longues': 'ull long sleeves',
#  'blouse_en_mousseline': 'chiffon blouse',
#  'brode_couleur_beige': 'beige color embroidery',
#  'attache_cheveux': 'hair tie',
#  'foulard_pour_les_cheveux': 'hair scarf',
#  'leggings_pantalon': 'pants leggings',
#  'motifs_zebre': 'zebra patterns',
#  'leggins_femme': 'leggins woman',
#  'tissu_de_crepe_et_dentelle': 'crepe and lace fabric',
#  'couleur_noir_et_blanc': 'black and white color',
#  'acrylique_imprime_et_dentelle': 'printed acrylic and lace',
#  'doudoune_a_capuche': 'hooded down jacket',
#  'dentelle_beige': 'beige lace',
#  'doudoune_fille': 'down jacket girl',
#  'tricot': 'knitting',
#  'gants_en_laine': 'woolen gloves',
#  'acrylique_et_elasthanne': 'acrylic and elastane',
#  'decore_de_dentelle': 'decorated with lace',
#  'gants_femme': "women's gloves",
#  'guetres_en_coton': 'cotton gaiters',
#  'guetres_femme': 'woman gaiters',
#  'guetres_fille': 'girl gaiters',
#  'snood_en_acrylique': 'acrylic snood',
#  'polyester_et_dentelle_couleur_bleu': 'polyester and lace blue color',
#  'echarpe': 'scarf',
#  'chauffe_epaules': 'shoulder warmers',
#  'a_rayures_larges': 'wide striped',
#  'dentelle_beige_et_noire': 'beige and black lace',
#  'brode_main': 'hand embroidered',
#  'bleu': 'blue',
#  'gilet_manche_longues': 'long sleeves vest',
#  'en_maille_jersey': 'knit jersey',
#  'couleur_bleu_chine': 'heather blue color',
#  'gilet_en_mohair_et_dentelle': 'mohair and lace vest',
#  'gilet_cape': 'cape vest',
#  'en_maille_imprime': 'printed mesh',
#  'crochet_et_acrylique': 'hook and acrylic',
#  'manteau_en_laine_et_dentelle': 'wool and lace coat',
#  'couleur_grise': 'grey color',
#  'dentelle_de_coton_beige': 'beige cotton lace',
#  'jupon_en_resille': 'petticoat in fishnet',
#  'jupon_en_resille_noire': 'petticoat black fishnet',
#  'jupon_en_dentelle': 'lace petticoat',
#  'jupon_en_dentelle_noire': 'black lace petticoat',
#  'couleur_imprime_noir': 'black printed color',
#  'robe_manches_longues': 'long sleeve dress',
#  'mohair_de_couleur_marron': 'brown mohair',
#  'robe_tricot': 'knit dress',
#  'pull_manches_longues': 'long sleeves sweater',
#  'en_coton_et_modal': 'in cotton and modal',
#  'pull_manches_courtes': 'short sleeve sweater',
#  'mitaines_longues': 'long mittens',
#  'de_ceremonie': 'ceremony',
#  ...}

# %%
dic_uniques = pickle.load( open( "_data/dic_uniques.pickle", "rb" ) )

# %%
for (key, texte) in dic_uniques.items() :
    if key in dic_translated:
        dic_uniques[key] = dic_translated[key]

# %%
dic_uniques['corail_rouge']
# Out:
# 'red coral'

# %%
len(dic_uniques)
# Out:
# 87376

# %%
dic_uniques_lem = OrderedDict()

# %%
for (key, texte) in dic_uniques.items() :
        dic_uniques_lem[key] = [dic_uniques[key], lemmanize(dic_uniques[key])]

# %%
dic_uniques_lem['corail_rouge']
# Out:
# ['red coral', 'coral']

# %%
pickle.dump( dic_uniques_lem, open( "_data/dic_uniques_lem.pickle", "wb" ) )

# %%
data_dict = pickle.load( open( "_data/data_dict.pickle", "rb" ) )

# %%
len(data_dict)
# Out:
# 1268606

# %%
data_dict
# Out:
# OrderedDict([('550866727_1', [550866727, 'glass', 'glass']),
#              ('639584419_1', [639584419, 'copper', 'copper']),
#              ('637314587_1', [637314587, 'cotton', 'cotton']),
#              ('550857329_1', [550857329, 'cotton', 'cotton']),
#              ('537056276_1', [537056276, 'wood', 'wood']),
#              ('537064510_1', [537064510, 'wood', 'wood']),
#              ('550858757_1', [550858757, 'wood', 'wood']),
#              ('550856537_1', [550856537, 'wood', 'wood']),
#              ('537057576_1', [537057576, 'cotton', 'cotton']),
#              ('537067898_1', [537067898, 'wood', 'wood']),
#              ('537067458_1', [537067458, 'cotton', 'cotton']),
#              ('634617401_1', [634617401, 'cotton', 'cotton']),
#              ('603638000_1', [603638000, 'cotton', 'cotton']),
#              ('537060516_1', [537060516, 'wood', 'wood']),
#              ('537056102_1', [537056102, 'cotton', 'cotton']),
#              ('537056096_1', [537056096, 'cotton', 'cotton']),
#              ('640463324_1', [640463324, 'cotton', 'cotton']),
#              ('550868801_1', [550868801, 'cotton', 'cotton']),
#              ('550868663_1', [550868663, 'cotton', 'cotton']),
#              ('550867647_1', [550867647, 'cotton', 'cotton']),
#              ('656177092_1', [656177092, 'polyester', 'polyester']),
#              ('656177092_2', [656177092, 'cotton', 'cotton']),
#              ('670019353_1', [670019353, 'cotton', 'cotton']),
#              ('656176904_1', [656176904, 'cotton', 'cotton']),
#              ('630995430_1', [630995430, 'fabric', 'fabric']),
#              ('656186930_1', [656186930, 'cotton', 'cotton']),
#              ('550856643_1', [550856643, 'glass', 'glass']),
#              ('550856643_2', [550856643, 'leather', 'leather']),
#              ('550856643_3', [550856643, 'brass', 'brass']),
#              ('537057030_1', [537057030, 'glass', 'glass']),
#              ('537056706_1', [537056706, 'cotton', 'cotton']),
#              ('670029107_1', [670029107, 'cotton', 'cotton']),
#              ('670027775_1', [670027775, 'cotton', 'cotton']),
#              ('656186648_1', [656186648, 'cotton', 'cotton']),
#              ('550857145_1', [550857145, 'wood', 'wood']),
#              ('550856911_1', [550856911, 'glass', 'glass']),
#              ('537057092_1', [537057092, 'glass', 'glass']),
#              ('537056816_1', [537056816, 'glass', 'glass']),
#              ('550858131_1', [550858131, 'cotton', 'cotton']),
#              ('550857807_1', [550857807, 'cotton', 'cotton']),
#              ('550864191_1', [550864191, 'cotton', 'cotton']),
#              ('550864191_2', [550864191, 'polyester', 'polyester']),
#              ('537056728_1', [537056728, 'paper', 'paper']),
#              ('537066760_1', [537066760, 'polyester', 'polyester']),
#              ('537064438_1', [537064438, 'polyester', 'polyester']),
#              ('550863117_1', [550863117, 'polyester', 'polyester']),
#              ('537066726_1', [537066726, 'polyester', 'polyester']),
#              ('537058388_1', [537058388, 'polyester', 'polyester']),
#              ('610199762_1', [610199762, 'plastic', 'plastic']),
#              ('610241345_1', [610241345, 'wood', 'wood']),
#              ('550866609_1', [550866609, 'wood', 'wood']),
#              ('550866351_1', [550866351, 'wood', 'wood']),
#              ('550863769_1', [550863769, 'plastic', 'plastic']),
#              ('550862893_1', [550862893, 'wood', 'wood']),
#              ('550858143_1', [550858143, 'wood', 'wood']),
#              ('537063520_1', [537063520, 'wood', 'wood']),
#              ('537062732_1', [537062732, 'wood', 'wood']),
#              ('550864621_1', [550864621, 'wood', 'wood']),
#              ('537063114_1', [537063114, 'wood', 'wood']),
#              ('537057794_1', [537057794, 'plastic', 'plastic']),
#              ('537055754_1', [537055754, 'wood', 'wood']),
#              ('550865713_1', [550865713, 'wood', 'wood']),
#              ('550864055_1', [550864055, 'wood', 'wood']),
#              ('550862189_1', [550862189, 'wood', 'wood']),
#              ('550856623_1', [550856623, 'wood', 'wood']),
#              ('537063354_1', [537063354, 'wood', 'wood']),
#              ('550863587_1', [550863587, 'wood', 'wood']),
#              ('550858215_1', [550858215, 'wood', 'wood']),
#              ('550856839_1', [550856839, 'plastic', 'plastic']),
#              ('550856165_1', [550856165, 'wood', 'wood']),
#              ('537058874_1', [537058874, 'wood', 'wood']),
#              ('537056402_1', [537056402, 'wood', 'wood']),
#              ('550861009_1', [550861009, 'wood', 'wood']),
#              ('550858773_1', [550858773, 'wood', 'wood']),
#              ('537059026_1', [537059026, 'wood', 'wood']),
#              ('537058422_1', [537058422, 'wood', 'wood']),
#              ('537056048_1', [537056048, 'wood', 'wood']),
#              ('550865933_1', [550865933, 'wood', 'wood']),
#              ('550858443_1', [550858443, 'wood', 'wood']),
#              ('550857041_1', [550857041, 'wood', 'wood']),
#              ('537064238_1', [537064238, 'wood', 'wood']),
#              ('537063400_1', [537063400, 'wood', 'wood']),
#              ('537062774_1', [537062774, 'wood', 'wood']),
#              ('537058906_1', [537058906, 'wood', 'wood']),
#              ('537058558_1', [537058558, 'wood', 'wood']),
#              ('537058542_1', [537058542, 'wood', 'wood']),
#              ('537057560_1', [537057560, 'plastic', 'plastic']),
#              ('550864381_1', [550864381, 'wood', 'wood']),
#              ('537066096_1', [537066096, 'wood', 'wood']),
#              ('537059658_1', [537059658, 'wood', 'wood']),
#              ('537058854_1', [537058854, 'wood', 'wood']),
#              ('537057688_1', [537057688, 'wood', 'wood']),
#              ('550866179_1', [550866179, 'steel', 'steel']),
#              ('550865803_1', [550865803, 'enamel', 'enamel']),
#              ('550865755_1', [550865755, 'enamel', 'enamel']),
#              ('550865261_1',
#               [550865261, 'porcelain__ceramic', 'porcelain  ceramic']),
#              ('550862645_1', [550862645, 'wood__nut', 'wood  nut']),
#              ('550861343_1', [550861343, 'glass', 'glass']),
#              ('550861229_1', [550861229, 'glass', 'glass']),
#              ('550860131_1', [550860131, 'wood__nut', 'wood  nut']),
#              ('537066658_1', [537066658, 'glass', 'glass']),
#              ('537060378_1', [537060378, 'wood__nut', 'wood  nut']),
#              ('537060100_1', [537060100, 'wood__nut', 'wood  nut']),
#              ('537057892_1',
#               [537057892, 'porcelain__ceramic', 'porcelain  ceramic']),
#              ('627513109_1', [627513109, 'plastic__resin', 'plastic  resin']),
#              ('550866849_1', [550866849, 'glass', 'glass']),
#              ('550861581_1', [550861581, 'wood__nut', 'wood  nut']),
#              ('550861133_1', [550861133, 'plastic__resin', 'plastic  resin']),
#              ('537066692_1', [537066692, 'glass', 'glass']),
#              ('537064840_1',
#               [537064840, 'porcelain__ceramic', 'porcelain  ceramic']),
#              ('550866705_1', [550866705, 'bloodstone', 'bloodstone']),
#              ('550861851_1', [550861851, 'plastic__resin', 'plastic  resin']),
#              ('550861263_1', [550861263, 'glass', 'glass']),
#              ('550859957_1',
#               [550859957, 'porcelain__ceramic', 'porcelain  ceramic']),
#              ('537066006_1', [537066006, 'glass', 'glass']),
#              ('537056326_1', [537056326, 'plastic__resin', 'plastic  resin']),
#              ('537066050_1',
#               [537066050, 'porcelain__ceramic', 'porcelain  ceramic']),
#              ('537062940_1', [537062940, 'wood__nut', 'wood  nut']),
#              ('537062138_1', [537062138, 'wood__nut', 'wood  nut']),
#              ('537062026_1', [537062026, 'glass', 'glass']),
#              ('537061570_1', [537061570, 'plastic__resin', 'plastic  resin']),
#              ('537061126_1', [537061126, 'plastic__resin', 'plastic  resin']),
#              ('537060688_1', [537060688, 'wood__nut', 'wood  nut']),
#              ('537060126_1', [537060126, 'wood__nut', 'wood  nut']),
#              ('625929332_1', [625929332, 'copper', 'copper']),
#              ('550866571_1', [550866571, 'pearl__shell', 'pearl  shell']),
#              ('550863433_1', [550863433, 'wood__nut', 'wood  nut']),
#              ('550862625_1', [550862625, 'plastic__resin', 'plastic  resin']),
#              ('550861767_1', [550861767, 'wood__nut', 'wood  nut']),
#              ('550861727_1', [550861727, 'wood__nut', 'wood  nut']),
#              ('550861309_1', [550861309, 'glass', 'glass']),
#              ('550861163_1', [550861163, 'glass', 'glass']),
#              ('550860489_1', [550860489, 'wood__nut', 'wood  nut']),
#              ('550857719_1', [550857719, 'plastic__resin', 'plastic  resin']),
#              ('537061766_1', [537061766, 'wood__nut', 'wood  nut']),
#              ('537061646_1', [537061646, 'plastic__resin', 'plastic  resin']),
#              ('649065414_1', [649065414, 'cotton', 'cotton']),
#              ('663201389_1', [663201389, 'cotton', 'cotton']),
#              ('656309491_1', [656309491, 'cotton', 'cotton']),
#              ('656158628_1', [656158628, 'cotton', 'cotton']),
#              ('642303026_1', [642303026, 'cotton', 'cotton']),
#              ('636322086_1', [636322086, 'cotton', 'cotton']),
#              ('633551136_1', [633551136, 'cotton', 'cotton']),
#              ('631262800_1', [631262800, 'cotton', 'cotton']),
#              ('550868929_1', [550868929, 'cotton', 'cotton']),
#              ('550868565_1', [550868565, 'cotton', 'cotton']),
#              ('550867925_1', [550867925, 'cotton', 'cotton']),
#              ('537066808_1', [537066808, 'cotton', 'cotton']),
#              ('547041329_1', [547041329, 'steel', 'steel']),
#              ('532186198_1', [532186198, 'coton', 'coton']),
#              ('532190012_1', [532190012, 'coton', 'coton']),
#              ('532188242_1', [532188242, 'coton', 'coton']),
#              ('545992657_1', [545992657, 'coton', 'coton']),
#              ('545988827_1', [545988827, 'coton', 'coton']),
#              ('532188104_1', [532188104, 'simili_cuir', 'simili cuir']),
#              ('532188104_2', [532188104, 'coton', 'coton']),
#              ('532188000_1', [532188000, 'simili_cuir', 'simili cuir']),
#              ('532188000_2', [532188000, 'coton', 'coton']),
#              ('545992819_1', [545992819, 'coton', 'coton']),
#              ('545992737_1', [545992737, 'coton', 'coton']),
#              ('545988559_1', [545988559, 'coton', 'coton']),
#              ('532187926_1', [532187926, 'coton', 'coton']),
#              ('532187926_2', [532187926, 'polaire', 'polaire']),
#              ('532187670_1', [532187670, 'coton', 'coton']),
#              ('545990701_1', [545990701, 'coton', 'coton']),
#              ('545990701_2', [545990701, 'doudou', 'doudou']),
#              ('545989143_1', [545989143, 'coton', 'coton']),
#              ('545989143_2', [545989143, 'doudou', 'doudou']),
#              ('532188528_1', [532188528, 'coton', 'coton']),
#              ('545991135_1', [545991135, 'coton', 'coton']),
#              ('545991019_1', [545991019, 'simili_cuir', 'simili cuir']),
#              ('545991019_2', [545991019, 'coton', 'coton']),
#              ('545990285_1', [545990285, 'coton', 'coton']),
#              ('545990237_1', [545990237, 'coton', 'coton']),
#              ('545990169_1', [545990169, 'coton', 'coton']),
#              ('545989289_1', [545989289, 'coton', 'coton']),
#              ('545989289_2', [545989289, 'doudou', 'doudou']),
#              ('545989163_1', [545989163, 'coton', 'coton']),
#              ('545989163_2', [545989163, 'doudou', 'doudou']),
#              ('532189154_1', [532189154, 'simili_cuir', 'simili cuir']),
#              ('532189154_2', [532189154, 'coton', 'coton']),
#              ('532188660_1', [532188660, 'coton', 'coton']),
#              ('532188660_2', [532188660, 'velour', 'velour']),
#              ('532186070_1', [532186070, 'coton', 'coton']),
#              ('532185304_1', [532185304, 'coton', 'coton']),
#              ('545991935_1', [545991935, 'coton', 'coton']),
#              ('545991659_1', [545991659, 'coton', 'coton']),
#              ('545990953_1', [545990953, 'simili_cuir', 'simili cuir']),
#              ('545990953_2', [545990953, 'coton', 'coton']),
#              ('545990839_1', [545990839, 'simili_cuir', 'simili cuir']),
#              ('545990839_2', [545990839, 'coton', 'coton']),
#              ('545988493_1', [545988493, 'coton', 'coton']),
#              ('545988383_1', [545988383, 'coton', 'coton']),
#              ('532189050_1', [532189050, 'fabric', 'fabric']),
#              ('532188570_1', [532188570, 'coton', 'coton']),
#              ('532188402_1', [532188402, 'polyester', 'polyester']),
#              ('532188402_2', [532188402, 'coton', 'coton']),
#              ('532188050_1', [532188050, 'simili_cuir', 'simili cuir']),
#              ('532188050_2', [532188050, 'coton', 'coton']),
#              ('532186656_1', [532186656, 'polyester', 'polyester']),
#              ('532186656_2', [532186656, 'coton', 'coton']),
#              ('532185840_1', [532185840, 'coton', 'coton']),
#              ('532185196_1', [532185196, 'coton', 'coton']),
#              ('545991897_1', [545991897, 'simili_cuir', 'simili cuir']),
#              ('545991897_2', [545991897, 'coton', 'coton']),
#              ('545991769_1', [545991769, 'coton', 'coton']),
#              ('545989061_1', [545989061, 'coton', 'coton']),
#              ('545988175_1', [545988175, 'coton', 'coton']),
#              ('532190308_1', [532190308, 'coton', 'coton']),
#              ('532190226_1', [532190226, 'simili_cuir', 'simili cuir']),
#              ('532190226_2', [532190226, 'coton', 'coton']),
#              ('532187910_1', [532187910, 'coton', 'coton']),
#              ('532187910_2', [532187910, 'doudou', 'doudou']),
#              ('532187846_1', [532187846, 'coton', 'coton']),
#              ('532186542_1', [532186542, 'coton', 'coton']),
#              ('532186520_1', [532186520, 'coton', 'coton']),
#              ('532186520_2', [532186520, 'polyester', 'polyester']),
#              ('545991479_1', [545991479, 'coton', 'coton']),
#              ('545991413_1', [545991413, 'simili_cuir', 'simili cuir']),
#              ('545991413_2', [545991413, 'coton', 'coton']),
#              ('545989005_1', [545989005, 'simili_cuir', 'simili cuir']),
#              ('545989005_2', [545989005, 'coton', 'coton']),
#              ('545988919_1', [545988919, 'coton', 'coton']),
#              ('545987803_1', [545987803, 'coton', 'coton']),
#              ('545987751_1', [545987751, 'lin', 'lin']),
#              ('545987751_2', [545987751, 'coton', 'coton']),
#              ('532189220_1', [532189220, 'coton', 'coton']),
#              ('532189006_1', [532189006, 'coton', 'coton']),
#              ('532188896_1', [532188896, 'simili_cuir', 'simili cuir']),
#              ('532188896_2', [532188896, 'coton', 'coton']),
#              ('532187614_1', [532187614, 'coton', 'coton']),
#              ('532187386_1', [532187386, 'coton', 'coton']),
#              ('532186496_1', [532186496, 'coton', 'coton']),
#              ('532186496_2', [532186496, 'doudou', 'doudou']),
#              ('532186424_1', [532186424, 'coton', 'coton']),
#              ('532186424_2', [532186424, 'doudou', 'doudou']),
#              ('545991733_1', [545991733, 'coton', 'coton']),
#              ('545991733_2', [545991733, 'velour', 'velour']),
#              ('545989035_1', [545989035, 'simili_cuir', 'simili cuir']),
#              ('545989035_2', [545989035, 'coton', 'coton']),
#              ('545988933_1', [545988933, 'lin_enduit', 'lin enduit']),
#              ('545988933_2', [545988933, 'coton', 'coton']),
#              ('545988629_1', [545988629, 'coton', 'coton']),
#              ('545988123_1', [545988123, 'coton', 'coton']),
#              ('545987685_1', [545987685, 'coton', 'coton']),
#              ('532187804_1', [532187804, 'coton', 'coton']),
#              ('532187804_2', [532187804, 'doudou', 'doudou']),
#              ('532187644_1', [532187644, 'coton', 'coton']),
#              ('532187644_2', [532187644, 'doudou', 'doudou']),
#              ('532187490_1', [532187490, 'simili_cuir', 'simili cuir']),
#              ('532187490_2', [532187490, 'coton', 'coton']),
#              ('532186214_1', [532186214, 'coton', 'coton']),
#              ('532185148_1', [532185148, 'coton', 'coton']),
#              ('545993201_1', [545993201, 'coton', 'coton']),
#              ('545991627_1', [545991627, 'simili_cuir', 'simili cuir']),
#              ('545991627_2', [545991627, 'coton', 'coton']),
#              ('545991437_1', [545991437, 'simili_cuir', 'simili cuir']),
#              ('545991437_2', [545991437, 'coton', 'coton']),
#              ('532190180_1', [532190180, 'coton', 'coton']),
#              ('532187298_1', [532187298, 'coton', 'coton']),
#              ('532187210_1', [532187210, 'coton', 'coton']),
#              ('532186946_1', [532186946, 'coton', 'coton']),
#              ('532186946_2', [532186946, 'doudou', 'doudou']),
#              ('532186630_1', [532186630, 'coton', 'coton']),
#              ('532186630_2', [532186630, 'doudou', 'doudou']),
#              ('532186434_1', [532186434, 'coton', 'coton']),
#              ('532186434_2', [532186434, 'doudou', 'doudou']),
#              ('532186174_1', [532186174, 'coton', 'coton']),
#              ('532186174_2', [532186174, 'coton_enduit', 'coton enduit']),
#              ('532185602_1', [532185602, 'coton', 'coton']),
#              ('532185570_1', [532185570, 'coton', 'coton']),
#              ('532185444_1', [532185444, 'simili_cuir', 'simili cuir']),
#              ('532185444_2', [532185444, 'coton', 'coton']),
#              ('532185272_1', [532185272, 'coton', 'coton']),
#              ('545993157_1', [545993157, 'simili_cuir', 'simili cuir']),
#              ('545993157_2', [545993157, 'coton', 'coton']),
#              ('545992999_1', [545992999, 'simili_cuir', 'simili cuir']),
#              ('545992999_2', [545992999, 'coton', 'coton']),
#              ('545992325_1', [545992325, 'coton', 'coton']),
#              ('545991327_1', [545991327, 'simili_cuir', 'simili cuir']),
#              ('545991327_2', [545991327, 'coton', 'coton']),
#              ('545990781_1', [545990781, 'coton', 'coton']),
#              ('545990781_2', [545990781, 'doudou', 'doudou']),
#              ('545990743_1', [545990743, 'coton', 'coton']),
#              ('545990743_2', [545990743, 'doudou', 'doudou']),
#              ('545989023_1', [545989023, 'coton', 'coton']),
#              ('545989023_2', [545989023, 'doudou', 'doudou']),
#              ('532188734_1', [532188734, 'simili_cuir', 'simili cuir']),
#              ('532188734_2', [532188734, 'coton', 'coton']),
#              ('532188714_1', [532188714, 'coton', 'coton']),
#              ('532188714_2', [532188714, 'doudou', 'doudou']),
#              ('532185320_1', [532185320, 'coton', 'coton']),
#              ('545991303_1', [545991303, 'coton', 'coton']),
#              ('545991253_1', [545991253, 'fabric', 'fabric']),
#              ('545991207_1', [545991207, 'fabric', 'fabric']),
#              ('545990623_1', [545990623, 'coton', 'coton']),
#              ('545990623_2', [545990623, 'suedine', 'suedine']),
#              ('545990561_1', [545990561, 'coton', 'coton']),
#              ('545990561_2', [545990561, 'doudou', 'doudou']),
#              ('545989981_1', [545989981, 'coton', 'coton']),
#              ('545989735_1', [545989735, 'simili_cuir', 'simili cuir']),
#              ('545989735_2', [545989735, 'coton', 'coton']),
#              ('545988611_1', [545988611, 'coton', 'coton']),
#              ('532190198_1', [532190198, 'coton', 'coton']),
#              ('532189942_1', [532189942, 'coton', 'coton']),
#              ('532188966_1', [532188966, 'simili_cuir', 'simili cuir']),
#              ('532188966_2', [532188966, 'coton', 'coton']),
#              ('532188788_1', [532188788, 'fabric', 'fabric']),
#              ('532188446_1', [532188446, 'simili_cuir', 'simili cuir']),
#              ('532188446_2', [532188446, 'coton', 'coton']),
#              ('532188362_1', [532188362, 'coton', 'coton']),
#              ('545990673_1', [545990673, 'simili_cuir', 'simili cuir']),
#              ('545990673_2', [545990673, 'coton', 'coton']),
#              ('545990483_1', [545990483, 'coton', 'coton']),
#              ('545990483_2', [545990483, 'doudou', 'doudou']),
#              ('545990339_1', [545990339, 'coton', 'coton']),
#              ('545990051_1', [545990051, 'coton', 'coton']),
#              ('545990051_2', [545990051, 'doudou', 'doudou']),
#              ('545989621_1', [545989621, 'coton', 'coton']),
#              ('545989421_1', [545989421, 'coton', 'coton']),
#              ('545989421_2', [545989421, 'doudou', 'doudou']),
#              ('532190066_1', [532190066, 'coton', 'coton']),
#              ('532190066_2', [532190066, 'doudou', 'doudou']),
#              ('532189684_1', [532189684, 'coton', 'coton']),
#              ('532189302_1', [532189302, 'coton', 'coton']),
#              ('532188760_1', [532188760, 'simili_cuir', 'simili cuir']),
#              ('532188760_2', [532188760, 'coton', 'coton']),
#              ('532188306_1', [532188306, 'coton', 'coton']),
#              ('532188306_2', [532188306, 'polyester', 'polyester']),
#              ('532186998_1', [532186998, 'coton', 'coton']),
#              ('532186998_2', [532186998, 'doudou', 'doudou']),
#              ('532186044_1', [532186044, 'coton', 'coton']),
#              ('545990075_1', [545990075, 'coton', 'coton']),
#              ('545989691_1', [545989691, 'simili_cuir', 'simili cuir']),
#              ('545989691_2', [545989691, 'coton', 'coton']),
#              ('545989531_1', [545989531, 'coton', 'coton']),
#              ('545989531_2', [545989531, 'doudou', 'doudou']),
#              ('545989189_1', [545989189, 'simili_cuir', 'simili cuir']),
#              ('532189968_1', [532189968, 'coton', 'coton']),
#              ('532189968_2', [532189968, 'doudou', 'doudou']),
#              ('532188272_1', [532188272, 'simili_cuir', 'simili cuir']),
#              ('532188272_2', [532188272, 'coton', 'coton']),
#              ('532188080_1', [532188080, 'simili_cuir', 'simili cuir']),
#              ('532188080_2', [532188080, 'coton', 'coton']),
#              ('532185636_1', [532185636, 'coton', 'coton']),
#              ('567707471_1', [567707471, 'stone', 'stone']),
#              ('567707471_2', [567707471, 'steel', 'steel']),
#              ('668502164_1', [668502164, 'lapis_lazuli', 'lapis lazuli']),
#              ('668502164_2', [668502164, 'steel', 'steel']),
#              ('668502164_3', [668502164, 'gemstone', 'gemstone']),
#              ('682344567_1', [682344567, 'amethyst', 'amethyst']),
#              ('682344567_2', [682344567, 'steel', 'steel']),
#              ('682344567_3', [682344567, 'gemstone', 'gemstone']),
#              ('668497050_1', [668497050, 'steel', 'steel']),
#              ('668497050_2', [668497050, 'gemstone', 'gemstone']),
#              ('668492794_1', [668492794, 'gemstone', 'gemstone']),
#              ('668492794_2', [668492794, 'steel', 'steel']),
#              ('668492794_3', [668492794, 'garnet', 'garnet']),
#              ('652940507_1', [652940507, 'stone', 'stone']),
#              ('652940507_2',
#               [652940507, 'stainless_steel', 'stainless steel']),
#              ('558028641_1', [558028641, 'steel', 'steel']),
#              ('558028641_2', [558028641, 'gemstone', 'gemstone']),
#              ('541265778_1', [541265778, 'garnet', 'garnet']),
#              ('541265778_2', [541265778, 'steel', 'steel']),
#              ('541265778_3', [541265778, 'stone', 'stone']),
#              ('541265778_4',
#               [541265778, 'stainless_steel', 'stainless steel']),
#              ('560608978_1', [560608978, 'gemstone', 'gemstone']),
#              ('558022923_1', [558022923, 'stone', 'stone']),
#              ('558022923_2',
#               [558022923, 'stainless_steel', 'stainless steel']),
#              ('558029719_1', [558029719, 'silver', 'silver']),
#              ('558029719_2', [558029719, 'paper', 'paper']),
#              ('558029719_3', [558029719, 'stone', 'stone']),
#              ('558029719_4', [558029719, 'garnet', 'garnet']),
#              ('555026013_1', [555026013, 'amethyst', 'amethyst']),
#              ('555026013_2', [555026013, 'steel', 'steel']),
#              ('555026013_3', [555026013, 'stone', 'stone']),
#              ('552996361_1', [552996361, 'lapis_lazuli', 'lapis lazuli']),
#              ('552996361_2', [552996361, 'steel', 'steel']),
#              ('552996361_3', [552996361, 'stone', 'stone']),
#              ('552996361_4',
#               [552996361, 'stainless_steel', 'stainless steel']),
#              ('565774636_1', [565774636, 'steel', 'steel']),
#              ('565774636_2', [565774636, 'gemstone', 'gemstone']),
#              ('558005021_1', [558005021, 'steel', 'steel']),
#              ('558005021_2', [558005021, 'stone', 'stone']),
#              ('540913718_1', [540913718, 'lapis_lazuli', 'lapis lazuli']),
#              ('540913718_2', [540913718, 'steel', 'steel']),
#              ('540913718_3', [540913718, 'stone', 'stone']),
#              ('565764544_1', [565764544, 'paper', 'paper']),
#              ('565764544_2', [565764544, 'stone', 'stone']),
#              ('565764544_3', [565764544, 'amethyst', 'amethyst']),
#              ('565764544_4',
#               [565764544, 'stainless_steel', 'stainless steel']),
#              ('579560107_1', [579560107, 'paper', 'paper']),
#              ('579560107_2', [579560107, 'stone', 'stone']),
#              ('579560107_3', [579560107, 'amethyst', 'amethyst']),
#              ('579560107_4',
#               [579560107, 'stainless_steel', 'stainless steel']),
#              ('537673417_1', [537673417, 'silver', 'silver']),
#              ('537673417_2', [537673417, 'paper', 'paper']),
#              ('537673417_3', [537673417, 'stone', 'stone']),
#              ('537673417_4', [537673417, 'amethyst', 'amethyst']),
#              ('500684049_1', [500684049, 'silver', 'silver']),
#              ('500684049_2', [500684049, 'paper', 'paper']),
#              ('500684049_3', [500684049, 'stone', 'stone']),
#              ('500684049_4', [500684049, 'amethyst', 'amethyst']),
#              ('536301918_1', [536301918, 'amethyst', 'amethyst']),
#              ('536301918_2', [536301918, 'steel', 'steel']),
#              ('536301918_3', [536301918, 'stone', 'stone']),
#              ('536301918_4', [536301918, 'shell', 'shell']),
#              ('639109078_1', [639109078, 'wood', 'wood']),
#              ('639109078_2', [639109078, 'stone', 'stone']),
#              ('639109078_3',
#               [639109078, 'stainless_steel', 'stainless steel']),
#              ('558006827_1',
#               [558006827, 'stainless_steel', 'stainless steel']),
#              ('558006827_2', [558006827, 'rose_quartz', 'rose quartz']),
#              ('558006827_3', [558006827, 'stone', 'stone']),
#              ('554999228_1', [554999228, 'silver', 'silver']),
#              ('554999228_2', [554999228, 'paper', 'paper']),
#              ('554999228_3', [554999228, 'stone', 'stone']),
#              ('554999228_4', [554999228, 'jade', 'jade']),
#              ('567710445_1', [567710445, 'silver', 'silver']),
#              ('567710445_2', [567710445, 'paper', 'paper']),
#              ('567710445_3', [567710445, 'stone', 'stone']),
#              ('567710445_4', [567710445, 'lapis_lazuli', 'lapis lazuli']),
#              ('668738880_1', [668738880, 'cosses', 'cosses']),
#              ('668738880_2', [668738880, 'sarrasin', 'sarrasin']),
#              ('668738880_3', [668738880, 'coton', 'coton']),
#              ('572380527_1', [572380527, 'cosses', 'cosses']),
#              ('572380527_2', [572380527, 'sarrasin', 'sarrasin']),
#              ('572380527_3', [572380527, 'coton', 'coton']),
#              ('572190903_1', [572190903, 'cosses', 'cosses']),
#              ('572190903_2', [572190903, 'sarrasin', 'sarrasin']),
#              ('572190903_3', [572190903, 'coton', 'coton']),
#              ('572096881_1', [572096881, 'coton', 'coton']),
#              ('520283534_1', [520283534, 'coton', 'coton']),
#              ('520283534_2', [520283534, 'cotton', 'cotton']),
#              ('520283534_3', [520283534, 'alogodon', 'alogodón']),
#              ('520283534_4',
#               [520283534,
#                'flocons_de_fibres_de_polyester',
#                'flocons de fibres de polyester']),
#              ('520283534_5',
#               [520283534,
#                'rembourrage_de_flocons_de_fibres_de_polyester',
#                'rembourrage de flocons de fibres de polyester']),
#              ('520283534_6', [520283534, 'amor', 'amor']),
#              ('520283534_7', [520283534, 'paciencia', 'paciencia']),
#              ('533931437_1', [533931437, 'coton', 'coton']),
#              ('533931437_2', [533931437, 'cotton', 'cotton']),
#              ('533931437_3', [533931437, 'algodon', 'algodón']),
#              ('533931437_4', [533931437, 'algodao', 'algodão']),
#              ('533931437_5', [533931437, 'amor_e_paixao', 'amor e paixão']),
#              ('533931437_6', [533931437, 'amor_y_pasion', 'amor y pasión']),
#              ('533931437_7',
#               [533931437, 'love_and_passion', 'love and passion']),
#              ('533944751_1', [533944751, 'coton', 'coton']),
#              ('533944751_2', [533944751, 'cotton', 'cotton']),
#              ('533944751_3', [533944751, 'algodon', 'algodón']),
#              ('533944751_4', [533944751, 'algodao', 'algodão']),
#              ('533944751_5', [533944751, 'amor_e_paixao', 'amor e paixão']),
#              ('533944751_6', [533944751, 'amor_y_pasion', 'amor y pasión']),
#              ('533944751_7',
#               [533944751, 'love_and_passion', 'love and passion']),
#              ('534095253_1', [534095253, 'coton', 'coton']),
#              ('534095253_2', [534095253, 'cotton', 'cotton']),
#              ('534095253_3', [534095253, 'alogodon', 'alogodón']),
#              ('534095253_4',
#               [534095253,
#                'flocons_de_fibres_de_polyester',
#                'flocons de fibres de polyester']),
#              ('534095253_5',
#               [534095253,
#                'rembourrage_de_flocons_de_fibres_de_polyester',
#                'rembourrage de flocons de fibres de polyester']),
#              ('534095253_6', [534095253, 'amor', 'amor']),
#              ('534095253_7', [534095253, 'paciencia', 'paciencia']),
#              ('552805170_1', [552805170, 'cosses', 'cosses']),
#              ('552805170_2', [552805170, 'sarrasin', 'sarrasin']),
#              ('552805170_3', [552805170, 'coton', 'coton']),
#              ('552764072_1', [552764072, 'cosses', 'cosses']),
#              ('552764072_2', [552764072, 'sarrasin', 'sarrasin']),
#              ('552764072_3', [552764072, 'coton', 'coton']),
#              ('565164035_1', [565164035, 'coton', 'coton']),
#              ('565164035_2', [565164035, 'polyester', 'polyester']),
#              ('565164035_3', [565164035, 'cotton', 'cotton']),
#              ('565164035_4', [565164035, 'algodon', 'algodón']),
#              ('565164035_5', [565164035, 'alogodao', 'alogodão']),
#              ('565164035_6', [565164035, 'poliester', 'poliester']),
#              ('565162661_1', [565162661, 'coton', 'coton']),
#              ('565162661_2', [565162661, 'polyester', 'polyester']),
#              ('565162661_3', [565162661, 'cotton', 'cotton']),
#              ('565162661_4', [565162661, 'algodon', 'algodón']),
#              ('565162661_5', [565162661, 'alogodao', 'alogodão']),
#              ('565162661_6', [565162661, 'poliester', 'poliester']),
#              ('531202201_1', [531202201, 'coton', 'coton']),
#              ('531202201_2', [531202201, 'polyester', 'polyester']),
#              ('531202201_3', [531202201, 'cotton', 'cotton']),
#              ('531202201_4', [531202201, 'algodon', 'algodón']),
#              ('531202201_5', [531202201, 'alogodao', 'alogodão']),
#              ('531202201_6', [531202201, 'poliester', 'poliester']),
#              ('531203421_1', [531203421, 'coton', 'coton']),
#              ('531203421_2', [531203421, 'polyester', 'polyester']),
#              ('531203421_3', [531203421, 'cotton', 'cotton']),
#              ('531203421_4', [531203421, 'algodon', 'algodón']),
#              ('531203421_5', [531203421, 'alogodao', 'alogodão']),
#              ('531203421_6', [531203421, 'poliester', 'poliester']),
#              ('520136166_1', [520136166, 'coton', 'coton']),
#              ('520136166_2', [520136166, 'cotton', 'cotton']),
#              ('520136166_3', [520136166, 'algodon', 'algodón']),
#              ('520136166_4', [520136166, 'algodao', 'algodão']),
#              ('520136166_5', [520136166, 'amor_e_paixao', 'amor e paixão']),
#              ('520136166_6', [520136166, 'amor_y_pasion', 'amor y pasión']),
#              ('520136166_7',
#               [520136166, 'love_and_passion', 'love and passion']),
#              ('515983706_1', [515983706, 'coton', 'coton']),
#              ('515983706_2', [515983706, 'cotton', 'cotton']),
#              ('515983706_3', [515983706, 'alogodon', 'alogodón']),
#              ('515983706_4',
#               [515983706,
#                'flocons_de_fibres_de_polyester',
#                'flocons de fibres de polyester']),
#              ('515983706_5',
#               [515983706,
#                'rembourrage_de_flocons_de_fibres_de_polyester',
#                'rembourrage de flocons de fibres de polyester']),
#              ('545239694_1', [545239694, 'coton', 'coton']),
#              ('545239694_2', [545239694, 'polyester', 'polyester']),
#              ('516030644_1', [516030644, 'coton', 'coton']),
#              ('516030644_2', [516030644, 'algodon', 'algodón']),
#              ('516030644_3', [516030644, 'cotton', 'cotton']),
#              ('516030644_4', [516030644, 'algodao', 'algodão']),
#              ('516030644_5',
#               [516030644,
#                'polyester_flakes_inside',
#                'polyester flakes inside']),
#              ('516030644_6',
#               [516030644,
#                'flocons_fibres_de_polyester',
#                'flocons fibres de polyester']),
#              ('516011644_1', [516011644, 'coton', 'coton']),
#              ('516011644_2', [516011644, 'cotton', 'cotton']),
#              ('516011644_3', [516011644, 'algodon', 'algodón']),
#              ('516011644_4', [516011644, 'algodao', 'algodão']),
#              ('516011644_5',
#               [516011644,
#                'flocons_fibres_de_polyester',
#                'flocons fibres de polyester']),
#              ('516011644_6',
#               [516011644,
#                'polyester_flakes_inside',
#                'polyester flakes inside']),
#              ('517607398_1', [517607398, 'coton', 'coton']),
#              ('517607398_2', [517607398, 'cotton', 'cotton']),
#              ('517607398_3', [517607398, 'algodon', 'algodón']),
#              ('517607398_4', [517607398, 'algodao', 'algodão']),
#              ('517607398_5',
#               [517607398,
#                'flocons_fibres_de_polyester',
#                'flocons fibres de polyester']),
#              ('517607398_6',
#               [517607398,
#                'polyester_flakes_inside',
#                'polyester flakes inside']),
#              ('550052370_1',
#               [550052370,
#                'watercolour_on_300_gsm_paper',
#                'watercolour on 300 gsm paper']),
#              ('563844949_1',
#               [563844949,
#                'watercolour_on_300_gsm_paper',
#                'watercolour on 300 gsm paper']),
#              ('563844053_1',
#               [563844053,
#                'watercolour_on_300_gsm_paper',
#                'watercolour on 300 gsm paper']),
#              ('563842757_1',
#               [563842757,
#                'watercolour_on_300_gsm_paper',
#                'watercolour on 300 gsm paper']),
#              ('277453546_1', [277453546, 'watercolour', 'watercolour']),
#              ('277453546_2', [277453546, '140lb_paper', '140lb paper']),
#              ('505865837_1', [505865837, 'giclee_print', 'giclee print']),
#              ('578197144_1', [578197144, 'watercolour', 'watercolour']),
#              ('578197144_2',
#               [578197144,
#                'heavy_arches_cotton_paper',
#                'heavy arches cotton paper']),
#              ('649324277_1',
#               [649324277,
#                'watercolour_on_300_gsm_paper',
#                'watercolour on 300 gsm paper']),
#              ('667217062_1', [667217062, 'watercolour', 'watercolour']),
#              ('667215396_1', [667215396, 'watercolour', 'watercolour']),
#              ('577234570_1', [577234570, 'watercolour', 'watercolour']),
#              ('577231276_1', [577231276, 'watercolour', 'watercolour']),
#              ('633325208_1',
#               [633325208,
#                'watercolour_on_300_gsm_paper',
#                'watercolour on 300 gsm paper']),
#              ('633074522_1', [633074522, 'watercolour', 'watercolour']),
#              ('646887827_1',
#               [646887827,
#                'watercolour_on_cotton_paper',
#                'watercolour on cotton paper']),
#              ('633057280_1',
#               [633057280,
#                'watercolour_on_cotton_paper',
#                'watercolour on cotton paper']),
#              ('493060306_1', [493060306, 'ready_to_hang', 'ready to hang']),
#              ('493060306_2',
#               [493060306, 'acrylic_on_canvas', 'acrylic on canvas']),
#              ('627954146_1', [627954146, 'watercolour', 'watercolour']),
#              ('627954146_2',
#               [627954146,
#                'heavy_cotton_moulin_du_roy_paper',
#                'heavy cotton moulin du roy paper']),
#              ('289633193_1', [289633193, 'watercolour', 'watercolour']),
#              ('289633193_2', [289633193, '140lb_paper', '140lb paper']),
#              ('268898410_1', [268898410, 'watercolour', 'watercolour']),
#              ('268898410_2', [268898410, '140lb_paper', '140lb paper']),
#              ('578310907_1', [578310907, 'watercolour', 'watercolour']),
#              ('578310907_2',
#               [578310907,
#                'heavy_arches_cotton_paper',
#                'heavy arches cotton paper']),
#              ('564071366_1', [564071366, 'watercolour', 'watercolour']),
#              ('564071366_2',
#               [564071366,
#                'heavy_arches_cotton_paper',
#                'heavy arches cotton paper']),
#              ('605567773_1', [605567773, 'watercolour', 'watercolour']),
#              ('605567773_2',
#               [605567773, 'heavy_cotton_paper', 'heavy cotton paper']),
#              ('563489000_1', [563489000, 'watercolour', 'watercolour']),
#              ('563489000_2',
#               [563489000,
#                'heavy_arches_cotton_paper',
#                'heavy arches cotton paper']),
#              ('563487780_1', [563487780, 'watercolour', 'watercolour']),
#              ('563487780_2',
#               [563487780,
#                'heavy_arches_cotton_paper',
#                'heavy arches cotton paper']),
#              ('577037453_1', [577037453, 'watercolour', 'watercolour']),
#              ('577037453_2',
#               [577037453,
#                'heavy_arches_cotton_paper',
#                'heavy arches cotton paper']),
#              ('572969157_1', [572969157, 'watercolour', 'watercolour']),
#              ('572969157_2', [572969157, '140lb_paper', '140lb paper']),
#              ('603174419_1', [603174419, 'watercolour', 'watercolour']),
#              ('603174419_2',
#               [603174419,
#                'artist_quality_cotton_paper',
#                'artist quality cotton paper']),
#              ('574428029_1', [574428029, 'watercolour', 'watercolour']),
#              ('574428029_2',
#               [574428029,
#                'heavy_arches_cotton_paper',
#                'heavy arches cotton paper']),
#              ('560612952_1', [560612952, 'watercolour', 'watercolour']),
#              ('560611236_1', [560611236, 'watercolour', 'watercolour']),
#              ('560610694_1', [560610694, 'watercolour', 'watercolour']),
#              ('560471418_1', [560471418, 'watercolour', 'watercolour']),
#              ('560471418_2',
#               [560471418,
#                'heavy_arches_cotton_paper',
#                'heavy arches cotton paper']),
#              ('574275361_1', [574275361, 'watercolour', 'watercolour']),
#              ('574275361_2',
#               [574275361,
#                'heavy_arches_cotton_paper',
#                'heavy arches cotton paper']),
#              ('574270697_1', [574270697, 'watercolour', 'watercolour']),
#              ('574270697_2',
#               [574270697,
#                'heavy_arches_cotton_paper',
#                'heavy arches cotton paper']),
#              ('574270013_1', [574270013, 'watercolour', 'watercolour']),
#              ('574270013_2',
#               [574270013,
#                'heavy_arches_cotton_paper',
#                'heavy arches cotton paper']),
#              ('574263923_1', [574263923, 'watercolour', 'watercolour']),
#              ('574263923_2',
#               [574263923,
#                'heavy_arches_cotton_paper',
#                'heavy arches cotton paper']),
#              ('574262637_1', [574262637, 'watercolour', 'watercolour']),
#              ('574262637_2',
#               [574262637,
#                'heavy_arches_cotton_paper',
#                'heavy arches cotton paper']),
#              ('560460986_1', [560460986, 'watercolour', 'watercolour']),
#              ('560459626_1', [560459626, 'watercolour', 'watercolour']),
#              ('560459626_2',
#               [560459626,
#                'heavy_arches_cotton_paper',
#                'heavy arches cotton paper']),
#              ('560456948_1', [560456948, 'watercolour', 'watercolour']),
#              ('560456948_2',
#               [560456948,
#                'heavy_arches_cotton_paper',
#                'heavy arches cotton paper']),
#              ('560455620_1', [560455620, 'watercolour', 'watercolour']),
#              ('560455620_2',
#               [560455620,
#                'heavy_arches_cotton_paper',
#                'heavy arches cotton paper']),
#              ('560453704_1', [560453704, 'watercolour', 'watercolour']),
#              ('560453704_2',
#               [560453704, 'carson_300gsm_paper', 'carson 300gsm paper']),
#              ('560453176_1', [560453176, 'watercolour', 'watercolour']),
#              ('560453176_2',
#               [560453176, 'carson_300gsm_paper', 'carson 300gsm paper']),
#              ('573887921_1', [573887921, 'watercolour', 'watercolour']),
#              ('573887921_2',
#               [573887921,
#                'heavy_arches_cotton_paper',
#                'heavy arches cotton paper']),
#              ('573887601_1', [573887601, 'watercolour', 'watercolour']),
#              ('573887601_2',
#               [573887601,
#                'heavy_arches_cotton_paper',
#                'heavy arches cotton paper']),
#              ('573886881_1', [573886881, 'watercolour', 'watercolour']),
#              ('573886881_2',
#               [573886881,
#                'heavy_arches_cotton_paper',
#                'heavy arches cotton paper']),
#              ('573885563_1', [573885563, 'watercolour', 'watercolour']),
#              ('573885563_2',
#               [573885563,
#                'heavy_arches_cotton_paper',
#                'heavy arches cotton paper']),
#              ('573884987_1', [573884987, 'watercolour', 'watercolour']),
#              ('573884987_2',
#               [573884987,
#                'heavy_arches_cotton_paper',
#                'heavy arches cotton paper']),
#              ('573884373_1', [573884373, 'watercolour', 'watercolour']),
#              ('573884373_2',
#               [573884373,
#                'heavy_arches_cotton_paper',
#                'heavy arches cotton paper']),
#              ('560080852_1', [560080852, 'watercolour', 'watercolour']),
#              ('560080852_2',
#               [560080852,
#                'heavy_arches_cotton_paper',
#                'heavy arches cotton paper']),
#              ('573882647_1', [573882647, 'watercolour', 'watercolour']),
#              ('573882647_2',
#               [573882647,
#                'heavy_arches_cotton_paper',
#                'heavy arches cotton paper']),
#              ('560078540_1', [560078540, 'watercolour', 'watercolour']),
#              ('560078540_2',
#               [560078540,
#                'heavy_arches_cotton_paper',
#                'heavy arches cotton paper']),
#              ('573875025_1', [573875025, 'watercolour', 'watercolour']),
#              ('573875025_2',
#               [573875025,
#                'heavy_arches_cotton_paper',
#                'heavy arches cotton paper']),
#              ('560071162_1', [560071162, 'watercolour', 'watercolour']),
#              ('560071162_2',
#               [560071162,
#                'heavy_arches_cotton_paper',
#                'heavy arches cotton paper']),
#              ('573872979_1', [573872979, 'watercolour', 'watercolour']),
#              ('573872979_2',
#               [573872979,
#                'heavy_arches_cotton_paper',
#                'heavy arches cotton paper']),
#              ('560069732_1', [560069732, 'watercolour', 'watercolour']),
#              ('560069732_2',
#               [560069732,
#                'heavy_arches_cotton_paper',
#                'heavy arches cotton paper']),
#              ('288290587_1', [288290587, 'watercolour', 'watercolour']),
#              ('288290587_2', [288290587, '140lb_paper', '140lb paper']),
#              ('274780790_1', [274780790, 'watercolour', 'watercolour']),
#              ('274780790_2', [274780790, '140lb_paper', '140lb paper']),
#              ('645303146_1', [645303146, 'watercolor', 'watercolor']),
#              ('645303146_2',
#               [645303146, 'heavy_cotton_paper', 'heavy cotton paper']),
#              ('645301924_1', [645301924, 'watercolour', 'watercolour']),
#              ('645301924_2',
#               [645301924, 'heavy_cotton_paper', 'heavy cotton paper']),
#              ('643428594_1', [643428594, 'watercolour', 'watercolour']),
#              ('643428594_2',
#               [643428594,
#                'moulin_du_roy_heavy_cotton_paper',
#                'moulin du roy heavy cotton paper']),
#              ('657254493_1', [657254493, 'watercolour', 'watercolour']),
#              ('657254493_2',
#               [657254493,
#                'heavy_cotton_moulin_de_roy_paper',
#                'heavy cotton moulin de roy paper']),
#              ('643412584_1', [643412584, 'watercolour', 'watercolour']),
#              ('643412584_2',
#               [643412584,
#                'moulin_du_roy_cotton_paper',
#                'moulin du roy cotton paper']),
#              ('657241597_1', [657241597, 'watercolour', 'watercolour']),
#              ('657241597_2', [657241597, 'cotton_paper', 'cotton paper']),
#              ('643397620_1', [643397620, 'watercolour', 'watercolour']),
#              ('643397620_2', [643397620, 'fine_liner', 'fine liner']),
#              ('643397620_3', [643397620, 'cotton_paper', 'cotton paper']),
#              ('643395410_1', [643395410, 'watercolour', 'watercolour']),
#              ('643395410_2', [643395410, 'fine_liner', 'fine liner']),
#              ('643395410_3', [643395410, 'cotton_paper', 'cotton paper']),
#              ('269710406_1',
#               [269710406, 'acrylic_on_canvas', 'acrylic on canvas']),
#              ('269710406_2', [269710406, 'giclee_print', 'giclee print']),
#              ('584273438_1',
#               [584273438,
#                'watercolour_on_arches_paper',
#                'watercolour on arches paper']),
#              ('525963529_1', [525963529, 'watercolour', 'watercolour']),
#              ('525963529_2', [525963529, '300_gsm_paper', '300 gsm paper']),
#              ('462031003_1', [462031003, 'watercolour', 'watercolour']),
#              ('462031003_2', [462031003, '140lb_paper', '140lb paper']),
#              ('488036519_1', [488036519, 'watercolour', 'watercolour']),
#              ('488036519_2', [488036519, '140lb_paper', '140lb paper']),
#              ('474540048_1', [474540048, 'watercolour', 'watercolour']),
#              ('474540048_2', [474540048, '140lb_paper', '140lb paper']),
#              ('474531942_1', [474531942, 'watercolour', 'watercolour']),
#              ('474531942_2', [474531942, '140lb_paper', '140lb paper']),
#              ('462023243_1', [462023243, 'watercolour', 'watercolour']),
#              ('462023243_2', [462023243, '140lb_paper', '140lb paper']),
# ...
#              ('583276572_2', [583276572, 'lampwork', 'lampwork']),
#              ('583276572_3',
#               [583276572, 'verre_de_murano', 'verre de murano']),
#              ('552372499_1', [552372499, 'glass', 'glass']),
#              ('654974119_1', [654974119, 'glass', 'glass']),
#              ('641140918_1', [641140918, 'glass', 'glass']),
#              ('654750439_1', [654750439, 'glass', 'glass']),
#              ('654749913_1', [654749913, 'glass', 'glass']),
#              ('640916692_1', [640916692, 'glass', 'glass']),
#              ('552369109_1', [552369109, 'glass', 'glass']),
#              ('549257251_1', [549257251, 'glass', 'glass']),
#              ('538567970_1', [538567970, 'glass', 'glass']),
#              ('640265464_1', [640265464, 'glass', 'glass']),
#              ('609201394_1', [609201394, 'verre', 'verre']),
#              ('623038131_1', [623038131, 'verre', 'verre']),
#              ('609202700_1', [609202700, 'verre', 'verre']),
#              ('623038777_1', [623038777, 'verre', 'verre']),
#              ('653834673_1', [653834673, 'glass', 'glass']),
#              ('549257231_1', [549257231, 'glass', 'glass']),
#              ('653832617_1', [653832617, 'glass', 'glass']),
#              ('639997222_1', [639997222, 'glass', 'glass']),
#              ('639996706_1', [639996706, 'glass', 'glass']),
#              ('639996170_1', [639996170, 'glass', 'glass']),
#              ('639925894_1', [639925894, 'glass', 'glass']),
#              ('653594353_1', [653594353, 'glass', 'glass']),
#              ('639758676_1', [639758676, 'glass', 'glass']),
#              ('623019517_1', [623019517, 'verre_file', 'verre filé']),
#              ('623019517_2', [623019517, 'lampwork', 'lampwork']),
#              ('623019517_3',
#               [623019517, 'verre_de_murano', 'verre de murano']),
#              ('623019397_1', [623019397, 'verre_file', 'verre filé']),
#              ('623019397_2', [623019397, 'lampwork', 'lampwork']),
#              ('623019397_3',
#               [623019397, 'verre_de_murano', 'verre de murano']),
#              ('623018343_1', [623018343, 'verre_file', 'verre filé']),
#              ('623018343_2', [623018343, 'lampwork', 'lampwork']),
#              ('623018343_3',
#               [623018343, 'verre_de_murano', 'verre de murano']),
#              ('609183706_1', [609183706, 'verre_file', 'verre filé']),
#              ('609183706_2', [609183706, 'lampwork', 'lampwork']),
#              ('609183706_3',
#               [609183706, 'verre_de_murano', 'verre de murano']),
#              ('609182888_1', [609182888, 'verre_file', 'verre filé']),
#              ('609182888_2', [609182888, 'lampwork', 'lampwork']),
#              ('609182888_3',
#               [609182888, 'verre_de_murano', 'verre de murano']),
#              ('536813888_1', [536813888, 'glass', 'glass']),
#              ('620084437_1', [620084437, 'glass', 'glass']),
#              ('638939320_1', [638939320, 'verre_file', 'verre filé']),
#              ('638939320_2', [638939320, 'lampwork', 'lampwork']),
#              ('638939320_3',
#               [638939320, 'verre_de_murano', 'verre de murano']),
#              ('652773311_1', [652773311, 'verre_file', 'verre filé']),
#              ('652773311_2', [652773311, 'lampwork', 'lampwork']),
#              ('652773311_3',
#               [652773311, 'verre_de_murano', 'verre de murano']),
#              ('652772799_1', [652772799, 'verre_file', 'verre filé']),
#              ('652772799_2', [652772799, 'lampwork', 'lampwork']),
#              ('652772799_3',
#               [652772799, 'verre_de_murano', 'verre de murano']),
#              ('552530761_1', [552530761, 'glass', 'glass']),
#              ('539941040_1', [539941040, 'verre', 'verre']),
#              ('539941040_2', [539941040, 'murano', 'murano']),
#              ('535452492_1', [535452492, 'glass', 'glass']),
#              ('638266952_1', [638266952, 'glass', 'glass']),
#              ('638266468_1', [638266468, 'glass', 'glass']),
#              ('620083893_1', [620083893, 'glass', 'glass']),
#              ('620084071_1', [620084071, 'glass', 'glass']),
#              ('637748556_1', [637748556, 'glass', 'glass']),
#              ('637747384_1', [637747384, 'glass', 'glass']),
#              ('637746776_1', [637746776, 'glass', 'glass']),
#              ('637746124_1', [637746124, 'glass', 'glass']),
#              ('637742388_1', [637742388, 'verre_file', 'verre filé']),
#              ('637742388_2', [637742388, 'lampwork', 'lampwork']),
#              ('637742388_3',
#               [637742388, 'verre_de_murano', 'verre de murano']),
#              ('637740622_1', [637740622, 'verre_file', 'verre filé']),
#              ('637740622_2', [637740622, 'lampwork', 'lampwork']),
#              ('637740622_3',
#               [637740622, 'verre_de_murano', 'verre de murano']),
#              ('637740094_1', [637740094, 'verre_file', 'verre filé']),
#              ('637740094_2', [637740094, 'lampwork', 'lampwork']),
#              ('637740094_3',
#               [637740094, 'verre_de_murano', 'verre de murano']),
#              ('538783520_1', [538783520, 'glass', 'glass']),
#              ('550149283_1', [550149283, 'glass', 'glass']),
#              ('655624670_1', [655624670, 'glass', 'glass']),
#              ('655185978_1', [655185978, 'glass', 'glass']),
#              ('670083093_1', [670083093, 'glass', 'glass']),
#              ('669514675_1', [669514675, 'polyester', 'polyester']),
#              ('669466103_1', [669466103, 'glass', 'glass']),
#              ('655624714_1', [655624714, 'glass', 'glass']),
#              ('655186020_1', [655186020, 'glass', 'glass']),
#              ('553757353_1', [553757353, 'verre_file', 'verre filé']),
#              ('553757353_2', [553757353, 'lampwork', 'lampwork']),
#              ('553757353_3',
#               [553757353, 'verre_de_murano', 'verre de murano']),
#              ('539956366_1', [539956366, 'verre_file', 'verre filé']),
#              ('539956366_2', [539956366, 'lampwork', 'lampwork']),
#              ('539956366_3',
#               [539956366, 'verre_de_murano', 'verre de murano']),
#              ('539951054_1', [539951054, 'verre_file', 'verre filé']),
#              ('539951054_2', [539951054, 'lampwork', 'lampwork']),
#              ('539951054_3',
#               [539951054, 'verre_de_murano', 'verre de murano']),
#              ('539943562_1', [539943562, 'verre_file', 'verre filé']),
#              ('539943562_2', [539943562, 'lampwork', 'lampwork']),
#              ('539943562_3',
#               [539943562, 'verre_de_murano', 'verre de murano']),
#              ('538356660_1', [538356660, 'stone', 'stone']),
#              ('553743861_1', [553743861, 'verre_file', 'verre filé']),
#              ('553743861_2', [553743861, 'lampwork', 'lampwork']),
#              ('553743861_3',
#               [553743861, 'verre_de_murano', 'verre de murano']),
#              ('551259177_1', [551259177, 'verre', 'verre']),
#              ('551259177_2',
#               [551259177, 'verre_de_murano', 'verre de murano']),
#              ('551259177_3', [551259177, 'lampwork', 'lampwork']),
#              ('551259177_4', [551259177, 'verre_file', 'verre filé']),
#              ('540571394_1', [540571394, 'glass', 'glass']),
#              ('539952484_1', [539952484, 'verre_file', 'verre filé']),
#              ('539952484_2', [539952484, 'lampwork', 'lampwork']),
#              ('539952484_3',
#               [539952484, 'verre_de_murano', 'verre de murano']),
#              ('539947058_1', [539947058, 'verre_file', 'verre filé']),
#              ('539947058_2', [539947058, 'lampwork', 'lampwork']),
#              ('539947058_3',
#               [539947058, 'verre_de_murano', 'verre de murano']),
#              ('615728595_1', [615728595, 'glass', 'glass']),
#              ('601896674_1', [601896674, 'glass', 'glass']),
#              ('553748931_1', [553748931, 'verre_file', 'verre filé']),
#              ('553748931_2', [553748931, 'lampwork', 'lampwork']),
#              ('553748931_3',
#               [553748931, 'verre_de_murano', 'verre de murano']),
#              ('552826677_1', [552826677, 'steel', 'steel']),
#              ('551506243_1', [551506243, 'glass', 'glass']),
#              ('551473203_1', [551473203, 'glass', 'glass']),
#              ('549281955_1', [549281955, 'glass', 'glass']),
#              ('539027644_1', [539027644, 'glass', 'glass']),
#              ('645465729_1', [645465729, 'verre_file', 'verre filé']),
#              ('645465729_2', [645465729, 'lampwork', 'lampwork']),
#              ('645465729_3',
#               [645465729, 'verre_de_murano', 'verre de murano']),
#              ('614016301_1', [614016301, 'glass', 'glass']),
#              ('601148162_1', [601148162, 'glass', 'glass']),
#              ('601148162_2', [601148162, 'stone', 'stone']),
#              ('600178124_1', [600178124, 'glass', 'glass']),
#              ('553757151_1', [553757151, 'verre_file', 'verre filé']),
#              ('553757151_2', [553757151, 'lampwork', 'lampwork']),
#              ('553757151_3',
#               [553757151, 'verre_de_murano', 'verre de murano']),
#              ('553742565_1', [553742565, 'verre_file', 'verre filé']),
#              ('553742565_2', [553742565, 'lampwork', 'lampwork']),
#              ('553742565_3',
#               [553742565, 'verre_de_murano', 'verre de murano']),
#              ('552795979_1', [552795979, 'glass', 'glass']),
#              ('539954154_1', [539954154, 'verre_file', 'verre filé']),
#              ('539954154_2', [539954154, 'lampwork', 'lampwork']),
#              ('539954154_3',
#               [539954154, 'verre_de_murano', 'verre de murano']),
#              ('539951388_1', [539951388, 'verre_file', 'verre filé']),
#              ('539951388_2', [539951388, 'lampwork', 'lampwork']),
#              ('539951388_3',
#               [539951388, 'verre_de_murano', 'verre de murano']),
#              ('539949988_1', [539949988, 'glass', 'glass']),
#              ('538354852_1', [538354852, 'glass', 'glass']),
#              ('643555573_1', [643555573, 'glass', 'glass']),
#              ('552832325_1', [552832325, 'glass', 'glass']),
#              ('552792837_1', [552792837, 'glass', 'glass']),
#              ('539943248_1', [539943248, 'verre_file', 'verre filé']),
#              ('539943248_2', [539943248, 'lampwork', 'lampwork']),
#              ('539943248_3',
#               [539943248, 'verre_de_murano', 'verre de murano']),
#              ('537398606_1',
#               [537398606, 'verre_de_murano', 'verre de murano']),
#              ('537398606_2', [537398606, 'lampwork', 'lampwork']),
#              ('537398606_3', [537398606, 'verre_file', 'verre filé']),
#              ('610996941_1', [610996941, 'glass', 'glass']),
#              ('553744145_1', [553744145, 'verre_file', 'verre filé']),
#              ('553744145_2', [553744145, 'lampwork', 'lampwork']),
#              ('553744145_3',
#               [553744145, 'verre_de_murano', 'verre de murano']),
#              ('549281809_1', [549281809, 'glass', 'glass']),
#              ('549263497_1', [549263497, 'glass', 'glass']),
#              ('539953524_1', [539953524, 'verre_file', 'verre filé']),
#              ('539953524_2', [539953524, 'lampwork', 'lampwork']),
#              ('539953524_3',
#               [539953524, 'verre_de_murano', 'verre de murano']),
#              ('539946772_1', [539946772, 'verre_file', 'verre filé']),
#              ('539946772_2', [539946772, 'lampwork', 'lampwork']),
#              ('539946772_3',
#               [539946772, 'verre_de_murano', 'verre de murano']),
#              ('539941658_1', [539941658, 'verre_file', 'verre filé']),
#              ('539941658_2', [539941658, 'lampwork', 'lampwork']),
#              ('539941658_3',
#               [539941658, 'verre_de_murano', 'verre de murano']),
#              ('535457748_1', [535457748, 'glass', 'glass']),
#              ('535455204_1', [535455204, 'glass', 'glass']),
#              ('597295946_1', [597295946, 'glass', 'glass']),
#              ('549259645_1', [549259645, 'glass', 'glass']),
#              ('539949512_1', [539949512, 'lapis_lazuli', 'lapis lazuli']),
#              ('539954930_1', [539954930, 'verre_file', 'verre filé']),
#              ('539954930_2', [539954930, 'lampwork', 'lampwork']),
#              ('539954930_3',
#               [539954930, 'verre_de_murano', 'verre de murano']),
#              ('539954118_1', [539954118, 'verre_file', 'verre filé']),
#              ('539954118_2', [539954118, 'lampwork', 'lampwork']),
#              ('539954118_3',
#               [539954118, 'verre_de_murano', 'verre de murano']),
#              ('538574220_1', [538574220, 'glass', 'glass']),
#              ('535468708_1', [535468708, 'glass', 'glass']),
#              ('536134612_1', [536134612, 'glass', 'glass']),
#              ('536133784_1', [536133784, 'glass', 'glass']),
#              ('536133332_1', [536133332, 'glass', 'glass']),
#              ('614985597_1', [614985597, 'glass', 'glass']),
#              ('614985597_2', [614985597, 'stone', 'stone']),
#              ('614228937_1', [614228937, 'glass', 'glass']),
#              ('614228937_2', [614228937, 'stone', 'stone']),
#              ('601148694_1', [601148694, 'glass', 'glass']),
#              ('601148694_2', [601148694, 'stone', 'stone']),
#              ('599121928_1', [599121928, 'glass', 'glass']),
#              ('554241573_1', [554241573, 'glass', 'glass']),
#              ('536824826_1', [536824826, 'glass', 'glass']),
#              ('649298307_1', [649298307, 'glass', 'glass']),
#              ('648615875_1', [648615875, 'glass', 'glass']),
#              ('634784664_1', [634784664, 'glass', 'glass']),
#              ('634782690_1', [634782690, 'glass', 'glass']),
#              ('605687684_1', [605687684, 'glass', 'glass']),
#              ('644267429_1', [644267429, 'glass', 'glass']),
#              ('633518962_1', [633518962, 'glass', 'glass']),
#              ('616909797_1', [616909797, 'glass', 'glass']),
#              ('603074858_1', [603074858, 'glass', 'glass']),
#              ('643579405_1', [643579405, 'glass', 'glass']),
#              ('643579155_1', [643579155, 'glass', 'glass']),
#              ('643555791_1', [643555791, 'glass', 'glass']),
#              ('633519168_1', [633519168, 'glass', 'glass']),
#              ('633518786_1', [633518786, 'glass', 'glass']),
#              ('603075426_1', [603075426, 'glass', 'glass']),
#              ('535471536_1', [535471536, 'glass', 'glass']),
#              ('599122338_1', [599122338, 'glass', 'glass']),
#              ('539952616_1', [539952616, 'verre_file', 'verre filé']),
#              ('539952616_2', [539952616, 'lampwork', 'lampwork']),
#              ('539952616_3',
#               [539952616, 'verre_de_murano', 'verre de murano']),
#              ('539951566_1', [539951566, 'verre_file', 'verre filé']),
#              ('539951566_2', [539951566, 'lampwork', 'lampwork']),
#              ('539951566_3',
#               [539951566, 'verre_de_murano', 'verre de murano']),
#              ('539951134_1', [539951134, 'verre_file', 'verre filé']),
#              ('539951134_2', [539951134, 'lampwork', 'lampwork']),
#              ('539951134_3',
#               [539951134, 'verre_de_murano', 'verre de murano']),
#              ('611144725_1', [611144725, 'glass', 'glass']),
#              ('611137519_1', [611137519, 'glass', 'glass']),
#              ('611136739_1', [611136739, 'glass', 'glass']),
#              ('611136111_1', [611136111, 'glass', 'glass']),
#              ('611134609_1', [611134609, 'glass', 'glass']),
#              ('611144591_1', [611144591, 'glass', 'glass']),
#              ('611137335_1', [611137335, 'glass', 'glass']),
#              ('611136003_1', [611136003, 'glass', 'glass']),
#              ('611135321_1', [611135321, 'glass', 'glass']),
#              ('611134711_1', [611134711, 'glass', 'glass']),
#              ('553739099_1', [553739099, 'verre_file', 'verre filé']),
#              ('552531429_1', [552531429, 'glass', 'glass']),
#              ('553753825_1', [553753825, 'verre_file', 'verre filé']),
#              ('553753825_2', [553753825, 'lampwork', 'lampwork']),
#              ('553753825_3',
#               [553753825, 'verre_de_murano', 'verre de murano']),
#              ...])

# %%
dict_final = OrderedDict()

# %%
for (key, row) in data_dict.items() :
    id_listing = row[0]
    key_texte = row[1]
    translated_texte = dic_uniques_lem[key_texte][0]
    lemmanized_texte = dic_uniques_lem[key_texte][1]
    dict_final[key] = [id_listing, key_texte, translated_texte, lemmanized_texte]

# %%
data_final = []

# %%
idx = 0
for (key, row) in dict_final.items():
    data_final.append(row)
    idx = idx + 1

# %%
df = pd.DataFrame(data_final, columns=['id_listing', 'key_texte', 'translated_texte', 'lemmanized_texte'])

# %%
df.head()
# Out:
#    id_listing key_texte translated_texte lemmanized_texte
# 0   550866727     glass            glass            glass
# 1   639584419    copper           copper           copper
# 2   637314587    cotton           cotton           cotton
# 3   550857329    cotton           cotton           cotton
# 4   537056276      wood             wood             wood

# %%
df.to_csv('_data/df_final.csv')

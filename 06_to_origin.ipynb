# %%
import pickle
import pandas as pd
from collections import OrderedDict
import spacy
nlp = spacy.load('en')

# %%
df = pd.read_excel('_data/uniques_translate_final.xlsx')

# %%
noisy_pos_tags = ["PROP","DET","PART","CCONJ","ADP","PRON","VERB","ADJ"]
min_token_length = 2 # minimum token length to remove

# %%
def is_noise(token):
    '''
    standard way to validate spacy tokens
    This method validate all the passed tokens and set true false on it
    '''
    is_noise = False
    if token.pos_ in noisy_pos_tags:
        is_noise = True
    elif token.is_stop == True:
        is_noise = True
    elif token.is_digit == True:
        is_noise = True
    elif token.is_space == True:
        is_noise = True
    elif len(token.string) <= min_token_length:
        is_noise = True
    return is_noise

# %%
def lemmanize(string):
    result_tempo = []
    nlp_words = nlp(string)
    for word in nlp_words:
        if not is_noise(word):
            result_tempo.append(word.lemma_)
    if len(result_tempo) > 0:
        return ' '.join(result_tempo)
    else:
        return ''

# %%
dic_translated = dict()

# %%
for index, row in df.iterrows():
    dic_translated[row.key] = row.en

# %%
dic_translated
# Out:
# {'corail_rouge': 'red coral',
#  'perles_naturelles': 'natural pearls',
#  'coquille': 'shell',
#  'laiton_bronze_antique': 'antique bronze brass',
#  'agate_blanche': 'white agate',
#  'papier_mache': 'paper mache',
#  'cover_painting_from_georges_braque': 'cover painting from george braque',
#  'midcentury_vintage_paquebot_cruise': 'midcentury vintage cruise liner',
#  'vintage_paquebot_brazza_menu': 'vintage liner brazza menu',
#  'donation_for_charity_red_cross_paris': 'donation for charity red cross paris',
#  'metal': 'metal',
#  'texture': 'texture',
#  'lace': 'laced',
#  'papier': 'paper',
#  'zen_and_warm_greetings': 'zen and warm greetings',
#  'miroir': 'mirror',
#  'coton': 'cotton',
#  'peinture': 'painting',
#  'orange': 'orange',
#  'vegetal': 'vegetal',
#  'medieval': 'medieval',
#  'baleine_en_acier': 'steel whale',
#  'synthetique': 'synthetic',
#  'cone': 'cone',
#  'tissus': 'tissues',
#  'laine': 'wool',
#  'photocopie': 'photocopy',
#  'atelier_sylphe': 'sylphe workshop',
#  'coton_recycle': 'recycled cotton',
#  'perle': 'pearl',
#  'dentelle': 'lace',
#  'gouache': 'gouache',
#  'mirabelle': 'mirabelle',
#  'fiole': 'flask',
#  'very_feminine_bel_buckle': 'very feminine beautiful buckle',
#  'strass': 'strass',
#  'bronze': 'bronze',
#  'metal_silver': 'silver metal',
#  'bonne_annee_happy_new_year_wishes': 'happy new year happy new year wishes',
#  'coton_biologique': 'organic cotton',
#  'fil_coton': 'cotton thread',
#  'fil_de_fer': 'wire',
#  'fil_de_fer_recuit': 'annealed wire',
#  'cuir': 'leather',
#  'peinture_acrylique': 'acrylic paint',
#  'brun': 'brown',
#  'noir': 'black',
#  'craie_noire': 'black chalk',
#  'encre': 'ink',
#  'bleu': 'blue',
#  'marron': 'Brown',
#  'vert': 'green',
#  'ocre': 'ocher',
#  'vinyle': 'vinyl',
#  'veste_patchwork': 'patchwork jacket',
#  'manteau_patchwork': 'patchwork coat',
#  'patchwork_enfant': 'child patchwork',
#  'glissiere': 'slide',
#  'email': 'E-mail',
#  'georgette_soie': 'silk georgette',
#  'peridot': 'peridot',
#  'chine': 'China',
#  'papier_haut_grammage': 'heavyweight paper',
#  'papier_art': 'art paper',
#  'brocante': 'flea market',
#  'soie': 'silk',
#  'chaine': 'chain',
#  'giclee': 'splash',
#  'vintage_paris_map': 'vintage paris map',
#  'photogravure': 'photogravure',
#  'vintage_photogravure': 'vintage photoengraving',
#  'photogravure_book_plate': 'photogravure book plate',
#  'bakelite': 'bakelite',
#  'vintage_smurfs_handkerchief': 'vintage smurfs handkerchief',
#  'smurfs_schlumpfe_schtroumpfette': 'smurfs schlumpfe smurfette',
#  'diamante_ondells': 'diamante ondells',
#  'coton_cotton': 'cotton cotton',
#  'col_roule': 'turtleneck',
#  'coutil': 'duck',
#  'busc': 'busk',
#  'oeillets': 'carnations',
#  'paris_le_printemps_store': 'paris spring store',
#  'vintage_paris_medal': 'vintage paris medal',
#  'paris_printemps_store': 'paris spring store',
#  'detachable_ajustable_strap': 'detachable adjustable strap',
#  'papier_photo': 'photo paper',
#  'fil_de_fer_noir': 'black iron wire',
#  'vermeil': 'red',
#  'fil_de_broderie': 'embroidery thread',
#  'cendre': 'ash',
#  'gres': 'sandstone',
#  'bois': 'wood',
#  'porcelaine_dure': 'hard porcelain',
#  'cerclage': 'strapping',
#  'ruban': 'ribbon',
#  'lacet': 'lace',
#  'lacage': 'the cage',
#  'cerceau': 'hoop',
#  'tissu': 'fabric',
#  'lin': 'linen',
#  'feutrine': 'Felt',
#  'fil_de_couture': 'sewing thread',
#  'brade': 'brade',
#  'opale': 'opal',
#  'plastique': 'plastic',
#  'verre_fume': 'smoked glass',
#  'porc_leather': 'leather pig',
#  'cuir_rouge': 'red leather',
#  'ceramique': 'ceramic',
#  'terre_cuite': 'terracotta',
#  'polaire': 'polar',
#  'fil': 'wire',
#  'bourrage': 'jam',
#  'galon_medieval': 'medieval gallon',
#  'taffetas_broderie_ruban': 'taffeta ribbon embroidery',
#  'verre': 'glass',
#  'platre': 'plaster',
#  'strass_glitter_puffy_effect_paint_embroidery': 'glitter glitter puffy effect paint embroidery',
#  'alliage': 'alloy',
#  'elastique': 'elastic',
#  'laiton': 'brass',
#  'recycled_enveloppe': 'recycled envelope',
#  'gris': 'Grey',
#  'oxyde': 'oxide',
#  'plaquage_or': 'gold plating',
#  'bouton_en_plastique': 'plastic button',
#  'lapis': 'lapis',
#  'boutons': 'buttons',
#  'rembourrage': 'padding',
#  'ammonite': 'ammonite',
#  'tissu_coton': 'cotton fabric',
#  'coton_fabric': 'cotton fabric',
#  'lapis_lazuli': 'lapis lazuli',
#  'gold_chain_maille': 'gold chain mesh',
#  'copal_amber': 'copal amber',
#  'pneu': 'tire',
#  'chambre_a_air': 'inner tube',
#  'pongee': 'pongée',
#  'daim_noir': 'black suede',
#  'cuir_noir': 'black leather',
#  'cuir_marron': 'brown leather',
#  'cuir_beige': 'beige leather',
#  'suede': 'Sweden',
#  'toile_de_jouy': 'jouy cloth',
#  'toile_du_jouy': 'canvas of jouy',
#  'amethystes': 'amethysts',
#  'plaque_or': 'gold plated',
#  'corail': 'coral',
#  'vintage_french_applique': 'vintage french applique',
#  'lace_applique': 'lace applique',
#  'velours_noir': 'black velvet',
#  'lace_appliques': 'applique lace',
#  'us_or_eu_high_quality_removable_vinyl': 'high quality removable vinyl',
#  'acrylique': 'acrylic',
#  'toile_coton': 'cotton canvas',
#  'chassis_bois': 'wooden frame',
#  'affaires_nomades_original_printed_linen': 'nomadic business original printed linen',
#  'alpaga': 'alpaca',
#  'merinos': 'merino',
#  'laine_merinos': 'merino wool',
#  'boutons_en_bois': 'wooden buttons',
#  'cristal_swarovski': 'swarovski crystal',
#  'merinos_alpaga_soie': 'silk alpaca merinos',
#  'pur_coton': 'pure cotton',
#  'copal': 'copal',
#  'voile_de_coton': 'cotton voile',
#  'papier_japon': 'japan paper',
#  'toile_de_coton_epaisse': 'thick cotton canvas',
#  'toile_de_coton': 'cotton canvas',
#  'cuivre': 'copper',
#  'golden_gouache': 'golden gouache',
#  'laque': 'lacquer',
#  'toile': 'canvas',
#  'cuir_lezard': 'lizard leather',
#  'opaline': 'opaline',
#  'oeillet': 'eyelet',
#  'corde_coton': 'cotton rope',
#  'maille': 'stitch',
#  'pure_laine': 'pure wool',
#  'bouton_en_etain': 'pewter button',
#  'laine_lavable_machine': 'washable wool machine',
#  'tissu_vert': 'green fabric',
#  'chinese_cloisonne': 'Chinese cloisonne',
#  'cuir_bleu': 'blue leather',
#  'coton_bleu': 'blue cotton',
#  'cou': 'neck',
#  'cristal_de_swarovski': 'swarovski crystal',
#  'silver_gouache': 'silver gouache',
#  'polyamide': 'polyamide',
#  'nacre': 'pearly',
#  'fer_forge': 'wrought iron',
#  'marcassites': 'marcasite',
#  'polyamide_satin': 'satin polyamide',
#  'resine': 'resin',
#  'argile': 'clay',
#  'pate_polymere': 'polymer clay',
#  'canvas_coton': 'cotton canvas',
#  'pression': 'pressure',
#  'bouton': 'button',
#  'bouton_de_pression': 'pressure button',
#  'fonte': 'melting',
#  'fusain': 'charcoal',
#  'fibres_melangees': 'mixed fibers',
#  'huile': 'oil',
#  'huile_sur_panneau': 'oil on panel',
#  'laine_lavable_en_machine': 'washable wool machine',
#  'polyester_polyamide_mix': 'polyester polyamide mix',
#  'emaille': 'enamel',
#  'sepia': 'sepia',
#  'baleines': 'whales',
#  'clous': 'nails',
#  'paris_photography': 'paris photography',
#  'ombre_silk_roses': 'pink silk shade',
#  'cuir_rose': 'pink leather',
#  'coton_rose': 'pink cotton',
#  'frene': 'ash',
#  'peuplier': 'poplar',
#  'ardoise': 'slate',
#  'vernis': 'varnish',
#  'couleur': 'color',
#  'citrine': 'citrine',
#  'raw_citrine': 'raw citrine',
#  'cristal': 'crystal',
#  'perles': 'beads',
#  'cable': 'cable',
#  'plaque_argent': 'silver plated',
#  'perles_de_boheme': 'bohemian pearls',
#  'perles_de_rocailles': 'seed beads',
#  'rocailles': 'rockeries',
#  'perle_argile_peinte': 'painted clay bead',
#  'heart_diamante': 'heart diamante',
#  'inox': 'stainless steel',
#  'laine_acrylique': 'acrylic wool',
#  'bouton_bois': 'wood button',
#  'coton_lycra': 'lycra cotton',
#  'feutre': 'felt',
#  'laine_feutree': 'felted wool',
#  'flanelle': 'flannel',
#  'soie_non_violente_sauvage': 'wild non-violent silk',
#  'teinture_vegetale_biologique': 'organic vegetable dye',
#  'soie_tissee_en_france': 'woven silk in France',
#  'teinture_vegetale_indigo': 'indigo vegetable dye',
#  'corde_et_dentelle_de_coton_bion': 'bion cotton rope and lace',
#  'soie_non_violente': 'non-violent silk',
#  'teinture_vegetale': 'vegetable dye',
#  'natural_dye_woad_isatis_tinctoria': 'natural dye woad isatis tinctoria',
#  'teinture_vegetale_naturelle': 'natural vegetable dye',
#  'pastel_isatis_tinctoria': 'pastel isatis tinctoria',
#  'lapis_beads': 'lapis beads',
#  'cordon_et_dentelle_en_coton_biologique': 'organic cotton cord and lace',
#  'fait_main_et_teint_a_la_main': 'handmade and dyed by hand',
#  'teinture_vegetale_indigo_pastel': 'pastel indigo vegetable dye',
#  'bracelet_pompon_artisanal': 'handmade pompom bracelet',
#  'teintures_vegetales': 'vegetable dyes',
#  'isatis_tinctoria': 'isatis tinctoria',
#  'coton_marron': 'brown cotton',
#  'chrome': 'chromium',
#  'cuir_gris': 'gray leather',
#  'coton_gris': 'gray cotton',
#  'paillette': 'paillette',
#  'argile_polymere': 'polymer clay',
#  'plateau_bague_reglable_metal': 'metal adjustable ring tray',
#  'brode': 'embroidered',
#  'serti': 'set',
#  'perles_de_rocaille': 'seed beads',
#  'perles_de_verre': 'glass beads',
#  'fibres_synthetiques': 'synthetic fibers',
#  'soie_sauvage_nonviolente': 'nonviolent wild silk',
#  'dentelle_en_coton_biologique': 'organic cotton lace',
#  'teinture_vegetale_de_garance': 'vegetable dye of madder',
#  'bouton_en_nacre': 'mother of pearl button',
#  'joie': 'joy',
#  'pave': 'pavement',
#  'noyer': 'walnut',
#  'bois_clair': 'clear wood',
#  'bois_fonce': 'dark wood',
#  'bois_blanc': 'White wood',
#  'boule': 'ball',
#  'chaine_argent': 'silver chain',
#  'bouton_pression': 'snap',
#  'patchouli': 'patchouli',
#  'fil_recuit': 'annealed wire',
#  'fer_noir': 'black iron',
#  'liege': 'cork',
#  'papier_epais': 'thick paper',
#  'papier_350gr': '350gr paper',
#  'carte_postale': 'Post card',
#  'papier_ecofriendly': 'ecofriendly paper',
#  'papier_source_renouvable': 'renewable source paper',
#  'carte_postale_illustree': 'illustrated postcard',
#  'broder': 'embroider',
#  'assiettes': 'plates',
#  'fleurs': 'flowers',
#  'coton_lace': 'lace cotton',
#  'paillettes': 'flakes',
#  'verres': 'glasses',
#  'corde': 'rope',
#  'coton_blanc': 'white cotton',
#  'rock_cristal': 'crystal rock',
#  'decoration': 'decoration',
#  'alliage_metal': 'alloy metal',
#  'sable': 'sand',
#  'metal_argente': 'silver plated',
#  'perles_en_pate_de_verre': 'glass paste beads',
#  'attaches_de_coton': 'cotton fasteners',
#  'fil_de_soie_sauvage': 'wild silk thread',
#  'teinture_naturelle_vegetale': 'natural vegetable dye',
#  'perle_de_rocaille': 'pearl of rockery',
#  'chain_maille': 'mesh chain',
#  'soutache_silk_cord': 'soutache silk cord',
#  'galuchat': 'sharkskin',
#  'peau_de_requin': 'shark skin',
#  'fermoir': 'clasp',
#  'biais': 'angle',
#  'bordure': 'border',
#  'doublure': 'lining',
#  'paris_romantic_photography': 'paris romantic photography',
#  'vermeil_beads': 'vermeil beads',
#  'pastell_auf_papier': 'pastell auf paper',
#  'pastel_sur_papier': 'pastel on paper',
#  'paris_apartment_chic_decor': 'paris apartment chic decor',
#  'paris_apartment_chic': 'paris apartment chic',
#  'plastron': 'breastplate',
#  'plexiglas': 'plexiglass',
#  'transfert': 'transfer',
#  'swarovsky_decorated_rondelles': 'swarovsky decorated washers',
#  'druzy_citrine': 'druzy citrine',
#  'cotons': 'cottons',
#  'imprimer': 'to print',
#  'mariee': 'married',
#  'rustique_x': 'rustic x',
#  'tissu_lin': 'linen fabric',
#  'ficelle': 'string',
#  'lin_naturel': 'natural linen',
#  'papier_recycle': 'recycled paper',
#  'imitation_bois': 'imitation wood',
#  'cuivre_emaille': 'enameled copper',
#  'porcelaine_froide': 'cold porcelain',
#  'polystyrene': 'polystyrene',
#  'terra_cotta': 'terra cotta',
#  'strass_swarovski': 'swarovski rhinestones',
#  'swarovski_strass': 'swarovski rhinestone',
#  'laqueur': 'lacquerer',
#  'creation_personnaliser': 'creation customize',
#  'mariage': 'wedding',
#  'teinture_vegetale_chlorophylle_alfafa': 'vegetable dye chlorophyll alfafa',
#  'patience_et_soin': 'patience and care',
#  'aquarelle_imprimee_sur_papier_recycle': 'watercolor printed on recycled paper',
#  'vintage_paris_le_ritz_necklace': 'vintage paris the ritz necklace',
#  'vintage_paris_chic_accessory': 'vintage paris chic accessory',
#  'ouate': 'wadding',
#  'pression_metal': 'metal pressure',
#  'ruban_velours': 'velvet ribbon',
#  'lapis_glass': 'lapis glass',
#  'bambou': 'bamboo',
#  'argente': 'silver',
#  'vieilli': 'aged',
#  'piece': 'piece',
#  'monnaie': 'change',
#  'mousqueton': 'carabiner',
#  'goutte': 'drop',
#  'anneau': 'ring',
#  'jupe': 'skirt',
#  'chene': 'Oak',
#  'fil_cire': 'waxed thread',
#  'natural_dye_from_woad_isatis_tinctoria': 'natural dye from woad isatis tinctoria',
#  'soie_sauvage_bio_nonviolente': 'nonviolent organic wild silk',
#  'teinture_vegetale_de_pastel_isatis_tinctoria': 'vegetable dye of pastel isatis tinctoria',
#  'soie_biologique_nonviolente': 'nonviolent organic silk',
#  'teinture_vegetale_ecorce_eucalyptus_bio': 'vegetable dyes eucalyptus bark bio',
#  'noir_et_blanc': 'black and white',
#  'encre_de_chine': 'Chinese ink',
#  'pompon': 'pompon',
#  'dentelle_noire': 'black lace',
#  'pompon_noir': 'black pompon',
#  'rubans_satin': 'satin ribbons',
#  'doublure_satin_noir': 'black satin lining',
#  'perles_agate_mousse': 'agate foam beads',
#  'soie_doupion': 'silk doupion',
#  'perles_amethyste': 'amethyst beads',
#  'galon_noir': 'black braid',
#  'baleines_metal': 'metal whales',
#  'perles_oeil_de_tigre': 'tiger eye beads',
#  'boutons_de_soie': 'silk buttons',
#  'galons': 'stripes',
#  'cabochon_oeil_de_tigre_tigereye': 'tigereye tiger eye cabochon',
#  'filigrane_cuivre': 'copper filigree',
#  'perles_labradorite': 'labradorite beads',
#  'filigrane_argente': 'silver filigree',
#  'oeil_de_tigre': 'Eye of tiger',
#  'feuilles_argentees': 'silver leaves',
#  'chaines_argentees': 'silver chains',
#  'azurite_malachite_beads': 'azurite malachite beads',
#  'fleur_en_taffetas': 'taffeta flower',
#  'perle_de_jade': 'jade pearl',
#  'fleur_taffetas': 'taffeta flower',
#  'coton_fabric_with_watches': 'cotton fabric with watches',
#  'coton_motifs_horloge': 'cotton patterns clock',
#  'azurite_beads': 'azurite beads',
#  'soie_turquoise': 'turquoise silk',
#  'perles_azurite_malachite': 'malachite azurite beads',
#  'tissu_noir': 'black fabric',
#  'perle_jade': 'pearl jade',
#  'chinese_knot_applique': 'chinese knot applique',
#  'coeur_onyx': 'onyx heart',
#  'appliques_asiatiques': 'Asian wall lights',
#  'taffetas_fleuri_rouge': 'red floral taffeta',
#  'cabochon_pierre_de_lune': 'cabochon moonstone',
#  'baleine': 'whale',
#  'perles_de_quartz': 'quartz beads',
#  'doublure_satin': 'satin lining',
#  'brocart': 'brocade',
#  'rubans': 'ribbons',
#  'cuivre_dore': 'golden copper',
#  'cuivre_argente': 'silvered copper',
#  'laiton_dore_or_fin': 'fine gold plated brass',
#  'acetate': 'acetate',
#  'bic_biro': 'bic biro',
#  'pate_de_verre': 'molten glass',
#  'fausse_fourrure': 'fake fur',
#  '5_disques_vinyl_vintage': '5 vintage vinyl records',
#  'disque_vinyl': 'vinyl disc',
#  'apprets_en_laiton_sans_nickel': 'nickel-free brass primers',
#  'paris_apartment_chic_accessory_circa_1900': 'paris apartment chic accessory circa 1900',
#  'argent_gris': 'silver grey',
#  'coton_bachette': 'cowhide cotton',
#  'simili_cuir': 'leatherette',
#  'toile_de_jouy_en_coton': 'cotton jouy cloth',
#  'cercle': 'circle',
#  'canevas': 'canvas',
#  'papier_ancien': 'old paper',
#  'metis': 'metis',
#  'french_written_tisse_sur_soie_woven_on_silk': 'french written woven on silk woven on silk',
#  'cristal_paved_rondelles': 'crystal paved washers',
#  'perle_tahiti': 'pearl tahiti',
#  'cuir_tresse': 'braided leather',
#  'perle_noire': 'black Pearl',
#  'perle_de_tahiti': 'Pearl of Tahiti',
#  'cuir_australien': 'Australian leather',
#  'perle_mer_sud': 'pearl south sea',
#  'fourrure': 'fur',
#  'woad_isatis_tinctoria': 'woad isatis tinctoria',
#  'perles_de_bois_brut': 'raw wood beads',
#  'corde_en_coton_bio': 'organic cotton rope',
#  'teinture_avec_du_pastel_isatis_tinctoria': 'dyeing with pastel isatis tinctoria',
#  'fait_a_la_main_avec_patience_et_douceur': 'handmade with patience and gentleness',
#  'plume_metal': 'metal feather',
#  'mousseline': 'muslin',
#  'dessin': 'drawing',
#  'autocollant': 'sticker',
#  'tatouage': 'tattoo',
#  'decalcomanie': 'transfer',
#  'pure_laine_vierge': 'natural wool',
#  'perle_nacree': 'pearly pearl',
#  'agate_verte': 'green agate',
#  'emeraude': 'emerald',
#  'hematite': 'hematite',
#  'perle_indienne': 'Indian pearl',
#  'serviette_eponge': 'towel',
#  'corne': 'horn',
#  'laine_et_alpaga': 'wool and alpaca',
#  'bouton_en_bois': 'wooden button',
#  'rond_leather': 'round leather',
#  'soie_synthetique': 'synthetic silk',
#  'guipure_lace': 'lace guipure',
#  'paris_france': 'Paris, France',
#  'brocard_de_soie': 'silk brocade',
#  'perles_verre': 'glass beads',
#  'emaux': 'enamels',
#  'patine': 'patina',
#  'fil_inox': 'stainless steel wire',
#  'hetre': 'beech',
#  'cp_plaque_chene': 'cp oak veneer',
#  'fil_aluminium': 'aluminum wire',
#  'impression_numerique_sur_papier': 'digital printing on paper',
#  'vinyle_strap': 'vinyl strap',
#  'vermeil_sterling': 'sterling vermeil',
#  'linoleum': 'linoleum',
#  'medium': 'medium',
#  'chocolat': 'chocolate',
#  'swarovski_cristal': 'swarovski crystal',
#  'cornaline': 'cornelian',
#  'ivoire': 'ivory',
#  'ecru': 'raw',
#  'fil_argent': 'silver wire',
#  'emaux_verts': 'green enamels',
#  'emaux_noirs': 'black enamel',
#  'emaux_blancs': 'white glazes',
#  'panneaux': 'panels',
#  'laine_merinos_alpaga': 'alpaca merino wool',
#  'emaux_jaune_noir': 'black yellow enamel',
#  'emaux_blanc_noir': 'black white enamel',
#  'panne_de_velours': 'velvet tip',
#  'verre_de_venise': 'glass of venice',
#  'verre_de_murano': 'Murano glass',
#  'verre_venitien': 'Venetian glass',
#  'chrysoprase': 'chrysoprasus',
#  'emaux_bleus': 'blue enamels',
#  'tresse': 'braided',
#  'gre': 'will',
#  'etain': 'tin',
#  'sangle': 'strap',
#  'dentelle_et_lin': 'lace and linen',
#  'perle_grise': 'gray pearl',
#  'perles_de_tahiti': 'Tahitian pearls',
#  'papier_de_crayon': 'pencil paper',
#  'perles_en_metal': 'metal beads',
#  'dorure': 'gilding',
#  'jade_jadeite': 'jadeite jade',
#  'fleurs_artificial': 'artificial flowers',
#  'perles_fimo': 'fimo beads',
#  'perles_en_verre': 'glass beads',
#  'perles_metal_cuivre': 'coppery metal beads',
#  'pierre_naturelle': 'natural stone',
#  'jaspe': 'jasper',
#  'jaspe_mokaite': 'jasper mokaite',
#  'lainage': 'woolen cloth',
#  'rocaille': 'rockery',
#  'tulle_plumetis': 'tulle plumetis',
#  'ph_neutral_venyl_glue': 'ph neutral venyl glue',
#  'fil_c_lon': 'thread c lon',
#  'ocre_jaune': 'yellow ochre',
#  'crayon_de_papier': 'pencil',
#  'chrysoprase_stone': 'chrysoprase stone',
#  'couture_fils_a_fin': 'sewing threads to end',
#  'pur_merinos': 'pure merino',
#  'biologique': 'biological',
#  'perles_semi_precieuses': 'semi precious pearls',
#  'contre_plaque': 'against plated',
#  'plaque_chene': 'oak veneer',
#  'rubis': 'ruby',
#  'imprime': 'printed',
#  'feutres': 'felts',
#  'toho_perles': 'toho pearls',
#  'bois_sec': 'dry wood',
#  'rondelles_de_bois': 'wooden washers',
#  'epicea': 'spruce',
#  'bois_tendre': 'softwood',
#  'marcassite': 'marcasite',
#  'coton_noir': 'black cotton',
#  'cuir_orange': 'orange leather',
#  'coton_orange': 'orange cotton',
#  'branches_de_bois': 'wooden branches',
#  'bois_noble': 'noble wood',
#  'bois_brun': 'brown wood',
#  'pattes': 'paws',
#  'autruche': 'ostrich',
#  'paris_vintage_chic_fashion_accessory': 'paris vintage chic fashion accessory',
#  'mousseline_imprimee': 'printed chiffon',
#  'lycra_lame': 'lycra blade',
#  'jersey_coton': 'cotton jersey',
#  'paris': 'Paris',
#  'sighthound_animalerie': 'sighthound pet shop',
#  'lin_et_soie': 'linen and silk',
#  'velours_de_soie': 'silk velvet',
#  'dentelle_coton_richelieu': 'cotton laces',
#  'mobile_en_bois': 'wooden mobile',
#  'molleton': 'duffel',
#  'bouclette': 'terry',
#  'colle': 'glue',
#  'afghani_lapis': 'afghani lapis',
#  'note_de_musique': 'music note',
#  'melodie': 'melody',
#  'violoncelle': 'cello',
#  'guitare': 'guitar',
#  'lin_liberty': 'liberty linen',
#  'matelasse': 'quilted',
#  'rayonne': 'rayon',
#  'satin_de_soie': 'silk satin',
#  'mousseline_de_soie': 'chiffon',
#  'maillon': 'link',
#  'tige': 'stem',
#  'paris_apartment': 'Paris Apartment',
#  'fil_cable': 'wired wire',
#  'nuits_st_georges': 'nights st georges',
#  'french_famous_cognac_courvoisier_alcool': 'french famous cognac courvoisier alcool',
#  'made_in_years_1970_in_inox': 'made in years 1970 in stainless steel',
#  'soie_naturelle': 'natural silk',
#  'indigo_botanique_biologique': 'organic botanical indigo',
#  'saphir_bleu': 'blue sapphire',
#  'or_jaune': 'yellow gold',
#  'or_brosse': 'brushed gold',
#  'perle_baroque': 'baroque pearl',
#  'fermoir_securitaire': 'secure clasp',
#  'argenterie_ancienne': 'old silverware',
#  'algue': 'seaweed',
#  'tapisserie': 'tapestry',
#  'presse': 'press',
#  'gaufrage': 'embossing',
#  'vaseline_beads': 'vaseline beads',
#  'anneau_ajustable': 'adjustable ring',
#  'ebene': 'ebony',
#  'plaster_of_paris': 'plaster of paris',
#  'ruban_de_polyester': 'polyester ribbon',
#  'lezard': 'lizard',
#  'vintage_canada_mid_century_postcard': 'vintage canada mid century postcard',
#  'vancouver_canada_edited': 'vancouver canada edited',
#  'metal_dore': 'golden metal',
#  'cabochon_rubis': 'ruby cabochon',
#  'baguette_diamant': 'diamond stick',
#  'papier_bristol_fsc': 'fsc Bristol paper',
#  'fils_a_broder_coton_dmc': 'dmc cotton embroidery thread',
#  'fils_dmc': 'dmc son',
#  'macassar_ebony': 'macassar ebony',
#  'lin_melange_soie': 'silk blend linen',
#  'eponge': 'sponge',
#  'email_noir': 'black enamel',
#  'email_blanc': 'white enamel',
#  'ruban_satin': 'satin ribbon',
#  'craie': 'chalk',
#  'cadre_en_bois': 'wooden frame',
#  'pate_fimo': 'Fimo clay',
#  'tube_en_metal': 'metal tube',
#  'cordon_en_cuir': 'leather cord',
#  'peau_de_raie_poncee': 'pitted skate skin',
#  'glas': 'knell',
#  'papier_decoupe': 'paper cut',
#  'limoges': 'limoges',
#  'hand_knitted_capelet': 'hand knitted capelet',
#  'gray_yarn_capelet': 'gray yarn capelet',
#  'gray_yarn_knitted_capelet': 'gray yarn knitted capelet',
#  'capelet_soft_acrylic_gray_yarn_knitted': 'capelet soft acrylic gray yarn knitted',
#  'soft_gray_hand_knitted_capelet': 'soft gray hand knitted capelet',
#  'capelet_gray_yarn_handknitted': 'capelet gray yarn handknitted',
#  'soft_gray_knitted_capelet': 'soft gray knitted capelet',
#  'lavender_blue_yarn_capelet': 'lavender blue yarn capelet',
#  'capelet_lavender_blue_yarn_handknitted': 'capelet lavender blue yarn handknitted',
#  'lavender_blue_hand_knitted_capelet': 'lavender blue hand knitted capelet',
#  'handknitted_capelet_lavender_blue_acrylic': 'handknitted capelet lavender blue acrylic',
#  'capelet_acrylic_lavender_blue_yarn_knitted': 'capelet acrylic lavender blue yarn knitted',
#  'lavender_blue_yarn_knitted_capelet': 'lavender blue yarn knitted capelet',
#  'papier_lamali': 'lamali paper',
#  'ruban_de_gros_grain_polyester': 'polyester grosgrain ribbon',
#  'lycra': 'lycra',
#  'anis': 'anise',
#  'daim': 'suede',
#  'enduit': 'coating',
#  'pencil_aquarelle': 'watercolor pencil',
#  'turquoise_naturelle': 'natural turquoise',
#  'nain_jaune': 'yellow dwarf',
#  'couleur_bronze': 'bronze color',
#  'laiton_dore': 'golden brass',
#  'yeux_de_securite': 'safety eyes',
#  'laine_melange_laine_et_acrylique': 'wool and acrylic wool blend',
#  'drap_ancien': 'old cloth',
#  'tissu_fleuri': 'flowery fabric',
#  'vintage_paris_chic_dining': 'vintage paris chic dining',
#  'paris_apartment_chic_accessory': 'paris apartment chic accessory',
#  'polyamide_nylon': 'nylon polyamide',
#  'dore': 'golden',
#  'soie_brute': 'raw silk',
#  'soie_matka': 'matka silk',
#  'soie_noire': 'black silk',
#  'image_vectorielle': 'vector image',
#  'vecteur': 'vector',
#  'art_graphique': 'graphic art',
#  'graphisme': 'graphics',
#  'image_numerique': 'digital image',
#  'image_digitale': 'digital image',
#  'art_graphisme': 'art graphics',
#  'pierre_de_lave': 'lava stone',
#  'illustration_numerique': 'digital illustration',
#  'magie': 'magic',
#  'celluloid': 'celluloid',
#  'rhodoid': 'rhodoïd',
#  'popeline': 'poplin',
#  'cristal_beads': 'crystal beads',
#  'coton_bio': 'organic cotton',
#  'soie_naturelle_tissee_en_france': 'natural silk woven in France',
#  'teinture_vegetale_par_ecoprint': 'vegetable dye by ecoprint',
#  'plantes_bio_ou_sauvages_fraiches': 'fresh organic or wild plants',
#  'ruban_de_satin': 'satin ribbon',
#  'fleur_en_tissu': 'fabric flower',
#  'gold_fille_ear_wires': 'gold girl ear wires',
#  'recycle': 'recycled',
#  'fichier_pdf': 'PDF file',
#  'tinte': 'tinkles',
#  'tinta': 'tinta',
#  'soja': 'soy',
#  'chainette': 'chain',
#  'telechargement_numerique': 'digital download',
#  'cuir_de_galuchat': 'shagreen leather',
#  'agate_en_poire': 'pear agate',
#  'perles_fantaisies': 'fancy beads',
#  'arg_graphique': 'graphical',
#  'imag_vectorielle': 'vector imag',
#  'bois_huile': 'oiled wood',
#  'bois_naturel': 'natural wood',
#  'naturel': 'natural',
#  'pressions': 'pressures',
#  'agrafes': 'staple',
#  'gomme_a_graver': 'engraving eraser',
#  'perles_de_rocaille_miyuki': 'miyuki seed beads',
#  'opal_rondelles': 'opal washers',
#  'pastel_isatis_tinctoria_bio': 'pastel isatis tinctoria bio',
#  'processus_de_teinture_bio': 'organic dyeing process',
#  'plaquage_or_rose': 'pink gold plating',
#  'coton_imprime_eokotex': 'eokotex printed cotton',
#  'cordelette': 'cord',
#  'flocage': 'flocking',
#  'fil_dor': 'Golden thread',
#  'gold_passementerie': 'gold trimmings',
#  'alfenide': 'nickel-silver',
#  'abaca': 'abaca',
#  'fils_a_broder': 'embroidery thread',
#  'coton_a_motif': 'patterned cotton',
#  'limoges_china': 'limoges china',
#  'acier': 'steel',
#  'indigo_naturel': 'natural indigo',
#  'bracelet_de_cuir': 'leather bracelet',
#  'pyrex': 'pyrex',
#  'damas': 'Damascus',
#  'galon': 'braid',
#  'montage_graphique': 'graphic editing',
#  'bouton_vintage': 'vintage button',
#  'huile_sur_toile': 'oil on canvas',
#  'ecorce': 'bark',
#  'velours_marron': 'brown velvet',
#  'silk_charmeuse': 'charming silk',
#  'silk_mousseline': 'silk chiffon',
#  'qualite_archive': 'archive quality',
#  'papier_archive': 'archive paper',
#  'jet_encre': 'inkjet',
#  'encre_a_pigment': 'pigment ink',
#  'dentelles': 'lace',
#  'lys': 'lily',
#  'orchidee': 'orchid',
#  'fronces': 'shirring',
#  'ortie': 'nettle',
#  'paris_chic_designer_scarf': 'paris chic designer scarf',
#  'vintage_jacques_griffe_foulard': 'vintage jacques claw scarf',
#  'paris_design_fashion_house': 'paris fashion house design',
#  'paris_chic_accessory': 'paris chic accessory',
#  'tete_de_mort': 'skull',
#  'blanche': 'white',
#  'rose_blanche': 'White Rose',
#  'cotton_peigne': 'combed cotton',
#  'gomme': 'rubber',
#  'metal_bronze': 'bronze metal',
#  'ordinateur': 'computer',
#  'came': 'cam',
#  'cire': 'wax',
#  'grillage_galvanise': 'galvanized wire mesh',
#  'lampe_en_ceramique_blanche': 'white ceramic lamp',
#  'pampilles_en_verre': 'glass pendants',
#  'cabochon_en_verre': 'glass cabochon',
#  'fil_electrique': 'electric wire',
#  'grillage': 'grilling',
#  'terre': 'Earth',
#  'boue': 'mud',
#  'cornes': 'horns',
#  'perles_fines': 'fine pearls',
#  'fleurs_de_soie': 'silk flowers',
#  'perles_cristal_tcheque': 'Czech crystal beads',
#  'fleurs_en_soie': 'silk flowers',
#  'fil_plaque_argent': 'silver plated wire',
#  'perles_eau_douce': 'freshwater pearls',
#  'perle_tube': 'pearl tube',
#  'cuir_rond': 'round leather',
#  'vanne_de_gonflage': 'inflation valve',
#  'petit_format_sur_papier_mat_archival_192_gr': 'small format archival matte paper 192 gr',
#  'grand_format_sur_papier_satin_170_gr': 'large format on satin paper 170 gr',
#  'support_papier_mat_archival_de_192_grammes': 'archival matte paper support of 192 grams',
#  'stylo_bille': 'pen',
#  'fleur_soie': 'silk flower',
#  'nacrees': 'pearly',
#  'topaze_imperiale': 'imperial topaz',
#  'perles_heishi_de_nacre': 'heishi mother-of-pearl beads',
#  'perles_or_18_kt': '18 kt gold beads',
#  'saphir_jaune_aa': 'yellow sapphire aa',
#  'poterie': 'pottery',
#  'email_orange': 'orange enamel',
#  'rhyolite_cabochon': 'rhyolite cabochon',
#  'moleskine': 'moleskine',
#  'pantalon_recycle_bleu_ciel_et_cotton_imprime': 'recycled blue sky and printed cotton trousers',
#  'organdi': 'organdy',
#  'dentelle_de_calais': 'Calais lace',
#  'fils': 'son',
#  'soie_de_qualite': 'quality silk',
#  'pinceau': 'brush',
#  'dentelle_de_bruges_peut_etre': 'lace of bruges can be',
#  'perle_en_verre_artisanal': 'handmade glass bead',
#  'coquillages': 'shells',
#  'fil_en_lin_et_paper': 'linen thread and paper',
#  'peinture_textile_ecofriendly': 'ecofriendly textile paint',
#  'fil_de_soir_brute': 'raw evening thread',
#  'peinture_ecofriendly': 'ecofriendly paint',
#  'papier_japonais': 'Japanese paper',
#  'panneau_solaire': 'solar panel',
#  'veilleuse_solaire': 'solar night light',
#  'chaine_argentee': 'silver chain',
#  'perles_cirees': 'waxed pearls',
#  'aventurine': 'aventurine',
#  'perle_noire_de_tahiti': 'black pearl of tahiti',
#  'perle_des_mers_du_sud_tahiti': 'Pearl of the South Seas Tahiti',
#  'antiqued_chain_maille': 'antique mesh chain',
#  'onyx_noir_mat': 'matte black onyx',
#  'tete_de_mort_plaquage_argent': 'silver plating skull',
#  'cabochons_en_resine': 'resin cabochons',
#  'perle_ciree': 'waxed pearl',
#  'perle_verre': 'glass bead',
#  'paris_decor': 'paris decor',
#  'perles_en_verre_de_boheme': 'bohemian glass beads',
#  'huile_sur_panneau_de_toile': 'oil on canvas board',
#  'couteau': 'knife',
#  'messer': 'Messer',
#  'cable_avec_gaine_de_nylon': 'cable with nylon sheath',
#  'verre_murano': 'murano glass',
#  'trine': 'triune',
#  'perles_en_cristal_nacre_swarovski': 'swarovski pearl crystal pearls',
#  'art_numerique': 'digital art',
#  'art_digitales': 'digital art',
#  'papeterie': 'stationery',
#  'papi': 'papi',
#  'diamantes': 'diamantes',
#  'barbotine': 'slip',
#  'brou_de_noix': 'Walnut',
#  'images_digitales': 'digital images',
#  'numerique': 'digital',
#  'perle_de_verre': 'glass bead',
#  'limoges_porcelain_tea_set': 'limoges porcelain tea set',
#  'fil_de_cuivre_argente': 'silver copper wire',
#  'fil_noir_en_coton': 'black cotton thread',
#  'grelots': 'bells',
#  'fil_de_coton': 'cotton thread',
#  'cahier_a_lignes': 'notebook with lines',
#  'couverture_kraft': 'kraft blanket',
#  'bois_uniforme': 'uniform wood',
#  'bois_du_nord': 'northern wood',
#  'bois_brut': 'raw wood',
#  'imprime_vintage': 'vintage print',
#  'chene_massif': 'massive oak',
#  'recyclage': 'recycling',
#  'bois_de_chene': 'Oak wood',
#  'bois_de_frene': 'ash wood',
#  'papier_chiffon': 'rag paper',
#  'crayon_gris': 'Gray pencil',
#  'encres': 'inks',
#  'encadrement': 'framing',
#  'bois_de_sapelli': 'sapelli wood',
#  'bois_de_hetre': 'Beech wood',
#  'chaine_plaquee_argent': 'silver plated chain',
#  'perles_nacrees': 'pearly pearls',
#  'fioles_en_verre_et_bouchon_de_liege': 'glass vials and cork',
#  'paillettes_argentees': 'silver glitter',
#  'limoges_porcelain': 'limoges porcelain',
#  'papier_nacree': 'pearly paper',
#  'carte_brodee': 'embroidered card',
#  'carte_crochetee': 'crocheted card',
#  'ange_christine': 'angel christine',
#  'perles_de_pluie': 'rain beads',
#  'carte_anniversaire_homme': 'birthday card man',
#  'die_lace': 'die laced',
#  'peau_de_crocodile': 'crocodile skin',
#  'ancien': 'former',
#  'florence': 'Florence',
#  'fibres_de_soja': 'soy fiber',
#  'papier_160_gsm': '160 gsm paper',
#  'encre_noire': 'black ink',
#  'papier_160gsm': '160gsm paper',
#  'paris_boudoir_chic_large_frame': 'paris boudoir chic large frame',
#  'billes_de_tapissier': "upholsterer's balls",
#  'perles_pate_polymere': 'polymer clay beads',
#  'tissu_naturel': 'natural fabric',
#  'lin_blanc': 'white linen',
#  'vert_d_eau': 'water green',
#  'cuir_et_perle_tahiti': 'Tahitian leather and pearl',
#  'tahiti_perle': 'Tahiti pearl',
#  'papier_160g': '160g paper',
#  'jaune': 'yellow',
#  'doublure_polyester': 'polyester lining',
#  'terre_emaillee': 'enamelled earth',
#  'email_bleu': 'blue enamel',
#  'fil_argent_925': '925 silver wire',
#  'perle_pate_polymere': 'pearl polymer paste',
#  'rubans_organza': 'organza ribbons',
#  'perle_verre_boheme': 'bohemian glass bead',
#  'cuir_vert': 'green leather',
#  'coton_vert': 'green cotton',
#  'perles_oranges': 'orange pearls',
#  'cuir_violet': 'purple leather',
#  'cuir_pourpre': 'purple leather',
#  'coton_violet': 'purple cotton',
#  'cuir_violet_fonce': 'dark purple leather',
#  'argent_ecologique': 'ecological money',
#  'argent_recycle': 'recycled money',
#  'toupies_cristal_de_swarovski': 'swarovski crystal tops',
#  'perles_de_rocaill_miyuki': 'Miyuki rock beads',
#  'toupies_en_cristal_de_swarovski': 'swarovski crystal tops',
#  'broche': 'brooch',
#  'os_de_yack': 'yak bone',
#  'argent_tibetain': 'Tibetan silver',
#  'amethyste': 'amethyst',
#  'azurite': 'azurite',
#  'agate_veines_de_dragon': 'dragon veins agate',
#  'nylon_cire': 'waxed nylon',
#  'nylon_noir': 'black nylon',
#  'laiton_argente': 'silver brass',
#  'micro_billes': 'micro balls',
#  'boutons_en_nacre': 'mother of pearl buttons',
#  'lien_en_coton': 'cotton tie',
#  'gold_multi_chain_maille': 'gold multi chain mesh',
#  'antiqued_bronze_resin_tulipe_pendants': 'antiqued bronze resin tulip pendants',
#  'fils_aluminium': 'aluminum wires',
#  'toile_ciree': 'oil cloth',
#  'dois': 'have',
#  'peaux_lainees': 'woolly skins',
#  'papier_peint': 'wallpaper',
#  'carres_granny': 'granny squares',
#  'mug_emaille': 'enamelled mug',
#  'article_pour_la_maison': 'article for the house',
#  'tasse': 'Cup',
#  'ceinture': 'belt',
#  'vaisselle': 'washing up',
#  'laine_merinos_feutree': 'felted merino wool',
#  'vernis_satine': 'satin varnish',
#  'paris_map': 'paris map',
#  'imprimable': 'printable',
#  'fichier_numerique': 'digital file',
#  'il_de_tigre': 'Eye of tiger',
#  'chassis_entoile': 'canvas frame',
#  'fleur': 'flower',
#  'argent_925_millieme': '925 thousandth silver',
#  'perle_de_culture': 'cultured pearl',
#  'estampe_venus': 'stamped venus',
#  'perle_de_crystal': 'crystal bead',
#  'perle_de_nacre': 'mother of pearl pearl',
#  'estampe_dorer_argent': 'stamped gilding silver',
#  'perle_de_nacre_naturelle': 'pearl of natural mother-of-pearl',
#  'crystal_de_roche': 'rock crystal',
#  'estampe_ancien': 'stamped old',
#  'veritable': 'true',
#  'estampe': 'print',
#  'perles_argent': 'silver beads',
#  'perles_bois_gravees': 'engraved wood beads',
#  'estampee': 'stamped',
#  'galon_satin_gris': 'gray satin braid',
#  'estampee_dorer_argent_925': 'stamped gilding silver 925',
#  'dessus_de_main_sensuel_et_poetique': 'sensual and poetic upper hand',
#  'crystal_de_roche_laser_du_bresil': 'laser rock crystal of brazil',
#  'perle_de_nacre_veritable': 'real pearl pearl',
#  'nacre_veritable': 'genuine mother-of-pearl',
#  'gingko_estampe': 'stamped gingko',
#  'estampe_gingko': 'stamped gingko',
#  'estampe_ancien_gingko': 'stamped old gingko',
#  'plis': 'folds',
#  'trapeze': 'trapeze',
#  'verroterie': 'beads',
#  'mont_saint_michel': 'Mont Saint Michel',
#  'pierres_semi_prescieuses': 'semi precious stones',
#  'oeil_verre': 'eye glass',
#  'amulette': 'amulet',
#  'feuilles_seches': 'dry leaves',
#  'tissu_madras': 'madras fabric',
#  'porcelaine_limoges': 'porcelain limoges',
#  'resine_nacree': 'pearly resin',
#  'fil_de_cuivre_plaque_or': 'gold-plated copper wire',
#  'broderie_de_crystal': 'crystal embroidery',
#  'broderie_de_crystal_de_boheme': 'Bohemian crystal embroidery',
#  'pierre_de_lune': 'moon stone',
#  'rubis_rouge': 'red ruby',
#  'azurite_jaune': 'yellow azurite',
#  'fil_de_cuivre': 'copper wire',
#  'graines': 'seeds',
#  'vernis_noir': 'black varnish',
#  'fibre_vegetale_naturelle': 'natural plant fiber',
#  'bois_de_kantsia': 'kantsia wood',
#  'fleur_de_nacre': 'mother of pearl',
#  'papier_de_soie': 'silk paper',
#  'cordon_nylon_noir': 'black nylon cord',
#  'howlite_blanche_10mm': 'white howlite 10mm',
#  'paillettes_vertes': 'green glitter',
#  'vernis_dore': 'golden varnish',
#  'natural_autumn_jaspe': 'natural autumn jasper',
#  'silk_soutache': 'silk soutache',
#  'edition_limitee': 'limited edition',
#  'panne_velvet': 'velvet failure',
#  'calcedoine': 'chalcedony',
#  'suedine': 'suede',
#  'monture_bague_anneau': 'ring ring mount',
#  'ancienne': 'Ancient',
#  'oreille': 'hear',
#  'perle_en_verre': 'glass bead',
#  'wool_alpaga': 'wool alpaca',
#  'baby_alpaga': 'baby alpaca',
#  'pierre_precieuse_citrine': 'citrine gemstone',
#  'matiere_vegetale': 'vegetable matter',
#  'perles_de_nacre': 'pearl beads',
#  'insecte': 'insect',
#  'papier_haute_qualite': 'high quality paper',
#  'papier_kraft_autocollant': 'self adhesive paper',
#  'peinture_huile': 'oil painting',
#  'recette_du_shabbat': 'Shabbat recipe',
#  'tube_en_corne': 'horn tube',
#  'peau_lainee': 'lined skin',
#  'peaux_de_mouton': 'sheepskins',
#  'copper_terra_beaded_bracelet': 'copper terra beaded bracelet',
#  'chunky_boho_terra_copper_bracelet': 'chunky boho terra copper bracelet',
#  'feuille_or': 'gold leaf',
#  'diamant': 'diamond',
#  ...}

# %%
dic_uniques = pickle.load( open( "_data/dic_uniques.pickle", "rb" ) )

# %%
for (key, texte) in dic_uniques.items() :
    if key in dic_translated:
        dic_uniques[key] = dic_translated[key]

# %%
dic_uniques['corail_rouge']
# Out:
# 'red coral'

# %%
len(dic_uniques)
# Out:
# 81980

# %%
dic_uniques_lem = OrderedDict()

# %%
for (key, texte) in dic_uniques.items() :
        dic_uniques_lem[key] = [dic_uniques[key], lemmanize(dic_uniques[key])]

# %%
dic_uniques_lem['corail_rouge']
# Out:
# ['red coral', 'coral']

# %%
pickle.dump( dic_uniques_lem, open( "_data/dic_uniques_lem.pickle", "wb" ) )

# %%
data_dict = pickle.load( open( "_data/data_dict.pickle", "rb" ) )

# %%
len(data_dict)
# Out:
# 1038485

# %%
data_dict
# Out:
# OrderedDict([('444500_1', [444500, 'clasp', 'clasp']),
#              ('444500_2', [444500, 'turpentine', 'turpentine']),
#              ('444500_3', [444500, 'toggle', 'toggle']),
#              ('444500_4', [444500, 'sterling', 'sterling']),
#              ('444500_5', [444500, 'silver', 'silver']),
#              ('444500_6', [444500, 'pearls', 'pearls']),
#              ('444500_7', [444500, 'swarovski', 'swarovski']),
#              ('444500_8', [444500, 'beads', 'beads']),
#              ('444500_9', [444500, 'glass', 'glass']),
#              ('444500_10', [444500, 'yellow_turquoise', 'yellow turquoise']),
#              ('444500_11', [444500, 'swarovski_pearls', 'swarovski pearls']),
#              ('6361780_1', [6361780, 'watercolour', 'watercolour']),
#              ('6361780_2', [6361780, 'ink', 'ink']),
#              ('6361780_3', [6361780, 'paper', 'paper']),
#              ('6361780_4', [6361780, 'paint', 'paint']),
#              ('6361916_1', [6361916, 'watercolour', 'watercolour']),
#              ('6361916_2', [6361916, 'ink', 'ink']),
#              ('6361916_3', [6361916, 'paint', 'paint']),
#              ('6361916_4', [6361916, 'paper', 'paper']),
#              ('6877192_1', [6877192, 'watercolors', 'watercolors']),
#              ('6877192_2', [6877192, 'ink', 'ink']),
#              ('6877192_3', [6877192, 'paper', 'paper']),
#              ('6880975_1', [6880975, 'glass', 'glass']),
#              ('6880975_2', [6880975, 'sterling', 'sterling']),
#              ('6880975_3', [6880975, 'silver', 'silver']),
#              ('6880975_4', [6880975, 'toggle', 'toggle']),
#              ('6880975_5', [6880975, 'clasp', 'clasp']),
#              ('6880975_6', [6880975, 'shell', 'shell']),
#              ('6880975_7', [6880975, 'bail', 'bail']),
#              ('6880975_8',
#               [6880975,
#                'lillypilly_carved_shell_pendant',
#                'lillypilly carved shell pendant']),
#              ('6880975_9', [6880975, 'beadalon_wire', 'beadalon wire']),
#              ('6880975_10',
#               [6880975, 'freshwater_pearls', 'freshwater pearls']),
#              ('7877617_1', [7877617, 'watercolor', 'watercolor']),
#              ('7877617_2', [7877617, 'paint', 'paint']),
#              ('7877617_3', [7877617, 'ink', 'ink']),
#              ('7877617_4', [7877617, 'paper', 'paper']),
#              ('10541055_1',
#               [10541055,
#                'recycled_sterling_silver',
#                'recycled sterling silver']),
#              ('10541055_2', [10541055, 'patina', 'patina']),
#              ('13366101_1', [13366101, 'sterling_silver', 'sterling silver']),
#              ('13366101_2',
#               [13366101, '950_reclaimed_silver', '950 reclaimed silver']),
#              ('13366101_3', [13366101, 'patina', 'patina']),
#              ('13838547_1', [13838547, 'canvas', 'canvas']),
#              ('13838547_2',
#               [13838547, 'acrylic_painting', 'acrylic painting']),
#              ('13838601_1', [13838601, 'oil_paint', 'oil paint']),
#              ('13838601_2', [13838601, 'canvas', 'canvas']),
#              ('13838601_3', [13838601, 'inspiration', 'inspiration']),
#              ('13838601_4',
#               [13838601,
#                'certificate_of_authenticity',
#                'certificate of authenticity']),
#              ('13850728_1', [13850728, 'canvas', 'canvas']),
#              ('13850728_2', [13850728, 'oil_paint', 'oil paint']),
#              ('13850885_1', [13850885, 'acrylic_paint', 'acrylic paint']),
#              ('13850885_2', [13850885, 'canvas', 'canvas']),
#              ('13850885_3', [13850885, 'nature_study', 'nature study']),
#              ('13870789_1', [13870789, 'string', 'string']),
#              ('13870789_2', [13870789, 'acrylic', 'acrylic']),
#              ('13870789_3',
#               [13870789, 'iridescent_medium', 'iridescent medium']),
#              ('13923827_1', [13923827, 'string', 'string']),
#              ('13923827_2', [13923827, 'acrylic', 'acrylic']),
#              ('13923827_3', [13923827, 'paint', 'paint']),
#              ('13923827_4',
#               [13923827, 'iridescent_medium', 'iridescent medium']),
#              ('13923827_5', [13923827, 'wood', 'wood']),
#              ('13923993_1', [13923993, 'string', 'string']),
#              ('13923993_2', [13923993, 'wood', 'wood']),
#              ('13923993_3',
#               [13923993, 'acrylic_painting', 'acrylic painting']),
#              ('13924066_1', [13924066, 'canvas', 'canvas']),
#              ('13924066_2', [13924066, 'oil_paint', 'oil paint']),
#              ('13924066_3', [13924066, 'kitchen_art', 'kitchen art']),
#              ('13924066_4', [13924066, 'food_art', 'food art']),
#              ('13924066_5', [13924066, 'abstract', 'abstract']),
#              ('13924066_6',
#               [13924066, 'repetition_of_objects', 'repetition of objects']),
#              ('13936148_1', [13936148, 'pearl', 'pearl']),
#              ('13938880_1', [13938880, 'coral', 'coral']),
#              ('14477394_1', [14477394, 'fabric', 'fabric']),
#              ('14477394_2', [14477394, 'paint', 'paint']),
#              ('14477394_3', [14477394, 'canvas', 'canvas']),
#              ('14759181_1', [14759181, 'tourmaline', 'tourmaline']),
#              ('14759181_2', [14759181, 'sterling_silver', 'sterling silver']),
#              ('14888609_1', [14888609, 'pearl', 'pearl']),
#              ('14949957_1', [14949957, 'conch_shell', 'conch shell']),
#              ('14949957_2', [14949957, 'corail_rouge', 'corail rouge']),
#              ('14949957_3',
#               [14949957, 'perles_naturelles', 'perles naturelles']),
#              ('14949957_4', [14949957, 'coquille', 'coquille']),
#              ('14949957_5', [14949957, 'red_coral', 'red coral']),
#              ('14949957_6',
#               [14949957, 'freshwater_pearls', 'freshwater pearls']),
#              ('14949957_7', [14949957, 'rose_conch', 'rose conch']),
#              ('15059759_1', [15059759, 'tourmaline', 'tourmaline']),
#              ('15067314_1', [15067314, 'bamboo', 'bamboo']),
#              ('15067314_2', [15067314, 'string', 'string']),
#              ('15413517_1', [15413517, 'paper', 'paper']),
#              ('15413517_2', [15413517, 'ink', 'ink']),
#              ('15413554_1', [15413554, 'paper_224_gr', 'paper 224 gr']),
#              ('15413554_2', [15413554, 'ink', 'ink']),
#              ('15440878_1', [15440878, 'paper', 'paper']),
#              ('15440878_2', [15440878, 'ink', 'ink']),
#              ('15445420_1', [15445420, 'string', 'string']),
#              ('15445420_2', [15445420, 'canvas', 'canvas']),
#              ('15445420_3', [15445420, 'acrylic_paint', 'acrylic paint']),
#              ('15459735_1', [15459735, 'pearl', 'pearl']),
#              ('15507591_1', [15507591, 'paper', 'paper']),
#              ('15507591_2', [15507591, 'ink', 'ink']),
#              ('15566197_1', [15566197, 'turquoise', 'turquoise']),
#              ('15780317_1', [15780317, 'photography', 'photography']),
#              ('15780317_2', [15780317, 'photograph', 'photograph']),
#              ('15780317_3', [15780317, 'camera', 'camera']),
#              ('15780317_4', [15780317, 'photo', 'photo']),
#              ('15780317_5', [15780317, 'fine_art_paper', 'fine art paper']),
#              ('15780317_6', [15780317, 'archival_inks', 'archival inks']),
#              ('15780317_7', [15780317, 'matte_paper', 'matte paper']),
#              ('15863644_1', [15863644, 'stone', 'stone']),
#              ('15863644_2', [15863644, 'silver', 'silver']),
#              ('15864139_1', [15864139, 'stone', 'stone']),
#              ('15864139_2', [15864139, 'silver', 'silver']),
#              ('15900958_1', [15900958, 'string', 'string']),
#              ('15900958_2', [15900958, 'acrylic', 'acrylic']),
#              ('15900958_3', [15900958, 'paint', 'paint']),
#              ('15900958_4', [15900958, 'canvas', 'canvas']),
#              ('15900958_5', [15900958, 'wood', 'wood']),
#              ('15900958_6', [15900958, 'frame', 'frame']),
#              ('15900958_7',
#               [15900958, 'unique_technique', 'unique technique']),
#              ('15900958_8', [15900958, 'string_art', 'string art']),
#              ('15900958_9', [15900958, 'flower_macro', 'flower macro']),
#              ('15900958_10',
#               [15900958, 'macro_photography', 'macro photography']),
#              ('15903412_1', [15903412, 'canvas', 'canvas']),
#              ('15903412_2', [15903412, 'acrylic_paint', 'acrylic paint']),
#              ('15904865_1', [15904865, 'acrylic_paint', 'acrylic paint']),
#              ('15904865_2', [15904865, 'canvas', 'canvas']),
#              ('15907493_1', [15907493, 'acrylic_paint', 'acrylic paint']),
#              ('15907493_2', [15907493, 'string', 'string']),
#              ('15907493_3', [15907493, 'shells', 'shells']),
#              ('15907493_4', [15907493, 'canvas', 'canvas']),
#              ('16165598_1',
#               [16165598, 'laiton_bronze_antique', 'laiton bronze antique']),
#              ('16165598_2', [16165598, 'agate_blanche', 'agate blanche']),
#              ('16168074_1',
#               [16168074, 'laiton_bronze_antique', 'laiton bronze antique']),
#              ('16272159_1', [16272159, 'oil_paint', 'oil paint']),
#              ('16272159_2', [16272159, 'canvas', 'canvas']),
#              ('16272936_1', [16272936, 'canvas', 'canvas']),
#              ('16272936_2', [16272936, 'acrylic', 'acrylic']),
#              ('16577999_1', [16577999, 'ink', 'ink']),
#              ('16577999_2', [16577999, 'watercolour', 'watercolour']),
#              ('16577999_3', [16577999, 'paint', 'paint']),
#              ('16577999_4', [16577999, 'paper', 'paper']),
#              ('16609477_1', [16609477, 'acrylic', 'acrylic']),
#              ('16609477_2', [16609477, 'paint', 'paint']),
#              ('16609477_3', [16609477, 'cotton_string', 'cotton string']),
#              ('16609477_4', [16609477, 'glue', 'glue']),
#              ('16609477_5', [16609477, 'wood', 'wood']),
#              ('16638098_1', [16638098, 'paper_pulp', 'paper pulp']),
#              ('16638098_2', [16638098, 'string', 'string']),
#              ('16638098_3', [16638098, 'acrylic_paint', 'acrylic paint']),
#              ('16638098_4', [16638098, 'wood', 'wood']),
#              ('16747508_1', [16747508, 'cotton_string', 'cotton string']),
#              ('16747508_2', [16747508, 'acrylic_paint', 'acrylic paint']),
#              ('16747508_3',
#               [16747508, 'nature_inspiration', 'nature inspiration']),
#              ('16747508_4',
#               [16747508, 'mussels_seashells', 'mussels seashells']),
#              ('16835277_1', [16835277, 'canvas', 'canvas']),
#              ('16835277_2', [16835277, 'linen', 'linen']),
#              ('16835277_3', [16835277, 'fiberglass', 'fiberglass']),
#              ('16835277_4', [16835277, 'string', 'string']),
#              ('16835277_5', [16835277, 'acrylic_paint', 'acrylic paint']),
#              ('16913436_1', [16913436, 'string', 'string']),
#              ('16913436_2', [16913436, 'papier_mache', 'papier mache']),
#              ('16913436_3', [16913436, 'acrylic_paint', 'acrylic paint']),
#              ('16913436_4', [16913436, 'wood', 'wood']),
#              ('16913436_5',
#               [16913436, 'food_inspired_art', 'food inspired art']),
#              ('16913436_6', [16913436, 'cooking', 'cooking']),
#              ('16913436_7',
#               [16913436, 'piece_of_broccoli', 'piece of broccoli']),
#              ('16914119_1', [16914119, 'string', 'string']),
#              ('16914119_2', [16914119, 'acrylic_paint', 'acrylic paint']),
#              ('16914119_3', [16914119, 'wood', 'wood']),
#              ('16914119_4', [16914119, 'payment_plan', 'payment plan']),
#              ('16914119_5', [16914119, 'rural_france', 'rural france']),
#              ('16915790_1', [16915790, 'string', 'string']),
#              ('16915790_2', [16915790, 'paper', 'paper']),
#              ('16915790_3', [16915790, 'wood', 'wood']),
#              ('16915790_4', [16915790, 'frame', 'frame']),
#              ('16915790_5',
#               [16915790,
#                'as_sold_at_christies_london',
#                'as sold at christies london']),
#              ('16915790_6', [16915790, 'rural_france', 'rural france']),
#              ('16915790_7',
#               [16915790, 'french_countryside', 'french countryside']),
#              ('16915790_8',
#               [16915790, 'nature_inspiration', 'nature inspiration']),
#              ('16915790_9',
#               [16915790, 'macro_photography', 'macro photography']),
#              ('17620681_1', [17620681, 'string', 'string']),
#              ('17620681_2', [17620681, 'canvas', 'canvas']),
#              ('17620681_3', [17620681, 'acrylic', 'acrylic']),
#              ('17620681_4', [17620681, 'wood', 'wood']),
#              ('17620681_5', [17620681, 'varnish', 'varnish']),
#              ('17620681_6', [17620681, 'pigments', 'pigments']),
#              ('17620681_7', [17620681, 'walnut_crystals', 'walnut crystals']),
#              ('18774503_1', [18774503, 'paper', 'paper']),
#              ('18774503_2', [18774503, 'ink', 'ink']),
#              ('19194348_1', [19194348, 'canvas', 'canvas']),
#              ('19194348_2', [19194348, 'cotton_fabric', 'cotton fabric']),
#              ('19194348_3', [19194348, 'oil_paint', 'oil paint']),
#              ('19194348_4', [19194348, 'acrylic_paint', 'acrylic paint']),
#              ('19265601_1',
#               [19265601, 'paper_16_x_12_cm', 'paper 16 x 12 cm']),
#              ('19265601_2', [19265601, 'ink', 'ink']),
#              ('19265617_1',
#               [19265617, 'paper_16_x_22_cm', 'paper 16 x 22 cm']),
#              ('19265617_2', [19265617, 'ink', 'ink']),
#              ('19265860_1',
#               [19265860, 'art_modern_museum', 'art modern museum']),
#              ('19265860_2',
#               [19265860, 'print_leaflet_2_parts', 'print leaflet 2 parts']),
#              ('19265860_3',
#               [19265860,
#                'inside_menu_diner_champagne',
#                'inside menu diner champagne']),
#              ('19265860_4',
#               [19265860,
#                'cover_painting_from_georges_braque',
#                'cover painting from georges braque']),
#              ('19265860_5',
#               [19265860,
#                'famous_french_painter_1882_work',
#                'famous french painter 1882 work']),
#              ('19265860_6',
#               [19265860,
#                'midcentury_vintage_paquebot_cruise',
#                'midcentury vintage paquebot cruise']),
#              ('19265860_7',
#               [19265860,
#                'cover_fresh_colors_good_condition',
#                'cover fresh colors good condition']),
#              ('19265860_8',
#               [19265860,
#                'inside_passenger_name_slight_scratched',
#                'inside passenger name slight scratched']),
#              ('19265860_9', [19265860, 'quick_delivery', 'quick delivery']),
#              ('19265860_10',
#               [19265860, 'safe_protected_package', 'safe protected package']),
#              ('19265860_11',
#               [19265860,
#                'free_shipping_worldwide',
#                'free shipping worldwide']),
#              ('19265860_12',
#               [19265860,
#                'vintage_paquebot_brazza_menu',
#                'vintage paquebot brazza menu']),
#              ('19265860_13',
#               [19265860,
#                'collector_artist_work_menus',
#                'collector artist work menus']),
#              ('19305288_1',
#               [19305288, 'paper_16_x_22_cm', 'paper 16 x 22 cm']),
#              ('19305288_2', [19305288, 'ink', 'ink']),
#              ('19606984_1', [19606984, 'jersey', 'jersey']),
#              ('19606984_2', [19606984, 'faux_fur', 'faux fur']),
#              ('19636315_1', [19636315, 'art', 'art']),
#              ('19636315_2', [19636315, 'paper', 'paper']),
#              ('19636315_3', [19636315, 'ink', 'ink']),
#              ('19765837_1', [19765837, 'copper', 'copper']),
#              ('19765837_2', [19765837, 'glass', 'glass']),
#              ('19765837_3', [19765837, 'brass', 'brass']),
#              ('19765838_1',
#               [19765838, 'screw_back_clips', 'screw back clips']),
#              ('19765838_2', [19765838, 'ear_wire_hooks', 'ear wire hooks']),
#              ('19765838_3', [19765838, 'antiqued_brass', 'antiqued brass']),
#              ('19765838_4', [19765838, 'howlite', 'howlite']),
#              ('19887600_1', [19887600, 'paper', 'paper']),
#              ('19887600_2', [19887600, 'ink', 'ink']),
#              ('19887600_3', [19887600, 'envelope', 'envelope']),
#              ('19887600_4', [19887600, 'cardstock', 'cardstock']),
#              ('19892504_1', [19892504, 'amber', 'amber']),
#              ('19892504_2', [19892504, 'old_brass_bell', 'old brass bell']),
#              ('19892660_1', [19892660, 'ceramic', 'ceramic']),
#              ('19892660_2', [19892660, 'stone', 'stone']),
#              ('19892660_3', [19892660, 'quartz', 'quartz']),
#              ('19902625_1', [19902625, 'sterling_silver', 'sterling silver']),
#              ('19902625_2', [19902625, 'rubber', 'rubber']),
#              ('20053806_1',
#               [20053806, 'paper_16_x_12_cm', 'paper 16 x 12 cm']),
#              ('20053806_2', [20053806, 'ink', 'ink']),
#              ('20066934_1',
#               [20066934,
#                'vintage_real_photos_postcards',
#                'vintage real photos postcards']),
#              ('20066934_2',
#               [20066934,
#                'donation_for_charity_red_cross_paris',
#                'donation for charity red cross paris']),
#              ('20066934_3',
#               [20066934,
#                'for_houston_harvey_damaged_people',
#                'for houston harvey damaged people']),
#              ('20066934_4',
#               [20066934,
#                'colorful_photos_by_art_meyer',
#                'colorful photos by art meyer']),
#              ('20066934_5',
#               [20066934,
#                'skyline_and_port_2_postcards',
#                'skyline and port 2 postcards']),
#              ('20066934_6', [20066934, 'years_1980', 'years 1980']),
#              ('20066934_7',
#               [20066934,
#                'mint_condition_both_sides',
#                'mint condition both sides']),
#              ('20066934_8',
#               [20066934,
#                'buyer_will_receive_the_2_postcards',
#                'buyer will receive the 2 postcards']),
#              ('20066934_9',
#               [20066934,
#                'free_worldwide_shipping',
#                'free worldwide shipping']),
#              ('20066934_10',
#               [20066934,
#                'i_will_pay_the_full_amount_to_red_cross',
#                'i will pay the full amount to red cross']),
#              ('20066934_11',
#               [20066934,
#                'receipt_of_redcross_will_be_sent_to_buyer',
#                'receipt of redcross will be sent to buyer']),
#              ('20066934_12',
#               [20066934,
#                'very_quick_and_safe_package',
#                'very quick and safe package']),
#              ('20066934_13',
#               [20066934,
#                'thanks_for_your_understanding',
#                'thanks for your understanding']),
#              ('20220479_1', [20220479, 'string', 'string']),
#              ('20220479_2',
#               [20220479, 'natural_pigments', 'natural pigments']),
#              ('20220479_3', [20220479, 'color_pencils', 'color pencils']),
#              ('20220479_4', [20220479, 'canvas', 'canvas']),
#              ('20357407_1',
#               [20357407, 'paper_16_x_12_cm', 'paper 16 x 12 cm']),
#              ('20357407_2', [20357407, 'ink', 'ink']),
#              ('20483640_1', [20483640, 'paper_16', 'paper 16']),
#              ('20483640_2', [20483640, '2_x_12_cm', '2 x 12 cm']),
#              ('20483640_3', [20483640, 'ink', 'ink']),
#              ('20490656_1', [20490656, 'silk', 'silk']),
#              ('20835760_1', [20835760, 'pdf_file', 'pdf file']),
#              ('20835760_2', [20835760, 'e_pattern', 'e pattern']),
#              ('20836261_1', [20836261, 'pdf_file', 'pdf file']),
#              ('20962199_1', [20962199, 'sterling_silver', 'sterling silver']),
#              ('20962199_2',
#               [20962199, 'peridot_gemstones', 'peridot gemstones']),
#              ('20962199_3', [20962199, 'green_peridot', 'green peridot']),
#              ('20965494_1', [20965494, 'sterling_silver', 'sterling silver']),
#              ('20965494_2', [20965494, '925_silver', '925 silver']),
#              ('20965494_3', [20965494, 'real_silver', 'real silver']),
#              ('20965494_4', [20965494, 'aquamarine', 'aquamarine']),
#              ('20969109_1', [20969109, 'leather', 'leather']),
#              ('20969109_2', [20969109, 'gold', 'gold']),
#              ('21017012_1', [21017012, 'camera', 'camera']),
#              ('21017012_2', [21017012, 'fine_art_paper', 'fine art paper']),
#              ('21017012_3', [21017012, 'photography', 'photography']),
#              ('21017012_4', [21017012, 'photograph', 'photograph']),
#              ('21017012_5', [21017012, 'photo', 'photo']),
#              ('21017012_6', [21017012, 'archival_inks', 'archival inks']),
#              ('21017012_7', [21017012, 'matte_paper', 'matte paper']),
#              ('21082466_1', [21082466, 'sterling_silver', 'sterling silver']),
#              ('21082466_2', [21082466, '925_silver', '925 silver']),
#              ('21083484_1', [21083484, 'sterling_silver', 'sterling silver']),
#              ('21163279_1', [21163279, 'paper', 'paper']),
#              ('21163279_2', [21163279, 'ink', 'ink']),
#              ('21260223_1', [21260223, 'sterling_silver', 'sterling silver']),
#              ('21260223_2', [21260223, 'rubber_rings', 'rubber rings']),
#              ('21260223_3',
#               [21260223, 'forged_sterling_silver', 'forged sterling silver']),
#              ('21387924_1',
#               [21387924, 'vintage_print_fabric', 'vintage print fabric']),
#              ('21387924_2',
#               [21387924,
#                'paint_signed_wall_ornament',
#                'paint signed wall ornament']),
#              ('21387924_3',
#               [21387924, 'busy_street_parade', 'busy street parade']),
#              ('21387924_4',
#               [21387924,
#                'horses_diligence_old_houses',
#                'horses diligence old houses']),
#              ('21387924_5',
#               [21387924, 'old_fashion_clothes', 'old fashion clothes']),
#              ('21387924_6',
#               [21387924, 'mid_century_work', 'mid century work']),
#              ('21387924_7',
#               [21387924,
#                'good_condition_few_rusty_stains',
#                'good condition few rusty stains']),
#              ('21387924_8',
#               [21387924, 'need_to_be_framed', 'need to be framed']),
#              ('21387924_9',
#               [21387924, 'grey_black_white_pink', 'grey black white pink']),
#              ('21387924_10', [21387924, 'quick_delivery', 'quick delivery']),
#              ('21387924_11',
#               [21387924, 'safe_protected_package', 'safe protected package']),
#              ('21387924_12',
#               [21387924,
#                'track_insurance_included',
#                'track insurance included']),
#              ('21387924_13',
#               [21387924,
#                'free_worldwide_shipping',
#                'free worldwide shipping']),
#              ('21388563_1',
#               [21388563, 'vintage_print_fabric', 'vintage print fabric']),
#              ('21388563_2',
#               [21388563, 'wall_paint_ornament', 'wall paint ornament']),
#              ('21388563_3', [21388563, 'signed_perez', 'signed perez']),
#              ('21388563_4',
#               [21388563,
#                'romantic_people_clothes',
#                'romantic people clothes']),
#              ('21388563_5',
#               [21388563,
#                'servants_gentlemen_laywer',
#                'servants gentlemen laywer']),
#              ('21388563_6',
#               [21388563, 'busy_street_old_houses', 'busy street old houses']),
#              ('21388563_7',
#               [21388563,
#                'grey_white_pink_few_rusty_stains',
#                'grey white pink few rusty stains']),
#              ('21388563_8',
#               [21388563,
#                'good_condition_need_frame',
#                'good condition need frame']),
#              ('21388563_9',
#               [21388563, 'mid_century_item', 'mid century item']),
#              ('21388563_10', [21388563, 'quick_delivery', 'quick delivery']),
#              ('21388563_11',
#               [21388563, 'safe_protected_package', 'safe protected package']),
#              ('21388563_12',
#               [21388563,
#                'track_insurance_included',
#                'track insurance included']),
#              ('21388563_13',
#               [21388563,
#                'free_worldwide_shipping',
#                'free worldwide shipping']),
#              ('21566752_1',
#               [21566752, 'silver_background', 'silver background']),
#              ('21566752_2',
#               [21566752,
#                'vintage_kospal_postcard',
#                'vintage kospal postcard']),
#              ('21566752_3',
#               [21566752,
#                'french_written_helvetia_stamp',
#                'french written helvetia stamp']),
#              ('21566752_4',
#               [21566752,
#                'romantic_girl_easter_basket',
#                'romantic girl easter basket']),
#              ('21566752_5',
#               [21566752, 'colorful_eggs_ribbon', 'colorful eggs ribbon']),
#              ('21566752_6',
#               [21566752, 'old_fashion_clothes', 'old fashion clothes']),
#              ('21566752_7',
#               [21566752, 'green_white_brown_pink', 'green white brown pink']),
#              ('21566752_8',
#               [21566752, 'green_paper_frame', 'green paper frame']),
#              ('21566752_9', [21566752, 'quick_delivery', 'quick delivery']),
#              ('21566752_10',
#               [21566752,
#                'good_condition_natural_age_marks',
#                'good condition natural age marks']),
#              ('21566752_11',
#               [21566752, 'safe_protected_package', 'safe protected package']),
#              ('21566752_12',
#               [21566752,
#                'free_worldwide_shipping',
#                'free worldwide shipping']),
#              ('21566752_13',
#               [21566752,
#                'warm_friendly_happy_easter_greetings',
#                'warm friendly happy easter greetings']),
#              ('21567965_1',
#               [21567965,
#                'vintage_kospal_postcard',
#                'vintage kospal postcard']),
#              ('21567965_2',
#               [21567965,
#                'embossed_colorful_print',
#                'embossed colorful print']),
#              ('21567965_3',
#               [21567965, 'easter_big_green_egg', 'easter big green egg']),
#              ('21567965_4',
#               [21567965,
#                'yellow_ribbon_purple_flowers',
#                'yellow ribbon purple flowers']),
#              ('21567965_5',
#               [21567965, 'beautiful_easter_theme', 'beautiful easter theme']),
#              ('21567965_6',
#               [21567965, 'elegant_retro_print', 'elegant retro print']),
#              ('21567965_7',
#               [21567965,
#                'not_written_very_good_condition',
#                'not written very good condition']),
#              ('21567965_8',
#               [21567965,
#                'art_nouveau_fancy_postcard',
#                'art nouveau fancy postcard']),
#              ('21567965_9',
#               [21567965, 'purple_blue_flowers', 'purple blue flowers']),
#              ('21567965_10', [21567965, 'quick_delivery', 'quick delivery']),
#              ('21567965_11',
#               [21567965, 'safe_protected_package', 'safe protected package']),
#              ('21567965_12',
#               [21567965,
#                'free_worldwide_shipping',
#                'free worldwide shipping']),
#              ('21567965_13',
#               [21567965,
#                'warm_freindly_happy_easter_wishes',
#                'warm freindly happy easter wishes']),
#              ('21568373_1',
#               [21568373, 'silver_background', 'silver background']),
#              ('21568373_2',
#               [21568373, 'vintage_postcard', 'vintage postcard']),
#              ('21568373_3', [21568373, 'embossed_print', 'embossed print']),
#              ('21568373_4',
#               [21568373, 'french_written_stamp', 'french written stamp']),
#              ('21568373_5',
#               [21568373, 'easter_angel_egg', 'easter angel egg']),
#              ('21568373_6',
#               [21568373, 'nice_white_flowers', 'nice white flowers']),
#              ('21568373_7',
#               [21568373, 'classic_kospal_theme', 'classic kospal theme']),
#              ('21568373_8', [21568373, 'good_condition', 'good condition']),
#              ('21568373_9', [21568373, 'quick_delivery', 'quick delivery']),
#              ('21568373_10',
#               [21568373, 'well_protected_package', 'well protected package']),
#              ('21568373_11',
#               [21568373,
#                'free_worldwide_shipping',
#                'free worldwide shipping']),
#              ('21568373_12', [21568373, 'warm_wishes', 'warm wishes']),
#              ('21568373_13', [21568373, 'vintagefr', 'vintagefr']),
#              ('21728796_1', [21728796, 'paper', 'paper']),
#              ('21728796_2', [21728796, 'ink', 'ink']),
#              ('21877615_1', [21877615, 'wood', 'wood']),
#              ('21877615_2', [21877615, 'paint', 'paint']),
#              ('21877615_3', [21877615, 'glass', 'glass']),
#              ('21877615_4', [21877615, 'paper', 'paper']),
#              ('22194186_1', [22194186, 'wood', 'wood']),
#              ('22194186_2', [22194186, 'paint', 'paint']),
#              ('22194186_3', [22194186, 'glass', 'glass']),
#              ('22194186_4', [22194186, 'paper', 'paper']),
#              ('22310249_1',
#               [22310249, 'vintage_postcard', 'vintage postcard']),
#              ('22310249_2', [22310249, 'colorful_print', 'colorful print']),
#              ('22310249_3', [22310249, 'easter_wishes', 'easter wishes']),
#              ('22310249_4', [22310249, 'french_written', 'french written']),
#              ('22310249_5',
#               [22310249, 'angel_sheeps_bell', 'angel sheeps bell']),
#              ('22310249_6', [22310249, 'landscape_water', 'landscape water']),
#              ('22310249_7',
#               [22310249, 'green_white_pink', 'green white pink']),
#              ('22310249_8', [22310249, 'good_condition', 'good condition']),
#              ('22310249_9', [22310249, 'quick_delivery', 'quick delivery']),
#              ('22310249_10',
#               [22310249, 'well_protected_package', 'well protected package']),
#              ('22310249_11', [22310249, 'art_nouveau', 'art nouveau']),
#              ('22310249_12',
#               [22310249,
#                'free_worldwide_shipping',
#                'free worldwide shipping']),
#              ('22310249_13', [22310249, 'warm_greetings', 'warm greetings']),
#              ('22311554_1', [22311554, 'wood', 'wood']),
#              ('22311554_2', [22311554, 'paint', 'paint']),
#              ('22311554_3', [22311554, 'wax_polish', 'wax polish']),
#              ('22311554_4', [22311554, 'glass', 'glass']),
#              ('22311554_5', [22311554, 'paper', 'paper']),
#              ('22312130_1', [22312130, 'wood', 'wood']),
#              ('22312130_2', [22312130, 'paint', 'paint']),
#              ('22312130_3', [22312130, 'wax_polish', 'wax polish']),
#              ('22312130_4', [22312130, 'glass', 'glass']),
#              ('22312130_5', [22312130, 'paper', 'paper']),
#              ('22416787_1', [22416787, 'wood', 'wood']),
#              ('22416787_2',
#               [22416787, 'semi_precious_stone', 'semi precious stone']),
#              ('22417076_1', [22417076, 'leather', 'leather']),
#              ('22417076_2', [22417076, 'bone', 'bone']),
#              ('22419223_1', [22419223, 'feathers', 'feathers']),
#              ('22419223_2', [22419223, 'bone', 'bone']),
#              ('22419223_3', [22419223, 'lava_stone', 'lava stone']),
#              ('22419223_4', [22419223, 'lava', 'lava']),
#              ('22578431_1', [22578431, 'paper_ink', 'paper ink']),
#              ('22775544_1', [22775544, 'paper', 'paper']),
#              ('22775544_2', [22775544, 'ink', 'ink']),
#              ('22855874_1',
#               [22855874,
#                'vintage_embossed_postcard',
#                'vintage embossed postcard']),
#              ('22855874_2',
#               [22855874, 'deutsch_poem_stamp', 'deutsch poem stamp']),
#              ('22855874_3',
#               [22855874, 'front_french_written', 'front french written']),
#              ('22855874_4',
#               [22855874, 'early_3_lines_postcard', 'early 3 lines postcard']),
#              ('22855874_5',
#               [22855874, 'sweet_yellow_chicks', 'sweet yellow chicks']),
#              ('22855874_6',
#               [22855874,
#                'colorful_lucky_shamrocks',
#                'colorful lucky shamrocks']),
#              ('22855874_7',
#               [22855874, 'green_luck_clovers', 'green luck clovers']),
#              ('22855874_8', [22855874, 'good_condition', 'good condition']),
#              ('22855874_9', [22855874, 'small_age_marks', 'small age marks']),
#              ('22855874_10', [22855874, 'quick_delivery', 'quick delivery']),
#              ('22855874_11',
#               [22855874, 'safe_protected_postage', 'safe protected postage']),
#              ('22855874_12',
#               [22855874,
#                'free_worldwide_shipping',
#                'free worldwide shipping']),
#              ('22855874_13',
#               [22855874,
#                'friendly_happy_easter_wishes',
#                'friendly happy easter wishes']),
#              ('22856132_1',
#               [22856132,
#                'vintage_french_postcard',
#                'vintage french postcard']),
#              ('22856132_2',
#               [22856132,
#                'embossed_colorful_print',
#                'embossed colorful print']),
#              ('22856132_3',
#               [22856132,
#                'golden_white_yellow_green',
#                'golden white yellow green']),
#              ('22856132_4',
#               [22856132, 'french_written_stamp', 'french written stamp']),
#              ('22856132_5',
#               [22856132,
#                'sligh_mark_right_bottom_corner',
#                'sligh mark right bottom corner']),
#              ('22856132_6',
#               [22856132,
#                'art_nouveau_happy_easter',
#                'art nouveau happy easter']),
#              ('22856132_7',
#               [22856132, 'nice_fancy_postcard', 'nice fancy postcard']),
#              ('22856132_8',
#               [22856132,
#                'golden_chick_light_blue_egg',
#                'golden chick light blue egg']),
#              ('22856132_9',
#               [22856132,
#                'golden_light_blue_flowers',
#                'golden light blue flowers']),
#              ('22856132_10', [22856132, 'quick_delivery', 'quick delivery']),
#              ('22856132_11',
#               [22856132, 'safe_protected_package', 'safe protected package']),
#              ('22856132_12',
#               [22856132,
#                'free_worldwide_shipping',
#                'free worldwide shipping']),
#              ('22856132_13',
#               [22856132,
#                'greetings_for_happy_easter',
#                'greetings for happy easter']),
#              ('22856416_1',
#               [22856416,
#                'vintage_french_postcard',
#                'vintage french postcard']),
#              ('22856416_2',
#               [22856416, 'pink_purse_white_eggs', 'pink purse white eggs']),
#              ('22856416_3',
#               [22856416,
#                'yellow_ribbon_blue_flowers',
#                'yellow ribbon blue flowers']),
#              ('22856416_4',
#               [22856416,
#                'embossed_french_written_print',
#                'embossed french written print']),
#              ('22856416_5',
#               [22856416,
#                'fresh_colors_good_condition',
#                'fresh colors good condition']),
#              ('22856416_6',
#               [22856416,
#                'blue_pink_forget_me_not',
#                'blue pink forget me not']),
#              ('22856416_7',
#               [22856416,
#                'art_nouveau_happy_easter',
#                'art nouveau happy easter']),
#              ('22856416_8',
#               [22856416, 'nice_fancy_poscard', 'nice fancy poscard']),
#              ('22856416_9', [22856416, 'quick_delivery', 'quick delivery']),
#              ('22856416_10',
#               [22856416, 'safe_protected_package', 'safe protected package']),
#              ('22856416_11', [22856416, 'warm_greetings', 'warm greetings']),
#              ('22856416_12',
#               [22856416,
#                'free_shopping_worldwide',
#                'free shopping worldwide']),
#              ('22856416_13',
#               [22856416,
#                'nice_collectors_embossed_easter_print',
#                'nice collectors embossed easter print']),
#              ('22875575_1', [22875575, 'wood', 'wood']),
#              ('22875575_2',
#               [22875575, 'semi_precious_stone', 'semi precious stone']),
#              ('22875575_3', [22875575, 'fimo_paste', 'fimo paste']),
#              ('22875575_4', [22875575, 'glass', 'glass']),
#              ('22875575_5', [22875575, 'lampwork', 'lampwork']),
#              ('22875575_6', [22875575, 'lava_stone', 'lava stone']),
#              ('22876077_1', [22876077, 'wood', 'wood']),
#              ('22876077_2', [22876077, 'gold_metal', 'gold metal']),
#              ('22902808_1', [22902808, 'agate', 'agate']),
#              ('22902808_2', [22902808, 'amber', 'amber']),
#              ('22902956_1', [22902956, 'horn', 'horn']),
#              ('22902956_2', [22902956, 'waxed_cord', 'waxed cord']),
#              ('22903930_1', [22903930, 'glass', 'glass']),
#              ('22903930_2',
#               [22903930, 'semi_precious_stone', 'semi precious stone']),
#              ('22903930_3', [22903930, 'jasper', 'jasper']),
#              ('22905069_1',
#               [22905069, 'semi_precious_stone', 'semi precious stone']),
#              ('22905267_1', [22905267, 'leather', 'leather']),
#              ('22905267_2', [22905267, 'cow_skin', 'cow skin']),
#              ('22905267_3', [22905267, 'quartz', 'quartz']),
#              ('22905267_4', [22905267, 'stone', 'stone']),
#              ('22906552_1', [22906552, 'leather', 'leather']),
#              ('22906552_2', [22906552, 'bones', 'bones']),
#              ('22991251_1', [22991251, 'wood', 'wood']),
#              ('22991251_2', [22991251, 'paint', 'paint']),
#              ('22991251_3', [22991251, 'wax_polish', 'wax polish']),
#              ('22991251_4', [22991251, 'glass', 'glass']),
#              ('22991251_5', [22991251, 'paper', 'paper']),
#              ('23425071_1', [23425071, 'leather', 'leather']),
#              ('23447986_1', [23447986, 'paper', 'paper']),
#              ('23447986_2', [23447986, 'ink', 'ink']),
#              ('23579862_1', [23579862, 'cotton', 'cotton']),
#              ('23579862_2', [23579862, 'wool', 'wool']),
#              ('23889569_1', [23889569, 'felt', 'felt']),
#              ('23889569_2', [23889569, 'wool', 'wool']),
#              ('23889569_3', [23889569, 'handmade', 'handmade']),
#              ('23889569_4', [23889569, 'handsewn', 'handsewn']),
#              ('23923053_1', [23923053, 'felt', 'felt']),
#              ('23923053_2', [23923053, 'beads', 'beads']),
#              ('23923053_3', [23923053, 'wool', 'wool']),
#              ('23972595_1', [23972595, 'paper', 'paper']),
#              ('23972595_2', [23972595, 'ink', 'ink']),
#              ('24290707_1', [24290707, 'cotton_fabric', 'cotton fabric']),
#              ('24290707_2',
#               [24290707, 'paint_textil_decoart', 'paint textil decoart']),
#              ('24485745_1',
#               [24485745, 'zinc_etching_plate', 'zinc etching plate']),
#              ('24485745_2',
#               [24485745, 'aquatint_with_rosin', 'aquatint with rosin']),
#              ('24485745_3',
#               [24485745, 'nitric_acid_bath', 'nitric acid bath']),
#              ('24485745_4',
#               [24485745,
#                'colors_used_include_turquoise_lake',
#                'colors used include turquoise lake']),
#              ('24485745_5', [24485745, 'mid_green', 'mid green']),
#              ('24485745_6', [24485745, 'lemon_yellow', 'lemon yellow']),
#              ('24485745_7',
#               [24485745,
#                'warm_yellow_and_vermilion_red',
#                'warm yellow and vermilion red']),
#              ('24684492_1', [24684492, 'paper', 'paper']),
#              ('24684492_2', [24684492, 'ink', 'ink']),
#              ('24686678_1', [24686678, 'cotton', 'cotton']),
#              ('24686678_2', [24686678, 'polyester', 'polyester']),
#              ('24686678_3', [24686678, 'metal', 'metal']),
#              ('24825046_1', [24825046, 'wood', 'wood']),
#              ('24825046_2', [24825046, 'bone', 'bone']),
#              ('25602994_1', [25602994, 'wood', 'wood']),
#              ('25602994_2', [25602994, 'paint', 'paint']),
#              ('25602994_3', [25602994, 'dutch_gold_leaf', 'dutch gold leaf']),
#              ('25602994_4', [25602994, 'paper', 'paper']),
#              ('25602994_5', [25602994, 'card', 'card']),
#              ('25602994_6', [25602994, 'glass', 'glass']),
#              ('25603201_1', [25603201, 'wood', 'wood']),
#              ('25603201_2', [25603201, 'dutch_gold_leaf', 'dutch gold leaf']),
#              ('25603201_3', [25603201, 'paint', 'paint']),
#              ('25603201_4', [25603201, 'paper', 'paper']),
#              ('25603201_5', [25603201, 'card', 'card']),
#              ('25603201_6', [25603201, 'glass', 'glass']),
#              ('25603415_1', [25603415, 'wood', 'wood']),
#              ('25603415_2', [25603415, 'dutch_gold_leaf', 'dutch gold leaf']),
#              ('25603415_3', [25603415, 'paint', 'paint']),
#              ('25603415_4', [25603415, 'paper', 'paper']),
#              ('25603415_5', [25603415, 'card', 'card']),
#              ('25603415_6', [25603415, 'glass', 'glass']),
#              ('25603678_1', [25603678, 'wood', 'wood']),
#              ('25603678_2', [25603678, 'paint', 'paint']),
#              ('25603678_3', [25603678, 'wax_polish', 'wax polish']),
#              ('25603678_4', [25603678, 'paper', 'paper']),
#              ('25603678_5', [25603678, 'glass', 'glass']),
#              ('25608097_1', [25608097, 'wood', 'wood']),
#              ('25608097_2', [25608097, 'paint', 'paint']),
#              ('25608097_3', [25608097, 'wax_polish', 'wax polish']),
#              ('25608097_4', [25608097, 'paper', 'paper']),
#              ('25608097_5', [25608097, 'glass', 'glass']),
#              ('25609814_1', [25609814, 'wood', 'wood']),
#              ('25609814_2', [25609814, 'paint', 'paint']),
#              ('25609814_3', [25609814, 'paper', 'paper']),
#              ('25609814_4', [25609814, 'glass', 'glass']),
#              ('25610768_1', [25610768, 'wood', 'wood']),
#              ('25610768_2', [25610768, 'paint', 'paint']),
#              ('25610768_3', [25610768, 'paper', 'paper']),
#              ('25610768_4', [25610768, 'card', 'card']),
#              ('25610768_5', [25610768, 'glass', 'glass']),
#              ('25653022_1', [25653022, 'acrylic_paint', 'acrylic paint']),
#              ('25653022_2', [25653022, 'canvas', 'canvas']),
#              ('25653022_3', [25653022, 'cotton_fabric', 'cotton fabric']),
#              ('25653022_4', [25653022, 'string', 'string']),
#              ('25658088_1', [25658088, 'wood', 'wood']),
#              ('25658088_2', [25658088, 'paint', 'paint']),
#              ('25658088_3', [25658088, 'wax_polish', 'wax polish']),
#              ('25658088_4', [25658088, 'paper', 'paper']),
#              ('25658088_5', [25658088, 'glass', 'glass']),
#              ('25705340_1', [25705340, 'wood', 'wood']),
#              ('25705340_2', [25705340, 'paint', 'paint']),
#              ('25705340_3', [25705340, 'wax_polish', 'wax polish']),
#              ('25705340_4', [25705340, 'paper', 'paper']),
#              ('25705340_5', [25705340, 'glass', 'glass']),
#              ('25979359_1', [25979359, 'fabric', 'fabric']),
#              ('25979359_2', [25979359, 'acrylic', 'acrylic']),
#              ('25979359_3', [25979359, 'canvas', 'canvas']),
#              ('25979359_4', [25979359, 'tactile', 'tactile']),
#              ('25979359_5', [25979359, 'texture', 'texture']),
#              ('25979359_6', [25979359, 'knots_of_fabric', 'knots of fabric']),
#              ('25979359_7', [25979359, 'paint', 'paint']),
#              ('25979359_8',
#               [25979359,
#                'inspiration_from_nature',
#                'inspiration from nature']),
#              ('25979359_9',
#               [25979359, 'daisy_flower_weed', 'daisy flower weed']),
#              ('25979359_10',
#               [25979359,
#                'flower_from_french_garden',
#                'flower from french garden']),
#              ('26029223_1', [26029223, 'wood', 'wood']),
#              ('26029223_2', [26029223, 'dutch_gold_leaf', 'dutch gold leaf']),
#              ('26029223_3', [26029223, 'paint', 'paint']),
#              ('26029223_4', [26029223, 'paper', 'paper']),
#              ('26029223_5', [26029223, 'card', 'card']),
#              ('26029223_6', [26029223, 'glass', 'glass']),
#              ('26029452_1', [26029452, 'wood', 'wood']),
#              ('26029452_2', [26029452, 'paint', 'paint']),
#              ('26029452_3', [26029452, 'wax_polish', 'wax polish']),
#              ('26029452_4', [26029452, 'paper', 'paper']),
#              ('26029452_5', [26029452, 'glass', 'glass']),
#              ('26077698_1', [26077698, 'wood', 'wood']),
#              ('26077698_2', [26077698, 'paint', 'paint']),
#              ('26077698_3', [26077698, 'paper', 'paper']),
#              ('26077698_4', [26077698, 'card', 'card']),
#              ('26077698_5', [26077698, 'glass', 'glass']),
#              ('26176683_1', [26176683, 'pvc', 'pvc']),
#              ('26176683_2', [26176683, 'paper', 'paper']),
#              ('26176683_3', [26176683, 'ribbon', 'ribbon']),
#              ('26180670_1', [26180670, 'pvc', 'pvc']),
#              ('26180670_2', [26180670, 'paper', 'paper']),
#              ('26180670_3', [26180670, 'ribbon', 'ribbon']),
#              ('26276151_1', [26276151, 'glass', 'glass']),
#              ('26276151_2', [26276151, 'sterling_silver', 'sterling silver']),
#              ('26276151_3', [26276151, 'stone', 'stone']),
#              ('26276151_4', [26276151, 'metal', 'metal']),
#              ('26440960_1', [26440960, 'aquamarine', 'aquamarine']),
#              ('26543154_1', [26543154, 'paper', 'paper']),
#              ('26543154_2', [26543154, 'traditional_ink', 'traditional ink']),
#              ('26775569_1', [26775569, 'metal', 'metal']),
#              ('26775569_2', [26775569, 'cotton_lace', 'cotton lace']),
#              ('26780412_1', [26780412, 'mother_of_pearl', 'mother of pearl']),
#              ('26780412_2', [26780412, 'wings', 'wings']),
#              ('26781915_1', [26781915, 'string', 'string']),
#              ('26781915_2', [26781915, 'acrylic', 'acrylic']),
#              ('26781915_3',
#               [26781915, 'iridescent_medium', 'iridescent medium']),
#              ('26781915_4', [26781915, 'wood', 'wood']),
#              ('26781915_5', [26781915, 'varnish', 'varnish']),
#              ('26781915_6', [26781915, 'from_france', 'from france']),
#              ('26781915_7', [26781915, 'frame', 'frame']),
#              ('26781915_8',
#               [26781915, 'macro_photography', 'macro photography']),
#              ('26781915_9', [26781915, 'peacock_feather', 'peacock feather']),
#              ('26781915_10',
#               [26781915, 'botanical_inspiration', 'botanical inspiration']),
#              ('26781915_11', [26781915, 'nature_inspired', 'nature inspired']),
#              ('26784083_1', [26784083, 'string', 'string']),
#              ('26784083_2', [26784083, 'clay', 'clay']),
#              ('26784083_3', [26784083, 'wood', 'wood']),
#              ('26784083_4', [26784083, 'paint', 'paint']),
#              ('26784083_5',
# ...
#              ('31733771_9',
#               [31733771,
#                'victorian_collector_piece',
#                'victorian collector piece']),
#              ('31733771_10', [31733771, 'quick_delivery', 'quick delivery']),
#              ('31733771_11',
#               [31733771, 'safe_protected_package', 'safe protected package']),
#              ('31733771_12',
#               [31733771,
#                'track_insurance_included',
#                'track insurance included']),
#              ('31733771_13',
#               [31733771,
#                'free_worldwide_shipping',
#                'free worldwide shipping']),
#              ('31791185_1', [31791185, 'wood', 'wood']),
#              ('31791185_2', [31791185, 'paint', 'paint']),
#              ('31791185_3', [31791185, 'wax', 'wax']),
#              ('31791185_4', [31791185, 'paper', 'paper']),
#              ('31791185_5', [31791185, 'glass', 'glass']),
#              ('31791883_1', [31791883, 'wood', 'wood']),
#              ('31791883_2', [31791883, 'paint', 'paint']),
#              ('31791883_3', [31791883, 'wax', 'wax']),
#              ('31791883_4', [31791883, 'paper', 'paper']),
#              ('31791883_5', [31791883, 'glass', 'glass']),
#              ('31863315_1', [31863315, 'paper', 'paper']),
#              ('31863315_2', [31863315, 'traditional_ink', 'traditional ink']),
#              ('31872297_1', [31872297, 'cotton', 'cotton']),
#              ('31872297_2', [31872297, 'polyester', 'polyester']),
#              ('31872297_3', [31872297, 'lace', 'lace']),
#              ('31872297_4', [31872297, 'mesh', 'mesh']),
#              ('32065650_1',
#               [32065650, 'rare_collector_piece', 'rare collector piece']),
#              ('32065650_2',
#               [32065650, 'vintage_wood_com_brush', 'vintage wood com brush']),
#              ('32065650_3',
#               [32065650,
#                'metal_com_horsehair_brush',
#                'metal com horsehair brush']),
#              ('32065650_4',
#               [32065650, 'sophistcated_man_gift', 'sophistcated man gift']),
#              ('32065650_5',
#               [32065650, 'button_for_wood_body', 'button for wood body']),
#              ('32065650_6',
#               [32065650,
#                'brown_wood_white_horsehair',
#                'brown wood white horsehair']),
#              ('32065650_7', [32065650, 'quick_delivery', 'quick delivery']),
#              ('32065650_8',
#               [32065650, 'safe_protected_package', 'safe protected package']),
#              ('32065650_9',
#               [32065650,
#                'free_worldwide_shipping',
#                'free worldwide shipping']),
#              ('32065650_10',
#               [32065650,
#                'track_insurance_inscluded',
#                'track insurance inscluded']),
#              ('32065650_11',
#               [32065650,
#                'very_good_condition_both_sides',
#                'very good condition both sides']),
#              ('32065650_12',
#               [32065650,
#                'art_nouveau_collectors_item',
#                'art nouveau collectors item']),
#              ('32065650_13',
#               [32065650,
#                'unusual_nice_vintage_gift',
#                'unusual nice vintage gift']),
#              ('32125774_1', [32125774, 'paper', 'paper']),
#              ('32125774_2', [32125774, 'ink', 'ink']),
#              ('32258179_1', [32258179, 'camera', 'camera']),
#              ('32258179_2', [32258179, 'fine_art_paper', 'fine art paper']),
#              ('32258179_3', [32258179, 'photography', 'photography']),
#              ('32258179_4', [32258179, 'photograph', 'photograph']),
#              ('32258179_5', [32258179, 'photo', 'photo']),
#              ('32258179_6', [32258179, 'archival_inks', 'archival inks']),
#              ('32258179_7', [32258179, 'matte_paper', 'matte paper']),
#              ('32269874_1', [32269874, 'stone', 'stone']),
#              ('32280013_1', [32280013, 'quartz', 'quartz']),
#              ('32281226_1', [32281226, 'amethyst', 'amethyst']),
#              ('32281226_2', [32281226, 'gemstone', 'gemstone']),
#              ('32281226_3', [32281226, 'pearl__shell', 'pearl  shell']),
#              ('32282974_1', [32282974, 'quartz', 'quartz']),
#              ('32368350_1', [32368350, 'zinc_plates', 'zinc plates']),
#              ('32368350_2', [32368350, 'aquatint', 'aquatint']),
#              ('32368350_3', [32368350, '3_mixed_colors', '3 mixed colors']),
#              ('32368350_4',
#               [32368350, 'handmade_italian_paper', 'handmade italian paper']),
#              ('32368720_1', [32368720, 'zinc_plates', 'zinc plates']),
#              ('32368720_2', [32368720, 'aquatint', 'aquatint']),
#              ('32368720_3', [32368720, 'etching_ink', 'etching ink']),
#              ('32368720_4',
#               [32368720, 'italian_handmade_paper', 'italian handmade paper']),
#              ('32400730_1', [32400730, 'satin_ribbon', 'satin ribbon']),
#              ('32400730_2',
#               [32400730, 'string_of_pearls', 'string of pearls']),
#              ('32400730_3', [32400730, 'lace_ribbon', 'lace ribbon']),
#              ('32400730_4', [32400730, 'silk_dogwood', 'silk dogwood']),
#              ('32400730_5', [32400730, 'thread', 'thread']),
#              ('32424070_1', [32424070, 'pdf_download', 'pdf download']),
#              ('32424070_2', [32424070, 'leather', 'leather']),
#              ('32424070_3', [32424070, 'paper', 'paper']),
#              ('32424070_4', [32424070, 'waxed_cotton', 'waxed cotton']),
#              ('32586339_1', [32586339, 'art', 'art']),
#              ('32586339_2', [32586339, 'paper', 'paper']),
#              ('32863738_1', [32863738, 'paper', 'paper']),
#              ('32863738_2', [32863738, 'ink', 'ink']),
#              ('32864665_1', [32864665, 'paper', 'paper']),
#              ('32864665_2', [32864665, 'ink', 'ink']),
#              ('32880537_1', [32880537, 'card', 'card']),
#              ('32880537_2', [32880537, 'glue', 'glue']),
#              ('32880537_3', [32880537, 'cord', 'cord']),
#              ('32880537_4', [32880537, 'ribbon', 'ribbon']),
#              ('32880537_5', [32880537, 'paper', 'paper']),
#              ('32880537_6', [32880537, 'momigami', 'momigami']),
#              ('32998797_1', [32998797, 'paper', 'paper']),
#              ('32998797_2', [32998797, 'print_artwork', 'print artwork']),
#              ('32998797_3', [32998797, 'ink', 'ink']),
#              ('32998797_4', [32998797, 'papier', 'papier']),
#              ('33118411_1', [33118411, 'wood', 'wood']),
#              ('33118411_2', [33118411, 'paint', 'paint']),
#              ('33118411_3', [33118411, 'dutch_gold_leaf', 'dutch gold leaf']),
#              ('33118411_4', [33118411, 'paper', 'paper']),
#              ('33410069_1', [33410069, 'paper', 'paper']),
#              ('33410069_2', [33410069, 'ink', 'ink']),
#              ('33467133_1', [33467133, 'wood', 'wood']),
#              ('33467133_2', [33467133, 'paint', 'paint']),
#              ('33467133_3', [33467133, 'dutch_gold_leaf', 'dutch gold leaf']),
#              ('33467133_4', [33467133, 'paper', 'paper']),
#              ('33815587_1', [33815587, 'photography', 'photography']),
#              ('33815587_2', [33815587, 'camera', 'camera']),
#              ('33815587_3', [33815587, 'photograph', 'photograph']),
#              ('33815587_4', [33815587, 'print', 'print']),
#              ('33815587_5', [33815587, 'fine_art_paper', 'fine art paper']),
#              ('33815587_6', [33815587, 'photo', 'photo']),
#              ('33815587_7', [33815587, 'archival_inks', 'archival inks']),
#              ('33815587_8', [33815587, 'matte_paper', 'matte paper']),
#              ('33818776_1', [33818776, 'paper', 'paper']),
#              ('33818776_2', [33818776, 'ink', 'ink']),
#              ('33818955_1', [33818955, 'paper', 'paper']),
#              ('33818955_2', [33818955, 'ink', 'ink']),
#              ('33819103_1', [33819103, 'paper', 'paper']),
#              ('33819103_2', [33819103, 'ink', 'ink']),
#              ('33819668_1', [33819668, 'paper', 'paper']),
#              ('33819668_2', [33819668, 'ink', 'ink']),
#              ('33819874_1', [33819874, 'paper', 'paper']),
#              ('33819874_2', [33819874, 'ink', 'ink']),
#              ('33820436_1', [33820436, 'paper', 'paper']),
#              ('33820436_2', [33820436, 'ink', 'ink']),
#              ('33820572_1', [33820572, 'paper', 'paper']),
#              ('33820572_2', [33820572, 'ink', 'ink']),
#              ('33820736_1', [33820736, 'paper', 'paper']),
#              ('33820736_2', [33820736, 'ink', 'ink']),
#              ('33891351_1', [33891351, 'paper', 'paper']),
#              ('33891351_2', [33891351, 'ink', 'ink']),
#              ('33956116_1', [33956116, 'paper', 'paper']),
#              ('33956116_2', [33956116, 'ink', 'ink']),
#              ('34115181_1', [34115181, 'paper', 'paper']),
#              ('34115181_2', [34115181, 'ink', 'ink']),
#              ('34172459_1', [34172459, 'sterling_silver', 'sterling silver']),
#              ('34172459_2', [34172459, 'polymer_clay', 'polymer clay']),
#              ('34172459_3', [34172459, 'silver_wire', 'silver wire']),
#              ('34172459_4', [34172459, 'silver', 'silver']),
#              ('34187852_1', [34187852, 'paper', 'paper']),
#              ('34187852_2', [34187852, 'ink', 'ink']),
#              ('34196457_1', [34196457, 'fine_art_paper', 'fine art paper']),
#              ('34196457_2', [34196457, 'camera', 'camera']),
#              ('34196457_3', [34196457, 'photography', 'photography']),
#              ('34196457_4', [34196457, 'photograph', 'photograph']),
#              ('34196457_5', [34196457, 'photo', 'photo']),
#              ('34196457_6', [34196457, 'archival_inks', 'archival inks']),
#              ('34196457_7', [34196457, 'matte_paper', 'matte paper']),
#              ('34279960_1', [34279960, 'paper', 'paper']),
#              ('34279960_2', [34279960, 'ink', 'ink']),
#              ('34674178_1', [34674178, 'wood', 'wood']),
#              ('34674178_2', [34674178, 'paint', 'paint']),
#              ('34674178_3',
#               [34674178, 'dutch_silver_leaf', 'dutch silver leaf']),
#              ('34674178_4', [34674178, 'paper', 'paper']),
#              ('34674178_5', [34674178, 'card', 'card']),
#              ('34674178_6', [34674178, 'glass', 'glass']),
#              ('34936701_1', [34936701, 'wood', 'wood']),
#              ('34936701_2', [34936701, 'paint', 'paint']),
#              ('34936701_3', [34936701, 'wax', 'wax']),
#              ('34936701_4', [34936701, 'paper', 'paper']),
#              ('34936701_5', [34936701, 'glass', 'glass']),
#              ('35194259_1', [35194259, 'autumn', 'autumn']),
#              ('35194259_2', [35194259, 'house', 'house']),
#              ('35194259_3', [35194259, 'photography', 'photography']),
#              ('35194259_4', [35194259, 'camera', 'camera']),
#              ('35194259_5', [35194259, 'photo', 'photo']),
#              ('35194259_6', [35194259, 'fine_art_paper', 'fine art paper']),
#              ('35194259_7', [35194259, 'matte_paper', 'matte paper']),
#              ('35324159_1', [35324159, 'paper', 'paper']),
#              ('35324159_2', [35324159, 'ink', 'ink']),
#              ('35329546_1', [35329546, 'art', 'art']),
#              ('35329546_2', [35329546, 'paper', 'paper']),
#              ('35377039_1', [35377039, 'organic_cotton', 'organic cotton']),
#              ('35377039_2', [35377039, 'gots_certified', 'gots certified']),
#              ('35377039_3', [35377039, 'cotton_thread', 'cotton thread']),
#              ('35403702_1', [35403702, 'art', 'art']),
#              ('35403702_2', [35403702, 'paper', 'paper']),
#              ('35459873_1', [35459873, 'fine_art', 'fine art']),
#              ('35459873_2', [35459873, 'paper', 'paper']),
#              ('35459873_3', [35459873, 'camera', 'camera']),
#              ('35459873_4', [35459873, 'photography', 'photography']),
#              ('35459873_5', [35459873, 'photograph', 'photograph']),
#              ('35459873_6', [35459873, 'photo', 'photo']),
#              ('35459873_7', [35459873, 'fine_art_paper', 'fine art paper']),
#              ('35459873_8', [35459873, 'archival_inks', 'archival inks']),
#              ('35459873_9', [35459873, 'matte_paper', 'matte paper']),
#              ('35614899_1', [35614899, 'paper', 'paper']),
#              ('35614899_2', [35614899, 'ink', 'ink']),
#              ('35801294_1', [35801294, 'art', 'art']),
#              ('35801294_2', [35801294, 'paper', 'paper']),
#              ('35802771_1', [35802771, 'paper', 'paper']),
#              ('35802771_2', [35802771, 'ink', 'ink']),
#              ('35949996_1', [35949996, 'sterling_silver', 'sterling silver']),
#              ('35951050_1', [35951050, 'sterling_silver', 'sterling silver']),
#              ('35951050_2',
#               [35951050,
#                'cultured_japanese_pearl',
#                'cultured japanese pearl']),
#              ('35951050_3', [35951050, 'argentium', 'argentium']),
#              ('35952223_1', [35952223, 'sterling_silver', 'sterling silver']),
#              ('35952223_2', [35952223, 'polymer_clay', 'polymer clay']),
#              ('36042166_1', [36042166, 'paper', 'paper']),
#              ('36042166_2', [36042166, 'ink', 'ink']),
#              ('36079417_1', [36079417, 'sterling_silver', 'sterling silver']),
#              ('36079417_2', [36079417, 'polymer_clay', 'polymer clay']),
#              ('36079417_3', [36079417, 'silver', 'silver']),
#              ('36079705_1', [36079705, 'sterling_silver', 'sterling silver']),
#              ('36079705_2', [36079705, 'polymer_clay', 'polymer clay']),
#              ('36080161_1', [36080161, 'sterling_silver', 'sterling silver']),
#              ('36080461_1', [36080461, 'sterling_silver', 'sterling silver']),
#              ('36082124_1', [36082124, 'sterling_silver', 'sterling silver']),
#              ('36082124_2', [36082124, 'polymer_clay', 'polymer clay']),
#              ('36134023_1', [36134023, 'art', 'art']),
#              ('36134023_2', [36134023, 'paper', 'paper']),
#              ('36502025_1', [36502025, 'wood', 'wood']),
#              ('36502025_2', [36502025, 'paint', 'paint']),
#              ('36502025_3', [36502025, 'paper', 'paper']),
#              ('36502025_4', [36502025, 'glass', 'glass']),
#              ('36502170_1', [36502170, 'wood', 'wood']),
#              ('36502170_2', [36502170, 'paint', 'paint']),
#              ('36502170_3', [36502170, 'glass', 'glass']),
#              ('36502170_4', [36502170, 'paper', 'paper']),
#              ('36502170_5', [36502170, 'wax_polish', 'wax polish']),
#              ('36513833_1', [36513833, 'silk_flower', 'silk flower']),
#              ('36513833_2', [36513833, 'bobby_pin', 'bobby pin']),
#              ('36513833_3', [36513833, 'hot_glue', 'hot glue']),
#              ('36513833_4', [36513833, 'thread', 'thread']),
#              ('36552435_1', [36552435, 'art', 'art']),
#              ('36552435_2', [36552435, 'paper', 'paper']),
#              ('36552435_3', [36552435, 'ink', 'ink']),
#              ('36702345_1', [36702345, 'ebook', 'ebook']),
#              ('36702345_2', [36702345, 'digital', 'digital']),
#              ('36702345_3', [36702345, 'download', 'download']),
#              ('36702345_4', [36702345, 'pdf', 'pdf']),
#              ('36775421_1', [36775421, 'art', 'art']),
#              ('36775421_2', [36775421, 'paper', 'paper']),
#              ('37235115_1', [37235115, 'paper', 'paper']),
#              ('37235115_2', [37235115, 'ink', 'ink']),
#              ('37235417_1', [37235417, 'organic_cotton', 'organic cotton']),
#              ('37235417_2',
#               [37235417, 'organic_cotton_sateen', 'organic cotton sateen']),
#              ('37235417_3', [37235417, 'gots_certified', 'gots certified']),
#              ('37235417_4', [37235417, 'oekotex100', 'oekotex100']),
#              ('37235417_5', [37235417, 'bamboo', 'bamboo']),
#              ('37235417_6', [37235417, 'organic_velour', 'organic velour']),
#              ('37237264_1', [37237264, 'paper', 'paper']),
#              ('37237264_2', [37237264, 'ink', 'ink']),
#              ('37458661_1', [37458661, 'fine_art', 'fine art']),
#              ...])

# %%
dict_final = OrderedDict()

# %%
for (key, row) in data_dict.items() :
    id_listing = row[0]
    key_texte = row[1]
    translated_texte = dic_uniques_lem[key_texte][0]
    lemmanized_texte = dic_uniques_lem[key_texte][1]
    dict_final[key] = [id_listing, key_texte, translated_texte, lemmanized_texte]

# %%
data_final = []

# %%
idx = 0
for (key, row) in dict_final.items():
    data_final.append(row)
    idx = idx + 1

# %%
df = pd.DataFrame(data_final, columns=['id_listing', 'key_texte', 'translated_texte', 'lemmanized_texte'])

# %%
df.head()
# Out:
#    id_listing   key_texte translated_texte lemmanized_texte
# 0      444500       clasp            clasp
# 1      444500  turpentine       turpentine
# 2      444500      toggle           toggle           toggle
# 3      444500    sterling         sterling         sterling
# 4      444500      silver           silver           silver

# %%
df.to_csv('_data/df_final.csv')

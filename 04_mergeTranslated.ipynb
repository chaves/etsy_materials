# %%
import pickle

# %%
translated_0_50 = pickle.load( open( "_data/translated_texts_0_50.pickle", "rb" ) )
translated_50_100 = pickle.load( open( "_data/translated_texts_50_100.pickle", "rb" ) )
translated_100_150 = pickle.load( open( "_data/translated_texts_100_150.pickle", "rb" ) )
translated_150_200 = pickle.load( open( "_data/translated_texts_150_200.pickle", "rb" ) )
translated_200_250 = pickle.load( open( "_data/translated_texts_200_250.pickle", "rb" ) )
translated_250_323 = pickle.load( open( "_data/translated_texts_250_323.pickle", "rb" ) )

# %%
translated_list = [*translated_0_50, *translated_50_100, *translated_100_150, *translated_150_200, *translated_200_250, *translated_250_323]

# %%
len(translated_list)
# Out:
# 323

# %%
translated_list_text = [t.text for t in translated_list]

# %%
translated_list_text[:50]
# Out:
# ['leatherette\npolar\nlinen\ncoated linen\ncoated cotton\nsuede\nlapis lazuli\nthimbles\nbuckwheat\nflakes of polyester fibers\npadding of polyester fiber flakes\npolyester fiber flakes\ngiclée print\nheavy cotton moulin du roy paper\nroy heavy cotton paper mill\nheavy cotton roy paper mill\nmill of roy cotton paper\nmoulin du roy paper\nspun glass\nMurano glass\nglass\ncopper\nPierre\nfine stone\ngem\ngemstone\nturquoise bead\nbutton\ntorch-blown glass\npendant\nVenetian pearls\nrockery\nrubber\nmetal\npaper\norganic cotton\nleather\nbrass\ngolden brass\nswarovski crystal\npolymer clay\nmetal powder\naluminum wire\nbeads\ncoated fabric\ncotton fabric\ncoating\nzipper\nfabric\nbamboo\nnatural maple\nmaple\nwood\ncotton fabric oeko tex\nuntreated\noeko tex fabric\nnatural wood\nangle\nelastic\nbamboo sponge\nbamboo sponges\nLiberty cotton\nkam snap button\nsponge\nchain\npearl\nstainless\nstainless chain\nstainless steel\nresin\nhemp twine\nglassine paper\nrice paper\nwashi paper\nstr
# ...

# %%
pickle.dump( translated_list_text, open( "_data/translated_list.pickle", "wb" ) )

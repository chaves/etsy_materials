# %%
import pickle

# %%
ETSY_ROUND = '_2019'
OUTPUT_FOLDER = ETSY_ROUND + '/output/'

# %%
translated_0_50 = pickle.load( open( OUTPUT_FOLDER + "translated_texts_0_50.pickle", "rb" ) )
translated_50_100 = pickle.load( open( OUTPUT_FOLDER + "translated_texts_50_100.pickle", "rb" ) )
translated_100_150 = pickle.load( open( OUTPUT_FOLDER + "translated_texts_100_150.pickle", "rb" ) )
translated_150_207 = pickle.load( open( OUTPUT_FOLDER + "translated_texts_150_207.pickle", "rb" ) )

# %%
translated_list = [*translated_0_50, *translated_50_100, *translated_100_150, *translated_150_207]

# %%
len(translated_list)
# Out:
# 207

# %%
translated_list_text = [t.text for t in translated_list]

# %%
translated_list_text[:50]
# Out:
# ['wool\nsilk\npure wool\nalpaca\nknitting\nhandmade\nmerino\nbeads\nwhite agate\nmarbled agate\nblack wooden bead\nsilver plated\nglass cracked\nwhite glass\ncrystal\nblack crystal\nMurano black oval\nMurano round white\ncubes of black glass\nbutterfly black crystal\nwooden beads\nmetallic pearl\nstrass\ngemstone\nblack and white fine stone\nstriped black agate\nnatural stone\nhook or clip\nquartz watermelon\nprecious stones\nMurano glass\nstrass crystal\nblack Murano\noval Murano\nMurano bead\nMurano glass black\ngreen fluorite\nFluorite rainbow\ncubic fluorite\nalabaster\nhematite\nMurano flower\nrhinestone bead\ngemstone\nred stone\nred crystal\ncrystal metallic\ncrystal red and gold\nagate frosted\nnail\ngold nail\njade green\njade Dark green\nfrosted jade\nrockery\nseed beads\ndark gold beads\ngold clasp\nClasp musical note\njade partially polished\ngreen Murano\nMurano with roses\nnail pink pattern\nRouter crystal\ncrystal copper\ncut glass\nRhinestone Rondelle\nGlass made hand
# ...

# %%
pickle.dump( translated_list_text, open( OUTPUT_FOLDER + "translated_list.pickle", "wb" ) )
